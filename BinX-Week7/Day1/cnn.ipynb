# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:48px 52px;
#     border-radius:28px;
#     background:linear-gradient(135deg,#F7F1E6 0%,#FFFDF8 48%,#EEF3EA 100%);
#     border:1px solid #C9BFAE;
#     box-shadow:0 12px 32px rgba(35,61,42,0.14);
#     font-family:'Segoe UI',Arial,sans-serif;
#     overflow:hidden;
# ">
#     <div style="
#         display:flex;
#         justify-content:space-between;
#         align-items:center;
#         margin-bottom:30px;
#     ">
#         <div style="
#             color:#183D2B;
#             font-size:15px;
#             font-weight:800;
#             letter-spacing:2.4px;
#         ">
#             BINX TECH • AI & MACHINE LEARNING
#         </div>
#         <div style="
#             background:#E8EDE5;
#             color:#183D2B;
#             border:1px solid #AEBEAA;
#             padding:10px 18px;
#             border-radius:22px;
#             font-size:12px;
#             font-weight:800;
#             letter-spacing:1.2px;
#         ">
#             ● WEEK 7 · DAY 1
#         </div>
#     </div>
#     <div style="
#         background:#FFFDF9;
#         border:1px solid #D8CFC0;
#         border-radius:23px;
#         padding:38px 40px;
#         box-sizing:border-box;
#         box-shadow:0 7px 22px rgba(48,63,46,0.08);
#     ">
#         <div style="
#             color:#66765A;
#             font-size:13px;
#             font-weight:800;
#             letter-spacing:2.2px;
#             margin-bottom:12px;
#         ">
#             PHASE 3 • SPRINT 2 • DEEP LEARNING
#         </div>
#         <h1 style="
#             color:#163C29;
#             font-size:46px;
#             line-height:1.15;
#             margin:0;
#             font-weight:850;
#             letter-spacing:-0.7px;
#         ">
#             Convolutional Neural Networks
#         </h1>
#         <div style="
#             color:#9F2638;
#             font-size:23px;
#             line-height:1.35;
#             font-weight:800;
#             margin-top:9px;
#         ">
#             CNNs • Filters • Feature Maps
#         </div>
#         <p style="
#             color:#4D594E;
#             font-size:17px;
#             line-height:1.8;
#             font-weight:600;
#             margin:19px 0 0 0;
#         ">
#             Understanding how convolutional architectures process visual data,
#             detect meaningful patterns, and learn hierarchical representations
#             from simple edges to complex features.
#         </p>
#         <div style="
#             margin-top:30px;
#             padding-top:22px;
#             border-top:2px solid #E4DED3;
#         ">
#             <div style="
#                 color:#183D2B;
#                 font-size:12px;
#                 font-weight:900;
#                 letter-spacing:1.8px;
#                 margin-bottom:11px;
#             ">
#                 CORE CONCEPTS
#             </div>
#             <div style="
#                 color:#4A554B;
#                 font-size:15px;
#                 font-weight:700;
#                 line-height:1.8;
#             ">
#                 Convolution
#                 <span style="color:#B4AA9A;"> • </span>
#                 Kernels
#                 <span style="color:#B4AA9A;"> • </span>
#                 Feature Maps
#                 <span style="color:#B4AA9A;"> • </span>
#                 Stride
#                 <span style="color:#B4AA9A;"> • </span>
#                 Padding
#             </div>
#         </div>
#     </div>
#     <div style="
#         margin-top:28px;
#         background:#F1F4EC;
#         border:1px solid #CBD5C4;
#         border-radius:21px;
#         padding:28px;
#         box-sizing:border-box;
#     ">
#         <div style="
#             color:#183D2B;
#             font-size:14px;
#             font-weight:900;
#             letter-spacing:2px;
#             margin-bottom:20px;
#         ">
#             TODAY'S LEARNING PATH
#         </div>
#         <table style="
#             width:100%;
#             border-collapse:separate;
#             border-spacing:10px 0;
#             table-layout:fixed;
#         ">
#             <tr>
#                 <td style="
#                     background:#FFFDF9;
#                     border:1px solid #D9CCBA;
#                     border-radius:15px;
#                     padding:20px;
#                     vertical-align:top;
#                 ">
#                     <div style="
#                         color:#9F2638;
#                         font-size:27px;
#                         font-weight:900;
#                     ">01</div>
#                     <div style="
#                         color:#183D2B;
#                         font-size:14px;
#                         font-weight:850;
#                         margin-top:8px;
#                     ">
#                         Sprint Planning
#                     </div>
#                     <div style="
#                         color:#596357;
#                         font-size:12px;
#                         font-weight:600;
#                         margin-top:6px;
#                     ">
#                         Goal • Backlog
#                     </div>
#                 </td>
#                 <td style="
#                     background:#FFFDF9;
#                     border:1px solid #D9CCBA;
#                     border-radius:15px;
#                     padding:20px;
#                     vertical-align:top;
#                 ">
#                     <div style="
#                         color:#6B7D58;
#                         font-size:27px;
#                         font-weight:900;
#                     ">02</div>
#                     <div style="
#                         color:#183D2B;
#                         font-size:14px;
#                         font-weight:850;
#                         margin-top:8px;
#                     ">
#                         Dense vs CNN
#                     </div>
#                     <div style="
#                         color:#596357;
#                         font-size:12px;
#                         font-weight:600;
#                         margin-top:6px;
#                     ">
#                         Spatial Structure
#                     </div>
#                 </td>
#                 <td style="
#                     background:#FFFDF9;
#                     border:1px solid #D9CCBA;
#                     border-radius:15px;
#                     padding:20px;
#                     vertical-align:top;
#                 ">
#                     <div style="
#                         color:#9F2638;
#                         font-size:27px;
#                         font-weight:900;
#                     ">03</div>
#                     <div style="
#                         color:#183D2B;
#                         font-size:14px;
#                         font-weight:850;
#                         margin-top:8px;
#                     ">
#                         Convolution
#                     </div>
#                     <div style="
#                         color:#596357;
#                         font-size:12px;
#                         font-weight:600;
#                         margin-top:6px;
#                     ">
#                         Filters • Feature Maps
#                     </div>
#                 </td>
#                 <td style="
#                     background:#FFFDF9;
#                     border:1px solid #D9CCBA;
#                     border-radius:15px;
#                     padding:20px;
#                     vertical-align:top;
#                 ">
#                     <div style="
#                         color:#6B7D58;
#                         font-size:27px;
#                         font-weight:900;
#                     ">04</div>
#                     <div style="
#                         color:#183D2B;
#                         font-size:14px;
#                         font-weight:850;
#                         margin-top:8px;
#                     ">
#                         Why CNNs Win
#                     </div>
#                     <div style="
#                         color:#596357;
#                         font-size:12px;
#                         font-weight:600;
#                         margin-top:6px;
#                     ">
#                         Sharing • Invariance
#                     </div>
#                 </td>
#             </tr>
#         </table>
#     </div>
#     <div style="
#         display:flex;
#         gap:14px;
#         margin-top:22px;
#     ">
#         <div style="
#             flex:1;
#             background:#F7EDE8;
#             border:1px solid #E3C8BE;
#             border-radius:15px;
#             padding:18px 20px;
#         ">
#             <div style="
#                 color:#9F2638;
#                 font-size:11px;
#                 font-weight:900;
#                 letter-spacing:1.7px;
#             ">
#                 FOCUS
#             </div>
#             <div style="
#                 color:#70202D;
#                 font-size:14px;
#                 font-weight:800;
#                 margin-top:7px;
#             ">
#                 Visual Feature Extraction
#             </div>
#         </div>
#         <div style="
#             flex:1;
#             background:#EEF3E9;
#             border:1px solid #C8D5C1;
#             border-radius:15px;
#             padding:18px 20px;
#         ">
#             <div style="
#                 color:#49623D;
#                 font-size:11px;
#                 font-weight:900;
#                 letter-spacing:1.7px;
#             ">
#                 TOOLS
#             </div>
#             <div style="
#                 color:#29452F;
#                 font-size:14px;
#                 font-weight:800;
#                 margin-top:7px;
#             ">
#                 NumPy • Matplotlib • TensorFlow
#             </div>
#         </div>
#         <div style="
#             flex:1;
#             background:#F5F0E7;
#             border:1px solid #DCCFB9;
#             border-radius:15px;
#             padding:18px 20px;
#         ">
#             <div style="
#                 color:#796A4F;
#                 font-size:11px;
#                 font-weight:900;
#                 letter-spacing:1.7px;
#             ">
#                 OUTPUT
#             </div>
#             <div style="
#                 color:#544A39;
#                 font-size:14px;
#                 font-weight:800;
#                 margin-top:7px;
#             ">
#                 Feature Maps • CNN Foundations
#             </div>
#         </div>
#     </div>
#     <div style="
#         margin-top:28px;
#         padding-top:18px;
#         border-top:2px solid #D9D4C9;
#         display:flex;
#         justify-content:space-between;
#         align-items:center;
#     ">
#         <div style="
#             color:#596454;
#             font-size:11px;
#             font-weight:900;
#             letter-spacing:1.6px;
#         ">
#             AI & MACHINE LEARNING INTERNSHIP
#         </div>
#         <div style="
#             color:#9F2638;
#             font-size:11px;
#             font-weight:900;
#             letter-spacing:1.6px;
#         ">
#             CNN.IPYNB
#         </div>
#     </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:34px 40px;
#     margin:28px 0;
#     background:linear-gradient(135deg,#F4EBDD 0%,#FFFDF8 55%,#EEF2E9 100%);
#     border:1px solid #D5C7B5;
#     border-left:8px solid #183D2B;
#     border-radius:24px;
#     box-shadow:0 9px 24px rgba(24,61,43,0.10);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:14px;
#     font-weight:900;
#     letter-spacing:2.5px;
#     margin-bottom:10px;
# ">
# SPRINT 2 • PLANNING
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:34px;
#     line-height:1.2;
#     font-weight:900;
#     margin:0;
# ">
# 1.1 Sprint 2 Planning
# </div>
#
# <div style="
#     color:#596357;
#     font-size:17px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:10px;
# ">
# Defining the Sprint 2 direction, backlog, and core-model development plan.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:34px 40px;
#     margin:22px 0;
#     background:#FFFDF8;
#     border:1px solid #D5C7B5;
#     border-radius:24px;
#     box-shadow:0 8px 22px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:10px;
# ">
# SPRINT 2 GOAL
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:29px;
#     font-weight:900;
#     margin-bottom:16px;
# ">
# Advancing the Core Model
# </div>
#
# <div style="
#     color:#465046;
#     font-size:17px;
#     line-height:1.9;
#     font-weight:600;
# ">
# The main goal of Sprint 2 is to
# <span style="color:#9F2638;font-weight:900;">advance the core model</span>
# by building on the existing baseline, exploring appropriate architectural and
# training choices, and developing a stronger model that can be evaluated against
# the Sprint 1 results.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:34px 40px;
#     margin:22px 0;
#     background:#F0F3EB;
#     border:1px solid #C9D3C1;
#     border-radius:24px;
#     box-shadow:0 8px 22px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:10px;
# ">
# SPRINT 2 BACKLOG
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:29px;
#     font-weight:900;
#     margin-bottom:22px;
# ">
# Core Model Development Tasks
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:18px 22px;
#     margin:0 0 12px 0;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:15px;
# ">
# <div style="color:#9F2638;font-size:12px;font-weight:900;letter-spacing:1.5px;margin-bottom:6px;">
# TASK 01
# </div>
# <div style="color:#354034;font-size:16px;line-height:1.7;font-weight:700;">
# Review the Sprint 1 baseline and identify areas for improvement.
# </div>
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:18px 22px;
#     margin:0 0 12px 0;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:15px;
# ">
# <div style="color:#687A55;font-size:12px;font-weight:900;letter-spacing:1.5px;margin-bottom:6px;">
# TASK 02
# </div>
# <div style="color:#354034;font-size:16px;line-height:1.7;font-weight:700;">
# Experiment with the model architecture and training configuration.
# </div>
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:18px 22px;
#     margin:0 0 12px 0;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:15px;
# ">
# <div style="color:#9F2638;font-size:12px;font-weight:900;letter-spacing:1.5px;margin-bottom:6px;">
# TASK 03
# </div>
# <div style="color:#354034;font-size:16px;line-height:1.7;font-weight:700;">
# Evaluate different modeling choices using consistent validation and test metrics.
# </div>
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:18px 22px;
#     margin:0 0 12px 0;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:15px;
# ">
# <div style="color:#687A55;font-size:12px;font-weight:900;letter-spacing:1.5px;margin-bottom:6px;">
# TASK 04
# </div>
# <div style="color:#354034;font-size:16px;line-height:1.7;font-weight:700;">
# Compare the improved model against the Sprint 1 baseline.
# </div>
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:18px 22px;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:15px;
# ">
# <div style="color:#9F2638;font-size:12px;font-weight:900;letter-spacing:1.5px;margin-bottom:6px;">
# TASK 05
# </div>
# <div style="color:#354034;font-size:16px;line-height:1.7;font-weight:700;">
# Document experiments, results, observations, and final decisions.
# </div>
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:34px 40px;
#     margin:22px 0;
#     background:linear-gradient(135deg,#FBF0EB 0%,#FFF9F5 100%);
#     border:1px solid #E1C8BC;
#     border-radius:24px;
#     box-shadow:0 8px 22px rgba(127,29,29,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:10px;
# ">
# SPRINT 1 RETROSPECTIVE
# </div>
#
# <div style="
#     color:#70202D;
#     font-size:29px;
#     font-weight:900;
#     margin-bottom:16px;
# ">
# Improvement Carried Forward
# </div>
#
# <div style="
#     color:#604A45;
#     font-size:17px;
#     line-height:1.9;
#     font-weight:600;
# ">
# The main improvement carried forward from Sprint 1 is to use a
# <span style="color:#9F2638;font-weight:900;">systematic experimentation approach</span>.
# Instead of changing multiple components at once, each modification will be tested
# and evaluated separately to understand its actual impact on model performance.
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     margin-top:25px;
#     padding:22px 24px;
#     background:#FFFDF9;
#     border:1px solid #E2D1C7;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.7px;
#     margin-bottom:8px;
# ">
# ARCHITECTURE DECISION
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:23px;
#     font-weight:900;
#     margin-bottom:10px;
# ">
# Dense Neural Network
# </div>
#
# <div style="
#     color:#554B47;
#     font-size:16px;
#     line-height:1.8;
#     font-weight:600;
# ">
# The project's data is structured as
# <span style="color:#9F2638;font-weight:800;">tabular data</span>.
# Therefore, a Dense Neural Network is the most appropriate architecture because
# it is designed to learn relationships between structured input features.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:34px 40px;
#     margin:30px 0 25px 0;
#     background:linear-gradient(135deg,#F4EBDD 0%,#FFFDF8 55%,#EEF2E9 100%);
#     border:1px solid #D5C7B5;
#     border-left:8px solid #183D2B;
#     border-radius:24px;
#     box-shadow:0 9px 24px rgba(24,61,43,0.10);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:14px;
#     font-weight:900;
#     letter-spacing:2.5px;
#     margin-bottom:10px;
# ">
# CNN FUNDAMENTALS
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:34px;
#     line-height:1.2;
#     font-weight:900;
# ">
# 1.2 Why Dense Networks Fail on Images
# </div>
#
# <div style="
#     color:#596357;
#     font-size:17px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:10px;
# ">
# Understanding why fully connected networks are inefficient for image data.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:34px 40px;
#     margin:22px 0;
#     background:#FFFDF8;
#     border:1px solid #D5C7B5;
#     border-radius:24px;
#     box-shadow:0 8px 22px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:28px;
#     font-weight:900;
#     margin-bottom:18px;
# ">
# The Problem with Dense Networks
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:17px;
#     line-height:1.9;
#     font-weight:600;
# ">
# A <span style="color:#9F2638;font-weight:900;">200 × 200 RGB image</span>
# contains:
# </div>
#
# <div style="
#     margin:20px 0;
#     padding:22px;
#     box-sizing:border-box;
#     width:100%;
#     background:#F1F4EC;
#     border:1px solid #CBD5C4;
#     border-radius:16px;
#     text-align:center;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:29px;
#     font-weight:900;
# ">
# 200 × 200 × 3 = 120,000
# </div>
#
# <div style="
#     color:#68735F;
#     font-size:14px;
#     font-weight:700;
#     margin-top:7px;
# ">
# input values
# </div>
#
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:17px;
#     line-height:1.9;
#     font-weight:600;
# ">
# If these 120,000 values are connected directly to a dense layer with
# <span style="color:#9F2638;font-weight:900;">128 neurons</span>,
# the first layer alone requires more than
# <span style="color:#183D2B;font-weight:900;">15 million trainable weights</span>.
# </div>
#
# <div style="
#     margin-top:27px;
#     padding-top:24px;
#     border-top:2px solid #E5DED2;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-bottom:16px;
# ">
# TWO KEY PROBLEMS
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#F8EDE8;
#     border:1px solid #E2C8BC;
#     border-radius:16px;
#     padding:21px 24px;
#     margin-bottom:14px;
# ">
#
# <div style="
#     color:#70202D;
#     font-size:19px;
#     font-weight:900;
#     margin-bottom:7px;
# ">
# 01 · Spatial Structure
# </div>
#
# <div style="
#     color:#604A45;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Nearby pixels are related. A pixel's meaning depends partly on the pixels
# around it, but a dense network treats every input connection independently
# and does not explicitly preserve this spatial relationship.
# </div>
#
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#EEF2E9;
#     border:1px solid #CBD5C4;
#     border-radius:16px;
#     padding:21px 24px;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:19px;
#     font-weight:900;
#     margin-bottom:7px;
# ">
# 02 · Translation Invariance
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# The same pattern can appear in different locations of an image. Dense networks
# do not naturally reuse the same learned pattern across different positions.
# CNNs solve this by applying the same filters throughout the image.
# </div>
#
# </div>
#
# </div>
#
# </div>

# %%
from IPython.display import display, HTML

# Image dimensions
image_height = 200
image_width = 200
channels = 3

# Total input values
input_size = image_height * image_width * channels

# Dense layer
dense_neurons = 128
dense_weights = input_size * dense_neurons
dense_biases = dense_neurons
dense_total = dense_weights + dense_biases

# CNN layer
kernel_size = 3
cnn_filters = 32

cnn_weights = kernel_size * kernel_size * channels * cnn_filters
cnn_biases = cnn_filters
cnn_total = cnn_weights + cnn_biases

# Comparison
ratio = dense_total / cnn_total

# Styled output
display(HTML(f"""
<div style="
    width:100%;
    box-sizing:border-box;
    background:linear-gradient(135deg,#F7F1E6 0%,#FFFDF8 55%,#EEF2E9 100%);
    border:1px solid #D5C7B5;
    border-radius:22px;
    padding:30px 34px;
    margin:15px 0;
    font-family:'Segoe UI',Arial,sans-serif;
    box-shadow:0 8px 22px rgba(24,61,43,0.09);
">

<div style="
    color:#183D2B;
    font-size:24px;
    font-weight:900;
    margin-bottom:22px;
">
Dense Layer vs CNN Layer
</div>

<div style="
    display:flex;
    gap:14px;
    width:100%;
    box-sizing:border-box;
">

<div style="
    flex:1;
    box-sizing:border-box;
    background:#FFFDF8;
    border:1px solid #D8CCBC;
    border-radius:16px;
    padding:22px;
">
<div style="
    color:#9F2638;
    font-size:12px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:12px;
">
IMAGE
</div>

<div style="
    color:#183D2B;
    font-size:19px;
    font-weight:850;
">
{image_height} × {image_width} × {channels}
</div>

<div style="
    color:#667060;
    font-size:14px;
    font-weight:600;
    margin-top:6px;
">
{input_size:,} input values
</div>
</div>


<div style="
    flex:1;
    box-sizing:border-box;
    background:#F8EDE8;
    border:1px solid #E2C8BC;
    border-radius:16px;
    padding:22px;
">
<div style="
    color:#9F2638;
    font-size:12px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:12px;
">
DENSE LAYER
</div>

<div style="
    color:#70202D;
    font-size:19px;
    font-weight:850;
">
{dense_total:,}
</div>

<div style="
    color:#76534D;
    font-size:14px;
    font-weight:600;
    margin-top:6px;
">
trainable parameters
</div>
</div>


<div style="
    flex:1;
    box-sizing:border-box;
    background:#EEF2E9;
    border:1px solid #CBD5C4;
    border-radius:16px;
    padding:22px;
">
<div style="
    color:#49623D;
    font-size:12px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:12px;
">
CNN LAYER
</div>

<div style="
    color:#183D2B;
    font-size:19px;
    font-weight:850;
">
{cnn_total:,}
</div>

<div style="
    color:#596657;
    font-size:14px;
    font-weight:600;
    margin-top:6px;
">
trainable parameters
</div>
</div>

</div>


<div style="
    width:100%;
    box-sizing:border-box;
    margin-top:18px;
    padding:20px 24px;
    background:#183D2B;
    border-radius:16px;
    text-align:center;
">

<div style="
    color:#EADCC8;
    font-size:12px;
    font-weight:800;
    letter-spacing:1.7px;
">
PARAMETER COMPARISON
</div>

<div style="
    color:#FFFFFF;
    font-size:32px;
    font-weight:900;
    margin-top:6px;
">
{ratio:,.0f}×
</div>

<div style="
    color:#D9E2D3;
    font-size:14px;
    font-weight:600;
    margin-top:4px;
">
more parameters in the Dense layer
</div>

</div>

</div>
"""))
# Out:
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#F7F1E6 0%,#FFFDF8 55%,#EEF2E9 100%);
#     border:1px solid #D5C7B5;
#     border-radius:22px;
#     padding:30px 34px;
#     margin:15px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 22px rgba(24,61,43,0.09);
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:24px;
#     font-weight:900;
#     margin-bottom:22px;
# ">
# Dense Layer vs CNN Layer
# </div>
#
# <div style="
#     display:flex;
#     gap:14px;
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     flex:1;
#     box-sizing:border-box;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:16px;
#     padding:22px;
# ">
# <div style="
#     color:#9F2638;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.5px;
#     margin-bottom:12px;
# ">
# IMAGE
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:19px;
# ...

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:38px 44px;
#     margin:30px 0 26px 0;
#     background:linear-gradient(135deg,#F3EBDD 0%,#FFFDF8 52%,#EAF0E8 100%);
#     border:1px solid #D5C7B5;
#     border-left:9px solid #183D2B;
#     border-radius:26px;
#     box-shadow:0 10px 28px rgba(24,61,43,0.10);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:14px;
#     font-weight:900;
#     letter-spacing:2.8px;
#     margin-bottom:12px;
# ">
# CNN FUNDAMENTALS
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:36px;
#     line-height:1.2;
#     font-weight:900;
# ">
# 1.3 Convolution: The Core Idea
# </div>
#
# <div style="
#     color:#596357;
#     font-size:17px;
#     line-height:1.75;
#     font-weight:600;
#     margin-top:12px;
# ">
# Understanding how convolution applies small filters across an image to detect
# important visual patterns and create feature maps.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:36px 42px;
#     margin:22px 0;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:24px;
#     box-shadow:0 8px 24px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:29px;
#     font-weight:900;
#     margin-bottom:25px;
# ">
# Understanding Convolution
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:17px;
#     line-height:1.9;
#     font-weight:600;
#     margin-bottom:25px;
# ">
# Convolution is the process of sliding a small
# <span style="color:#9F2638;font-weight:900;">filter (kernel)</span>
# across an image and calculating a value at each position. The resulting
# feature map shows where the pattern detected by the filter appears.
# </div>
#
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:21px 24px;
#     margin-bottom:14px;
#     background:#F8EDE8;
#     border:1px solid #E2C8BC;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:19px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# 01 · Filter / Kernel
# </div>
#
# <div style="
#     color:#604A45;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# A small matrix of weights, such as
# <span style="font-weight:900;color:#70202D;">3 × 3</span>,
# that learns to detect a specific visual pattern such as an edge, curve, or texture.
# </div>
#
# </div>
#
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:21px 24px;
#     margin-bottom:14px;
#     background:#EEF2E9;
#     border:1px solid #CBD5C4;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:19px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# 02 · Feature Map
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# The output produced after applying a filter to the image. It represents
# <span style="font-weight:900;color:#183D2B;">where and how strongly</span>
# the detected pattern appears.
# </div>
#
# </div>
#
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:21px 24px;
#     margin-bottom:14px;
#     background:#F3EBDD;
#     border:1px solid #D8CCBC;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:19px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# 03 · Stride
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Stride controls how far the filter moves at each step.
# <br>
# <span style="color:#9F2638;font-weight:900;">Stride = 1</span>
# → moves one pixel at a time.
# <br>
# <span style="color:#9F2638;font-weight:900;">Stride = 2</span>
# → moves two pixels at a time and produces a smaller output.
# </div>
#
# </div>
#
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:21px 24px;
#     background:#F8EDE8;
#     border:1px solid #E2C8BC;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#70202D;
#     font-size:19px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# 04 · Padding
# </div>
#
# <div style="
#     color:#604A45;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Padding adds extra pixels around the image borders before convolution.
# <strong>Valid</strong> uses no padding, while
# <strong>Same</strong> adds padding to preserve the spatial dimensions
# when using stride 1.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:36px 42px;
#     margin:22px 0;
#     background:linear-gradient(135deg,#EAF0E8 0%,#FFFDF8 100%);
#     border:1px solid #CBD5C4;
#     border-radius:24px;
#     box-shadow:0 8px 24px rgba(24,61,43,0.08);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:10px;
# ">
# CONNECTION TO WEEK 2
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:29px;
#     font-weight:900;
#     margin-bottom:18px;
# ">
# Convolution = Local Dot Product
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:17px;
#     line-height:1.9;
#     font-weight:600;
# ">
# Convolution is directly connected to the
# <span style="color:#9F2638;font-weight:900;">dot product</span>
# we studied in Week 2.
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     margin:22px 0;
#     padding:22px;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:17px;
#     text-align:center;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:21px;
#     font-weight:900;
# ">
# Image Patch × Filter → Sum → One Output Value
# </div>
#
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:16px;
#     line-height:1.9;
#     font-weight:600;
# ">
# At each position, the values of a small image patch are multiplied
# element-by-element with the filter values and then summed to produce
# one value in the feature map.
#
# The filter then moves to the next position and repeats the same calculation.
# Because the same filter is reused across the entire image, convolution also
# introduces the concept of
# <span style="color:#183D2B;font-weight:900;">parameter sharing</span>.
# </div>
#
# </div>

# %%
from IPython.display import display, HTML

display(HTML(f"""
<div style="
    width:100%;
    max-width:100%;
    box-sizing:border-box;
    margin:22px 0 30px 0;
    padding:26px 32px;
    background:linear-gradient(135deg,#F3EBDD 0%,#FFFDF8 100%);
    border:1px solid #D8CCBC;
    border-left:6px solid #315C47;
    border-radius:18px;
    box-shadow:0 7px 20px rgba(24,61,43,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
    overflow:hidden;
">

<div style="
    color:#9F2638;
    font-size:13px;
    font-weight:900;
    letter-spacing:2.3px;
    margin-bottom:18px;
">
SAMPLE IMAGE · OUTPUT
</div>

<div style="
    display:flex;
    flex-wrap:wrap;
    gap:14px;
    width:100%;
    box-sizing:border-box;
">

<div style="
    flex:1 1 220px;
    min-width:0;
    box-sizing:border-box;
    padding:18px 20px;
    background:#FFFFFF;
    border:1px solid #DDD3C4;
    border-radius:14px;
">

<div style="
    color:#687A6B;
    font-size:11px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:7px;
">
IMAGE SHAPE
</div>

<div style="
    color:#183D2B;
    font-size:22px;
    font-weight:900;
">
{image.shape}
</div>

</div>

<div style="
    flex:1 1 220px;
    min-width:0;
    box-sizing:border-box;
    padding:18px 20px;
    background:#FFFFFF;
    border:1px solid #DDD3C4;
    border-radius:14px;
">

<div style="
    color:#687A6B;
    font-size:11px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:7px;
">
MINIMUM PIXEL VALUE
</div>

<div style="
    color:#315C47;
    font-size:22px;
    font-weight:900;
">
{image.min()}
</div>

</div>

<div style="
    flex:1 1 220px;
    min-width:0;
    box-sizing:border-box;
    padding:18px 20px;
    background:#F8EDE8;
    border:1px solid #E2C8BC;
    border-radius:14px;
">

<div style="
    color:#8F2838;
    font-size:11px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:7px;
">
MAXIMUM PIXEL VALUE
</div>

<div style="
    color:#8F2838;
    font-size:22px;
    font-weight:900;
">
{image.max()}
</div>

</div>

</div>

<div style="
    margin-top:18px;
    padding-top:16px;
    border-top:1px solid #D8CCBC;
    color:#596357;
    font-size:14px;
    line-height:1.7;
    font-weight:600;
">
The sample image contains <strong style="color:#183D2B;">100 × 100 pixels</strong>,
with pixel values ranging from <strong style="color:#315C47;">0.0</strong>
to <strong style="color:#8F2838;">1.0</strong>.
</div>

</div>
"""))
# Out:
# <div style="
#     width:100%;
#     max-width:100%;
#     box-sizing:border-box;
#     margin:22px 0 30px 0;
#     padding:26px 32px;
#     background:linear-gradient(135deg,#F3EBDD 0%,#FFFDF8 100%);
#     border:1px solid #D8CCBC;
#     border-left:6px solid #315C47;
#     border-radius:18px;
#     box-shadow:0 7px 20px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
#     overflow:hidden;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2.3px;
#     margin-bottom:18px;
# ">
# SAMPLE IMAGE · OUTPUT
# </div>
#
# <div style="
#     display:flex;
#     flex-wrap:wrap;
#     gap:14px;
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     flex:1 1 220px;
#     min-width:0;
#     box-sizing:border-box;
#     padding:18px 20px;
#     background:#FFFFFF;
#     border:1px solid #DDD3C4;
#     border-radius:14px;
# ">
#
# <div style="
#     color:#687A6B;
#     font-size:11px;
# ...

# %%
from IPython.display import display, HTML

display(HTML(f"""
<div style="
    width:100%;
    max-width:100%;
    box-sizing:border-box;
    margin:22px 0 30px 0;
    padding:28px 32px;
    background:linear-gradient(135deg,#F3EBDD 0%,#FFFDF8 100%);
    border:1px solid #D8CCBC;
    border-left:6px solid #8F2838;
    border-radius:18px;
    box-shadow:0 7px 20px rgba(24,61,43,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
    overflow:hidden;
">

<div style="
    color:#9F2638;
    font-size:13px;
    font-weight:900;
    letter-spacing:2.3px;
    margin-bottom:18px;
">
EDGE-DETECTION FILTER
</div>

<div style="
    color:#183D2B;
    font-size:18px;
    font-weight:800;
    margin-bottom:18px;
">
3×3 Vertical Edge Detection Kernel
</div>

<div style="
    display:flex;
    justify-content:center;
    align-items:center;
    width:100%;
    box-sizing:border-box;
    padding:22px;
    background:#FFFFFF;
    border:1px solid #DDD3C4;
    border-radius:15px;
">

<pre style="
    margin:0;
    padding:0;
    color:#315C47;
    font-family:'Courier New',monospace;
    font-size:24px;
    line-height:1.6;
    font-weight:800;
    text-align:center;
    background:transparent;
    border:none;
">
[ -1   0   1 ]
[ -1   0   1 ]
[ -1   0   1 ]
</pre>

</div>

<div style="
    margin-top:18px;
    padding-top:16px;
    border-top:1px solid #D8CCBC;
    color:#596357;
    font-size:15px;
    line-height:1.8;
    font-weight:600;
">
This filter is designed to highlight <strong style="color:#8F2838;">
vertical edges</strong> by responding to intensity changes from left to right.
</div>

</div>
"""))
# Out:
# <div style="
#     width:100%;
#     max-width:100%;
#     box-sizing:border-box;
#     margin:22px 0 30px 0;
#     padding:28px 32px;
#     background:linear-gradient(135deg,#F3EBDD 0%,#FFFDF8 100%);
#     border:1px solid #D8CCBC;
#     border-left:6px solid #8F2838;
#     border-radius:18px;
#     box-shadow:0 7px 20px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
#     overflow:hidden;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2.3px;
#     margin-bottom:18px;
# ">
# EDGE-DETECTION FILTER
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:18px;
#     font-weight:800;
#     margin-bottom:18px;
# ">
# 3×3 Vertical Edge Detection Kernel
# </div>
#
# <div style="
#     display:flex;
#     justify-content:center;
#     align-items:center;
#     width:100%;
#     box-sizing:border-box;
#     padding:22px;
#     background:#FFFFFF;
#     border:1px solid #DDD3C4;
# ...

# %%
from IPython.display import display, HTML

display(HTML(f"""
<div style="
    width:100%;
    max-width:100%;
    box-sizing:border-box;
    margin:22px 0 30px 0;
    padding:28px 32px;
    background:linear-gradient(135deg,#F3EBDD 0%,#FFFDF8 100%);
    border:1px solid #D8CCBC;
    border-left:6px solid #315C47;
    border-radius:18px;
    box-shadow:0 7px 20px rgba(24,61,43,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
    overflow:hidden;
">

<div style="
    color:#9F2638;
    font-size:13px;
    font-weight:900;
    letter-spacing:2.3px;
    margin-bottom:18px;
">
CONVOLUTION · OUTPUT
</div>

<div style="
    display:flex;
    flex-wrap:wrap;
    gap:14px;
    width:100%;
    box-sizing:border-box;
">

<!-- ORIGINAL IMAGE -->

<div style="
    flex:1 1 220px;
    min-width:0;
    box-sizing:border-box;
    padding:20px;
    background:#FFFFFF;
    border:1px solid #DDD3C4;
    border-radius:15px;
">

<div style="
    color:#687A6B;
    font-size:11px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:8px;
">
ORIGINAL IMAGE
</div>

<div style="
    color:#183D2B;
    font-size:22px;
    font-weight:900;
">
{image.shape}
</div>

<div style="
    margin-top:7px;
    color:#596357;
    font-size:13px;
    font-weight:600;
">
Input dimensions
</div>

</div>


<!-- FEATURE MAP -->

<div style="
    flex:1 1 220px;
    min-width:0;
    box-sizing:border-box;
    padding:20px;
    background:#EEF3EC;
    border:1px solid #CFDCCB;
    border-radius:15px;
">

<div style="
    color:#315C47;
    font-size:11px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:8px;
">
FEATURE MAP
</div>

<div style="
    color:#183D2B;
    font-size:22px;
    font-weight:900;
">
{feature_map.shape}
</div>

<div style="
    margin-top:7px;
    color:#596357;
    font-size:13px;
    font-weight:600;
">
Output dimensions
</div>

</div>


<!-- MIN -->

<div style="
    flex:1 1 220px;
    min-width:0;
    box-sizing:border-box;
    padding:20px;
    background:#FFFFFF;
    border:1px solid #DDD3C4;
    border-radius:15px;
">

<div style="
    color:#687A6B;
    font-size:11px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:8px;
">
MINIMUM RESPONSE
</div>

<div style="
    color:#315C47;
    font-size:22px;
    font-weight:900;
">
{feature_map.min():.1f}
</div>

</div>


<!-- MAX -->

<div style="
    flex:1 1 220px;
    min-width:0;
    box-sizing:border-box;
    padding:20px;
    background:#F8EDE8;
    border:1px solid #E2C8BC;
    border-radius:15px;
">

<div style="
    color:#8F2838;
    font-size:11px;
    font-weight:900;
    letter-spacing:1.5px;
    margin-bottom:8px;
">
MAXIMUM RESPONSE
</div>

<div style="
    color:#8F2838;
    font-size:22px;
    font-weight:900;
">
{feature_map.max():.1f}
</div>

</div>

</div>


<div style="
    margin-top:20px;
    padding:18px 20px;
    box-sizing:border-box;
    background:#FFFFFF;
    border:1px solid #DDD3C4;
    border-radius:15px;
    color:#596357;
    font-size:15px;
    line-height:1.8;
    font-weight:600;
">

The <strong style="color:#183D2B;">3×3 filter</strong> slides across the
100×100 image and produces a <strong style="color:#315C47;">
98×98 feature map</strong>. The feature map represents the filter's response
at each valid position.

</div>

</div>
"""))
# Out:
# <div style="
#     width:100%;
#     max-width:100%;
#     box-sizing:border-box;
#     margin:22px 0 30px 0;
#     padding:28px 32px;
#     background:linear-gradient(135deg,#F3EBDD 0%,#FFFDF8 100%);
#     border:1px solid #D8CCBC;
#     border-left:6px solid #315C47;
#     border-radius:18px;
#     box-shadow:0 7px 20px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
#     overflow:hidden;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2.3px;
#     margin-bottom:18px;
# ">
# CONVOLUTION · OUTPUT
# </div>
#
# <div style="
#     display:flex;
#     flex-wrap:wrap;
#     gap:14px;
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <!-- ORIGINAL IMAGE -->
#
# <div style="
#     flex:1 1 220px;
#     min-width:0;
#     box-sizing:border-box;
#     padding:20px;
#     background:#FFFFFF;
#     border:1px solid #DDD3C4;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#687A6B;
# ...

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(
    1,
    2,
    figsize=(16, 7),
    gridspec_kw={"wspace": 0.22}
)

axes[0].imshow(
    image,
    cmap="gray",
    interpolation="nearest"
)

axes[0].set_title(
    "Original Image",
    fontsize=22,
    fontweight="bold",
    pad=20
)

axes[0].set_xlabel(
    "Input Image",
    fontsize=15,
    fontweight="600",
    labelpad=15
)

axes[0].set_xticks([])
axes[0].set_yticks([])


im2 = axes[1].imshow(
    feature_map,
    cmap="gray",
    interpolation="nearest"
)

axes[1].set_title(
    "Feature Map",
    fontsize=22,
    fontweight="bold",
    pad=20
)

axes[1].set_xlabel(
    "Detected Vertical Edges",
    fontsize=15,
    fontweight="600",
    labelpad=15
)

axes[1].set_xticks([])
axes[1].set_yticks([])


cbar = fig.colorbar(
    im2,
    ax=axes[1],
    fraction=0.045,
    pad=0.06
)

cbar.set_label(
    "Filter Response",
    fontsize=15,
    fontweight="600",
    labelpad=14
)

cbar.ax.tick_params(
    labelsize=13
)


fig.suptitle(
    "Convolution: From Image to Feature Map",
    fontsize=26,
    fontweight="bold",
    y=0.98
)

plt.subplots_adjust(
    top=0.82,
    bottom=0.14,
    left=0.06,
    right=0.94
)

plt.show()

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:38px 44px;
#     margin:30px 0 26px 0;
#     background:linear-gradient(135deg,#F3EBDD 0%,#FFFDF8 52%,#EAF0E8 100%);
#     border:1px solid #D5C7B5;
#     border-left:9px solid #183D2B;
#     border-radius:26px;
#     box-shadow:0 10px 28px rgba(24,61,43,0.10);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:14px;
#     font-weight:900;
#     letter-spacing:2.8px;
#     margin-bottom:12px;
# ">
# CNN FUNDAMENTALS
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:36px;
#     line-height:1.2;
#     font-weight:900;
# ">
# 1.4 Why Convolution Wins
# </div>
#
# <div style="
#     color:#596357;
#     font-size:17px;
#     line-height:1.75;
#     font-weight:600;
#     margin-top:12px;
# ">
# Understanding why convolution is efficient, reusable, and powerful for visual data.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:34px 42px;
#     margin:22px 0;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:24px;
#     box-shadow:0 8px 24px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:10px;
# ">
# ADVANTAGE 01
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:29px;
#     font-weight:900;
#     margin-bottom:16px;
# ">
# Parameter Sharing
# </div>
#
# <div style="
#     color:#4D574B;
#     font-size:17px;
#     line-height:1.9;
#     font-weight:600;
# ">
# A CNN uses the
# <span style="color:#9F2638;font-weight:900;">same filter</span>
# across different locations of an image instead of learning a separate set
# of weights for every position.
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     margin-top:22px;
#     padding:21px 24px;
#     background:#F1F4EC;
#     border:1px solid #CBD5C4;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:20px;
#     font-weight:900;
# ">
# One Filter → Reused Across the Entire Image
# </div>
#
# <div style="
#     color:#596357;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
#     margin-top:7px;
# ">
# This dramatically reduces the number of trainable parameters compared with
# a fully connected network, making CNNs more efficient.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:34px 42px;
#     margin:22px 0;
#     background:linear-gradient(135deg,#F8EDE8 0%,#FFFDF8 100%);
#     border:1px solid #E2C8BC;
#     border-radius:24px;
#     box-shadow:0 8px 24px rgba(127,29,45,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:10px;
# ">
# ADVANTAGE 02
# </div>
#
# <div style="
#     color:#70202D;
#     font-size:29px;
#     font-weight:900;
#     margin-bottom:16px;
# ">
# Translation Invariance
# </div>
#
# <div style="
#     color:#604A45;
#     font-size:17px;
#     line-height:1.9;
#     font-weight:600;
# ">
# The same visual pattern can appear in different locations within an image.
# Because a CNN applies the same filter across the entire image, it can detect
# that pattern
# <span style="color:#9F2638;font-weight:900;">regardless of where it appears</span>.
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     margin-top:22px;
#     padding:21px 24px;
#     background:#FFFDF8;
#     border:1px solid #E2D1C7;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:20px;
#     font-weight:900;
# ">
# Same Pattern → Different Location → Still Detected
# </div>
#
# <div style="
#     color:#604A45;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
#     margin-top:7px;
# ">
# This allows CNNs to recognize important features without requiring the feature
# to appear in one fixed position.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:36px 42px;
#     margin:22px 0;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:24px;
#     box-shadow:0 8px 24px rgba(24,61,43,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F2638;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:10px;
# ">
# HOW CNNs LEARN
# </div>
#
# <div style="
#     color:#183D2B;
#     font-size:29px;
#     font-weight:900;
#     margin-bottom:25px;
# ">
# Feature Hierarchy
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:22px 25px;
#     margin-bottom:14px;
#     background:#EEF2E9;
#     border:1px solid #CBD5C4;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# Early Layers → Edges
# </div>
#
# <div style="
#     color:#596357;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# The first layers learn simple visual patterns such as edges, lines, and basic
# directions.
# </div>
#
# </div>
#
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:22px 25px;
#     margin-bottom:14px;
#     background:#F3EBDD;
#     border:1px solid #D8CCBC;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#687A55;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# Middle Layers → Shapes & Textures
# </div>
#
# <div style="
#     color:#596357;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Middle layers combine simpler features to learn more meaningful structures,
# such as shapes, curves, patterns, and textures.
# </div>
#
# </div>
#
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:22px 25px;
#     background:#F8EDE8;
#     border:1px solid #E2C8BC;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#70202D;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# Deep Layers → Whole Objects
# </div>
#
# <div style="
#     color:#604A45;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Deeper layers combine increasingly complex features to recognize high-level
# representations such as complete objects or meaningful parts of objects.
# </div>
#
# </div>
#
# <div style="
#     margin-top:22px;
#     padding-top:20px;
#     border-top:1px solid #DDD4C8;
#     color:#596357;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# The network learns this hierarchy automatically from the training data rather
# than requiring us to manually define each visual feature.
# </div>
#
# </div>

# %%
from IPython.display import display, HTML

hierarchy = [
    ("Early Layers", "Edges", "Simple visual patterns"),
    ("Middle Layers", "Shapes & Textures", "Combined visual patterns"),
    ("Deep Layers", "Whole Objects", "High-level representations")
]

rows = ""

for layer, feature, description in hierarchy:
    rows += f"""
    <tr>
        <td style="
            padding:16px 18px;
            font-weight:800;
            color:#183D2B;
            border-bottom:1px solid #E1D8CA;
        ">
            {layer}
        </td>

        <td style="
            padding:16px 18px;
            font-weight:800;
            color:#9F2638;
            border-bottom:1px solid #E1D8CA;
        ">
            {feature}
        </td>

        <td style="
            padding:16px 18px;
            color:#596357;
            font-weight:600;
            border-bottom:1px solid #E1D8CA;
        ">
            {description}
        </td>
    </tr>
    """

display(HTML(f"""
<div style="
    width:100%;
    box-sizing:border-box;
    padding:30px 34px;
    margin:15px 0;
    background:linear-gradient(135deg,#F7F1E6 0%,#FFFDF8 55%,#EEF2E9 100%);
    border:1px solid #D5C7B5;
    border-radius:22px;
    box-shadow:0 8px 22px rgba(24,61,43,0.09);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="
    color:#183D2B;
    font-size:24px;
    font-weight:900;
    margin-bottom:20px;
">
CNN Feature Hierarchy
</div>

<table style="
    width:100%;
    border-collapse:collapse;
    background:#FFFDF8;
    border:1px solid #D8CCBC;
    border-radius:14px;
    overflow:hidden;
">

<thead>
<tr style="background:#183D2B;">

<th style="
    padding:15px 18px;
    color:#F3EBDD;
    text-align:left;
    font-size:13px;
    letter-spacing:1px;
">
LAYER
</th>

<th style="
    padding:15px 18px;
    color:#F3EBDD;
    text-align:left;
    font-size:13px;
    letter-spacing:1px;
">
LEARNED FEATURE
</th>

<th style="
    padding:15px 18px;
    color:#F3EBDD;
    text-align:left;
    font-size:13px;
    letter-spacing:1px;
">
DESCRIPTION
</th>

</tr>
</thead>

<tbody>
{rows}
</tbody>

</table>

<div style="
    margin-top:18px;
    padding:16px 20px;
    background:#F8EDE8;
    border:1px solid #E2C8BC;
    border-radius:13px;
    color:#70202D;
    font-size:14px;
    font-weight:700;
">
The deeper the network goes, the more complex and meaningful the learned
representations become.
</div>

</div>
"""))
# Out:
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:30px 34px;
#     margin:15px 0;
#     background:linear-gradient(135deg,#F7F1E6 0%,#FFFDF8 55%,#EEF2E9 100%);
#     border:1px solid #D5C7B5;
#     border-radius:22px;
#     box-shadow:0 8px 22px rgba(24,61,43,0.09);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#183D2B;
#     font-size:24px;
#     font-weight:900;
#     margin-bottom:20px;
# ">
# CNN Feature Hierarchy
# </div>
#
# <table style="
#     width:100%;
#     border-collapse:collapse;
#     background:#FFFDF8;
#     border:1px solid #D8CCBC;
#     border-radius:14px;
#     overflow:hidden;
# ">
#
# <thead>
# <tr style="background:#183D2B;">
#
# <th style="
#     padding:15px 18px;
#     color:#F3EBDD;
#     text-align:left;
#     font-size:13px;
#     letter-spacing:1px;
# ">
# LAYER
# </th>
#
# <th style="
#     padding:15px 18px;
#     color:#F3EBDD;
#     text-align:left;
#     font-size:13px;
# ...
