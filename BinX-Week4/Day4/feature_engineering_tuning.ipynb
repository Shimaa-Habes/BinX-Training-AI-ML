# %% [markdown]
# <div style="
# background:linear-gradient(155deg,#042142 0%,#153C6A 52%,#042142 100%);
# border-radius:20px;
# padding:0;
# position:relative;
# overflow:hidden;
# border:2px solid #2475AC;
# box-shadow:
# 0 0 0 1px rgba(61,224,252,0.12),
# inset 0 0 40px rgba(61,224,252,0.035);
# font-family:'Courier New',monospace;
# box-sizing:border-box;
# width:100%;
# ">
#
#
# <!-- TOP PIXEL STRIP -->
# <div style="
# position:absolute;
# top:0;
# left:0;
# right:0;
# height:7px;
# background:repeating-linear-gradient(
# 90deg,
# #3DE0FC 0px,
# #3DE0FC 16px,
# #733E85 16px,
# #733E85 32px,
# #E977F5 32px,
# #E977F5 48px
# );
# "></div>
#
#
# <!-- TOP RIGHT GLOW -->
# <div style="
# position:absolute;
# top:-55px;
# right:-45px;
# width:210px;
# height:210px;
# background:#733E85;
# opacity:0.22;
# border-radius:50%;
# box-shadow:0 0 55px rgba(233,119,245,0.22);
# pointer-events:none;
# "></div>
#
#
# <!-- BOTTOM LEFT GLOW -->
# <div style="
# position:absolute;
# bottom:-90px;
# left:-70px;
# width:220px;
# height:220px;
# background:#2475AC;
# opacity:0.22;
# border-radius:50%;
# box-shadow:0 0 60px rgba(61,224,252,0.18);
# pointer-events:none;
# "></div>
#
#
# <!-- PIXEL DECORATIONS -->
# <div style="
# position:absolute;
# top:28px;
# right:34px;
# font-size:30px;
# color:#3DE0FC;
# opacity:0.9;
# pointer-events:none;
# ">
# ✦
# </div>
#
# <div style="
# position:absolute;
# top:70px;
# right:82px;
# font-size:22px;
# color:#E977F5;
# opacity:0.65;
# pointer-events:none;
# ">
# ◆
# </div>
#
# <div style="
# position:absolute;
# bottom:35px;
# right:38px;
# font-size:28px;
# color:#733E85;
# opacity:0.7;
# pointer-events:none;
# ">
# ▣
# </div>
#
# <div style="
# position:absolute;
# bottom:65px;
# right:82px;
# font-size:18px;
# color:#3DE0FC;
# opacity:0.45;
# pointer-events:none;
# ">
# ✦
# </div>
#
#
# <!-- MAIN CONTENT -->
# <div style="
# position:relative;
# z-index:2;
# padding:40px 36px 34px 36px;
# box-sizing:border-box;
# width:100%;
# ">
#
#
# <!-- SERIES LABEL -->
# <div style="
# display:flex;
# align-items:center;
# gap:13px;
# width:100%;
# box-sizing:border-box;
# ">
#
# <span style="
# font-size:28px;
# line-height:1;
# ">
# 👾
# </span>
#
# <span style="
# font-family:'Press Start 2P','Courier New',monospace;
# font-size:14px;
# letter-spacing:2px;
# color:#3DE0FC;
# text-transform:uppercase;
# font-weight:700;
# line-height:1.5;
# ">
# BINX AI GAME LAB
# </span>
#
# </div>
#
#
# <!-- WEEK / DAY -->
# <div style="
# margin-top:27px;
# display:flex;
# align-items:center;
# gap:15px;
# flex-wrap:wrap;
# width:100%;
# box-sizing:border-box;
# ">
#
# <span style="
# font-family:'Press Start 2P','Courier New',monospace;
# font-size:13px;
# color:#E977F5;
# font-weight:700;
# line-height:1.5;
# ">
# WEEK 04
# </span>
#
# <span style="
# font-size:17px;
# color:#3DE0FC;
# line-height:1;
# ">
# ▸
# </span>
#
# <span style="
# font-family:'Press Start 2P','Courier New',monospace;
# font-size:13px;
# color:#E977F5;
# font-weight:700;
# line-height:1.5;
# ">
# DAY 04 / 05
# </span>
#
# </div>
#
#
# <!-- MAIN TITLE -->
# <h1 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#FFFFFF;
# font-size:50px;
# font-weight:700;
# line-height:1.65;
# margin:22px 0 18px 0;
# max-width:760px;
# text-shadow:
# 3px 3px 0 #733E85,
# 0 0 18px rgba(61,224,252,0.18);
# box-sizing:border-box;
# ">
#
# FEATURE ENGINEERING
# <br>
# & HYPERPARAMETER TUNING
#
# </h1>
#
#
# <!-- DESCRIPTION -->
# <p style="
# font-family:'Courier New',monospace;
# color:#D9F7FF;
# font-size:19px;
# line-height:1.8;
# margin:0 0 32px 0;
# max-width:760px;
# box-sizing:border-box;
# ">
#
# Upgrade the game data with smarter features, then tune the model
# until the best configuration wins the round.
#
# </p>
#
#
# <!-- INFORMATION CARDS CONTAINER -->
# <div style="
# display:flex;
# gap:15px;
# flex-wrap:wrap;
# width:100%;
# box-sizing:border-box;
# align-items:stretch;
# ">
#
#
# <!-- DATASET CARD -->
# <div style="
# background:rgba(4,33,66,0.88);
# border:2px solid #2475AC;
# border-radius:12px;
# padding:18px 19px;
# display:flex;
# align-items:center;
# gap:14px;
# flex:1 1 220px;
# min-width:220px;
# box-sizing:border-box;
# overflow:hidden;
# box-shadow:
# inset 0 0 20px rgba(61,224,252,0.04),
# 0 0 12px rgba(36,117,172,0.10);
# ">
#
# <div style="
# font-size:28px;
# width:34px;
# height:34px;
# display:flex;
# align-items:center;
# justify-content:center;
# flex-shrink:0;
# ">
# 🎮
# </div>
#
# <div style="
# min-width:0;
# flex:1;
# box-sizing:border-box;
# ">
#
# <div style="
# font-family:'Press Start 2P','Courier New',monospace;
# font-size:10px;
# color:#3DE0FC;
# font-weight:700;
# text-transform:uppercase;
# margin-bottom:10px;
# line-height:1.5;
# ">
# DATASET
# </div>
#
# <div style="
# font-family:'Courier New',monospace;
# font-size:16px;
# color:#FFFFFF;
# font-weight:700;
# line-height:1.5;
# word-break:break-word;
# ">
# Video Game Sales & Ratings
# </div>
#
# </div>
# </div>
#
#
# <!-- FEATURE ENGINEERING CARD -->
# <div style="
# background:rgba(4,33,66,0.88);
# border:2px solid #2475AC;
# border-radius:12px;
# padding:18px 19px;
# display:flex;
# align-items:center;
# gap:14px;
# flex:1 1 220px;
# min-width:220px;
# box-sizing:border-box;
# overflow:hidden;
# box-shadow:
# inset 0 0 20px rgba(233,119,245,0.04),
# 0 0 12px rgba(36,117,172,0.10);
# ">
#
# <div style="
# font-size:28px;
# width:34px;
# height:34px;
# display:flex;
# align-items:center;
# justify-content:center;
# flex-shrink:0;
# ">
# 🧩
# </div>
#
# <div style="
# min-width:0;
# flex:1;
# box-sizing:border-box;
# ">
#
# <div style="
# font-family:'Press Start 2P','Courier New',monospace;
# font-size:10px;
# color:#E977F5;
# font-weight:700;
# text-transform:uppercase;
# margin-bottom:10px;
# line-height:1.5;
# ">
# POWER-UP
# </div>
#
# <div style="
# font-family:'Courier New',monospace;
# font-size:16px;
# color:#FFFFFF;
# font-weight:700;
# line-height:1.5;
# word-break:break-word;
# ">
# Feature Engineering
# </div>
#
# </div>
# </div>
#
#
# <!-- TUNING CARD -->
# <div style="
# background:rgba(4,33,66,0.88);
# border:2px solid #2475AC;
# border-radius:12px;
# padding:18px 19px;
# display:flex;
# align-items:center;
# gap:14px;
# flex:1 1 220px;
# min-width:220px;
# box-sizing:border-box;
# overflow:hidden;
# box-shadow:
# inset 0 0 20px rgba(61,224,252,0.04),
# 0 0 12px rgba(36,117,172,0.10);
# ">
#
# <div style="
# font-size:28px;
# width:34px;
# height:34px;
# display:flex;
# align-items:center;
# justify-content:center;
# flex-shrink:0;
# ">
# ⚙️
# </div>
#
# <div style="
# min-width:0;
# flex:1;
# box-sizing:border-box;
# ">
#
# <div style="
# font-family:'Press Start 2P','Courier New',monospace;
# font-size:10px;
# color:#3DE0FC;
# font-weight:700;
# text-transform:uppercase;
# margin-bottom:10px;
# line-height:1.5;
# ">
# BOSS FIGHT
# </div>
#
# <div style="
# font-family:'Courier New',monospace;
# font-size:16px;
# color:#FFFFFF;
# font-weight:700;
# line-height:1.5;
# word-break:break-word;
# ">
# GridSearchCV · Random Forest
# </div>
#
# </div>
# </div>
#
#
# </div>
#
#
# <!-- PIXEL DIVIDER -->
# <div style="
# margin-top:30px;
# width:100%;
# height:4px;
# background:repeating-linear-gradient(
# 90deg,
# #3DE0FC 0px,
# #3DE0FC 22px,
# #2475AC 22px,
# #2475AC 38px,
# #733E85 38px,
# #733E85 50px,
# transparent 50px,
# transparent 58px
# );
# box-sizing:border-box;
# ">
# </div>
#
#
# <!-- TOPICS -->
# <div style="
# margin-top:22px;
# display:flex;
# gap:11px;
# flex-wrap:wrap;
# width:100%;
# box-sizing:border-box;
# ">
#
#
# <!-- TAG 1 -->
# <span style="
# font-family:'Courier New',monospace;
# font-size:14px;
# color:#3DE0FC;
# font-weight:700;
# background:rgba(61,224,252,0.08);
# border:1px solid #2475AC;
# padding:9px 14px;
# border-radius:5px;
# ">
# 🧩 feature creation
# </span>
#
#
# <!-- TAG 2 -->
# <span style="
# font-family:'Courier New',monospace;
# font-size:14px;
# color:#E977F5;
# font-weight:700;
# background:rgba(233,119,245,0.08);
# border:1px solid #733E85;
# padding:9px 14px;
# border-radius:5px;
# ">
# 📦 binning
# </span>
#
#
# <span style="
# font-family:'Courier New',monospace;
# font-size:14px;
# color:#3DE0FC;
# font-weight:700;
# background:rgba(61,224,252,0.08);
# border:1px solid #2475AC;
# padding:9px 14px;
# border-radius:5px;
# ">
# 🔤 encoding
# </span>
#
#
# <span style="
# font-family:'Courier New',monospace;
# font-size:14px;
# color:#E977F5;
# font-weight:700;
# background:rgba(233,119,245,0.08);
# border:1px solid #733E85;
# padding:9px 14px;
# border-radius:5px;
# ">
# ⚖️ scaling
# </span>
#
#
# <span style="
# font-family:'Courier New',monospace;
# font-size:14px;
# color:#3DE0FC;
# font-weight:700;
# background:rgba(61,224,252,0.08);
# border:1px solid #2475AC;
# padding:9px 14px;
# border-radius:5px;
# ">
# 🎯 GridSearchCV
# </span>
#
#
# <span style="
# font-family:'Courier New',monospace;
# font-size:14px;
# color:#E977F5;
# font-weight:700;
# background:rgba(233,119,245,0.08);
# border:1px solid #733E85;
# padding:9px 14px;
# border-radius:5px;
# ">
# 🧪 hands-on lab
# </span>
#
#
# </div>
#
#
# <!-- BOTTOM STATUS BAR -->
# <div style="
# margin-top:30px;
# padding-top:18px;
# border-top:1px solid rgba(36,117,172,0.55);
# display:flex;
# align-items:center;
# gap:11px;
# width:100%;
# box-sizing:border-box;
# font-family:'Press Start 2P','Courier New',monospace;
# font-size:11px;
# color:#8AB8D9;
# ">
#
# <span style="
# color:#3DE0FC;
# font-size:15px;
# line-height:1;
# ">
# ●
# </span>
#
# <span>
# PLAYER 01
# </span>
#
# <span style="
# margin-left:auto;
# color:#E977F5;
# ">
# LEVEL 04
# </span>
#
# </div>
#
#
# </div>
# </div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 28px 0;
# letter-spacing:1px;
# ">
# 🎮 ▶ DATASET OVERVIEW
# </h2>
#
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 💾 [01] DATASET USED
# </h3>
#
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# <strong>Video Game Sales & Ratings</strong>
# </p>
#
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# line-height:1.6;
# font-weight:700;
# margin:28px 0 12px 0;
# ">
# 🧩 [02] WHAT DOES IT CONTAIN?
# </h3>
#
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# The dataset contains information about video games, including
# <strong>platform, genre, release year, publisher, developer, regional sales, global sales, critic scores, user scores,</strong> and <strong>ESRB ratings</strong>.
# </p>
#
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# line-height:1.6;
# font-weight:700;
# margin:28px 0 12px 0;
# ">
# 🎯 [03] WHY DID WE USE IT?
# </h3>
#
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We selected this dataset because it contains a mix of <strong>numerical and categorical features</strong>, making it suitable for practicing <strong>feature engineering, data transformation, and hyperparameter tuning</strong>.
# </p>
#
#
# <div style="
# margin-top:28px;
# height:4px;
# width:100%;
# background:repeating-linear-gradient(
# 90deg,
# #3DE0FC 0px,
# #3DE0FC 18px,
# #733E85 18px,
# #733E85 32px,
# transparent 32px,
# transparent 40px
# );
# ">
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 28px 0;
# letter-spacing:1px;
# ">
# 🧠 ▶ 4.1 WHY FEATURE ENGINEERING OFTEN BEATS MODEL CHOICE
# </h2>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🎮 [01] BETTER FEATURES
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Good features can give a model more useful information to learn from, which can improve its performance even without changing the model itself.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🧩 [02] TURNING DATA INTO SIGNAL
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Feature engineering transforms existing data into more meaningful variables that can help the model detect patterns more effectively.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🎯 [03] IN THIS DATASET
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# For the gaming dataset, we will create and transform features related to <strong>sales, game age, scores, categories,</strong> and other useful information before tuning the model.
# </p>
#
# <div style="
# margin-top:28px;
# height:4px;
# width:100%;
# background:repeating-linear-gradient(
# 90deg,
# #3DE0FC 0px,
# #3DE0FC 18px,
# #733E85 18px,
# #733E85 32px,
# transparent 32px,
# transparent 40px
# );
# ">
# </div>
#
# </div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 28px 0;
# letter-spacing:1px;
# ">
# 🧩 ▶ 4.2 COMMON FEATURE ENGINEERING TECHNIQUES
# </h2>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0 0 22px 0;
# ">
# Feature engineering includes several techniques that transform existing data into features that are more useful for machine learning models.
# </p>
#
# <table style="
# width:100%;
# border-collapse:collapse;
# font-family:'Courier New',monospace;
# font-size:15px;
# ">
#
# <tr>
# <th style="
# background:#153C6A;
# color:#3DE0FC;
# border:1px solid #2475AC;
# padding:12px;
# text-align:center;
# ">
# Technique
# </th>
#
# <th style="
# background:#153C6A;
# color:#3DE0FC;
# border:1px solid #2475AC;
# padding:12px;
# text-align:center;
# ">
# What It Does
# </th>
#
# <th style="
# background:#153C6A;
# color:#3DE0FC;
# border:1px solid #2475AC;
# padding:12px;
# text-align:center;
# ">
# Gaming Example
# </th>
# </tr>
#
# <tr>
# <td style="border:1px solid #2475AC;padding:12px;color:#E977F5;font-weight:bold;">
# Creating Features
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Combines or transforms existing columns into a more meaningful feature.
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Total Regional Sales
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #2475AC;padding:12px;color:#E977F5;font-weight:bold;">
# Binning
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Groups continuous values into meaningful categories.
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Critic Score → Poor / Average / Good / Excellent
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #2475AC;padding:12px;color:#E977F5;font-weight:bold;">
# One-Hot Encoding
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Converts categorical values into separate binary columns.
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Genre → Genre_Action, Genre_Sports, ...
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #2475AC;padding:12px;color:#E977F5;font-weight:bold;">
# Datetime Extraction
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Extracts useful information such as year, month, or day from dates.
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Release Date → Year / Month
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #2475AC;padding:12px;color:#E977F5;font-weight:bold;">
# Scaling
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Places numerical features on a comparable scale.
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# StandardScaler on scores and sales
# </td>
# </tr>
#
# </table>
#
# </div>

# %%
regional_sales = df[['NA_Sales', 'EU_Sales']].copy()

regional_sales['NA_EU_Sales'] = (
    regional_sales['NA_Sales'] +
    regional_sales['EU_Sales']
)

regional_sales.head(10).style \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '14px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '15px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_c0beb th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 15px;
# }
# #T_c0beb td {
#   border-color: #2475AC;
#   text-align: center;
# }
# #T_c0beb_row0_col0, #T_c0beb_row0_col1, #T_c0beb_row0_col2, #T_c0beb_row1_col0, #T_c0beb_row1_col1, #T_c0beb_row1_col2, #T_c0beb_row2_col0, #T_c0beb_row2_col1, #T_c0beb_row2_col2, #T_c0beb_row3_col0, #T_c0beb_row3_col1, #T_c0beb_row3_col2, #T_c0beb_row4_col0, #T_c0beb_row4_col1, #T_c0beb_row4_col2, #T_c0beb_row5_col0, #T_c0beb_row5_col1, #T_c0beb_row5_col2, #T_c0beb_row6_col0, #T_c0beb_row6_col1, #T_c0beb_row6_col2, #T_c0beb_row7_col0, #T_c0beb_row7_col1, #T_c0beb_row7_col2, #T_c0beb_row8_col0, #T_c0beb_row8_col1, #T_c0beb_row8_col2, #T_c0beb_row9_col0, #T_c0beb_row9_col1, #T_c0beb_row9_col2 {
#   background-color: #042142;
#   color: #D9F7FF;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 14px;
# }
# ...

# %%
critic_bins = [0, 50, 70, 85, 100]

critic_labels = [
    'Poor',
    'Average',
    'Good',
    'Excellent'
]

df['Critic_Score_Category'] = pd.cut(
    df['Critic_Score'],
    bins=critic_bins,
    labels=critic_labels,
    include_lowest=True
)

df[
    ['Name', 'Critic_Score', 'Critic_Score_Category']
].dropna().head(10).style \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '14px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '15px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_25892 th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 15px;
# }
# #T_25892 td {
#   border-color: #2475AC;
#   text-align: center;
# }
# #T_25892_row0_col0, #T_25892_row0_col1, #T_25892_row0_col2, #T_25892_row1_col0, #T_25892_row1_col1, #T_25892_row1_col2, #T_25892_row2_col0, #T_25892_row2_col1, #T_25892_row2_col2, #T_25892_row3_col0, #T_25892_row3_col1, #T_25892_row3_col2, #T_25892_row4_col0, #T_25892_row4_col1, #T_25892_row4_col2, #T_25892_row5_col0, #T_25892_row5_col1, #T_25892_row5_col2, #T_25892_row6_col0, #T_25892_row6_col1, #T_25892_row6_col2, #T_25892_row7_col0, #T_25892_row7_col1, #T_25892_row7_col2, #T_25892_row8_col0, #T_25892_row8_col1, #T_25892_row8_col2, #T_25892_row9_col0, #T_25892_row9_col1, #T_25892_row9_col2 {
#   background-color: #042142;
#   color: #D9F7FF;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 14px;
# }
# ...

# %%
genre_encoded = pd.get_dummies(
    df['Genre'],
    prefix='Genre',
    dummy_na=True
)

genre_encoded.head(10).style \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '13px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '14px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_cc841 th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 14px;
# }
# #T_cc841 td {
#   border-color: #2475AC;
#   text-align: center;
# }
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaling_features = [
    'Critic_Score',
    'User_Score',
    'Global_Sales'
]

scaling_data = df[scaling_features].copy()

scaling_data['User_Score'] = pd.to_numeric(
    scaling_data['User_Score'],
    errors='coerce'
)

scaling_data = scaling_data.fillna(
    scaling_data.median()
)

scaler = StandardScaler()

scaled_values = scaler.fit_transform(
    scaling_data
)

scaled_example = pd.DataFrame(
    scaled_values,
    columns=scaling_features,
    index=df.index
)

scaled_example.head(10).style \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '14px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '15px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_6148d th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 15px;
# }
# #T_6148d td {
#   border-color: #2475AC;
#   text-align: center;
# }
# #T_6148d_row0_col0, #T_6148d_row0_col1, #T_6148d_row0_col2, #T_6148d_row1_col0, #T_6148d_row1_col1, #T_6148d_row1_col2, #T_6148d_row2_col0, #T_6148d_row2_col1, #T_6148d_row2_col2, #T_6148d_row3_col0, #T_6148d_row3_col1, #T_6148d_row3_col2, #T_6148d_row4_col0, #T_6148d_row4_col1, #T_6148d_row4_col2, #T_6148d_row5_col0, #T_6148d_row5_col1, #T_6148d_row5_col2, #T_6148d_row6_col0, #T_6148d_row6_col1, #T_6148d_row6_col2, #T_6148d_row7_col0, #T_6148d_row7_col1, #T_6148d_row7_col2, #T_6148d_row8_col0, #T_6148d_row8_col1, #T_6148d_row8_col2, #T_6148d_row9_col0, #T_6148d_row9_col1, #T_6148d_row9_col2 {
#   background-color: #042142;
#   color: #D9F7FF;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 14px;
# }
# ...

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 28px 0;
# letter-spacing:1px;
# ">
# ⚙️ ▶ 4.3 HYPERPARAMETERS VS. PARAMETERS
# </h2>
#
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🧠 [01] PARAMETERS
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Parameters are values that the model <strong>learns automatically during training</strong>. For example, a linear regression model learns its coefficients from the training data.
# </p>
#
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🎛️ [02] HYPERPARAMETERS
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Hyperparameters are settings that are chosen <strong>before training</strong>. They control how the learning algorithm behaves and are not learned directly from the training data.
# </p>
#
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🎮 [03] EXAMPLES FROM DIFFERENT MODELS
# </h3>
#
# <table style="
# width:100%;
# border-collapse:collapse;
# font-family:'Courier New',monospace;
# font-size:15px;
# ">
#
# <tr>
# <th style="
# background:#153C6A;
# color:#3DE0FC;
# border:1px solid #2475AC;
# padding:12px;
# ">
# Model
# </th>
#
# <th style="
# background:#153C6A;
# color:#3DE0FC;
# border:1px solid #2475AC;
# padding:12px;
# ">
# Hyperparameter
# </th>
#
# <th style="
# background:#153C6A;
# color:#3DE0FC;
# border:1px solid #2475AC;
# padding:12px;
# ">
# Purpose
# </th>
# </tr>
#
# <tr>
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Random Forest
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#E977F5;font-weight:bold;">
# max_depth
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Controls the maximum depth of each tree.
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# k-NN
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#E977F5;font-weight:bold;">
# k
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Controls the number of neighbors considered.
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Ridge
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#E977F5;font-weight:bold;">
# alpha
# </td>
#
# <td style="border:1px solid #2475AC;padding:12px;color:#D9F7FF;">
# Controls the strength of regularization.
# </td>
# </tr>
#
# </table>
#
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🎯 [04] WHY DO WE TUNE THEM?
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Different hyperparameter values can produce different model performance. We will use <strong>GridSearchCV</strong> to systematically test possible values and find a configuration that performs well.
# </p>
#
#
# <div style="
# margin-top:28px;
# height:4px;
# width:100%;
# background:repeating-linear-gradient(
# 90deg,
# #3DE0FC 0px,
# #3DE0FC 18px,
# #733E85 18px,
# #733E85 32px,
# transparent 32px,
# transparent 40px
# );
# ">
# </div>
#
# </div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 28px 0;
# letter-spacing:1px;
# ">
# 🔍 ▶ 4.4 GRIDSEARCHCV
# </h2>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🎛️ [01] DEFINE THE PARAMETER GRID
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will define a grid of possible values for the Random Forest hyperparameters <strong>n_estimators</strong> and <strong>max_depth</strong>.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# ⚔️ [02] SEARCH WITH CROSS-VALIDATION
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# GridSearchCV will test every parameter combination using <strong>5-fold cross-validation</strong> and evaluate each one using the <strong>F1 score</strong>.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:28px 0 12px 0;
# ">
# 🏆 [03] SELECT THE BEST MODEL
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# After testing the combinations, we will extract the <strong>best parameters</strong>, the <strong>best cross-validated score</strong>, and the <strong>best estimator</strong>.
# </p>
#
# </div>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, None]
}

print(param_grid)
# Out:
# {'n_estimators': [100, 200], 'max_depth': [5, 10, None]}

# %%
grid_search = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, None],
#                          'n_estimators': [100, 200]},
#              scoring='f1')

# %%
print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest Cross-Validated F1 Score:")
print(round(grid_search.best_score_, 4))
# Out:
# Best Parameters:
# {'max_depth': 10, 'n_estimators': 200}
#
# Best Cross-Validated F1 Score:
# 0.6973

# %%
best_model = grid_search.best_estimator_

print("Best Estimator:")
print(best_model)
# Out:
# Best Estimator:
# RandomForestClassifier(max_depth=10, n_estimators=200, random_state=42)

# %%
grid_results = pd.DataFrame({
    'Metric': [
        'Best n_estimators',
        'Best max_depth',
        'Best CV F1 Score'
    ],
    'Value': [
        grid_search.best_params_['n_estimators'],
        grid_search.best_params_['max_depth'],
        round(grid_search.best_score_, 4)
    ]
})

grid_results.style \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '14px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '15px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_7e32f th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 15px;
# }
# #T_7e32f td {
#   border-color: #2475AC;
#   text-align: center;
# }
# #T_7e32f_row0_col0, #T_7e32f_row0_col1, #T_7e32f_row1_col0, #T_7e32f_row1_col1, #T_7e32f_row2_col0, #T_7e32f_row2_col1 {
#   background-color: #042142;
#   color: #D9F7FF;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 14px;
# }
# </style>
# <table id="T_7e32f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e32f_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_7e32f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e32f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e32f_row0_col0" class="data row0 col0" >Best n_estimators</td>
# ...

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:22px 28px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 14px 0;
# ">
# ⚡ GRID SEARCH COST
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0 0 14px 0;
# ">
# The computational cost of <strong>GridSearchCV</strong> increases as the number of hyperparameter combinations grows. For example, our grid has <strong>2 × 3 = 6 combinations</strong>, and with <strong>5-fold cross-validation</strong>, this requires <strong>30 model fits</strong>.
# </p>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# For much larger search spaces, <strong style="color:#3DE0FC;">RandomizedSearchCV</strong> can be more efficient because it tests a selected number of combinations instead of evaluating every possible combination.
# </p>
#
# <div style="
# margin-top:20px;
# height:3px;
# width:100%;
# background:repeating-linear-gradient(
# 90deg,
# #3DE0FC 0px,
# #3DE0FC 18px,
# #733E85 18px,
# #733E85 32px,
# transparent 32px,
# transparent 40px
# );
# ">
# </div>
#
# </div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 28px 0;
# letter-spacing:1px;
# ">
# 🧪 ▶ HANDS-ON LAB
# </h2>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0 0 24px 0;
# ">
# In this lab, we will apply feature engineering and hyperparameter tuning to the <strong>Video Game Sales & Ratings</strong> dataset and evaluate whether tuning improves the Random Forest model.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:24px 0 10px 0;
# ">
# 🎮 [STEP 01] CREATE ENGINEERED FEATURES
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Create at least two new features and justify why they may provide useful information to the model.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:24px 0 10px 0;
# ">
# ⚙️ [STEP 02] DEFINE THE HYPERPARAMETER GRID
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Use the <strong>Random Forest Classifier</strong> from Week 3 and define a grid of possible hyperparameter values.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:24px 0 10px 0;
# ">
# 🔍 [STEP 03] RUN GRIDSEARCHCV
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Run <strong>GridSearchCV</strong> with <strong>5-fold cross-validation</strong> and record the best parameters and score.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:24px 0 10px 0;
# ">
# 🏆 [STEP 04] COMPARE TUNED VS. BASELINE
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Compare the tuned model's cross-validated score with the untuned baseline from Week 3.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:24px 0 10px 0;
# ">
# 🧠 [STEP 05] FIND WHAT MATTERED MOST
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# Identify which engineered feature was most useful and which hyperparameter had the greatest impact on the model's performance.
# </p>
#
# <div style="
# margin-top:28px;
# height:4px;
# width:100%;
# background:repeating-linear-gradient(
# 90deg,
# #3DE0FC 0px,
# #3DE0FC 18px,
# #733E85 18px,
# #733E85 32px,
# transparent 32px,
# transparent 40px
# );
# ">
# </div>
#
# </div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 24px 0;
# letter-spacing:1px;
# ">
# 🎮 ▶ STEP 01 — CREATE ENGINEERED FEATURES
# </h2>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 🧩 [01] CREATE NEW FEATURES
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will create at least two new features from the existing gaming data to provide more meaningful information for the model.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 🎯 [02] WHY THESE FEATURES?
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# <strong>Total_Regional_Sales</strong> will combine sales from different regions into one feature, while <strong>Game_Age</strong> will represent how old each game is based on its release year.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# ⚙️ [03] PREPARE THE FEATURES
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# These engineered features will later be included with the other processed features when preparing the data for the <strong>Decision Tree Classifier</strong>.
# </p>
#
# <div style="
# margin-top:24px;
# height:4px;
# width:100%;
# background:repeating-linear-gradient(
# 90deg,
# #3DE0FC 0px,
# #3DE0FC 18px,
# #733E85 18px,
# #733E85 32px,
# transparent 32px,
# transparent 40px
# );
# ">
# </div>
#
# </div>

# %%
from sklearn.tree import DecisionTreeClassifier

param_grid = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10]
}

# %%
engineered_features = df[
    [
        'Name',
        'Total_Regional_Sales',
        'Game_Age',
        'Average_Score'
    ]
].head(10)

engineered_features.style \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '14px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '15px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_11557 th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 15px;
# }
# #T_11557 td {
#   border-color: #2475AC;
#   text-align: center;
# }
# ...

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 24px 0;
# letter-spacing:1px;
# ">
# ⚙️ ▶ STEP 02 — DEFINE THE HYPERPARAMETER GRID
# </h2>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 🌳 [01] CHOOSE THE MODEL
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will use the <strong>Decision Tree Classifier</strong> from Week 3 and tune its hyperparameters to find a better configuration.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 🎛️ [02] DEFINE THE SEARCH SPACE
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will test different values for <strong>max_depth</strong> and <strong>min_samples_split</strong> to see which combination produces the best model performance.
# </p>
#
# </div>

# %%
from sklearn.tree import DecisionTreeClassifier

baseline_model = DecisionTreeClassifier(
    random_state=42
)

# %%
param_grid = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10]
}

print(param_grid)
# Out:
# {'max_depth': [3, 5, 10, None], 'min_samples_split': [2, 5, 10]}

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 24px 0;
# letter-spacing:1px;
# ">
# 🔍 ▶ STEP 03 — RUN GRIDSEARCHCV
# </h2>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# ⚔️ [01] RUN 5-FOLD CROSS-VALIDATION
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will use <strong>GridSearchCV</strong> with <strong>5-fold cross-validation</strong> to test every hyperparameter combination and evaluate them using the F1 score.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 🏆 [02] FIND THE BEST CONFIGURATION
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# After the search is complete, we will retrieve the best hyperparameters, the best cross-validated F1 score, and the best estimator.
# </p>
#
# </div>

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(
    estimator=DecisionTreeClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 10, None],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='f1')

# %%
print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest CV F1 Score:")
print(round(grid_search.best_score_, 4))
# Out:
# Best Parameters:
# {'max_depth': 10, 'min_samples_split': 2}
#
# Best CV F1 Score:
# 0.6967

# %%
best_model = grid_search.best_estimator_

print("Best Estimator:")
print(best_model)
# Out:
# Best Estimator:
# DecisionTreeClassifier(max_depth=10, random_state=42)

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 24px 0;
# letter-spacing:1px;
# ">
# 🏆 ▶ STEP 04 — COMPARE TUNED VS. BASELINE
# </h2>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# ⚔️ [01] TRAIN THE BASELINE
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will evaluate the untuned <strong>Decision Tree</strong> using the same 5-fold cross-validation and F1 score.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 📊 [02] COMPARE THE SCORES
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will compare the baseline score with the best cross-validated score returned by <strong>GridSearchCV</strong>.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 🎯 [03] CHECK THE IMPROVEMENT
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will calculate the difference between the tuned and baseline scores to see whether hyperparameter tuning improved the model.
# </p>
#
# </div>

# %%
from sklearn.model_selection import cross_val_score

baseline_scores = cross_val_score(
    baseline_model,
    X_train,
    y_train,
    cv=5,
    scoring='f1'
)

baseline_score = baseline_scores.mean()

print("Baseline CV F1 Score:", round(baseline_score, 4))
# Out:
# Baseline CV F1 Score: 0.6445

# %%
tuned_score = grid_search.best_score_

improvement = tuned_score - baseline_score

print("Baseline CV F1 Score:", round(baseline_score, 4))
print("Tuned CV F1 Score:", round(tuned_score, 4))
print("Improvement:", round(improvement, 4))
# Out:
# Baseline CV F1 Score: 0.6445
# Tuned CV F1 Score: 0.6967
# Improvement: 0.0523

# %%
comparison_results = pd.DataFrame({
    'Model': [
        'Untuned Decision Tree',
        'Tuned Decision Tree'
    ],
    'CV F1 Score': [
        baseline_score,
        tuned_score
    ],
    'Improvement': [
        0,
        improvement
    ]
})

comparison_results.style \
    .format({
        'CV F1 Score': '{:.4f}',
        'Improvement': '{:.4f}'
    }) \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '14px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '15px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_12f07 th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 15px;
# }
# #T_12f07 td {
#   border-color: #2475AC;
#   text-align: center;
# }
# #T_12f07_row0_col0, #T_12f07_row0_col1, #T_12f07_row0_col2, #T_12f07_row1_col0, #T_12f07_row1_col1, #T_12f07_row1_col2 {
#   background-color: #042142;
#   color: #D9F7FF;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 14px;
# }
# </style>
# <table id="T_12f07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12f07_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_12f07_level0_col1" class="col_heading level0 col1" >CV F1 Score</th>
#       <th id="T_12f07_level0_col2" class="col_heading level0 col2" >Improvement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12f07_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#042142 0%,#153C6A 100%);
# border:2px solid #2475AC;
# border-radius:20px;
# padding:26px 30px;
# color:#FFFFFF;
# overflow:hidden;
# box-sizing:border-box;
# width:100%;
# ">
#
# <h2 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#3DE0FC;
# font-size:26px;
# font-weight:700;
# line-height:1.6;
# margin:0 0 24px 0;
# letter-spacing:1px;
# ">
# 🧠 ▶ STEP 05 — WHAT MATTERED MOST?
# </h2>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 🧩 [01] FEATURE IMPORTANCE
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will examine the feature importance values from the tuned Decision Tree to identify which features contributed most to the model's predictions.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# ⚙️ [02] BEST HYPERPARAMETERS
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# We will review the best hyperparameters selected by <strong>GridSearchCV</strong> and use them to understand which settings produced the strongest result.
# </p>
#
# <h3 style="
# font-family:'Press Start 2P','Courier New',monospace;
# color:#E977F5;
# font-size:18px;
# font-weight:700;
# line-height:1.6;
# margin:22px 0 12px 0;
# ">
# 🏆 [03] FINAL OBSERVATION
# </h3>
#
# <p style="
# font-family:'Courier New',monospace;
# font-size:17px;
# line-height:1.8;
# color:#D9F7FF;
# margin:0;
# ">
# The most important engineered feature and the selected hyperparameter configuration will be documented based on the actual results from the model.
# </p>
#
# </div>

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': best_model.feature_importances_
}).sort_values(
    by='Importance',
    ascending=False
)

feature_importance.head(10).style \
    .format({'Importance': '{:.4f}'}) \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '14px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '15px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_00c00 th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 15px;
# }
# #T_00c00 td {
#   border-color: #2475AC;
#   text-align: center;
# }
# #T_00c00_row0_col0, #T_00c00_row0_col1, #T_00c00_row1_col0, #T_00c00_row1_col1, #T_00c00_row2_col0, #T_00c00_row2_col1, #T_00c00_row3_col0, #T_00c00_row3_col1, #T_00c00_row4_col0, #T_00c00_row4_col1, #T_00c00_row5_col0, #T_00c00_row5_col1, #T_00c00_row6_col0, #T_00c00_row6_col1, #T_00c00_row7_col0, #T_00c00_row7_col1, #T_00c00_row8_col0, #T_00c00_row8_col1, #T_00c00_row9_col0, #T_00c00_row9_col1 {
#   background-color: #042142;
#   color: #D9F7FF;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 14px;
# }
# </style>
# <table id="T_00c00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00c00_level0_col0" class="col_heading level0 col0" >Feature</th>
# ...

# %%
top_feature = feature_importance.iloc[0]

print("Most Important Feature:", top_feature['Feature'])
print("Importance:", round(top_feature['Importance'], 4))
# Out:
# Most Important Feature: Critic_Score
# Importance: 0.2479

# %%
print("Winning Hyperparameters:")
print(grid_search.best_params_)
# Out:
# Winning Hyperparameters:
# {'max_depth': 10, 'min_samples_split': 2}

# %%
final_summary = pd.DataFrame({
    'Result': [
        'Most Important Feature',
        'Best Hyperparameters',
        'Baseline CV F1',
        'Tuned CV F1',
        'Improvement'
    ],
    'Value': [
        top_feature['Feature'],
        str(grid_search.best_params_),
        round(baseline_score, 4),
        round(tuned_score, 4),
        round(improvement, 4)
    ]
})

final_summary.style \
    .set_properties(**{
        'background-color': '#042142',
        'color': '#D9F7FF',
        'border-color': '#2475AC',
        'text-align': 'center',
        'font-size': '14px'
    }) \
    .set_table_styles([
        {
            'selector': 'th',
            'props': [
                ('background-color', '#153C6A'),
                ('color', '#3DE0FC'),
                ('font-weight', 'bold'),
                ('border-color', '#2475AC'),
                ('text-align', 'center'),
                ('font-size', '15px')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border-color', '#2475AC'),
                ('text-align', 'center')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_3647d th {
#   background-color: #153C6A;
#   color: #3DE0FC;
#   font-weight: bold;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 15px;
# }
# #T_3647d td {
#   border-color: #2475AC;
#   text-align: center;
# }
# #T_3647d_row0_col0, #T_3647d_row0_col1, #T_3647d_row1_col0, #T_3647d_row1_col1, #T_3647d_row2_col0, #T_3647d_row2_col1, #T_3647d_row3_col0, #T_3647d_row3_col1, #T_3647d_row4_col0, #T_3647d_row4_col1 {
#   background-color: #042142;
#   color: #D9F7FF;
#   border-color: #2475AC;
#   text-align: center;
#   font-size: 14px;
# }
# </style>
# <table id="T_3647d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3647d_level0_col0" class="col_heading level0 col0" >Result</th>
#       <th id="T_3647d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3647d_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
print("Baseline CV F1 Score:", round(baseline_score, 4))
print("Tuned CV F1 Score:", round(tuned_score, 4))
# Out:
# Baseline CV F1 Score: 0.6445
# Tuned CV F1 Score: 0.6967
