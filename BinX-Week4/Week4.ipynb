# %% [markdown]
# <!-- MAIN FLOW -->
#
# <div style="
# background:linear-gradient(145deg,#FFFFFF 0%,#F8FAFC 100%);
# border:1px solid #E2E8F0;
# border-radius:24px;
# padding:30px;
# box-shadow:0 12px 35px rgba(15,23,42,0.06);
# font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
# text-align:center;
# font-size:11px;
# font-weight:800;
# letter-spacing:3px;
# color:#64748B;
# margin-bottom:10px;
# text-transform:uppercase;
# ">
# BINX TECH • WEEK 04
# </div>
#
# <div style="
# text-align:center;
# font-size:22px;
# font-weight:800;
# color:#0F172A;
# margin-bottom:6px;
# ">
# Evaluation → Tuning → Pipelines
# </div>
#
# <div style="
# text-align:center;
# font-size:13px;
# color:#94A3B8;
# margin-bottom:25px;
# ">
# From model evaluation to a trustworthy end-to-end workflow
# </div>
#
# <!-- ROOT -->
#
# <div style="
# width:100%;
# max-width:390px;
# margin:0 auto;
# background:linear-gradient(135deg,#EFF6FF,#F0F9FF);
# border:2px solid #BFDBFE;
# border-radius:18px;
# padding:21px;
# text-align:center;
# box-sizing:border-box;
# box-shadow:0 8px 20px rgba(37,99,235,0.08);
# ">
#
# <div style="font-size:30px;">🧠</div>
#
# <div style="
# font-size:20px;
# font-weight:800;
# color:#1E3A8A;
# margin-top:7px;
# ">
# Build a Trustworthy Model
# </div>
#
# <div style="
# font-size:13px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Evaluate · Diagnose · Engineer · Tune · Package
# </div>
#
# </div>
#
# <!-- CONNECTOR -->
#
# <div style="
# width:2px;
# height:30px;
# background:linear-gradient(#CBD5E1,#E2E8F0);
# margin:0 auto;
# "></div>
#
# <!-- DAY CARDS -->
#
# <div style="
# display:flex;
# justify-content:center;
# align-items:stretch;
# gap:13px;
# flex-wrap:wrap;
# ">
#
# <!-- DAY 1 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:linear-gradient(145deg,#ECFEFF,#F0FDFA);
# border:1px solid #A5F3FC;
# border-radius:17px;
# padding:19px;
# text-align:center;
# box-sizing:border-box;
# box-shadow:0 7px 18px rgba(8,145,178,0.06);
# ">
#
# <div style="font-size:27px;">📂</div>
#
# <div style="
# display:inline-block;
# margin-top:8px;
# padding:4px 9px;
# border-radius:20px;
# background:#CFFAFE;
# font-size:10px;
# font-weight:800;
# letter-spacing:1px;
# color:#155E75;
# ">
# DAY 01
# </div>
#
# <div style="
# font-size:15px;
# font-weight:750;
# color:#334155;
# margin-top:9px;
# ">
# Train / Validation / Test
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Keep the final test set untouched.
# </div>
#
# </div>
#
# <!-- DAY 2 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:linear-gradient(145deg,#EFF6FF,#F5F9FF);
# border:1px solid #BFDBFE;
# border-radius:17px;
# padding:19px;
# text-align:center;
# box-sizing:border-box;
# box-shadow:0 7px 18px rgba(37,99,235,0.06);
# ">
#
# <div style="font-size:27px;">🔄</div>
#
# <div style="
# display:inline-block;
# margin-top:8px;
# padding:4px 9px;
# border-radius:20px;
# background:#DBEAFE;
# font-size:10px;
# font-weight:800;
# letter-spacing:1px;
# color:#1D4ED8;
# ">
# DAY 02
# </div>
#
# <div style="
# font-size:15px;
# font-weight:750;
# color:#334155;
# margin-top:9px;
# ">
# Cross-Validation
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# 5 folds · mean · standard deviation.
# </div>
#
# </div>
#
# <!-- DAY 3 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:linear-gradient(145deg,#F5F3FF,#FAF9FF);
# border:1px solid #DDD6FE;
# border-radius:17px;
# padding:19px;
# text-align:center;
# box-sizing:border-box;
# box-shadow:0 7px 18px rgba(109,40,217,0.06);
# ">
#
# <div style="font-size:27px;">⚖️</div>
#
# <div style="
# display:inline-block;
# margin-top:8px;
# padding:4px 9px;
# border-radius:20px;
# background:#EDE9FE;
# font-size:10px;
# font-weight:800;
# letter-spacing:1px;
# color:#6D28D9;
# ">
# DAY 03
# </div>
#
# <div style="
# font-size:15px;
# font-weight:750;
# color:#334155;
# margin-top:9px;
# ">
# Bias &amp; Variance
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Diagnose overfitting and underfitting.
# </div>
#
# </div>
#
# <!-- DAY 4 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:linear-gradient(145deg,#FFFBEB,#FEFCE8);
# border:1px solid #FDE68A;
# border-radius:17px;
# padding:19px;
# text-align:center;
# box-sizing:border-box;
# box-shadow:0 7px 18px rgba(161,98,7,0.06);
# ">
#
# <div style="font-size:27px;">🧩</div>
#
# <div style="
# display:inline-block;
# margin-top:8px;
# padding:4px 9px;
# border-radius:20px;
# background:#FEF3C7;
# font-size:10px;
# font-weight:800;
# letter-spacing:1px;
# color:#A16207;
# ">
# DAY 04
# </div>
#
# <div style="
# font-size:15px;
# font-weight:750;
# color:#334155;
# margin-top:9px;
# ">
# Feature Engineering
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Create better features and tune the model.
# </div>
#
# </div>
#
# <!-- DAY 5 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:linear-gradient(145deg,#FFF1F2,#FFF7F8);
# border:1px solid #FECDD3;
# border-radius:17px;
# padding:19px;
# text-align:center;
# box-sizing:border-box;
# box-shadow:0 7px 18px rgba(190,18,60,0.06);
# ">
#
# <div style="font-size:27px;">🔗</div>
#
# <div style="
# display:inline-block;
# margin-top:8px;
# padding:4px 9px;
# border-radius:20px;
# background:#FFE4E6;
# font-size:10px;
# font-weight:800;
# letter-spacing:1px;
# color:#BE123C;
# ">
# DAY 05
# </div>
#
# <div style="
# font-size:15px;
# font-weight:750;
# color:#334155;
# margin-top:9px;
# ">
# Pipeline
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Combine preprocessing and modeling safely.
# </div>
#
# </div>
#
# </div>
#
# <!-- CONNECTOR -->
#
# <div style="
# width:2px;
# height:30px;
# background:linear-gradient(#E2E8F0,#CBD5E1);
# margin:0 auto;
# "></div>
#
# <!-- FINAL RESULT -->
#
# <div style="
# width:100%;
# max-width:540px;
# margin:0 auto;
# background:linear-gradient(135deg,#F0FDF4,#ECFDF5);
# border:2px solid #86EFAC;
# border-radius:18px;
# padding:22px;
# text-align:center;
# box-sizing:border-box;
# box-shadow:0 9px 24px rgba(22,101,52,0.07);
# ">
#
# <div style="font-size:30px;">🚀</div>
#
# <div style="
# font-size:20px;
# font-weight:800;
# color:#166534;
# margin-top:6px;
# ">
# End-to-End Tuned Workflow
# </div>
#
# <div style="
# font-size:13px;
# line-height:1.7;
# color:#64748B;
# margin-top:8px;
# ">
# Feature Engineering
# <span style="color:#94A3B8;"> → </span>
# Cross-Validation
# <span style="color:#94A3B8;"> → </span>
# GridSearchCV
# <span style="color:#94A3B8;"> → </span>
# Pipeline
# </div>
#
# <div style="
# margin-top:14px;
# display:inline-block;
# padding:6px 12px;
# border-radius:20px;
# background:#DCFCE7;
# color:#166534;
# font-size:11px;
# font-weight:800;
# letter-spacing:1px;
# ">
# LEAKAGE-FREE WORKFLOW
# </div>
#
# </div>
#
# </div>
#
# <!-- WEEK TAKEAWAY -->
#
# <div style="
# margin-top:18px;
# background:linear-gradient(145deg,#F8FAFC,#FFFFFF);
# border:1px solid #E2E8F0;
# border-radius:17px;
# padding:22px 24px;
# box-sizing:border-box;
# box-shadow:0 6px 18px rgba(15,23,42,0.035);
# ">
#
# <div style="
# display:flex;
# align-items:center;
# gap:9px;
# margin-bottom:10px;
# ">
#
# <span style="font-size:20px;">💡</span>
#
# <span style="
# font-size:11px;
# font-weight:800;
# letter-spacing:2px;
# color:#64748B;
# text-transform:uppercase;
# ">
# WEEKLY TAKEAWAY </span>
#
# </div>
#
# <div style="
# font-size:15px;
# line-height:1.8;
# color:#475569;
# ">
# The week started with reliable evaluation and gradually built toward
# a complete machine learning workflow. Each day added one layer:
# better evaluation, better diagnosis, better features, better tuning,
# and finally a cleaner, safer, and more reproducible pipeline.
# </div>
#
# </div>
#
# <!-- FINAL STATEMENT -->
#
# <div style="
# margin-top:14px;
# background:linear-gradient(135deg,#E0F2FE 0%,#EEF2FF 100%);
# border:1px solid #BFDBFE;
# border-radius:17px;
# padding:22px 24px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="
# font-size:18px;
# font-weight:800;
# line-height:1.7;
# color:#1E293B;
# ">
# A good model gives predictions.<br>
# <span style="color:#2563EB;">
# A trustworthy workflow gives evidence.
# </span>
# </div>
#
# <div style="
# margin-top:9px;
# font-size:11px;
# letter-spacing:1px;
# font-weight:700;
# color:#64748B;
# ">
# WEEK 04 • EVALUATION • TUNING • PIPELINES
# </div>
#
# </div>
