# %% [markdown]
# <!-- MAIN FLOW -->
#
# <div style="
# background:#FFFFFF;
# border:1px solid #E2E8F0;
# border-radius:20px;
# padding:28px;
# ">
#
# <div style="
# text-align:center;
# font-size:12px;
# font-weight:800;
# letter-spacing:2px;
# color:#64748B;
# margin-bottom:22px;
# ">
# WEEK 04 LEARNING PATH
# </div>
#
#
# <!-- ROOT -->
#
# <div style="
# width:100%;
# max-width:360px;
# margin:0 auto;
# background:#EFF6FF;
# border:2px solid #BFDBFE;
# border-radius:16px;
# padding:20px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="font-size:28px;">🧠</div>
#
# <div style="
# font-size:20px;
# font-weight:800;
# color:#1E3A8A;
# margin-top:7px;
# ">
# Build a Trustworthy Model
# </div>
#
# <div style="
# font-size:13px;
# line-height:1.6;
# color:#64748B;
# margin-top:6px;
# ">
# Evaluate · Diagnose · Improve · Tune · Package
# </div>
#
# </div>
#
#
# <!-- CONNECTOR -->
#
# <div style="
# width:2px;
# height:28px;
# background:#CBD5E1;
# margin:0 auto;
# "></div>
#
#
# <!-- DAY CARDS -->
#
# <div style="
# display:flex;
# justify-content:center;
# align-items:stretch;
# gap:12px;
# flex-wrap:wrap;
# ">
#
#
# <!-- DAY 1 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:#ECFEFF;
# border:2px solid #A5F3FC;
# border-radius:16px;
# padding:18px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="font-size:27px;">📂</div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#155E75;
# margin-top:7px;
# ">
# DAY 1
# </div>
#
# <div style="
# font-size:15px;
# font-weight:700;
# color:#334155;
# margin-top:7px;
# ">
# Train / Validation / Test
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Keep the final test set untouched.
# </div>
#
# </div>
#
#
# <!-- DAY 2 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:#EFF6FF;
# border:2px solid #BFDBFE;
# border-radius:16px;
# padding:18px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="font-size:27px;">🔄</div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#1D4ED8;
# margin-top:7px;
# ">
# DAY 2
# </div>
#
# <div style="
# font-size:15px;
# font-weight:700;
# color:#334155;
# margin-top:7px;
# ">
# Cross-Validation
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# 5 folds · mean · standard deviation.
# </div>
#
# </div>
#
#
# <!-- DAY 3 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:#F5F3FF;
# border:2px solid #DDD6FE;
# border-radius:16px;
# padding:18px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="font-size:27px;">⚖️</div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#6D28D9;
# margin-top:7px;
# ">
# DAY 3
# </div>
#
# <div style="
# font-size:15px;
# font-weight:700;
# color:#334155;
# margin-top:7px;
# ">
# Bias &amp; Variance
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Diagnose overfitting and underfitting.
# </div>
#
# </div>
#
#
# <!-- DAY 4 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:#FFFBEB;
# border:2px solid #FDE68A;
# border-radius:16px;
# padding:18px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="font-size:27px;">🧩</div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#A16207;
# margin-top:7px;
# ">
# DAY 4
# </div>
#
# <div style="
# font-size:15px;
# font-weight:700;
# color:#334155;
# margin-top:7px;
# ">
# Feature Engineering
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Create better features and tune the model.
# </div>
#
# </div>
#
#
# <!-- DAY 5 -->
#
# <div style="
# flex:1 1 165px;
# max-width:190px;
# background:#FFF1F2;
# border:2px solid #FECDD3;
# border-radius:16px;
# padding:18px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="font-size:27px;">🔗</div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#BE123C;
# margin-top:7px;
# ">
# DAY 5
# </div>
#
# <div style="
# font-size:15px;
# font-weight:700;
# color:#334155;
# margin-top:7px;
# ">
# Pipeline
# </div>
#
# <div style="
# font-size:12px;
# line-height:1.6;
# color:#64748B;
# margin-top:7px;
# ">
# Combine preprocessing and modeling safely.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- CONNECTOR -->
#
# <div style="
# width:2px;
# height:30px;
# background:#CBD5E1;
# margin:0 auto;
# "></div>
#
#
# <!-- FINAL RESULT -->
#
# <div style="
# width:100%;
# max-width:520px;
# margin:0 auto;
# background:#F0FDF4;
# border:2px solid #86EFAC;
# border-radius:16px;
# padding:20px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="font-size:29px;">🚀</div>
#
# <div style="
# font-size:19px;
# font-weight:800;
# color:#166534;
# margin-top:6px;
# ">
# End-to-End Tuned Workflow
# </div>
#
# <div style="
# font-size:13px;
# line-height:1.7;
# color:#64748B;
# margin-top:7px;
# ">
# Feature Engineering → Cross-Validation → GridSearchCV → Pipeline
# </div>
#
# </div>
#
# </div>
#
#
# <!-- WEEK TAKEAWAY -->
#
# <div style="
# margin-top:18px;
# background:#F8FAFC;
# border:1px solid #E2E8F0;
# border-radius:16px;
# padding:22px 24px;
# box-sizing:border-box;
# ">
#
# <div style="
# display:flex;
# align-items:center;
# gap:9px;
# margin-bottom:10px;
# ">
#
# <span style="font-size:20px;">💡</span>
#
# <span style="
# font-size:12px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#64748B;
# text-transform:uppercase;
# ">
# WEEKLY TAKEAWAY
# </span>
#
# </div>
#
# <div style="
# font-size:15px;
# line-height:1.8;
# color:#475569;
# ">
# The week started with reliable evaluation and gradually built toward
# a complete machine learning workflow. Each day added one layer:
# better evaluation, better diagnosis, better features, better tuning,
# and finally a cleaner and safer pipeline.
# </div>
#
# </div>
#
#
# <!-- FINAL STATEMENT -->
#
# <div style="
# margin-top:14px;
# background:linear-gradient(135deg,#E0F2FE,#EEF2FF);
# border:1px solid #BFDBFE;
# border-radius:16px;
# padding:20px 24px;
# text-align:center;
# box-sizing:border-box;
# ">
#
# <div style="
# font-size:18px;
# font-weight:800;
# line-height:1.7;
# color:#1E293B;
# ">
# A good model gives predictions.<br>
# <span style="color:#2563EB;">
# A trustworthy workflow gives evidence.
# </span>
# </div>
#
# </div>
