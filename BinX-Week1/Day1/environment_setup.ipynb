# %% [markdown]
# <div style="background-color:#0D1F1A; border-left:7px solid #10B981; padding:25px; border-radius:14px;">
# <h1 style="color:#FFFFFF; font-size:34px; text-shadow:0 0 6px #10B981; margin:0; border-bottom:3px solid #10B981; padding-bottom:8px;">
# 🛠️ AI & ML Course with BinX — Week 1 — Day 1 — Environment Setup
# </h1>
# </div>

# %% [markdown]
# <div style="background-color:#0D1F1A; border-left:7px solid #10B981; padding:20px; border-radius:14px;">
# <h2 style="color:#FFFFFF; font-size:17px; line-height:1.8; margin:0;">
# Hi, my name is Shimaa Habes, and I'm really excited to start this
# journey learning AI and Machine Learning with BinX. Looking forward
# to everything I'll build and learn along the way!
# </h2>
# </div>

# %% [markdown]
# <div style="background-color:#0D1F1A; border-left:5px solid #10B981; padding:15px 20px; border-radius:10px;">
# <h3 style="color:#FFFFFF; font-size:22px; text-shadow:0 0 5px #10B981; margin:0;">
# Verifying the Installed Libraries
# </h3>
# </div>

# %%
import numpy, pandas, matplotlib, jupyter

print("\033[92mNumPy:\033[0m", numpy.__version__)
print("\033[94mPandas:\033[0m", pandas.__version__)
print("\033[93mMatplotlib:\033[0m", matplotlib.__version__)
# Out:
# NumPy: 2.5.1
# Pandas: 3.0.5
# Matplotlib: 3.11.1
