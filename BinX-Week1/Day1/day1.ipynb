# %% [markdown]
# <h1 style="color:#C39BD3; border-bottom: 3px solid #C39BD3; padding-bottom: 8px;">
# AI & ML Course with BinX — Day 1 — Environment Setup
# </h1>

# %% [markdown]
# <blockquote style="border-left: 3px solid #7FB3D5; padding-left: 12px; margin-left: 0;">
# <b>My name is Shimaa Habes and I'm happy to be with you today, thank you so much.</b>
# </blockquote>

# %% [markdown]
# ### <span style="color:#F7DC6F">Verifying the Installed Libraries</span>

# %%
import numpy, pandas, matplotlib, jupyter

print("\033[92mNumPy:\033[0m", numpy.__version__)
print("\033[94mPandas:\033[0m", pandas.__version__)
print("\033[93mMatplotlib:\033[0m", matplotlib.__version__)
# Out:
# NumPy: 2.5.1
# Pandas: 3.0.5
# Matplotlib: 3.11.1
