# %% [markdown]
# <div style="background:linear-gradient(135deg,#17211B,#26352A); padding:30px; border-radius:18px; border:1px solid #84A98C; box-shadow:0 0 20px rgba(132,169,140,0.16);">
#
# <div style="font-size:14px; color:#F4A261; letter-spacing:2px; margin-bottom:10px; font-weight:bold;">
# 📊 EXPLORATORY DATA ANALYSIS
# </div>
#
# <h1 style="color:#F1FAEE; font-size:34px; margin:0; line-height:1.35;">
# 🔎 Week 2 — Day 4 <br>
# <span style="color:#A8DADC;">EDA Part 1: Distributions & Outliers</span>
# </h1>
#
# <div style="height:4px; width:100px; background:linear-gradient(90deg,#84A98C,#F4A261); margin-top:18px; border-radius:5px;"></div>
#
# <p style="color:#D8E2DC; font-size:15px; line-height:1.7; margin:16px 0 0 0;">
# Exploring data distributions, identifying unusual values, and understanding how outliers affect statistical analysis.
# </p>
#
# </div>

# %% [markdown]
# <div style="background:#17211B; border-left:5px solid #84A98C; padding:20px 22px; border-radius:12px; box-shadow:0 0 12px rgba(132,169,140,0.12);">
#
# <h2 style="color:#A8DADC; margin:0 0 12px 0;">
# 🛒 Dataset Overview — E-Commerce Product Performance
# </h2>
#
# <p style="color:#D8E2DC; line-height:1.7; margin:0 0 12px 0;">
# For this EDA session, we will use the
# <b style="color:#F4A261;">E-Commerce Product Performance Dataset</b>
# from Kaggle.
# The dataset contains <b style="color:#F4A261;">2,000 product records</b>
# and <b style="color:#F4A261;">8 columns</b> describing different
# e-commerce product performance metrics.
# </p>
#
# <div style="background:#26352A; border-radius:9px; padding:14px 18px; margin:12px 0;">
#
# <p style="color:#D8E2DC; margin:0; line-height:1.8;">
# <b style="color:#84A98C;">Main variables include:</b>
# <br>
# 💰 Product Price
# <br>
# 🏷️ Discount Rate
# <br>
# ⭐ Product Rating
# <br>
# 👀 Number of Reviews
# <br>
# 📦 Stock Availability
# <br>
# 🚚 Days to Deliver
# <br>
# 🔄 Return Rate
# <br>
# 🗂️ Category ID
# </p>
#
# </div>
#
# <h3 style="color:#F4A261; margin:16px 0 8px 0;">
# 🎯 Why This Dataset?
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.7; margin:0;">
# This dataset is particularly suitable for
# <b style="color:#A8DADC;">EDA Part 1: Distributions & Outliers</b>
# because it contains numerical variables with different distributions,
# including highly skewed values and potential outliers.
# For example,
# <b style="color:#F4A261;">Number of Reviews</b> contains many smaller values
# alongside much larger values, making it useful for exploring
# <b style="color:#A8DADC;">skewness, distributions, and outliers</b>.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.7; margin:12px 0 0 0;">
# The dataset also contains approximately
# <b style="color:#F4A261;">5% missing values per column</b>,
# providing a realistic example of the kinds of imperfections commonly
# found in real-world data.
# </p>
#
# </div>

# %% [markdown]
# <h2 style="color:#A8DADC; border-left:5px solid #84A98C; padding:10px 15px; background:#17211B; border-radius:8px; margin-top:25px;">
# 🔎 4.1 What EDA Is and Why It Comes First
# </h2>
#
# <blockquote style="background:#26352A; border-left:4px solid #F4A261; padding:14px 18px; margin:15px 0; border-radius:8px; color:#D8E2DC; line-height:1.8;">
# Before jumping into any model, I need to actually understand my data first —
# what it looks like, how it's distributed, and where the problems are hiding.
# Skipping this step is probably one of the biggest reasons ML projects fail,
# because a model is only as good as how well you understand what you're feeding it.
# </blockquote>

# %% [markdown]
# <h2 style="color:#A8DADC; border-left:5px solid #84A98C; padding:10px 15px; background:#17211B; border-radius:8px; margin-top:25px;">
# 📊 4.2 Seaborn: Statistical Visualization
# </h2>
#
# <blockquote style="background:#26352A; border-left:4px solid #F4A261; padding:14px 18px; margin:15px 0; border-radius:8px; color:#D8E2DC; line-height:1.8;">
# Seaborn is essentially Matplotlib leveled up for statistical visualization.
# It uses Matplotlib underneath, but simplifies common statistical plots such as
# histograms and box plots. It also works directly with Pandas DataFrames,
# making it easier to explore and visualize our e-commerce product data.
# </blockquote>

# %%
import pandas as pd

df = pd.read_csv("ecommerce_product_performance.csv")

print("Dataset Shape:", df.shape)
display(df.head(10))
# Out:
# Dataset Shape: (2000, 8)
#    Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 0     199.671415       0.177024        4.411071               62.0
# 1     136.173570       0.041467        3.033534              201.0
# 2     214.768854       0.276197        2.866881              479.0
# 3     302.302986       0.094254        4.473473              252.0
# 4     126.584663       0.411845        3.553082              671.0
# 5     126.586304       0.515701        1.874022              303.0
# 6     307.921282       0.634228             NaN              350.0
# 7     226.743473       0.271702        3.366010              330.0
# 8     103.052561       0.161156        5.000000              179.0
# 9     204.256004       0.301962        5.000000              350.0
#
#    Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# 0                 1.0              9.0     0.185116          5.0
# 1                 1.0              3.0     0.384639         10.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("ecommerce_product_performance.csv")

sns.histplot(data=df, x="Number_of_Reviews", color="#84A98C")

plt.title("Distribution of Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# <h2 style="color:#A8DADC; border-left:5px solid #84A98C; padding:10px 15px; background:#17211B; border-radius:8px; margin-top:25px;">
# 📊 4.3 Univariate Analysis
# </h2>
#
# <div style="background:#26352A; border-left:4px solid #F4A261; padding:16px 18px; margin:15px 0; border-radius:8px;">
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0 0 12px 0;">
# <b style="color:#F4A261;">Univariate Analysis</b> focuses on analyzing
# <b style="color:#A8DADC;">one variable at a time</b> to understand its
# distribution and characteristics.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0 0 8px 0;">
# It helps answer questions such as:
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:0;">
# <li>📈 How are the values distributed?</li>
# <li>📦 Are there any outliers?</li>
# <li>📊 How often does each category appear?</li>
# <li>📉 Is the distribution symmetric or skewed?</li>
# </ul>
#
# </div>

# %% [markdown]
# <h3 style="color:#F4A261; border-bottom:2px solid #84A98C; padding-bottom:7px; margin-top:25px;">
# 📊 Common Univariate Plots
# </h3>
#
# <table style="border-collapse:collapse; width:100%; background:#17211B; border-radius:10px; overflow:hidden;">
#
# <tr style="background:#26352A;">
# <th style="border:1px solid #84A98C; padding:10px; color:#A8DADC;">Plot</th>
# <th style="border:1px solid #84A98C; padding:10px; color:#A8DADC;">Seaborn Function</th>
# <th style="border:1px solid #84A98C; padding:10px; color:#A8DADC;">What It Reveals</th>
# </tr>
#
# <tr>
# <td style="border:1px solid #84A98C; padding:10px; color:#F4A261;">📈 Histogram</td>
# <td style="border:1px solid #84A98C; padding:10px; color:#D8E2DC;"><code>sns.histplot()</code></td>
# <td style="border:1px solid #84A98C; padding:10px; color:#D8E2DC;">Shows the distribution of a numeric variable</td>
# </tr>
#
# <tr style="background:#26352A;">
# <td style="border:1px solid #84A98C; padding:10px; color:#F4A261;">📦 Box Plot</td>
# <td style="border:1px solid #84A98C; padding:10px; color:#D8E2DC;"><code>sns.boxplot()</code></td>
# <td style="border:1px solid #84A98C; padding:10px; color:#D8E2DC;">Shows the median, quartiles, and potential outliers</td>
# </tr>
#
# <tr>
# <td style="border:1px solid #84A98C; padding:10px; color:#F4A261;">📊 Count Plot</td>
# <td style="border:1px solid #84A98C; padding:10px; color:#D8E2DC;"><code>sns.countplot()</code></td>
# <td style="border:1px solid #84A98C; padding:10px; color:#D8E2DC;">Shows the frequency of each category</td>
# </tr>
#
# <tr style="background:#26352A;">
# <td style="border:1px solid #84A98C; padding:10px; color:#F4A261;">📉 KDE Plot</td>
# <td style="border:1px solid #84A98C; padding:10px; color:#D8E2DC;"><code>sns.kdeplot()</code></td>
# <td style="border:1px solid #84A98C; padding:10px; color:#D8E2DC;">Shows a smooth estimate of the distribution</td>
# </tr>
#
# </table>

# %% [markdown]
# <h3 style="color:#F4A261; border-left:5px solid #84A98C; padding:10px 15px; background:#17211B; border-radius:8px; margin-top:25px;">
# 💻 Histogram Example
# </h3>
#
# <div style="background:#26352A; border-left:4px solid #A8DADC; padding:16px 18px; margin:15px 0; border-radius:8px;">
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0 0 10px 0;">
# A <b style="color:#F4A261;">histogram</b> displays how numeric values are distributed across different ranges.
# In our e-commerce dataset, it can help us understand variables such as
# <b style="color:#A8DADC;">Product Price</b> or
# <b style="color:#A8DADC;">Number of Reviews</b>.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# It is useful for identifying:
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:8px 0 0 0;">
# <li>📊 Distribution shape</li>
# <li>📉 Skewness</li>
# <li>〰️ Gaps</li>
# <li>⛰️ Peaks</li>
# </ul>
#
# </div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("ecommerce_product_performance.csv")

sns.histplot(
    data=df,
    x="Number_of_Reviews",
    color="#84A98C",
    bins=30
)

plt.title("Distribution of Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #84A98C; padding:18px 20px; border-radius:10px; margin:18px 0;">
#
# <h3 style="color:#A8DADC; margin:0 0 10px 0;">
# ✅ Histogram Explanation
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# The histogram groups numeric values into <b style="color:#F4A261;">bins</b>
# and shows how many observations fall into each range.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# For our <b style="color:#A8DADC;">e-commerce dataset</b>, this helps us quickly
# understand the overall distribution of variables such as
# <b style="color:#F4A261;">Number of Reviews</b> and identify patterns such as
# skewness, concentration, and unusually large values.
# </p>
#
# </div>

# %% [markdown]
# <h3 style="color:#F4A261; border-left:5px solid #84A98C; padding:10px 15px; background:#17211B; border-radius:8px; margin-top:25px;">
# 💻 Box Plot Example
# </h3>
#
# <div style="background:#26352A; border-left:4px solid #A8DADC; padding:16px 18px; margin:15px 0; border-radius:8px;">
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0 0 10px 0;">
# A <b style="color:#F4A261;">box plot</b> summarizes the distribution of a numeric
# variable and makes unusual values easier to identify.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# It displays:
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:8px 0 0 0;">
# <li>📍 <b style="color:#A8DADC;">Median</b></li>
# <li>📦 <b style="color:#A8DADC;">Quartiles</b></li>
# <li>📏 <b style="color:#A8DADC;">Minimum and maximum values</b></li>
# <li>⚠️ <b style="color:#F4A261;">Potential outliers</b></li>
# </ul>
#
# </div>

# %%
sns.boxplot(
    data=df,
    x="Number_of_Reviews",
    color="#84A98C"
)

plt.title("Box Plot of Number of Reviews")
plt.xlabel("Number of Reviews")

plt.show()

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #84A98C; padding:18px 20px; border-radius:10px; margin:18px 0;">
#
# <h3 style="color:#A8DADC; margin:0 0 10px 0;">
# ✅ Box Plot Explanation
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# The line inside the box represents the <b style="color:#F4A261;">median</b>.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# The box represents the <b style="color:#A8DADC;">middle 50%</b> of the data,
# between the first and third quartiles.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# Points outside the whiskers may indicate
# <b style="color:#F4A261;">potential outliers</b>.
# </p>
#
# </div>

# %% [markdown]
# <h3 style="color:#F4A261; border-left:5px solid #84A98C; padding:10px 15px; background:#17211B; border-radius:8px; margin-top:25px;">
# 💻 Count Plot Example
# </h3>
#
# <div style="background:#26352A; border-left:4px solid #A8DADC; padding:16px 18px; margin:15px 0; border-radius:8px;">
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0 0 10px 0;">
# A <b style="color:#F4A261;">count plot</b> displays the frequency of each category
# in a categorical variable.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# It helps identify:
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:8px 0 0 0;">
# <li>📊 <b style="color:#A8DADC;">Most common categories</b></li>
# <li>⚖️ <b style="color:#A8DADC;">Class imbalance</b></li>
# <li>📈 <b style="color:#A8DADC;">Distribution of categorical data</b></li>
# </ul>
#
# </div>

# %%
plt.figure(figsize=(12, 6))

sns.countplot(
    data=df,
    x="Category_ID",
    color="#84A98C"
)

plt.title("Product Count by Category")
plt.xlabel("Category ID")
plt.ylabel("Number of Products")

plt.tight_layout()

plt.show()

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #84A98C; padding:18px 20px; border-radius:10px; margin:18px 0;">
#
# <h3 style="color:#A8DADC; margin:0 0 10px 0;">
# ✅ Count Plot Explanation
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# The count plot shows the <b style="color:#F4A261;">frequency of products</b>
# within each category.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# In our dataset, <b style="color:#A8DADC;">Category_ID</b> represents product
# categories, allowing us to compare how many products belong to each category.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# This plot can also help identify <b style="color:#F4A261;">most common categories</b>
# and detect potential <b style="color:#F4A261;">class imbalance</b>.
# </p>
#
# </div>

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #84A98C; padding:18px 20px; border-radius:10px; margin:18px 0;">
#
# <h3 style="color:#A8DADC; margin:0 0 10px 0;">
# 💻 KDE Plot Example
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0 0 10px 0;">
# A <b style="color:#F4A261;">KDE (Kernel Density Estimation)</b> plot shows
# a smooth estimate of the distribution of a numeric variable.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# It helps us understand:
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:8px 0 0 0;">
# <li>📈 The shape of the distribution</li>
# <li>🎯 Where values are concentrated</li>
# <li>↔️ Possible skewness in the data</li>
# </ul>
#
# </div>

# %%
plt.figure(figsize=(10, 5))

sns.kdeplot(
    data=df,
    x="Product_Price",
    fill=True,
    color="#84A98C"
)

plt.title("KDE Plot of Product Price")
plt.xlabel("Product Price (USD)")
plt.ylabel("Density")

plt.show()

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #84A98C; padding:18px 20px; border-radius:10px; margin:18px 0;">
#
# <h3 style="color:#A8DADC; margin:0 0 10px 0;">
# ✅ KDE Plot Explanation
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# The KDE plot provides a <b style="color:#F4A261;">smooth representation</b>
# of the data distribution.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# The highest points of the curve indicate where values are
# <b style="color:#A8DADC;">most concentrated</b>.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# It helps identify the overall shape of the distribution and makes
# patterns easier to understand than looking at individual data points.
# </p>
#
# </div>

# %% [markdown]
# <h2 style="color:#A8DADC; border-left:5px solid #F4A261; padding:10px 15px; background:#17211B; border-radius:8px; margin-top:30px;">
# ⚠️ 4.4 Outlier Detection with the IQR Method
# </h2>
#
# <div style="background:#26352A; border-left:4px solid #84A98C; padding:16px 18px; margin:15px 0; border-radius:8px;">
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# An <b style="color:#F4A261;">outlier</b> is a value that is significantly
# different from the rest of the data.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 8px 0;">
# Outliers can represent:
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:0;">
# <li>✅ A real rare event</li>
# <li>❌ A data entry mistake</li>
# <li>⚠️ An unusual but important observation</li>
# </ul>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:12px 0 0 0;">
# Finding outliers helps us understand our data before building
# <b style="color:#A8DADC;">Machine Learning models</b>.
# </p>
#
# </div>
#
# <h3 style="color:#F4A261; border-bottom:2px solid #84A98C; padding-bottom:7px; margin-top:25px;">
# 📐 Understanding the IQR Method
# </h3>
#
# <div style="background:#17211B; border:1px solid #84A98C; padding:16px 18px; border-radius:10px; margin:15px 0;">
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0 0 10px 0;">
# The <b style="color:#A8DADC;">Interquartile Range (IQR)</b> measures the spread
# of the middle 50% of the data.
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:0 0 12px 0;">
# <li><b style="color:#F4A261;">Q1</b> → 25th percentile</li>
# <li><b style="color:#F4A261;">Q2</b> → Median (50th percentile)</li>
# <li><b style="color:#F4A261;">Q3</b> → 75th percentile</li>
# </ul>
#
# <div style="background:#26352A; padding:12px 16px; border-radius:8px; text-align:center; margin:10px 0;">
# <p style="color:#A8DADC; font-size:18px; font-weight:bold; margin:0;">
# IQR = Q3 - Q1
# </p>
# </div>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:12px 0 8px 0;">
# A value is considered a potential outlier if it falls:
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:0;">
# <li>⬇️ Below: <b style="color:#F4A261;">Q1 - 1.5 × IQR</b></li>
# <li>⬆️ Above: <b style="color:#F4A261;">Q3 + 1.5 × IQR</b></li>
# </ul>
#
# </div>

# %%
Q1 = df["Number_of_Reviews"].quantile(0.25)
Q3 = df["Number_of_Reviews"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[
    (df["Number_of_Reviews"] < lower_bound) |
    (df["Number_of_Reviews"] > upper_bound)
]

outliers
# Out:
#       Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 48              NaN            NaN        5.000000             1300.0
# 59       247.554513       0.176769             NaN              977.0
# 61       131.434102       0.397173        2.185250             1316.0
# 68       186.163603       0.243699        5.000000             1298.0
# 80       128.032811       0.400997        5.000000             1226.0
# ...             ...            ...             ...                ...
# 1927     121.399578       0.289665        2.073786             1111.0
# 1928     260.095963       0.279210        3.639550             1600.0
# 1934     414.434335       0.214387        1.887149             1030.0
# 1942     176.912694       0.076729        5.000000             1182.0
# 1979     190.705229       0.332031        4.937858             1675.0
#
#       Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# ...

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #84A98C; padding:18px 20px; border-radius:10px; margin:18px 0;">
#
# <h3 style="color:#A8DADC; margin:0 0 10px 0;">
# ✅ IQR Calculation Explanation
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# The <b style="color:#F4A261;">IQR method</b> helps identify values that fall
# far outside the typical range of the data.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# First, we calculate <b style="color:#A8DADC;">Q1</b> and
# <b style="color:#A8DADC;">Q3</b> to understand the spread of the middle
# 50% of the data.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# Then, we calculate the <b style="color:#A8DADC;">lower and upper bounds</b>.
# Any value outside these boundaries is marked as a
# <b style="color:#F4A261;">potential outlier</b>.
# </p>
#
# </div>

# %%
print("\033[91mNumber of outliers:\033[0m", len(outliers))
# Out:
# Number of outliers: 75

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #F4A261; padding:18px 20px; border-radius:10px; margin:18px 0;">
#
# <h3 style="color:#F4A261; margin:0 0 10px 0;">
# 💡 Important Note
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# An outlier is <b style="color:#A8DADC;">a question, not a verdict</b>.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# We should investigate whether the value represents a
# <b style="color:#A8DADC;">real observation</b> or a
# <b style="color:#F4A261;">data error</b> before deciding whether to keep,
# modify, or remove it.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# Outliers should never be <b style="color:#F4A261;">deleted silently</b>.
# </p>
#
# </div>

# %% [markdown]
# <div style="background:linear-gradient(135deg,#17211B,#26352A); padding:24px 28px; border-radius:16px; border:1px solid #84A98C; box-shadow:0 0 18px rgba(132,169,140,0.14); margin-top:30px;">
#
# <div style="font-size:13px; color:#F4A261; letter-spacing:2px; margin-bottom:8px; font-weight:bold;">
# 🧪 HANDS-ON LAB
# </div>
#
# <h2 style="color:#F1FAEE; margin:0; line-height:1.4;">
# Univariate EDA on an E-Commerce Dataset
# </h2>
#
# <div style="height:3px; width:90px; background:#84A98C; margin:14px 0; border-radius:4px;"></div>
#
# <p style="color:#D8E2DC; font-size:15px; line-height:1.8; margin:0;">
# In this lab, we will apply <b style="color:#A8DADC;">Univariate Exploratory Data Analysis (EDA)</b>
# techniques to our e-commerce product performance dataset.
# </p>
#
# <p style="color:#D8E2DC; font-size:15px; line-height:1.8; margin:10px 0 0 0;">
# The goal is to understand the dataset's
# <b style="color:#F4A261;">distributions</b>, detect potential
# <b style="color:#F4A261;">outliers</b>, and discover patterns before applying
# Machine Learning models.
# </p>
#
# </div>

# %% [markdown]
# <h2 style="color:#A8DADC; border-left:5px solid #F4A261; padding:10px 15px; background:#17211B; border-radius:8px;">
# 🔹 Step 1 — Explore Numeric Variables
# </h2>
#
# <div style="background:#26352A; border-left:4px solid #84A98C; padding:16px 18px; margin:15px 0; border-radius:8px;">
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# First, we load the <b style="color:#F4A261;">E-Commerce Product Performance</b>
# dataset and identify its numeric variables.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# Histograms help us understand how variables such as
# <b style="color:#A8DADC;">Product Price</b>,
# <b style="color:#A8DADC;">Number of Reviews</b>, and
# <b style="color:#A8DADC;">Days to Deliver</b> are distributed.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:10px 0 0 0;">
# This gives us an initial view of the data and helps us notice
# <b style="color:#F4A261;">skewness, concentration, gaps, and unusual values</b>.
# </p>
#
# </div>

# %%
numeric_columns = df.select_dtypes(include="number").columns

print("\033[94mNumeric Columns:\033[0m")
print(numeric_columns)
# Out:
# Numeric Columns:
# Index(['Product_Price', 'Discount_Rate', 'Product_Rating', 'Number_of_Reviews',
#        'Stock_Availability', 'Days_to_Deliver', 'Return_Rate', 'Category_ID'],
#       dtype='str')

# %%
numeric_columns = [
    "Product_Price",
    "Discount_Rate",
    "Product_Rating",
    "Number_of_Reviews",
    "Days_to_Deliver",
    "Return_Rate"
]

for column in numeric_columns:
    plt.figure(figsize=(8, 4))

    sns.histplot(
        data=df,
        x=column,
        bins=20,
        color="#84A98C"
    )

    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #F4A261; padding:16px 18px; margin:20px 0; border-radius:10px;">
#
# <h3 style="color:#A8DADC; margin:0 0 8px 0;">
# 📦 Step 2 — Detect Outliers Visually
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# Box plots provide a quick visual way to identify
# <b style="color:#F4A261;">potential outliers</b> in the numeric variables.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:8px 0 0 0;">
# Values outside the whiskers may require further investigation before deciding
# whether they represent unusual observations or data issues.
# </p>
#
# </div>

# %%
for column in numeric_columns:
    plt.figure(figsize=(8, 3))

    sns.boxplot(
        data=df,
        x=column,
        color="#84A98C"
    )

    plt.title(f"Box Plot of {column}")
    plt.xlabel(column)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #F4A261; padding:16px 18px; margin:20px 0; border-radius:10px;">
#
# <h3 style="color:#A8DADC; margin:0 0 8px 0;">
# 📐 Step 3 — Apply IQR Outlier Detection
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# We apply the <b style="color:#F4A261;">IQR method</b> to detect potential
# outliers in the <b style="color:#A8DADC;">Number_of_Reviews</b> variable.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:8px 0 0 0;">
# After detecting potential outliers, we investigate whether they represent
# <b style="color:#A8DADC;">valid product observations</b> or possible data issues.
# </p>
#
# </div>

# %%
column = "Number_of_Reviews"

Q1 = df[column].quantile(0.25)
Q3 = df[column].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[
    (df[column] < lower_bound) |
    (df[column] > upper_bound)
]

print("\033[91mNumber of detected outliers:\033[0m", len(outliers))

outliers.head()
# Out:
# Number of detected outliers: 75
#     Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 48            NaN            NaN         5.00000             1300.0
# 59     247.554513       0.176769             NaN              977.0
# 61     131.434102       0.397173         2.18525             1316.0
# 68     186.163603       0.243699         5.00000             1298.0
# 80     128.032811       0.400997         5.00000             1226.0
#
#     Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# 48                 1.0             22.0     0.321321          9.0
# 59                 1.0             26.0     0.088149          9.0
# 61                 1.0             22.0     0.225413          1.0
# 68                 1.0             11.0     0.159424          5.0
# 80                 0.0             21.0     0.020199          5.0

# %% [markdown]
# <div style="background:#26352A; border-left:5px solid #84A98C; padding:16px 18px; margin:20px 0; border-radius:10px;">
#
# <h3 style="color:#A8DADC; margin:0 0 8px 0;">
# 📊 Step 4 — Analyze Categorical Variables
# </h3>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0;">
# Count plots show how frequently each category appears.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:8px 0 0 0;">
# They help us understand categorical distributions and identify
# <b style="color:#F4A261;">imbalanced or dominant categories</b>.
# </p>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:8px 0 0 0;">
# In this dataset, <b style="color:#A8DADC;">Category_ID</b> and
# <b style="color:#A8DADC;">Stock_Availability</b> are stored as numbers,
# but they represent categorical information.
# </p>
#
# </div>

# %%
categorical_columns = [
    "Category_ID",
    "Stock_Availability"
]

print("\033[94mCategorical Columns:\033[0m")

for col in categorical_columns:
    print("\033[92m✓\033[0m", col)
# Out:
# Categorical Columns:
# ✓ Category_ID
# ✓ Stock_Availability

# %%
category_counts = df["Category_ID"].value_counts().sort_index()

plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    x="Category_ID",
    order=category_counts.index,
    color="#84A98C"
)

plt.title("Product Count by Category")
plt.xlabel("Category ID")
plt.ylabel("Number of Products")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background:linear-gradient(135deg,#17211B,#26352A); padding:24px 28px; border-radius:16px; border:1px solid #84A98C; margin-top:25px;">
#
# <h2 style="color:#A8DADC; margin:0 0 15px 0;">
# 🔹 Step 5 — Data Insights
# </h2>
#
# <div style="height:3px; width:90px; background:#F4A261; margin-bottom:16px; border-radius:4px;"></div>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:0 0 10px 0;">
# After performing EDA, we can summarize the main characteristics of the
# <b style="color:#F4A261;">E-Commerce Product Performance</b> dataset:
# </p>
#
# <ul style="color:#D8E2DC; line-height:2; margin:0;">
# <li>📊 The distributions of numeric variables such as product price, ratings, reviews, and delivery time.</li>
# <li>⚠️ The presence of potential outliers, especially in variables with highly skewed distributions.</li>
# <li>🏷️ The frequency of products across different <b style="color:#A8DADC;">categories</b>.</li>
# <li>🔎 Patterns, skewness, concentration, and unusual observations that may require further investigation.</li>
# </ul>
#
# <p style="color:#D8E2DC; line-height:1.8; margin:15px 0 0 0;">
# EDA gives us a clearer understanding of the data and helps us make better
# decisions about <b style="color:#A8DADC;">preprocessing, feature selection,
# and Machine Learning models</b> before moving to the modeling stage.
# </p>
#
# </div>
