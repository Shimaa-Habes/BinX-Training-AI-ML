# %% [markdown]
# <div style="background:#0B1120; padding:30px; border-radius:6px; border-top:4px solid #38BDF8; border-bottom:4px solid #A78BFA;">
#
# <div style="font-size:14px; color:#38BDF8; letter-spacing:2px; font-weight:bold; margin-bottom:12px;">
# 📈 AI & ML COURSE / BINX
# </div>
#
# <h1 style="color:#F8FAFC; font-size:34px; margin:0; line-height:1.35;">
#
# 🎲 WEEK 2 — DAY 2 <br>
# <span style="color:#A78BFA;">Probability & Distributions</span>
#
# </h1>
#
# <div style="margin-top:20px; padding-top:14px; border-top:1px solid #334155; color:#94A3B8; font-size:15px;">
# Understanding uncertainty, probability, and how data is distributed.
# </div>
#
# </div>

# %% [markdown]
# <div style="background:#111827; border-left:5px solid #A78BFA; padding:16px; border-radius:8px;">
#
# <h3 style="color:#A78BFA; margin:0 0 8px 0;">
# 🤖 AI Assistance Note
# </h3>
#
# <p style="color:#E2E8F0; margin:0; line-height:1.7;">
# I used <b style="color:#38BDF8;">ChatGPT</b> as a learning assistant to help me
# add explanatory notes and comments inside the code.
# Some parts of this lesson were challenging, so these notes were added to make
# the code easier to understand and help me remember the purpose of each step
# when reviewing this notebook in the future.
# </p>
#
# <p style="color:#CBD5E1; margin:10px 0 0 0; line-height:1.7;">
# The goal of using AI was to improve my understanding, organize my learning
# process, and make the code more readable.
# </p>
#
# </div>

# %% [markdown]
# <div style="background:#0B1120; border-left:5px solid #A78BFA; padding:18px; border-radius:10px;">
#
# <h3 style="color:#A78BFA; margin:0 0 10px 0;">
# 🎲 2.1 Probability Basics
# </h3>
#
# <p style="color:#E2E8F0; margin:0; line-height:1.8;">
# <b style="color:#38BDF8;">Probability</b> quantifies uncertainty — and ML models
# fundamentally output probabilities, such as <i>"85% likely to churn"</i>.
# A probability is a number from <b style="color:#34D399;">0 (impossible)</b>
# to <b style="color:#34D399;">1 (certain)</b>.
# When outcomes are equally likely, the probability of an event is calculated
# as the number of favorable outcomes divided by the total number of possible
# outcomes.
# </p>
#
# </div>

# %% [markdown]
# <div style="background:#0B1120; border:1px solid #334155; border-top:4px solid #38BDF8; padding:20px; border-radius:10px;">
#
# <h3 style="color:#38BDF8; margin:0 0 14px 0;">
# 📐 2.2 Core Rules
# </h3>
#
# <table style="border-collapse:collapse; width:100%; color:#E2E8F0;">
#
# <tr>
# <th style="border:1px solid #475569; padding:10px; background:#172033; color:#A78BFA;">
# Rule
# </th>
# <th style="border:1px solid #475569; padding:10px; background:#172033; color:#A78BFA;">
# Statement
# </th>
# <th style="border:1px solid #475569; padding:10px; background:#172033; color:#A78BFA;">
# Meaning
# </th>
# </tr>
#
# <tr>
# <td style="border:1px solid #475569; padding:10px;">
# Complement
# </td>
# <td style="border:1px solid #475569; padding:10px; color:#67E8F9;">
# P(not A) = 1 - P(A)
# </td>
# <td style="border:1px solid #475569; padding:10px;">
# The chance something does NOT happen
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #475569; padding:10px;">
# Addition
# </td>
# <td style="border:1px solid #475569; padding:10px; color:#67E8F9;">
# P(A or B) = P(A) + P(B) - P(A and B)
# </td>
# <td style="border:1px solid #475569; padding:10px;">
# The chance of either event
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #475569; padding:10px;">
# Multiplication (independent)
# </td>
# <td style="border:1px solid #475569; padding:10px; color:#67E8F9;">
# P(A and B) = P(A) × P(B)
# </td>
# <td style="border:1px solid #475569; padding:10px;">
# Both happen, when unrelated
# </td>
# </tr>
#
# </table>
#
# </div>

# %%
p_A = 1 / 2
p_B = 1 / 2



p_not_A = 1 - p_A

print("\033[92mP(not A):\033[0m", p_not_A)



p_A_or_B = p_A + p_B

print("\033[94mP(A or B):\033[0m", p_A_or_B)



p_A_and_B = p_A * p_B

print("\033[93mP(A and B):\033[0m", p_A_and_B)
# Out:
# P(not A): 0.5
# P(A or B): 1.0
# P(A and B): 0.25

# %% [markdown]
# <div style="background:linear-gradient(135deg,#111827,#1E293B); padding:20px; border-radius:14px; border-left:5px solid #22C1C3; box-shadow:0 0 12px rgba(34,193,195,0.15);">
#
# <h2 style="color:#67E8F9; margin:0 0 12px 0;">
# 🎯 2.3 Conditional Probability
# </h2>
#
# <p style="color:#E2E8F0; line-height:1.7; margin:0;">
# Conditional probability, written <b style="color:#FDE68A;">P(A | B)</b>, is the probability of event A
# given that event B has already happened. It is an important concept in
# predictive modeling because many ML predictions can be understood as:
# <b style="color:#67E8F9;">"Given these features, what is the probability of this outcome?"</b>
# </p>
#
# </div>

# %%
p_A_and_B = 12 / 27
p_B = 20 / 2004



p_A_given_B = p_A_and_B / p_B



print("\033[92mP(King | Face Card):\033[0m", p_A_given_B)
# Out:
# P(King | Face Card): 44.53333333333333

# %% [markdown]
# <div style="background:linear-gradient(135deg,#111827,#1E293B); padding:20px; border-radius:14px; border-left:5px solid #A78BFA; box-shadow:0 0 12px rgba(167,139,250,0.15);">
#
# <h2 style="color:#C4B5FD; margin:0 0 12px 0;">
# 🧠 2.4 Bayes' Theorem
# </h2>
#
# <p style="color:#E2E8F0; line-height:1.7; margin:0;">
# Bayes' theorem allows us to reverse a conditional probability by computing
# <b style="color:#FDE68A;">P(A | B)</b> from <b style="color:#67E8F9;">P(B | A)</b>.
# It is an important concept in machine learning and forms the mathematical
# foundation of the <b style="color:#C4B5FD;">Naive Bayes classifier</b>.
# </p>
#
# <p style="color:#CBD5E1; line-height:1.7; margin:12px 0 0 0;">
# It also describes how our belief about an event changes when new evidence
# becomes available.
# </p>
#
# </div>

# %% [markdown]
# <div style="background:#0F172A; border:1px solid #A78BFA; padding:18px; border-radius:10px; text-align:center;">
#
# <h3 style="color:#C4B5FD; margin:0 0 12px 0;">
# 📐 Bayes' Theorem Formula
# </h3>
#
# <p style="color:#F8FAFC; font-size:20px; margin:0;">
# P(A | B) = (P(B | A) × P(A)) / P(B)
# </p>
#
# </div>

# %% [markdown]
# <div style="background:#111827; padding:16px; border-radius:10px; border-left:4px solid #22C1C3;">
#
# <p style="color:#E2E8F0; line-height:1.8; margin:0;">
# 🔹 <b style="color:#FDE68A;">Prior — P(A):</b> What we believed before seeing the evidence.<br>
# 🔹 <b style="color:#67E8F9;">Likelihood — P(B | A):</b> How strongly the evidence supports the event.<br>
# 🔹 <b style="color:#C4B5FD;">Posterior — P(A | B):</b> Our updated belief after considering the evidence.
# </p>
#
# </div>

# %%
p_A = 0.01
p_B_given_A = 0.95
p_B_given_not_A = 0.05



p_not_A = 1 - p_A



p_B = (
    p_B_given_A * p_A
    + p_B_given_not_A * p_not_A
)



p_A_given_B = (
    p_B_given_A * p_A
) / p_B



print("\033[92mPrior P(Disease):\033[0m", p_A)
print("\033[94mLikelihood P(Positive | Disease):\033[0m", p_B_given_A)
print("\033[93mP(Positive Test) Overall:\033[0m", round(p_B, 4))
print("\033[95mPosterior P(Disease | Positive):\033[0m", round(p_A_given_B, 4))
# Out:
# Prior P(Disease): 0.01
# Likelihood P(Positive | Disease): 0.95
# P(Positive Test) Overall: 0.059
# Posterior P(Disease | Positive): 0.161

# %% [markdown]
# <div style="background:linear-gradient(135deg,#111827,#1E293B); padding:20px; border-radius:14px; border-left:5px solid #22C1C3; box-shadow:0 0 12px rgba(34,193,195,0.15);">
#
# <h2 style="color:#67E8F9; margin:0 0 14px 0;">
# 📊 2.5 Common Distributions
# </h2>
#
# <table style="border-collapse:collapse; width:100%; color:#E2E8F0;">
#
# <tr>
# <th style="border:1px solid #22C1C3; padding:10px; color:#FDE68A;">
# Distribution
# </th>
# <th style="border:1px solid #22C1C3; padding:10px; color:#FDE68A;">
# Describes
# </th>
# <th style="border:1px solid #22C1C3; padding:10px; color:#FDE68A;">
# Example
# </th>
# </tr>
#
# <tr>
# <td style="border:1px solid #22C1C3; padding:10px;">
# 🎯 Binomial
# </td>
# <td style="border:1px solid #22C1C3; padding:10px;">
# Number of successes in a fixed number of yes/no trials
# </td>
# <td style="border:1px solid #22C1C3; padding:10px;">
# Number of heads in 10 coin flips
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #22C1C3; padding:10px;">
# 🎲 Uniform
# </td>
# <td style="border:1px solid #22C1C3; padding:10px;">
# Every outcome is equally likely
# </td>
# <td style="border:1px solid #22C1C3; padding:10px;">
# A fair die roll
# </td>
# </tr>
#
# <tr>
# <td style="border:1px solid #22C1C3; padding:10px;">
# 🔔 Normal (Gaussian)
# </td>
# <td style="border:1px solid #22C1C3; padding:10px;">
# Symmetric, bell-shaped data clustered around a mean
# </td>
# <td style="border:1px solid #22C1C3; padding:10px;">
# Human heights, measurement error
# </td>
# </tr>
#
# </table>
#
# <div style="background:#0F172A; border-left:4px solid #F0DA1A; padding:14px; margin-top:16px; border-radius:8px;">
#
# <p style="color:#E2E8F0; line-height:1.7; margin:0;">
# 💡 <b style="color:#F0DA1A;">Important:</b>
# The normal distribution is especially important because many statistical
# methods and machine learning assumptions rely on data being approximately
# normal. Checking the shape of a distribution is therefore an important part
# of Exploratory Data Analysis (EDA).
# </p>
#
# </div>
#
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

normal_data = np.random.normal(loc=0, scale=1, size=1000)

axes[0].hist(
    normal_data,
    bins=30,
    color="#8B5CF6"
)
axes[0].set_title("Normal Distribution")
axes[0].set_xlabel("Value")
axes[0].set_ylabel("Frequency")


binomial_data = np.random.binomial(
    n=10,
    p=0.5,
    size=1000
)

axes[1].hist(
    binomial_data,
    bins=10,
    color="#F97316"
)
axes[1].set_title("Binomial Distribution")
axes[1].set_xlabel("Number of Successes")
axes[1].set_ylabel("Frequency")


uniform_data = np.random.uniform(
    low=0,
    high=1,
    size=1000
)

axes[2].hist(
    uniform_data,
    bins=30,
    color="#FACC15"
)
axes[2].set_title("Uniform Distribution")
axes[2].set_xlabel("Value")
axes[2].set_ylabel("Frequency")


plt.tight_layout()

plt.show()

# %% [markdown]
# <div style="background:linear-gradient(135deg,#111827,#1F2937); padding:22px 26px; border-radius:16px; border:1px solid #8B5CF6; box-shadow:0 0 16px rgba(139,92,246,0.2);">
#
# <h2 style="color:#F9FAFB; margin:0; font-size:28px; line-height:1.4;">
# 🧪 Hands-On Lab: <span style="color:#A78BFA;">Probability & Distributions in Code</span>
# </h2>
#
# <div style="height:3px; width:80px; background:#22D3EE; margin-top:14px; border-radius:5px;"></div>
#
# </div>

# %% [markdown]
# <div style="background-color:#111827; border-left:5px solid #8B5CF6; padding:16px; border-radius:10px;">
#
# <h3 style="color:#8B5CF6; margin:0 0 8px 0;">
# 🪙 Step 1: Simulate 10,000 Coin Flips
# </h3>
#
# <p style="color:#E5E7EB; margin:0; line-height:1.7;">
# We begin by simulating <b style="color:#FACC15;">10,000 coin flips</b> using NumPy.
# Each flip has two possible outcomes — <b style="color:#22D3EE;">Heads</b> or
# <b style="color:#F97316;">Tails</b>. This simulation helps us observe how the
# experimental probabilities approach the expected 50/50 distribution as the
# number of trials increases.
# </p>
#
# </div>

# %%
np.random.seed(42)  

n_flips = 10000

flips = np.random.randint(0, 2, size=n_flips)

proportion_heads = np.mean(flips)

print("\033[92mProportion of Heads:\033[0m", proportion_heads)
print("\033[94mExpected (Theoretical):\033[0m", 0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.random.seed(42)
#       2 n_flips = 10000
#       3
#       4 # 0 = Tails, 1 = Heads
#
# NameError: name 'np' is not defined

# %% [markdown]
# <div style="background-color:#111827; border-left:5px solid #8B5CF6; padding:16px; border-radius:10px;">
#
# <h3 style="color:#A78BFA; margin:0;">
# 📈 Step 2: Sample from a Normal Distribution
# </h3>
#
# </div>

# %%
np.random.seed(42)  

normal_sample = np.random.normal(
    loc=50,
    scale=10,
    size=10000
)

plt.hist(
    normal_sample,
    bins=40,
    color="#8B5CF6"
)

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Sample from a Normal Distribution (Mean = 50, Std = 10)")

plt.show()

print("\033[92mSample Mean:\033[0m", np.mean(normal_sample))
print("\033[94mSample Standard Deviation:\033[0m", np.std(normal_sample))
# Out:
# Sample Mean: 49.97864016631574
# Sample Standard Deviation: 10.034122061299875

# %% [markdown]
# <div style="background-color:#111827; border-left:5px solid #8B5CF6; padding:16px; border-radius:10px;">
#
# <h3 style="color:#A78BFA; margin:0;">
# 🧮 Step 3: Compute a Conditional Probability by Hand and Verify with Simulation
# </h3>
#
# </div>

# %% [markdown]
# <div style="background:linear-gradient(135deg,#111827,#1F2937); padding:20px 24px; border-radius:14px; border:1px solid #8B5CF6; box-shadow:0 0 14px rgba(139,92,246,0.18);">
#
# <h4 style="color:#A78BFA; margin:0 0 12px 0;">
# 🎲 Conditional Probability Scenario
# </h4>
#
# <p style="color:#E5E7EB; line-height:1.7; margin:0;">
# <b style="color:#22D3EE;">Scenario:</b> Rolling two dice.
# Let <b style="color:#A78BFA;">A</b> = "the sum is greater than 8",
# and <b style="color:#A78BFA;">B</b> = "the first die shows a 6".
# </p>
#
# <br>
#
# <p style="color:#CBD5E1; line-height:1.7; margin:0;">
# <b style="color:#FBBF24;">By hand:</b> If the first die shows 6, the second die can be
# 1–6, giving sums of 7, 8, 9, 10, 11, and 12.
# </p>
#
# <p style="color:#CBD5E1; line-height:1.7;">
# Out of these 6 possible outcomes, the sum is greater than 8 in 4 cases:
# <b style="color:#34D399;">9, 10, 11, 12</b>.
# </p>
#
# <div style="background:#1E1B4B; padding:12px 16px; border-radius:10px; border-left:4px solid #22D3EE;">
#
# <p style="color:#F8FAFC; margin:0; font-size:16px;">
# <b style="color:#22D3EE;">Result:</b>
# P(A | B) = 4/6 ≈ <b style="color:#A78BFA;">0.667</b>
# </p>
#
# </div>
#
# </div>

# %%
np.random.seed(42)  

n_rolls = 100000

die1 = np.random.randint(1, 7, size=n_rolls)
die2 = np.random.randint(1, 7, size=n_rolls)

total = die1 + die2

B = (die1 == 6)

A_and_B = (total > 8) & B

p_A_given_B_sim = np.sum(A_and_B) / np.sum(B)

print("\033[92mSimulated P(A | B):\033[0m", round(p_A_given_B_sim, 4))
print("\033[94mBy-hand Calculation:\033[0m", round(4 / 6, 4))
# Out:
# Simulated P(A | B): 0.6624
# By-hand Calculation: 0.6667

# %% [markdown]
# <div style="background:linear-gradient(135deg,#111827,#1F2937); padding:22px 26px; border-radius:16px; border:1px solid #8B5CF6; box-shadow:0 0 16px rgba(139,92,246,0.18);">
#
# <h3 style="color:#A78BFA; margin:0 0 16px 0;">
# 📝 Step 4: Documentation of Results
# </h3>
#
# <div style="background:#1E1B4B; padding:14px 16px; border-radius:10px; margin-bottom:12px; border-left:4px solid #22D3EE;">
# <p style="color:#E5E7EB; margin:0; line-height:1.7;">
# <b style="color:#22D3EE;">🪙 Step 1 — Coin Flips:</b>
# With 10,000 simulated flips, the proportion of heads landed very close to
# <b style="color:#A78BFA;">0.5</b>, demonstrating the Law of Large Numbers.
# As the number of trials grows, the observed proportion converges toward the
# true theoretical probability.
# </p>
# </div>
#
# <div style="background:#1E1B4B; padding:14px 16px; border-radius:10px; margin-bottom:12px; border-left:4px solid #8B5CF6;">
# <p style="color:#E5E7EB; margin:0; line-height:1.7;">
# <b style="color:#A78BFA;">📊 Step 2 — Normal Distribution:</b>
# Sampling 10,000 values from a normal distribution with a mean of
# <b style="color:#22D3EE;">50</b> and standard deviation of
# <b style="color:#22D3EE;">10</b> produced a classic bell-shaped histogram.
# The sample mean and standard deviation were also close to the parameters
# used to generate the data.
# </p>
# </div>
#
# <div style="background:#1E1B4B; padding:14px 16px; border-radius:10px; border-left:4px solid #FBBF24;">
# <p style="color:#E5E7EB; margin:0; line-height:1.7;">
# <b style="color:#FBBF24;">🎲 Step 3 — Conditional Probability:</b>
# The simulated probability of rolling a sum greater than 8 given that the
# first die shows a 6 matched the hand-calculated value of
# <b style="color:#A78BFA;">4/6 ≈ 0.667</b> almost exactly, confirming that
# simulation can be used to verify probability calculations.
# </p>
# </div>
#
# </div>
