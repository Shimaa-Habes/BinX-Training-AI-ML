# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF1F2, #FFE4E6);
#     border-radius: 22px;
#     padding: 30px;
#     color: #3F0D12;
#     border: 2px solid #FDA4AF;
#     box-shadow: 0 6px 18px rgba(190, 24, 93, 0.10);
#     text-align: center;
#     margin-bottom: 22px;
# ">
#
# <div style="
#     font-size: 13px;
#     letter-spacing: 2.5px;
#     font-weight: 800;
#     color: #9F1239;
# ">
# BINX TECH • AI & MACHINE LEARNING
# </div>
#
# <div style="
#     font-size: 31px;
#     font-weight: 900;
#     margin-top: 12px;
#     color: #881337;
# ">
# ❤️ Cardiac Data Analysis
# </div>
#
# <div style="
#     font-size: 17px;
#     margin-top: 8px;
#     color: #BE123C;
#     font-weight: 600;
# ">
# Heart Disease Dataset • Machine Learning Practice
# </div>
#
# <div style="
#     margin: 22px auto 0;
#     max-width: 650px;
#     background: rgba(255,255,255,0.65);
#     border: 1px solid #FECDD3;
#     border-radius: 14px;
#     padding: 15px 20px;
#     font-size: 15px;
#     line-height: 1.7;
#     color: #4C0519;
# ">
# Exploring cardiac patient data, understanding important features,
# and applying today's machine learning concepts to a real-world
# healthcare dataset.
# </div>
#
# <div style="
#     margin-top: 18px;
#     display: inline-block;
#     background: #BE123C;
#     color: white;
#     padding: 9px 20px;
#     border-radius: 22px;
#     font-size: 13px;
#     font-weight: 800;
#     letter-spacing: 0.5px;
# ">
# 🫀 HEART DISEASE • DATA ANALYSIS
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7F8, #FFE4E6);
#     border-radius: 20px;
#     padding: 25px;
#     color: #4C0519;
#     border: 2px solid #FDA4AF;
#     margin-bottom: 20px;
# ">
#
# <div style="
#     font-size: 24px;
#     font-weight: 800;
#     color: #9F1239;
#     margin-bottom: 12px;
# ">
# 🫀 Dataset Overview
# </div>
#
# <p style="font-size: 16px; line-height: 1.8;">
# The dataset contains <b>patient-level cardiac information</b> collected for
# heart disease analysis and classification.
# It includes demographic information, clinical measurements,
# and diagnostic test results.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     border-radius: 14px;
#     padding: 16px 20px;
#     border-left: 5px solid #E11D48;
#     margin-top: 15px;
# ">
#
# <b style="color:#BE123C;">📊 Main Information</b>
#
# <ul style="line-height: 1.9; font-size: 15px;">
#     <li><b>Dataset:</b> Heart Disease / Cardiac Dataset</li>
#     <li><b>Target:</b> <code>num</code></li>
#     <li><b>Features:</b> Patient demographics, clinical measurements, and diagnostic results</li>
#     <li><b>Data Types:</b> Numerical, categorical, and boolean features</li>
#     <li><b>Task:</b> Analyze patient characteristics and predict heart disease presence/severity</li>
# </ul>
#
# </div>
#
# <div style="
#     background: #FFE4E6;
#     padding: 14px 18px;
#     border-radius: 12px;
#     margin-top: 16px;
#     font-size: 15px;
#     line-height: 1.7;
# ">
# 🎯 <b>Today's Goal:</b>
# We will inspect the dataset, understand its structure and features,
# prepare the data according to today's topic, and apply the required
# machine learning techniques to extract meaningful results.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7F8, #FFE4E6);
#     border-radius: 20px;
#     padding: 24px;
#     color: #4C0519;
#     border: 2px solid #FDA4AF;
# ">
#
# <div style="
#     font-size: 24px;
#     font-weight: 800;
#     color: #9F1239;
#     margin-bottom: 12px;
# ">
# 📐 3.1 — The Curse of Dimensionality
# </div>
#
# <p style="font-size: 16px; line-height: 1.8;">
# As the number of features increases, machine learning models have to work
# with a much larger and more complex feature space.
# This can make the data more difficult to analyze and visualize.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     border-radius: 14px;
#     padding: 16px 20px;
#     border-left: 5px solid #E11D48;
# ">
#
# <b style="color:#BE123C;">⚠️ Why is high dimensionality a problem?</b>
#
# <ul style="font-size:15px; line-height:1.9;">
#     <li>Data becomes more sparse.</li>
#     <li>Distances between observations become less meaningful.</li>
#     <li>Models can become more prone to overfitting.</li>
#     <li>Visualizing data becomes difficult when there are many features.</li>
#     <li>Models may require more computational resources.</li>
# </ul>
#
# </div>
#
# <div style="
#     background: #FFE4E6;
#     padding: 14px 18px;
#     border-radius: 12px;
#     margin-top: 16px;
#     font-size: 15px;
#     line-height: 1.7;
# ">
#
# 💡 <b>Dimensionality Reduction</b> helps by transforming a large number
# of features into a smaller set of informative components while attempting
# to preserve the important structure and variation in the data.
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7F8, #FFE4E6);
#     border-radius: 20px;
#     padding: 24px;
#     color: #4C0519;
#     border: 2px solid #FDA4AF;
# ">
#
# <div style="
#     font-size: 24px;
#     font-weight: 800;
#     color: #9F1239;
#     margin-bottom: 12px;
# ">
# 🧠 3.2 — What PCA Does
# </div>
#
# <p style="font-size: 16px; line-height: 1.8;">
# <b>Principal Component Analysis (PCA)</b> transforms the original features
# into new features called <b>Principal Components</b>.
# These components are designed to capture the directions of greatest
# variance in the data.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     border-radius: 14px;
#     padding: 16px 20px;
#     border-left: 5px solid #E11D48;
# ">
#
# <b style="color:#BE123C;">🔎 How it works</b>
#
# <ul style="font-size:15px; line-height:1.9;">
#     <li><b>PC1</b> captures the largest amount of variance.</li>
#     <li><b>PC2</b> captures the next largest amount of variance.</li>
#     <li>Each component is a combination of the original features.</li>
#     <li>Keeping fewer components reduces the dimensionality of the dataset.</li>
# </ul>
#
# </div>
#
# <div style="
#     background: #FFE4E6;
#     padding: 14px 18px;
#     border-radius: 12px;
#     margin-top: 16px;
#     font-size: 15px;
#     line-height: 1.7;
# ">
#
# 🎯 <b>Important:</b> PCA is variance-based, so the features should be
# scaled before applying PCA. Otherwise, features with larger numerical
# ranges could dominate the principal components.
#
# </div>
#
# </div>

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Load the Cardiovascular Disease dataset
df = pd.read_csv("heart_disease_uci.csv", sep=";")

# Separate features and target
X = df.drop(columns=["id", "cardio"])
y = df["cardio"]

# Encode categorical features
X = pd.get_dummies(X, drop_first=True)

# Convert all features to numeric values
X = X.astype(float)

# Check missing values
print("Missing values before imputation:")
print(X.isnull().sum().sum())

# Impute missing values using the median
imputer = SimpleImputer(strategy="median")
X_imputed = imputer.fit_transform(X)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

print("\nOriginal feature count:", X.shape[1])
print("Scaled data shape:", X_scaled.shape)
print("Missing values after imputation:", np.isnan(X_scaled).sum())
# Out:
# Missing values before imputation:
# 0
#
# Original feature count: 11
# Scaled data shape: (70000, 11)
# Missing values after imputation: 0

# %%
print("Dataset shape:", df.shape)
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Dataset shape: (70000, 13)
# Number of rows: 70000
# Number of columns: 13

# %%
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# Make sure X is numeric
X_numeric = X.copy()

# Replace infinite values with NaN
X_numeric = X_numeric.replace([np.inf, -np.inf], np.nan)

# Remove columns that are completely empty
X_numeric = X_numeric.dropna(axis=1, how="all")

# Impute remaining missing values
imputer = SimpleImputer(strategy="median")
X_imputed = imputer.fit_transform(X_numeric)

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# Verify that there are no NaN values
print("Missing values after preprocessing:", np.isnan(X_scaled).sum())

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("Original number of features:", X_scaled.shape[1])
print("Reduced number of components:", X_pca.shape[1])
# Out:
# Missing values after preprocessing: 0
# Original number of features: 11
# Reduced number of components: 2

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7F8, #FFE4E6);
#     border-radius: 20px;
#     padding: 24px;
#     color: #4C0519;
#     border: 2px solid #FDA4AF;
# ">
#
# <div style="
#     font-size: 24px;
#     font-weight: 800;
#     color: #9F1239;
#     margin-bottom: 12px;
# ">
# 📊 3.3 — Explained Variance
# </div>
#
# <p style="font-size: 16px; line-height: 1.8;">
# The <b>explained variance ratio</b> tells us how much of the total
# variance in the original dataset is captured by each principal component.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     border-radius: 14px;
#     padding: 16px 20px;
#     border-left: 5px solid #E11D48;
# ">
#
# <b style="color:#BE123C;">📌 Key Idea</b>
#
# <ul style="font-size:15px; line-height:1.9;">
#     <li>Each principal component explains a portion of the total variance.</li>
#     <li>Adding the components gives the cumulative variance retained.</li>
#     <li>A common target is to retain approximately <b>95%</b> of the variance.</li>
# </ul>
#
# </div>
#
# <div style="
#     background: #FFE4E6;
#     padding: 14px 18px;
#     border-radius: 12px;
#     margin-top: 16px;
#     font-size: 15px;
#     line-height: 1.7;
# ">
#
# 🎯 <b>Our goal:</b> Find the smallest number of principal components
# that preserves approximately <b>95% of the variance</b> in the
# Heart Disease dataset.
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7ED, #FFEDD5);
#     border-radius: 20px;
#     padding: 24px;
#     color: #431407;
#     border: 2px solid #FDBA74;
# ">
#
# <div style="
#     font-size: 24px;
#     font-weight: 800;
#     color: #C2410C;
#     margin-bottom: 12px;
# ">
# 🔍 3.4 — When to Use PCA
# </div>
#
# <p style="font-size: 16px; line-height: 1.8; color: #7C2D12;">
# PCA is useful when a dataset contains a large number of features or when many features are correlated.
# It transforms the original features into a smaller set of principal components while preserving most of the important variation in the data.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     padding: 16px 20px;
#     border-radius: 12px;
#     margin-top: 14px;
#     border-left: 5px solid #F97316;
# ">
#
# <b style="color: #C2410C;">✅ PCA can be used to:</b>
#
# <ul style="font-size: 15px; line-height: 1.8; color: #7C2D12;">
# <li>Reduce the number of features and make the dataset smaller.</li>
# <li>Speed up machine learning models by using fewer dimensions.</li>
# <li>Reduce redundant or highly correlated features.</li>
# <li>Make high-dimensional data easier to visualize in 2D or 3D.</li>
# </ul>
#
# </div>
#
# <div style="
#     background: #FFF7ED;
#     padding: 16px 20px;
#     border-radius: 12px;
#     margin-top: 14px;
#     border-left: 5px solid #EA580C;
# ">
#
# <b style="color: #C2410C;">⚠️ Trade-off:</b>
#
# <p style="font-size: 15px; line-height: 1.7; color: #7C2D12;">
# The new principal components are combinations of the original features.
# Therefore, PCA can make the data less interpretable because each component no longer represents one original feature directly.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7ED, #FFEDD5);
#     border-radius: 20px;
#     padding: 24px;
#     color: #431407;
#     border: 2px solid #FDBA74;
# ">
#
# <div style="
#     font-size: 24px;
#     font-weight: 800;
#     color: #C2410C;
# ">
# 🧪 Step 1 — Data Preparation & Scaling
# </div>
#
# <p style="font-size: 16px; line-height: 1.8; color: #7C2D12;">
# Before applying PCA, the Heart Disease dataset must be prepared and standardized.
# Categorical features are encoded, missing values are handled using median imputation,
# and numerical values are scaled using <b>StandardScaler</b>.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     padding: 14px 18px;
#     border-radius: 10px;
#     border-left: 5px solid #F97316;
#     font-size: 15px;
#     line-height: 1.7;
# ">
# 🎯 <b>Goal:</b> Prepare a clean, numeric, and standardized feature matrix that can be safely used by PCA.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7ED, #FFEDD5);
#     border-radius: 20px;
#     padding: 26px;
#     color: #431407;
#     border: 2px solid #FDBA74;
# ">
#
# <div style="
#     font-size: 13px;
#     letter-spacing: 2px;
#     font-weight: 700;
#     color: #EA580C;
# ">
# HANDS-ON PCA LAB
# </div>
#
# <div style="
#     font-size: 27px;
#     font-weight: 800;
#     margin-top: 8px;
#     color: #9A3412;
# ">
# 📊 Step 2 — Cumulative Explained Variance
# </div>
#
# <p style="
#     font-size: 16px;
#     line-height: 1.8;
#     color: #7C2D12;
# ">
# Now that the features have been standardized, we apply PCA to all available
# components and calculate how much variance is retained as the number of
# components increases.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     padding: 16px 20px;
#     border-radius: 12px;
#     border-left: 5px solid #F97316;
# ">
#
# <b style="color: #C2410C;">🎯 What are we looking for?</b>
#
# <p style="font-size: 15px; line-height: 1.7; color: #7C2D12;">
# We will use the cumulative explained variance to determine how many principal
# components are needed to preserve approximately <b>95% of the information</b>
# in the original dataset.
# </p>
#
# </div>
#
# </div>

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

# Fit PCA using all available components
pca_full = PCA()
X_pca_full = pca_full.fit_transform(X_scaled)

# Calculate cumulative explained variance
cumulative_variance = np.cumsum(
    pca_full.explained_variance_ratio_
)

# Plot cumulative explained variance
plt.figure(figsize=(10, 6))

plt.plot(
    range(1, len(cumulative_variance) + 1),
    cumulative_variance,
    marker="o",
    markersize=3
)

plt.axhline(
    y=0.95,
    linestyle="--",
    label="95% Variance"
)

plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA — Cumulative Explained Variance")
plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7ED, #FFEDD5);
#     border-radius: 20px;
#     padding: 26px;
#     color: #431407;
#     border: 2px solid #FDBA74;
# ">
#
# <div style="
#     font-size: 13px;
#     letter-spacing: 2px;
#     font-weight: 700;
#     color: #EA580C;
# ">
# HANDS-ON PCA LAB
# </div>
#
# <div style="
#     font-size: 27px;
#     font-weight: 800;
#     margin-top: 8px;
#     color: #9A3412;
# ">
# 🎯 Step 3 — Choosing the Components
# </div>
#
# <p style="
#     font-size: 16px;
#     line-height: 1.8;
#     color: #7C2D12;
# ">
# The cumulative explained variance curve helps us identify the smallest number
# of principal components required to retain approximately <b>95%</b> of the
# variance in the original dataset.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     padding: 16px 20px;
#     border-radius: 12px;
#     border-left: 5px solid #F97316;
#     font-size: 15px;
#     line-height: 1.7;
# ">
# 📌 <b style="color: #C2410C;">Decision Rule:</b>
# Choose the first component count where cumulative explained variance reaches
# or exceeds <b>95%</b>.
# </div>
#
# </div>

# %%
# Find the number of components needed to retain 95% variance
n_components_95 = np.argmax(cumulative_variance >= 0.95) + 1

variance_95 = cumulative_variance[n_components_95 - 1]

print("Original number of features:", X_scaled.shape[1])
print("Components needed for 95% variance:", n_components_95)
print("Variance retained:", variance_95)
# Out:
# Original number of features: 11
# Components needed for 95% variance: 10
# Variance retained: 0.9591113571195681

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7ED, #FFEDD5);
#     border-radius: 20px;
#     padding: 26px;
#     color: #431407;
#     border: 2px solid #FDBA74;
# ">
#
# <div style="
#     font-size: 13px;
#     letter-spacing: 2px;
#     font-weight: 700;
#     color: #EA580C;
# ">
# HANDS-ON PCA LAB
# </div>
#
# <div style="
#     font-size: 27px;
#     font-weight: 800;
#     margin-top: 8px;
#     color: #9A3412;
# ">
# 🩺 Step 4 — 2D PCA Visualization
# </div>
#
# <p style="
#     font-size: 16px;
#     line-height: 1.8;
#     color: #7C2D12;
# ">
# For visualization, we reduce the standardized Heart Disease dataset to just
# <b>2 principal components</b>. This allows us to represent the high-dimensional
# data on a two-dimensional plot.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     padding: 16px 20px;
#     border-radius: 12px;
#     border-left: 5px solid #F97316;
#     font-size: 15px;
#     line-height: 1.7;
# ">
# 🎯 <b style="color: #C2410C;">Goal:</b>
# Visualize how the patient samples are distributed in the first two principal
# components and use the known target classes to color the points.
# </div>
#
# </div>

# %%
# Reduce the data to 2 principal components
pca_2d = PCA(n_components=2)

X_pca_2d = pca_2d.fit_transform(X_scaled)

print("Original number of features:", X_scaled.shape[1])
print("Reduced number of components:", X_pca_2d.shape[1])
print("Variance retained by 2 components:",
      pca_2d.explained_variance_ratio_.sum())
# Out:
# Original number of features: 11
# Reduced number of components: 2
# Variance retained by 2 components: 0.31986450618965606

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))

scatter = plt.scatter(
    X_pca_2d[:, 0],
    X_pca_2d[:, 1],
    c=y,
    alpha=0.6,
    s=15,
    cmap="tab10"
)

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("Heart Disease Dataset — PCA 2D Projection")

plt.colorbar(scatter, label="Heart Disease Class")
plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #FFF7ED, #FFEDD5);
#     border-radius: 20px;
#     padding: 26px;
#     color: #431407;
#     border: 2px solid #FDBA74;
# ">
#
# <div style="
#     font-size: 13px;
#     letter-spacing: 2px;
#     font-weight: 700;
#     color: #EA580C;
# ">
# HANDS-ON PCA LAB • FINAL RESULTS
# </div>
#
# <div style="
#     font-size: 27px;
#     font-weight: 800;
#     margin-top: 8px;
#     color: #9A3412;
# ">
# 📌 Step 5 — PCA Results & Trade-offs
# </div>
#
# <p style="
#     font-size: 16px;
#     line-height: 1.8;
#     color: #7C2D12;
# ">
# PCA reduced the dimensionality of the Heart Disease dataset while preserving
# most of the variation in the original features.
# </p>
#
# <div style="
#     background: #FFFFFF;
#     padding: 16px 20px;
#     border-radius: 12px;
#     border-left: 5px solid #F97316;
#     margin-top: 14px;
# ">
#
# <b style="color: #C2410C;">📊 What was preserved?</b>
#
# <ul style="font-size: 15px; line-height: 1.8; color: #7C2D12;">
# <li>The original dataset contained <b>21 features</b>.</li>
# <li><b>17 principal components</b> were enough to retain approximately <b>95.83%</b> of the variance.</li>
# <li>The 2D projection allowed us to visualize the dataset using only two principal components.</li>
# </ul>
#
# </div>
#
# <div style="
#     background: #FFF7ED;
#     padding: 16px 20px;
#     border-radius: 12px;
#     border-left: 5px solid #EA580C;
#     margin-top: 14px;
# ">
#
# <b style="color: #C2410C;">⚖️ What did we give up?</b>
#
# <p style="font-size: 15px; line-height: 1.8; color: #7C2D12;">
# The new principal components are combinations of the original medical features,
# so they are harder to interpret directly. Reducing the data to only two
# components also discards some information, since the first two components
# capture only part of the total variance.
# </p>
#
# </div>
#
# <div style="
#     margin-top: 18px;
#     background: #FFEDD5;
#     padding: 16px 20px;
#     border-radius: 12px;
#     border: 1px solid #FDBA74;
#     font-size: 15px;
#     line-height: 1.8;
#     color: #7C2D12;
# ">
#
# 🎯 <b style="color: #C2410C;">Conclusion:</b>
# PCA successfully compressed the 21-dimensional feature space while retaining
# approximately 95.83% of the variance with 17 components. The 2D representation
# was useful for visualization, but it provides less direct interpretability than
# the original medical features.
#
# </div>
#
# </div>
