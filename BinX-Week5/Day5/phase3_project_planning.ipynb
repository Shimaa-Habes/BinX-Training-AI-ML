# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFF9F7 0%,#FFFFFF 48%,#F7FBFC 100%);
#     border:1px solid #E6D5D1;
#     border-radius:28px;
#     padding:42px;
#     margin:20px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 12px 32px rgba(100,40,30,0.08);
#     overflow:hidden;
# ">
#
# <!-- TOP BAR -->
# <div style="
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
#     margin-bottom:30px;
# ">
#
# <div style="
#     color:#8B3A32;
#     font-size:13px;
#     font-weight:800;
#     letter-spacing:2.5px;
# ">
# CARDIO • AI & MACHINE LEARNING
# </div>
#
# <div style="
#     background:#FFF1EE;
#     border:1px solid #F1C7BF;
#     color:#A33A2F;
#     padding:8px 16px;
#     border-radius:20px;
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# WEEK 5 • DAY 5
# </div>
#
# </div>
#
#
# <!-- MAIN HERO -->
# <div style="
#     display:flex;
#     gap:32px;
#     align-items:stretch;
# ">
#
# <div style="
#     flex:1;
#     min-width:0;
#     background:#FFFFFF;
#     border:1px solid #EADAD6;
#     border-radius:22px;
#     padding:30px;
#     box-shadow:0 5px 18px rgba(100,40,30,0.05);
# ">
#
# <div style="
#     color:#A06A63;
#     font-size:12px;
#     font-weight:800;
#     letter-spacing:2px;
#     margin-bottom:11px;
# ">
# PHASE 3 • PROJECT KICKOFF
# </div>
#
# <div style="
#     color:#5C1714;
#     font-size:37px;
#     line-height:1.15;
#     font-weight:900;
# ">
# Cardiac Patient
# <br>
# <span style="color:#C2413A;">Monitoring System</span>
# </div>
#
# <div style="
#     color:#745A57;
#     font-size:15px;
#     line-height:1.75;
#     font-weight:500;
#     margin-top:16px;
#     max-width:650px;
# ">
# Planning the next phase of the project through a structured
# four-sprint roadmap — from the existing baseline to a complete,
# documented, and usable machine-learning solution.
# </div>
#
# <div style="
#     display:flex;
#     gap:10px;
#     margin-top:24px;
# ">
#
# <div style="
#     background:#FFF5F3;
#     border:1px solid #F0D0CA;
#     color:#8F332D;
#     padding:9px 13px;
#     border-radius:10px;
#     font-size:11px;
#     font-weight:800;
# ">
# 📋 PLANNING
# </div>
#
# <div style="
#     background:#F0F9FC;
#     border:1px solid #CBE4EC;
#     color:#17627A;
#     padding:9px 13px;
#     border-radius:10px;
#     font-size:11px;
#     font-weight:800;
# ">
# 🗓️ SPRINTS
# </div>
#
# <div style="
#     background:#F1FAF7;
#     border:1px solid #C9E5DC;
#     color:#176B5D;
#     padding:9px 13px;
#     border-radius:10px;
#     font-size:11px;
#     font-weight:800;
# ">
# 🚀 PHASE 3
# </div>
#
# </div>
#
# </div>
#
#
# <!-- RIGHT PROJECT STATUS -->
# <div style="
#     width:235px;
#     min-width:235px;
#     background:#5C1714;
#     border-radius:22px;
#     padding:27px;
#     box-sizing:border-box;
#     color:white;
#     display:flex;
#     flex-direction:column;
#     justify-content:space-between;
# ">
#
# <div>
#
# <div style="
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:2px;
#     color:#F3B5AE;
# ">
# PROJECT STATUS
# </div>
#
# <div style="
#     font-size:25px;
#     font-weight:900;
#     margin-top:12px;
# ">
# Planning
# </div>
#
# <div style="
#     font-size:12px;
#     line-height:1.6;
#     color:#EBC9C5;
#     margin-top:7px;
# ">
# Preparing the roadmap for the upcoming development sprints.
# </div>
#
# </div>
#
# <div style="
#     margin-top:28px;
#     padding-top:18px;
#     border-top:1px solid #7A3935;
# ">
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     margin-bottom:11px;
# ">
#
# <span style="font-size:11px;color:#DDB4B0;">PROJECT</span>
# <span style="font-size:11px;font-weight:800;">CARDIO ML</span>
#
# </div>
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     margin-bottom:11px;
# ">
#
# <span style="font-size:11px;color:#DDB4B0;">PHASE</span>
# <span style="font-size:11px;font-weight:800;">03</span>
#
# </div>
#
# <div style="
#     display:flex;
#     justify-content:space-between;
# ">
#
# <span style="font-size:11px;color:#DDB4B0;">SPRINTS</span>
# <span style="font-size:11px;font-weight:800;">04</span>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- ROADMAP -->
# <div style="
#     margin-top:25px;
#     padding:25px;
#     background:#FFFCFB;
#     border:1px solid #EBDDD8;
#     border-radius:20px;
# ">
#
# <div style="
#     color:#74312C;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:18px;
# ">
# PHASE 3 ROADMAP
# </div>
#
# <div style="
#     display:flex;
#     gap:11px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E9CFCB;
#     border-radius:14px;
#     padding:17px;
# ">
#
# <div style="color:#C2413A;font-size:21px;font-weight:900;">01</div>
#
# <div style="
#     color:#6D2722;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Data & Baseline
# </div>
#
# <div style="
#     color:#98716D;
#     font-size:10px;
#     line-height:1.5;
#     margin-top:5px;
# ">
# EDA • Preprocessing • Baseline Model
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #CDE4EC;
#     border-radius:14px;
#     padding:17px;
# ">
#
# <div style="color:#0284A8;font-size:21px;font-weight:900;">02</div>
#
# <div style="
#     color:#155E75;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Model Improvement
# </div>
#
# <div style="
#     color:#668996;
#     font-size:10px;
#     line-height:1.5;
#     margin-top:5px;
# ">
# Feature Engineering • Tuning
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #CDE5DE;
#     border-radius:14px;
#     padding:17px;
# ">
#
# <div style="color:#0F8A78;font-size:21px;font-weight:900;">03</div>
#
# <div style="
#     color:#16665B;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Evaluation
# </div>
#
# <div style="
#     color:#668E87;
#     font-size:10px;
#     line-height:1.5;
#     margin-top:5px;
# ">
# Comparison • Validation • Explainability
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #DADDE3;
#     border-radius:14px;
#     padding:17px;
# ">
#
# <div style="color:#64748B;font-size:21px;font-weight:900;">04</div>
#
# <div style="
#     color:#3F4A5A;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Final Delivery
# </div>
#
# <div style="
#     color:#758294;
#     font-size:10px;
#     line-height:1.5;
#     margin-top:5px;
# ">
# Deployment • Documentation • Testing
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- FOOTER -->
# <div style="
#     margin-top:25px;
#     padding-top:17px;
#     border-top:1px solid #E7D8D4;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#987572;
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:1.4px;
# ">
# PHASE 3 • PROJECT PLANNING
# </div>
#
# <div style="
#     color:#A33A2F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# SPRINT 1 • ROADMAP • ACCEPTANCE CRITERIA
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFFFFF 0%,#FFF9F7 100%);
#     border:1px solid #E6D8D4;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(90,45,35,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #EAE0DD;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF1EE;
#     border:1px solid #F0CFC8;
#     border-radius:14px;
#     font-size:22px;
# ">
# ❤️
# </div>
#
# <div>
#
# <div style="
#     color:#A33A2F;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 01 • PROJECT SELECTION
# </div>
#
# <div style="
#     color:#4F1714;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# Cardiac Patient Monitoring System
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:16px;
#     margin-top:22px;
# ">
#
#
# <div style="
#     flex:1;
#     background:#FFF9F7;
#     border:1px solid #EED8D3;
#     border-radius:17px;
#     padding:21px;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# SELECTED PROJECT
# </div>
#
# <div style="
#     color:#681C18;
#     font-size:21px;
#     font-weight:900;
#     margin-top:8px;
# ">
# CardioML
# </div>
#
# <div style="
#     color:#765F5B;
#     font-size:13px;
#     line-height:1.7;
#     margin-top:7px;
# ">
# An end-to-end machine-learning project focused on
# cardiac patient data, heart disease classification,
# model evaluation, and future deployment.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F4FAFC;
#     border:1px solid #D2E6EC;
#     border-radius:17px;
#     padding:21px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# PHASE 3 PURPOSE
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:21px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Continuous Development
# </div>
#
# <div style="
#     color:#647D86;
#     font-size:13px;
#     line-height:1.7;
#     margin-top:7px;
# ">
# The existing CardioML work will be extended and improved
# through the upcoming Phase 3 sprints rather than starting
# a completely new project.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:20px 22px;
#     background:#F5FAF8;
#     border-left:4px solid #0F766E;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.4px;
#     margin-bottom:7px;
# ">
# 🎯 PROJECT RATIONALE
# </div>
#
# <div style="
#     color:#5F706C;
#     font-size:13px;
#     line-height:1.75;
# ">
# CardioML was selected as the Phase 3 project because it provides
# a practical way to build on the machine-learning work already completed
# during the training. The project can be progressively improved through
# model development, evaluation, deployment, and professional documentation.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     display:flex;
#     gap:12px;
# ">
#
#
# <div style="
#     flex:1;
#     background:#FFF5F3;
#     border:1px solid #F0D0CA;
#     border-radius:13px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#9F332C;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# PROJECT TYPE
# </div>
#
# <div style="
#     color:#71352F;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Machine Learning Classification
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F3F9FC;
#     border:1px solid #CDE3EA;
#     border-radius:13px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# DOMAIN
# </div>
#
# <div style="
#     color:#315F6D;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Cardiac / Healthcare Data
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F3FAF7;
#     border:1px solid #CDE5DC;
#     border-radius:13px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# DEVELOPMENT
# </div>
#
# <div style="
#     color:#356B61;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Phase 3 • Four Sprints
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding-top:16px;
#     border-top:1px solid #E8DEDA;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#927A75;
#     font-size:11px;
#     font-weight:700;
#     letter-spacing:1.2px;
# ">
# PROJECT PLANNING
# </div>
#
# <div style="
#     background:#EAF7F3;
#     color:#176B5D;
#     border:1px solid #BFE1D8;
#     padding:7px 13px;
#     border-radius:15px;
#     font-size:10px;
#     font-weight:900;
# ">
# ● SELECTED FOR PHASE 3
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFFFFF 0%,#F8FBFC 100%);
#     border:1px solid #DCE6E9;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(35,65,75,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #E4EBED;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#EEF7FA;
#     border:1px solid #C9E2E9;
#     border-radius:14px;
#     font-size:22px;
# ">
# 🎯
# </div>
#
# <div>
#
# <div style="
#     color:#176A82;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 02 • PROJECT DEFINITION
# </div>
#
# <div style="
#     color:#293D45;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# Problem Statement
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:22px;
#     padding:22px 24px;
#     background:#FFF9F7;
#     border:1px solid #EED8D3;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.5px;
#     margin-bottom:9px;
# ">
# THE PROBLEM
# </div>
#
# <div style="
#     color:#5B3F3B;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Heart disease is a complex health problem where multiple patient
# characteristics can be related to the presence and severity of
# cardiac disease. Working with these variables manually can make it
# difficult to identify useful patterns and consistently distinguish
# between different patient outcomes.
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:16px;
#     margin-top:18px;
# ">
#
#
# <div style="
#     flex:1;
#     background:#F4FAFC;
#     border:1px solid #D2E6EC;
#     border-radius:17px;
#     padding:21px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# INPUT
# </div>
#
# <div style="
#     color:#315F6D;
#     font-size:18px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Patient Features
# </div>
#
# <div style="
#     color:#6B8088;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Clinical and demographic attributes contained in
# the heart disease dataset.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F3FAF7;
#     border:1px solid #CDE5DC;
#     border-radius:17px;
#     padding:21px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# TARGET
# </div>
#
# <div style="
#     color:#356B61;
#     font-size:18px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Heart Disease Classification
# </div>
#
# <div style="
#     color:#71827E;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Use machine-learning models to learn patterns
# associated with the target outcome.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:18px;
#     padding:20px 22px;
#     background:#F7F8FA;
#     border-left:4px solid #64748B;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#475569;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.4px;
#     margin-bottom:7px;
# ">
# 💡 PROJECT OBJECTIVE
# </div>
#
# <div style="
#     color:#65717D;
#     font-size:13px;
#     line-height:1.75;
# ">
# The objective of CardioML is to develop a reliable machine-learning
# workflow that processes cardiac patient data, identifies meaningful
# patterns, trains classification models, evaluates their performance,
# and prepares the best-performing solution for future deployment.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     display:flex;
#     gap:12px;
# ">
#
#
# <div style="
#     flex:1;
#     background:#FFF5F3;
#     border:1px solid #F0D0CA;
#     border-radius:13px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#9F332C;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# ML TASK
# </div>
#
# <div style="
#     color:#71352F;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Supervised Classification
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F3F9FC;
#     border:1px solid #CDE3EA;
#     border-radius:13px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# DATA
# </div>
#
# <div style="
#     color:#315F6D;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Heart Disease UCI Dataset
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F3FAF7;
#     border:1px solid #CDE5DC;
#     border-radius:13px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# END GOAL
# </div>
#
# <div style="
#     color:#356B61;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Reliable & Deployable Solution
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding-top:16px;
#     border-top:1px solid #E3E9EB;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#829097;
#     font-size:11px;
#     font-weight:700;
#     letter-spacing:1.2px;
# ">
# CARDIOML • PROJECT DEFINITION
# </div>
#
# <div style="
#     color:#176A82;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# PROBLEM → MODEL → EVALUATION
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFFFFF 0%,#FFFDF8 100%);
#     border:1px solid #E6DFD2;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(75,60,40,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #EBE6DE;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF6E8;
#     border:1px solid #EBD9B8;
#     border-radius:14px;
#     font-size:22px;
# ">
# 🏁
# </div>
#
# <div>
#
# <div style="
#     color:#9A6A24;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 03 • PROJECT STANDARD
# </div>
#
# <div style="
#     color:#403A35;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# Definition of Done
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:21px;
#     padding:20px 22px;
#     background:#FFF9EE;
#     border:1px solid #E9DDC6;
#     border-radius:17px;
# ">
#
# <div style="
#     color:#95651F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.5px;
#     margin-bottom:7px;
# ">
# FINAL STANDARD
# </div>
#
# <div style="
#     color:#62584A;
#     font-size:13px;
#     line-height:1.75;
# ">
# CardioML will be considered complete when the machine-learning
# workflow is fully implemented, the final model is evaluated,
# the application is prepared for deployment, and all project
# documentation and repository requirements are completed.
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     flex-wrap:wrap;
#     gap:14px;
#     margin-top:19px;
# ">
#
#
# <div style="
#     flex:1 1 calc(50% - 7px);
#     min-width:280px;
#     background:#FFF7F5;
#     border:1px solid #EED8D2;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 01 • NOTEBOOK
# </div>
#
# <div style="
#     color:#70453E;
#     font-size:15px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Complete ML Workflow
# </div>
#
# <div style="
#     color:#806A63;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# EDA → preprocessing → feature engineering →
# modelling → evaluation
# </div>
#
# </div>
#
#
# <div style="
#     flex:1 1 calc(50% - 7px);
#     min-width:280px;
#     background:#F4FAFC;
#     border:1px solid #D3E6EC;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 02 • MODEL
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:15px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Trained & Evaluated Model
# </div>
#
# <div style="
#     color:#637D86;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Final model selected using appropriate evaluation metrics
# and documented validation results.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1 1 calc(50% - 7px);
#     min-width:280px;
#     background:#F3FAF7;
#     border:1px solid #CDE5DC;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 03 • DEPLOYMENT
# </div>
#
# <div style="
#     color:#176B5D;
#     font-size:15px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Working Application
# </div>
#
# <div style="
#     color:#638078;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# The selected model is integrated into a usable application
# and prepared for public deployment.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1 1 calc(50% - 7px);
#     min-width:280px;
#     background:#F7F7FB;
#     border:1px solid #DDDDEA;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#555A7A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 04 • REPOSITORY
# </div>
#
# <div style="
#     color:#4F536F;
#     font-size:15px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Clean GitHub Repository
# </div>
#
# <div style="
#     color:#6E7188;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Organized project structure • README • requirements.txt •
# model artifacts • reproducible workflow
# </div>
#
# </div>
#
#
# <div style="
#     flex:1 1 100%;
#     background:#FFFBEF;
#     border:1px solid #E8DCA9;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#95721B;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 05 • DOCUMENTATION
# </div>
#
# <div style="
#     color:#80621B;
#     font-size:15px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Technical Write-up & Final Presentation
# </div>
#
# <div style="
#     color:#796A45;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Document the problem, methodology, results, limitations,
# and final conclusions in a clear technical format.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:17px 21px;
#     background:#F2F8F5;
#     border-left:4px solid #0F766E;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# ✓ COMPLETION CHECK
# </div>
#
# <div style="
#     color:#64756F;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# The project is done only when the model, application,
# documentation, and GitHub repository are all ready for final delivery.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding-top:16px;
#     border-top:1px solid #E5DED5;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#8B8075;
#     font-size:11px;
#     font-weight:700;
#     letter-spacing:1.2px;
# ">
# CARDIOML • DEFINITION OF DONE
# </div>
#
# <div style="
#     color:#9A6A24;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# FINAL DELIVERY STANDARD
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFFFFF 0%,#F8FBFC 100%);
#     border:1px solid #DDE6E9;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(35,65,75,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #E5EBED;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#EEF7FA;
#     border:1px solid #C9E2E9;
#     border-radius:14px;
#     font-size:22px;
# ">
# 📋
# </div>
#
# <div>
#
# <div style="
#     color:#176A82;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 04 • SPRINT 1 PLANNING
# </div>
#
# <div style="
#     color:#293D45;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# Sprint 1 Backlog
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:19px 21px;
#     background:#F4F9FB;
#     border:1px solid #D6E6EB;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# SPRINT FOCUS
# </div>
#
# <div style="
#     color:#536D76;
#     font-size:13px;
#     line-height:1.75;
#     margin-top:6px;
# ">
# Establish a reliable foundation for the next development phase by
# reviewing the existing project, validating the data workflow,
# and defining the baseline that future improvements will be measured against.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     display:flex;
#     flex-direction:column;
#     gap:13px;
# ">
#
#
# <!-- TASK 01 -->
#
# <div style="
#     display:flex;
#     gap:17px;
#     align-items:stretch;
# ">
#
# <div style="
#     width:58px;
#     min-width:58px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF5F2;
#     border:1px solid #F0D5CC;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:20px;
#     font-weight:900;
# ">
# 01
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E5E8E8;
#     border-radius:15px;
#     padding:17px 19px;
# ">
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#6D302A;
#     font-size:15px;
#     font-weight:900;
# ">
# Review Project & Dataset
# </div>
#
# <div style="
#     background:#FFF4E8;
#     color:#95651F;
#     border:1px solid #E8D7B8;
#     padding:5px 10px;
#     border-radius:12px;
#     font-size:10px;
#     font-weight:900;
# ">
# 2 H
# </div>
#
# </div>
#
# <div style="
#     color:#77716E;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Review the existing CardioML workflow, dataset structure,
# features, target variable, preprocessing decisions, and previous results.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- TASK 02 -->
#
# <div style="
#     display:flex;
#     gap:17px;
#     align-items:stretch;
# ">
#
# <div style="
#     width:58px;
#     min-width:58px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F2F8FB;
#     border:1px solid #D2E5EB;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:20px;
#     font-weight:900;
# ">
# 02
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E5E8E8;
#     border-radius:15px;
#     padding:17px 19px;
# ">
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:15px;
#     font-weight:900;
# ">
# Validate Data & EDA
# </div>
#
# <div style="
#     background:#EEF7FA;
#     color:#17627A;
#     border:1px solid #CDE2E9;
#     padding:5px 10px;
#     border-radius:12px;
#     font-size:10px;
#     font-weight:900;
# ">
# 2 H
# </div>
#
# </div>
#
# <div style="
#     color:#707B7F;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Confirm data quality, inspect distributions and relationships,
# and document the key findings that affect model development.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- TASK 03 -->
#
# <div style="
#     display:flex;
#     gap:17px;
#     align-items:stretch;
# ">
#
# <div style="
#     width:58px;
#     min-width:58px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F3FAF7;
#     border:1px solid #CFE5DC;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:20px;
#     font-weight:900;
# ">
# 03
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E5E8E8;
#     border-radius:15px;
#     padding:17px 19px;
# ">
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:15px;
#     font-weight:900;
# ">
# Establish Baseline Model
# </div>
#
# <div style="
#     background:#F0F9F6;
#     color:#176B5D;
#     border:1px solid #C9E5DC;
#     padding:5px 10px;
#     border-radius:12px;
#     font-size:10px;
#     font-weight:900;
# ">
# 2 H
# </div>
#
# </div>
#
# <div style="
#     color:#6D7D79;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Train and evaluate a baseline classification model using the
# validated preprocessing pipeline and record its performance metrics.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- TASK 04 -->
#
# <div style="
#     display:flex;
#     gap:17px;
#     align-items:stretch;
# ">
#
# <div style="
#     width:58px;
#     min-width:58px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F7F7FB;
#     border:1px solid #DDDDEA;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#555A7A;
#     font-size:20px;
#     font-weight:900;
# ">
# 04
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E5E8E8;
#     border-radius:15px;
#     padding:17px 19px;
# ">
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#4F536F;
#     font-size:15px;
#     font-weight:900;
# ">
# Document Sprint Results
# </div>
#
# <div style="
#     background:#F5F5FA;
#     color:#555A7A;
#     border:1px solid #DDDDEA;
#     padding:5px 10px;
#     border-radius:12px;
#     font-size:10px;
#     font-weight:900;
# ">
# 1 H
# </div>
#
# </div>
#
# <div style="
#     color:#727587;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Record the completed work, baseline metrics, observations,
# and next-step recommendations in the project documentation.
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
#     padding:17px 20px;
#     background:#FFFBF3;
#     border:1px solid #E9DEC5;
#     border-radius:14px;
# ">
#
# <div>
#
# <div style="
#     color:#95721B;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# ESTIMATED EFFORT
# </div>
#
# <div style="
#     color:#6F6143;
#     font-size:13px;
#     font-weight:800;
#     margin-top:5px;
# ">
# 7 hours • Sprint 1 core tasks
# </div>
#
# </div>
#
# <div style="
#     color:#A33A2F;
#     font-size:12px;
#     font-weight:900;
# ">
# FOUNDATION FIRST
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFFFFF 0%,#F8FBFC 100%);
#     border:1px solid #DDE6E9;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(35,65,75,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #E5EBED;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F0F9F6;
#     border:1px solid #C9E5DC;
#     border-radius:14px;
#     font-size:22px;
# ">
# ✓
# </div>
#
# <div>
#
# <div style="
#     color:#176B5D;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 05 • TASK VALIDATION
# </div>
#
# <div style="
#     color:#293D45;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# Acceptance Criteria
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     color:#63737A;
#     font-size:13px;
#     line-height:1.75;
# ">
# Each Sprint 1 task must meet clear acceptance criteria before it is
# considered complete. The criteria ensure that the work is reproducible,
# documented, reviewed, and ready for the next development stage.
# </div>
#
#
# <div style="
#     display:flex;
#     flex-direction:column;
#     gap:13px;
#     margin-top:21px;
# ">
#
#
# <!-- CRITERION 01 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     background:#FFF9F7;
#     border:1px solid #E9D8D3;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:20px;
#     font-weight:900;
#     min-width:30px;
# ">
# 01
# </div>
#
# <div>
#
# <div style="
#     color:#71322B;
#     font-size:14px;
#     font-weight:900;
# ">
# Notebook Execution
# </div>
#
# <div style="
#     color:#786B67;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# All relevant notebook cells run successfully without errors,
# and the workflow produces reproducible results.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- CRITERION 02 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     background:#F5FAFC;
#     border:1px solid #D4E6EC;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:20px;
#     font-weight:900;
#     min-width:30px;
# ">
# 02
# </div>
#
# <div>
#
# <div style="
#     color:#155E75;
#     font-size:14px;
#     font-weight:900;
# ">
# Results Documented
# </div>
#
# <div style="
#     color:#697B82;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# EDA findings, preprocessing decisions, model results, and important
# observations are explained clearly using Markdown documentation.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- CRITERION 03 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     background:#F4FAF7;
#     border:1px solid #CFE5DC;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:20px;
#     font-weight:900;
#     min-width:30px;
# ">
# 03
# </div>
#
# <div>
#
# <div style="
#     color:#176B5D;
#     font-size:14px;
#     font-weight:900;
# ">
# Metrics Recorded
# </div>
#
# <div style="
#     color:#687B76;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Baseline performance metrics are recorded and will be used as the
# reference point for evaluating improvements in future sprints.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- CRITERION 04 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     background:#F8F8FB;
#     border:1px solid #DDDDEA;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#555A7A;
#     font-size:20px;
#     font-weight:900;
#     min-width:30px;
# ">
# 04
# </div>
#
# <div>
#
# <div style="
#     color:#4F536F;
#     font-size:14px;
#     font-weight:900;
# ">
# GitHub Commit
# </div>
#
# <div style="
#     color:#707387;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Completed work is committed to the correct Git branch using a
# clear and descriptive commit message.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- CRITERION 05 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     background:#FFFBF2;
#     border:1px solid #E9DEC4;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#95721B;
#     font-size:20px;
#     font-weight:900;
#     min-width:30px;
# ">
# 05
# </div>
#
# <div>
#
# <div style="
#     color:#80621B;
#     font-size:14px;
#     font-weight:900;
# ">
# Review Ready
# </div>
#
# <div style="
#     color:#756A50;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# The completed task is organized and documented well enough for
# mentor review before being considered fully accepted.
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:21px;
#     padding:18px 21px;
#     background:#F3FAF7;
#     border-left:4px solid #0F766E;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# ✓ ACCEPTANCE RULE
# </div>
#
# <div style="
#     color:#63756F;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# A task is considered accepted only when its implementation,
# results, documentation, and GitHub workflow requirements have
# all been completed.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding-top:16px;
#     border-top:1px solid #E5EBED;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#8A7975;
#     font-size:11px;
#     font-weight:700;
#     letter-spacing:1.2px;
# ">
# SPRINT 1 • QUALITY CHECK
# </div>
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# READY FOR REVIEW
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFFDFC 0%,#F7FBFC 100%);
#     border:1px solid #E2E6E7;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(45,55,60,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #E6EBEC;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF5E8;
#     border:1px solid #EBD8B5;
#     border-radius:14px;
#     font-size:22px;
# ">
# 🎯
# </div>
#
# <div>
#
# <div style="
#     color:#9A6A24;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 06 • SPRINT OBJECTIVE
# </div>
#
# <div style="
#     color:#293D45;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# Sprint 1 Goal
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:22px;
#     padding:25px 26px;
#     background:#FFF9EE;
#     border:1px solid #E9DCC3;
#     border-radius:18px;
#     text-align:center;
# ">
#
# <div style="
#     color:#95721B;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.8px;
# ">
# PRIMARY SPRINT GOAL
# </div>
#
# <div style="
#     color:#554A39;
#     font-size:20px;
#     font-weight:900;
#     line-height:1.6;
#     margin-top:10px;
# ">
# Establish a reliable machine-learning baseline for CardioML
# and define a clear foundation for the upcoming development sprints.
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:14px;
#     margin-top:20px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF7F5;
#     border:1px solid #EBD8D3;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 01 • UNDERSTAND
# </div>
#
# <div style="
#     color:#71352E;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Understand the Data
# </div>
#
# <div style="
#     color:#7B6B67;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Review the dataset, features, target,
# quality, and existing EDA findings.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F5FAFC;
#     border:1px solid #D4E6EC;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 02 • ESTABLISH
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Establish a Baseline
# </div>
#
# <div style="
#     color:#697C84;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Run a reliable baseline model and
# record its evaluation metrics.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F3FAF7;
#     border:1px solid #CFE5DC;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 03 • PREPARE
# </div>
#
# <div style="
#     color:#176B5D;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Prepare for Improvement
# </div>
#
# <div style="
#     color:#687B76;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Identify weaknesses and define the next
# steps for model improvement.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:18px 21px;
#     background:#F4F8F7;
#     border-left:4px solid #0F766E;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# 🏁 SPRINT OUTCOME
# </div>
#
# <div style="
#     color:#63736E;
#     font-size:12px;
#     line-height:1.75;
#     margin-top:5px;
# ">
# By the end of Sprint 1, CardioML should have a validated data workflow,
# a documented baseline model, measurable performance results, and a
# clear starting point for the next sprint.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding-top:16px;
#     border-top:1px solid #E5EBED;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#8A7975;
#     font-size:11px;
#     font-weight:700;
#     letter-spacing:1.2px;
# ">
# CARDIOML • SPRINT 1
# </div>
#
# <div style="
#     color:#9A6A24;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# BASELINE • FOUNDATION • NEXT STEPS
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFFFFF 0%,#F8FAFB 100%);
#     border:1px solid #DDE6E9;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(35,65,75,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #E5EBED;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#EEF7FA;
#     border:1px solid #C9E2E9;
#     border-radius:14px;
#     font-size:22px;
# ">
# 🗺️
# </div>
#
# <div>
#
# <div style="
#     color:#176A82;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 07 • PHASE 3 ROADMAP
# </div>
#
# <div style="
#     color:#293D45;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# CardioML Development Roadmap
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     color:#63737A;
#     font-size:13px;
#     line-height:1.75;
# ">
# The CardioML project will continue to evolve throughout Phase 3.
# Each upcoming week has a defined focus and builds on the previous
# work, gradually moving the project from its current machine-learning
# foundation toward a complete, tested, documented, and deployable solution.
# </div>
#
#
# <div style="
#     display:flex;
#     flex-direction:column;
#     gap:13px;
#     margin-top:22px;
# ">
#
#
# <!-- WEEK 6 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     align-items:stretch;
# ">
#
# <div style="
#     width:82px;
#     min-width:82px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF5F2;
#     border:1px solid #F0D5CC;
#     border-radius:16px;
# ">
#
# <div style="text-align:center;">
#
# <div style="
#     color:#A33A2F;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# WEEK
# </div>
#
# <div style="
#     color:#8F2923;
#     font-size:27px;
#     font-weight:900;
# ">
# 06
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E3E9E8;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# SPRINT 2 • MODEL DEVELOPMENT
# </div>
#
# <div style="
#     color:#4F403D;
#     font-size:16px;
#     font-weight:900;
#     margin-top:6px;
# ">
# Improve the CardioML model
# </div>
#
# <div style="
#     color:#73716F;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Feature engineering • model comparison • hyperparameter tuning •
# cross-validation • performance improvement
# </div>
#
# </div>
#
# </div>
#
#
# <!-- WEEK 7 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     align-items:stretch;
# ">
#
# <div style="
#     width:82px;
#     min-width:82px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F2F8FB;
#     border:1px solid #D2E5EB;
#     border-radius:16px;
# ">
#
# <div style="text-align:center;">
#
# <div style="
#     color:#17627A;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# WEEK
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:27px;
#     font-weight:900;
# ">
# 07
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E3E9E8;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#17627A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# SPRINT 3 • ADVANCED ANALYSIS
# </div>
#
# <div style="
#     color:#3F5F69;
#     font-size:16px;
#     font-weight:900;
#     margin-top:6px;
# ">
# Deepen model analysis and interpretation
# </div>
#
# <div style="
#     color:#6B7D83;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Feature importance • model interpretability • error analysis •
# additional evaluation • extracting meaningful insights
# </div>
#
# </div>
#
# </div>
#
#
# <!-- WEEK 8 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     align-items:stretch;
# ">
#
# <div style="
#     width:82px;
#     min-width:82px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F2FAF7;
#     border:1px solid #CFE5DC;
#     border-radius:16px;
# ">
#
# <div style="text-align:center;">
#
# <div style="
#     color:#176B5D;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# WEEK
# </div>
#
# <div style="
#     color:#176B5D;
#     font-size:27px;
#     font-weight:900;
# ">
# 08
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E3E9E8;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# SPRINT 4 • PRODUCTIZATION
# </div>
#
# <div style="
#     color:#416D64;
#     font-size:16px;
#     font-weight:900;
#     margin-top:6px;
# ">
# Prepare CardioML for deployment
# </div>
#
# <div style="
#     color:#71817D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Finalize the pipeline • save the trained model • build the application
# interface • prepare deployment requirements
# </div>
#
# </div>
#
# </div>
#
#
# <!-- WEEK 9 -->
#
# <div style="
#     display:flex;
#     gap:16px;
#     align-items:stretch;
# ">
#
# <div style="
#     width:82px;
#     min-width:82px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFFBEF;
#     border:1px solid #E8DCA9;
#     border-radius:16px;
# ">
#
# <div style="text-align:center;">
#
# <div style="
#     color:#95721B;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# WEEK
# </div>
#
# <div style="
#     color:#80621B;
#     font-size:27px;
#     font-weight:900;
# ">
# 09
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E3E9E8;
#     border-radius:16px;
#     padding:18px 20px;
# ">
#
# <div style="
#     color:#95721B;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# FINAL DELIVERY
# </div>
#
# <div style="
#     color:#665B3C;
#     font-size:16px;
#     font-weight:900;
#     margin-top:6px;
# ">
# Finalize, document, and present
# </div>
#
# <div style="
#     color:#77705B;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Final testing • README • technical write-up • deployment verification •
# GitHub cleanup • final presentation
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:22px;
#     padding:18px 21px;
#     background:#F4F8F7;
#     border-left:4px solid #0F766E;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# 🏁 FINAL DIRECTION
# </div>
#
# <div style="
#     color:#63736E;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# The roadmap provides a clear progression from model improvement
# to advanced analysis, deployment, and final delivery while keeping
# the CardioML project as the continuous Phase 3 focus.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding-top:16px;
#     border-top:1px solid #E5EBED;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#8A7975;
#     font-size:11px;
#     font-weight:700;
#     letter-spacing:1.2px;
# ">
# CARDIOML • PHASE 3
# </div>
#
# <div style="
#     color:#17627A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# WEEK 6 → WEEK 9
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFFFFF 0%,#F8FAFB 100%);
#     border:1px solid #DDE6E9;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(35,65,75,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #E5EBED;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F3F1FA;
#     border:1px solid #DCD5ED;
#     border-radius:14px;
#     font-size:22px;
# ">
# 🔀
# </div>
#
# <div>
#
# <div style="
#     color:#68528A;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 08 • GITHUB WORKFLOW
# </div>
#
# <div style="
#     color:#293D45;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# Branch & Pull Request Workflow
# </div>
#
# </div>
# </div>
#
#
# <div style="
#     margin-top:20px;
#     color:#63737A;
#     font-size:13px;
#     line-height:1.75;
# ">
#
# To keep the CardioML project organized throughout Phase 3,
# development work will follow a structured GitHub branch and
# pull-request workflow. Each task will be developed separately,
# reviewed, and merged only after the work is complete and documented.
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-top:22px;
#     align-items:stretch;
# ">
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E4DDF0;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#8066A2;
#     font-size:22px;
#     font-weight:900;
# ">
# 01
# </div>
#
# <div style="
#     color:#55436E;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Create Branch
# </div>
#
# <div style="
#     color:#7A7184;
#     font-size:11px;
#     line-height:1.6;
#     margin-top:5px;
# ">
# Create a feature branch for each major task or sprint activity.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #D5E6EC;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#176A82;
#     font-size:22px;
#     font-weight:900;
# ">
# 02
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Develop & Test
# </div>
#
# <div style="
#     color:#687F87;
#     font-size:11px;
#     line-height:1.6;
#     margin-top:5px;
# ">
# Implement the task, run the notebook, and verify that the results are correct.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #D7E7E1;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:22px;
#     font-weight:900;
# ">
# 03
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Commit Changes
# </div>
#
# <div style="
#     color:#66807B;
#     font-size:11px;
#     line-height:1.6;
#     margin-top:5px;
# ">
# Commit completed work using a clear and descriptive commit message.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E8DFC2;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#9A761D;
#     font-size:22px;
#     font-weight:900;
# ">
# 04
# </div>
#
# <div style="
#     color:#705A20;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Pull Request
# </div>
#
# <div style="
#     color:#80755B;
#     font-size:11px;
#     line-height:1.6;
#     margin-top:5px;
# ">
# Open a pull request for review before merging the changes into the main branch.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:19px 21px;
#     background:#F8F6FC;
#     border-left:4px solid #8066A2;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#68528A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 🔎 REVIEW & MERGE
# </div>
#
# <div style="
#     color:#686274;
#     font-size:12px;
#     line-height:1.75;
#     margin-top:6px;
# ">
# Before merging, the completed work should be reviewed for correct
# results, clear documentation, reproducibility, and adherence to the
# task acceptance criteria. Approved changes can then be merged into
# the main branch.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:18px 21px;
#     background:#F4F8F7;
#     border-left:4px solid #0F766E;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# 📌 CARDIOML WORKFLOW
# </div>
#
# <div style="
#     color:#63736E;
#     font-size:13px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Feature Branch → Development → Testing → Commit → Pull Request → Review → Merge
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding-top:16px;
#     border-top:1px solid #E5EBED;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#8A7975;
#     font-size:11px;
#     font-weight:700;
#     letter-spacing:1.2px;
# ">
# CARDIOML • GITHUB WORKFLOW
# </div>
#
# <div style="
#     color:#68528A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# BRANCH • PR • REVIEW
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFF9F7 0%,#FFFFFF 50%,#F7FBFC 100%);
#     border:1px solid #E4D9D5;
#     border-radius:24px;
#     padding:32px 36px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 8px 24px rgba(80,40,35,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #E9E0DD;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF1EE;
#     border:1px solid #F1C8C0;
#     border-radius:14px;
#     font-size:22px;
# ">
# 🎯
# </div>
#
# <div>
#
# <div style="
#     color:#A33A2F;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 09 • SPRINT 1 SUMMARY
# </div>
#
# <div style="
#     color:#3F3432;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# Sprint 1 Planning Summary
# </div>
#
# </div>
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:20px 22px;
#     background:#FFF7F5;
#     border:1px solid #F0D5CF;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# 🎯 SPRINT GOAL
# </div>
#
# <div style="
#     color:#5E3935;
#     font-size:15px;
#     font-weight:800;
#     line-height:1.7;
#     margin-top:7px;
# ">
# Establish a clear and reliable machine-learning foundation for
# CardioML by organizing the project scope, validating the dataset,
# reviewing the existing analysis, and defining the next development
# tasks to improve the final solution.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:22px;
#     color:#6D3933;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# SPRINT 1 BACKLOG
# </div>
#
#
# <div style="
#     display:flex;
#     flex-direction:column;
#     gap:11px;
#     margin-top:12px;
# ">
#
#
# <div style="
#     display:flex;
#     gap:15px;
#     align-items:center;
#     background:#FFFFFF;
#     border:1px solid #E7DEDB;
#     border-radius:14px;
#     padding:15px 17px;
# ">
#
# <div style="
#     width:34px;
#     height:34px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     flex-shrink:0;
#     background:#FFF1EE;
#     color:#A33A2F;
#     border:1px solid #F1D0C9;
#     border-radius:10px;
#     font-size:13px;
#     font-weight:900;
# ">
# 01
# </div>
#
# <div>
# <div style="color:#4F3B38;font-size:13px;font-weight:900;">
# Review & Validate the Dataset
# </div>
# <div style="color:#7C716E;font-size:11px;margin-top:4px;">
# Check structure • missing values • duplicates • data quality • target distribution
# </div>
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:15px;
#     align-items:center;
#     background:#FFFFFF;
#     border:1px solid #E0E7EA;
#     border-radius:14px;
#     padding:15px 17px;
# ">
#
# <div style="
#     width:34px;
#     height:34px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     flex-shrink:0;
#     background:#F0F8FB;
#     color:#17627A;
#     border:1px solid #D1E5EB;
#     border-radius:10px;
#     font-size:13px;
#     font-weight:900;
# ">
# 02
# </div>
#
# <div>
# <div style="color:#405D67;font-size:13px;font-weight:900;">
# Complete Exploratory Data Analysis
# </div>
# <div style="color:#718087;font-size:11px;margin-top:4px;">
# Feature distributions • correlations • target relationships • visual insights
# </div>
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:15px;
#     align-items:center;
#     background:#FFFFFF;
#     border:1px solid #DCE8E3;
#     border-radius:14px;
#     padding:15px 17px;
# ">
#
# <div style="
#     width:34px;
#     height:34px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     flex-shrink:0;
#     background:#F0F9F6;
#     color:#0F766E;
#     border:1px solid #CDE4DB;
#     border-radius:10px;
#     font-size:13px;
#     font-weight:900;
# ">
# 03
# </div>
#
# <div>
# <div style="color:#3E625B;font-size:13px;font-weight:900;">
# Establish the Baseline Model
# </div>
# <div style="color:#71847F;font-size:11px;margin-top:4px;">
# Train a baseline classifier • evaluate performance • record baseline metrics
# </div>
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:15px;
#     align-items:center;
#     background:#FFFFFF;
#     border:1px solid #E5E1D2;
#     border-radius:14px;
#     padding:15px 17px;
# ">
#
# <div style="
#     width:34px;
#     height:34px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     flex-shrink:0;
#     background:#FFFBEF;
#     color:#95721B;
#     border:1px solid #E7DDAE;
#     border-radius:10px;
#     font-size:13px;
#     font-weight:900;
# ">
# 04
# </div>
#
# <div>
# <div style="color:#665B3C;font-size:13px;font-weight:900;">
# Define Improvement Priorities
# </div>
# <div style="color:#81785F;font-size:11px;margin-top:4px;">
# Identify model weaknesses • select improvement areas • prepare next sprint tasks
# </div>
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:22px;
#     display:flex;
#     gap:15px;
# ">
#
#
# <div style="
#     flex:1;
#     background:#F8FAFA;
#     border:1px solid #DDE8E5;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# ✅ ACCEPTANCE CRITERIA
# </div>
#
# <div style="
#     color:#63736E;
#     font-size:12px;
#     line-height:1.75;
#     margin-top:8px;
# ">
# Notebook cells run without errors.<br>
# Results are documented in Markdown.<br>
# Metrics are recorded and compared.<br>
# Changes are committed clearly.<br>
# Work is reviewed before merging.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F7F5FB;
#     border:1px solid #E2DDEE;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     color:#68528A;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# 🏁 DEFINITION OF DONE
# </div>
#
# <div style="
#     color:#6F6879;
#     font-size:12px;
#     line-height:1.75;
#     margin-top:8px;
# ">
# Clean and documented notebook.<br>
# Validated data and EDA results.<br>
# Trained baseline model with metrics.<br>
# Clear project documentation.<br>
# Changes committed to GitHub.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:21px;
#     padding:18px 21px;
#     background:#F4F8F7;
#     border-left:4px solid #0F766E;
#     border-radius:13px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# 🚀 PHASE 3 COMMITMENT
# </div>
#
# <div style="
#     color:#63736E;
#     font-size:12px;
#     line-height:1.75;
#     margin-top:6px;
# ">
# CardioML will be developed incrementally throughout Phase 3.
# Each sprint will build on the previous results, with progress tracked
# through documented tasks, measurable results, GitHub commits, and
# reviewable project updates.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding-top:16px;
#     border-top:1px solid #E5DCD9;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#8A7975;
#     font-size:11px;
#     font-weight:700;
#     letter-spacing:1.2px;
# ">
# CARDIOML • SPRINT 1
# </div>
#
# <div style="
#     color:#A33A2F;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# PLANNED • DOCUMENTED • READY
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:linear-gradient(135deg,#FFF9F7 0%,#FFFFFF 50%,#F5FAFC 100%);
#     border:1px solid #E4D8D5;
#     border-radius:26px;
#     padding:34px 38px;
#     margin:24px 0;
#     font-family:'Segoe UI',Arial,sans-serif;
#     box-shadow:0 9px 26px rgba(80,35,30,0.07);
# ">
#
# <!-- HEADER -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:15px;
#     padding-bottom:20px;
#     border-bottom:1px solid #E9E0DD;
# ">
#
# <div style="
#     width:48px;
#     height:48px;
#     flex-shrink:0;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF1EE;
#     border:1px solid #F0C9C1;
#     border-radius:14px;
#     font-size:21px;
# ">
# 🌳
# </div>
#
# <div>
#
# <div style="
#     color:#A33A2F;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# 08 • DAY 5 SUMMARY
# </div>
#
# <div style="
#     color:#4F1714;
#     font-size:26px;
#     font-weight:900;
#     margin-top:3px;
# ">
# CardioML Planning Structure
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     color:#65747A;
#     font-size:13px;
#     line-height:1.75;
#     text-align:center;
# ">
# The Day 5 planning process connects the existing CardioML foundation
# with Sprint 1 tasks and the long-term Phase 3 roadmap.
# </div>
#
#
# <!-- ROOT -->
#
# <div style="
#     margin-top:25px;
#     display:flex;
#     justify-content:center;
# ">
#
# <div style="
#     width:300px;
#     background:#5C1714;
#     color:#FFFFFF;
#     border-radius:18px;
#     padding:20px 24px;
#     text-align:center;
#     box-shadow:0 6px 16px rgba(92,23,20,0.16);
# ">
#
# <div style="
#     color:#F3B5AE;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.8px;
# ">
# PHASE 3 PROJECT
# </div>
#
# <div style="
#     font-size:21px;
#     font-weight:900;
#     margin-top:6px;
# ">
# CardioML
# </div>
#
# <div style="
#     color:#EBC9C5;
#     font-size:11px;
#     margin-top:5px;
# ">
# Cardiac Patient Monitoring System
# </div>
#
# </div>
#
# </div>
#
#
# <!-- CONNECTOR -->
#
# <div style="
#     text-align:center;
#     height:35px;
#     color:#B58B84;
#     font-size:22px;
#     line-height:35px;
# ">
# │
# </div>
#
#
# <!-- SPRINT 1 -->
#
# <div style="
#     display:flex;
#     justify-content:center;
# ">
#
# <div style="
#     width:330px;
#     background:#FFF5F2;
#     border:1px solid #EBCFC8;
#     border-radius:18px;
#     padding:20px 24px;
#     text-align:center;
# ">
#
# <div style="
#     color:#A33A2F;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.8px;
# ">
# SPRINT 1 GOAL
# </div>
#
# <div style="
#     color:#6D2722;
#     font-size:19px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Strengthen the ML foundation
# </div>
#
# <div style="
#     color:#8B6A65;
#     font-size:11px;
#     line-height:1.6;
#     margin-top:6px;
# ">
# Establish a clear baseline and prepare the project
# for the upcoming development work.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- BRANCH CONNECTOR -->
#
# <div style="
#     display:flex;
#     justify-content:center;
#     margin-top:0;
# ">
#
# <div style="
#     width:78%;
#     height:28px;
#     border-left:2px solid #D8C4BF;
#     border-right:2px solid #D8C4BF;
#     border-top:2px solid #D8C4BF;
#     border-radius:18px 18px 0 0;
# ">
# </div>
#
# </div>
#
#
# <!-- THREE BRANCHES -->
#
# <div style="
#     display:flex;
#     gap:14px;
#     margin-top:0;
# ">
#
#
# <!-- BACKLOG -->
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E6DCD9;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     width:38px;
#     height:38px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF1EE;
#     border:1px solid #F0D0CA;
#     border-radius:11px;
#     font-size:17px;
# ">
# 📋
# </div>
#
# <div style="
#     color:#A33A2F;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.4px;
#     margin-top:12px;
# ">
# 01 • BACKLOG
# </div>
#
# <div style="
#     color:#4F3B38;
#     font-size:14px;
#     font-weight:900;
#     margin-top:6px;
# ">
# Sprint Tasks
# </div>
#
# <div style="
#     color:#74716F;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Dataset review<br>
# EDA & preprocessing<br>
# Baseline model review
# </div>
#
# </div>
#
#
# <!-- ACCEPTANCE -->
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #D6E4E9;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     width:38px;
#     height:38px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F1F8FA;
#     border:1px solid #CDE1E7;
#     border-radius:11px;
#     font-size:17px;
# ">
# ✓
# </div>
#
# <div style="
#     color:#17627A;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.4px;
#     margin-top:12px;
# ">
# 02 • ACCEPTANCE
# </div>
#
# <div style="
#     color:#405A63;
#     font-size:14px;
#     font-weight:900;
#     margin-top:6px;
# ">
# Definition of Done
# </div>
#
# <div style="
#     color:#718087;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Error-free notebook<br>
# Documented results<br>
# Clear metrics & comparison
# </div>
#
# </div>
#
#
# <!-- GITHUB -->
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #D5E4DE;
#     border-radius:16px;
#     padding:19px;
# ">
#
# <div style="
#     width:38px;
#     height:38px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F2FAF7;
#     border:1px solid #CDE5DC;
#     border-radius:11px;
#     font-size:17px;
# ">
# ↗
# </div>
#
# <div style="
#     color:#176B5D;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.4px;
#     margin-top:12px;
# ">
# 03 • GITHUB WORKFLOW
# </div>
#
# <div style="
#     color:#416D64;
#     font-size:14px;
#     font-weight:900;
#     margin-top:6px;
# ">
# Develop & Review
# </div>
#
# <div style="
#     color:#71817D;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Feature branch<br>
# Clear commit messages<br>
# Pull Request → Review → Merge
# </div>
#
# </div>
#
# </div>
#
#
# <!-- LOWER CONNECTOR -->
#
# <div style="
#     display:flex;
#     justify-content:center;
#     margin-top:5px;
# ">
#
# <div style="
#     width:2px;
#     height:30px;
#     background:#D8C4BF;
# ">
# </div>
#
# </div>
#
#
# <!-- ROADMAP -->
#
# <div style="
#     background:#F8FAFA;
#     border:1px solid #DCE8E6;
#     border-radius:18px;
#     padding:20px 22px;
# ">
#
# <div style="
#     color:#176B5D;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.7px;
#     text-align:center;
# ">
# PHASE 3 ROADMAP
# </div>
#
# <div style="
#     display:flex;
#     gap:10px;
#     margin-top:15px;
# ">
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E5D1CC;
#     border-radius:12px;
#     padding:13px;
#     text-align:center;
# ">
#
# <div style="color:#C2413A;font-size:18px;font-weight:900;">
# W6
# </div>
#
# <div style="
#     color:#6D2722;
#     font-size:11px;
#     font-weight:800;
#     margin-top:4px;
# ">
# Model Improvement
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #D1E3E9;
#     border-radius:12px;
#     padding:13px;
#     text-align:center;
# ">
#
# <div style="color:#0284A8;font-size:18px;font-weight:900;">
# W7
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:11px;
#     font-weight:800;
#     margin-top:4px;
# ">
# Advanced Analysis
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #CFE3DB;
#     border-radius:12px;
#     padding:13px;
#     text-align:center;
# ">
#
# <div style="color:#0F8A78;font-size:18px;font-weight:900;">
# W8
# </div>
#
# <div style="
#     color:#16665B;
#     font-size:11px;
#     font-weight:800;
#     margin-top:4px;
# ">
# Deployment
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFFFFF;
#     border:1px solid #E2DBBC;
#     border-radius:12px;
#     padding:13px;
#     text-align:center;
# ">
#
# <div style="color:#95721B;font-size:18px;font-weight:900;">
# W9
# </div>
#
# <div style="
#     color:#665B3C;
#     font-size:11px;
#     font-weight:800;
#     margin-top:4px;
# ">
# Final Delivery
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- OUTCOME -->
#
# <div style="
#     margin-top:20px;
#     padding:17px 20px;
#     background:#FFFDF8;
#     border-left:4px solid #95721B;
#     border-radius:12px;
# ">
#
# <div style="
#     color:#80621B;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# 🏁 DAY 5 OUTCOME
# </div>
#
# <div style="
#     color:#756B52;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# A clear development structure was established for CardioML:
# Sprint 1 defines the immediate work, while the Phase 3 roadmap
# defines the progression toward a tested, documented, and deployable
# final solution.
# </div>
#
# </div>
#
#
# <!-- FOOTER -->
#
# <div style="
#     margin-top:18px;
#     padding-top:15px;
#     border-top:1px solid #E5EBED;
#     display:flex;
#     justify-content:space-between;
# ">
#
# <div style="
#     color:#8A7975;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# CARDIOML • DAY 5
# </div>
#
# <div style="
#     color:#A33A2F;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# PLANNING COMPLETE
# </div>
#
# </div>
#
# </div>
