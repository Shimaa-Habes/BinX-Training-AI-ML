# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#FFF8F8 0%,#FFFFFF 52%,#F4FAFC 100%);
#     padding:42px 46px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #E8C8C8;
#     box-shadow:0 10px 30px rgba(127,29,29,0.10);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="display:flex; justify-content:space-between; align-items:center; margin-bottom:28px;">
# <div style="color:#991B1B; font-size:14px; font-weight:700; letter-spacing:2px;">CARDIO • MACHINE LEARNING</div>
# <div style="background:#FFF1F2; color:#B91C1C; border:1px solid #F3B8B8; padding:8px 15px; border-radius:20px; font-size:12px; font-weight:700; letter-spacing:1px;">● INDIVIDUAL PROJECT</div>
# </div>
#
# <div style="display:flex; align-items:center; gap:38px; background:#FFFFFF; padding:28px; border-radius:20px; border:1px solid #F0D7D7; box-shadow:0 5px 18px rgba(127,29,29,0.06);">
#
# <div style="flex:1; min-width:0;">
# <div style="color:#8F5555; font-size:13px; font-weight:700; letter-spacing:2px; margin-bottom:10px;">AI & MACHINE LEARNING TRACK</div>
# <h1 style="color:#641111; font-size:38px; line-height:1.18; margin:0; font-weight:800;">
# CardioML Project
# <br>
# <span style="color:#B91C1C;">Heart Disease Classification</span>
# </h1>
# <p style="color:#704D4D; font-size:16px; line-height:1.75; font-weight:500; margin:17px 0 0 0;">
# A complete machine-learning workflow for exploring cardiac patient data, building classification models, and evaluating their performance.
# </p>
#
# <div style="margin-top:25px; height:48px;">
# <svg width="100%" height="48" viewBox="0 0 520 48" preserveAspectRatio="none" style="display:block;">
# <polyline points="0,24 70,24 105,24 120,24 130,7 142,41 154,24 170,24 205,24 220,24 230,15 238,33 246,24 275,24 320,24 350,24 365,24 375,7 387,41 399,24 420,24 470,24 520,24" style="fill:none; stroke:#DC2626; stroke-width:2.8; stroke-linecap:round; stroke-linejoin:round;"/>
# </svg>
# </div>
#
# </div>
#
# <div style="width:200px; min-width:200px; height:200px; display:flex; align-items:center; justify-content:center; background:#FFFFFF; border-radius:50%; border:2px solid #F3CACA; box-shadow:inset 0 0 25px rgba(185,28,28,0.06); overflow:hidden;">
# <img src="..\media\heart.png" alt="Human heart anatomy" style="width:200px; height:200px; object-fit:contain;">
# </div>
#
# </div>
#
# <div style="margin-top:32px; padding:24px; border-radius:18px; background:#FFFAFA; border:1px solid #F0D7D7;">
# <div style="color:#7A2020; font-size:14px; letter-spacing:2px; font-weight:800; margin-bottom:17px;">ANALYSIS PIPELINE</div>
#
# <div style="display:flex; gap:12px;">
#
# <div style="flex:1; background:#FFFFFF; border:1px solid #E8CACA; border-radius:13px; padding:16px;">
# <div style="color:#DC2626; font-size:22px; font-weight:800;">01</div>
# <div style="color:#7A2020; font-size:14px; font-weight:800; margin-top:7px;">Data Preparation</div>
# <div style="color:#9A6A6A; font-size:11px; font-weight:600; margin-top:5px;">Cleaning • Missing Values</div>
# </div>
#
# <div style="flex:1; background:#FFFFFF; border:1px solid #C9E4EF; border-radius:13px; padding:16px;">
# <div style="color:#0284C7; font-size:22px; font-weight:800;">02</div>
# <div style="color:#155E75; font-size:14px; font-weight:800; margin-top:7px;">EDA & Statistics</div>
# <div style="color:#648A99; font-size:11px; font-weight:600; margin-top:5px;">Distributions • Correlations</div>
# </div>
#
# <div style="flex:1; background:#FFFFFF; border:1px solid #CBE7E1; border-radius:13px; padding:16px;">
# <div style="color:#0F766E; font-size:22px; font-weight:800;">03</div>
# <div style="color:#115E59; font-size:14px; font-weight:800; margin-top:7px;">Classification</div>
# <div style="color:#5F8984; font-size:11px; font-weight:600; margin-top:5px;">Baseline • Comparison</div>
# </div>
#
# <div style="flex:1; background:#FFFFFF; border:1px solid #D7DCE2; border-radius:13px; padding:16px;">
# <div style="color:#475569; font-size:22px; font-weight:800;">04</div>
# <div style="color:#334155; font-size:14px; font-weight:800; margin-top:7px;">Evaluation</div>
# <div style="color:#718096; font-size:11px; font-weight:600; margin-top:5px;">CV • F1 • ROC-AUC</div>
# </div>
#
# <div style="flex:1; background:#FFFFFF; border:1px solid #C9E4EF; border-radius:13px; padding:16px;">
# <div style="color:#0369A1; font-size:22px; font-weight:800;">05</div>
# <div style="color:#155E75; font-size:14px; font-weight:800; margin-top:7px;">Pipeline</div>
# <div style="color:#648A99; font-size:11px; font-weight:600; margin-top:5px;">Feature Eng • Rerun-ready</div>
# </div>
#
# </div>
# </div>
#
# <div style="display:flex; gap:14px; margin-top:22px;">
#
# <div style="flex:1; background:#FFF1F2; border-radius:13px; padding:15px 17px; border:1px solid #F5C2C7;">
# <div style="color:#9F1239; font-size:11px; letter-spacing:1.5px; font-weight:800;">OBJECTIVE</div>
# <div style="color:#7A2020; font-size:13px; font-weight:700; margin-top:6px;">Compare reliable classification models</div>
# </div>
#
# <div style="flex:1; background:#F0F9FF; border-radius:13px; padding:15px 17px; border:1px solid #BAE6FD;">
# <div style="color:#0369A1; font-size:11px; letter-spacing:1.5px; font-weight:800;">TOOLS</div>
# <div style="color:#155E75; font-size:13px; font-weight:700; margin-top:6px;">Python • Pandas • NumPy • Scikit-learn</div>
# </div>
#
# <div style="flex:1; background:#F0FDFA; border-radius:13px; padding:15px 17px; border:1px solid #99F6E4;">
# <div style="color:#0F766E; font-size:11px; letter-spacing:1.5px; font-weight:800;">OUTPUT</div>
# <div style="color:#115E59; font-size:13px; font-weight:700; margin-top:6px;">Models • Metrics • Insights</div>
# </div>
#
# </div>
#
# <div style="margin-top:25px; padding-top:16px; border-top:1px solid #E8D3D3; display:flex; justify-content:space-between; align-items:center;">
# <div style="color:#987171; font-size:11px; font-weight:700; letter-spacing:1.4px;">CARDIAC DATA ANALYSIS</div>
# <div style="color:#B91C1C; font-size:11px; font-weight:800; letter-spacing:1.4px;">HEART_ANALYSIS.IPYNB</div>
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#FFF9F9 0%,#FFFFFF 55%,#F7FBFD 100%);
#     padding:40px 44px;
#     border-radius:24px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #E8D2D2;
#     box-shadow:0 8px 28px rgba(100,17,17,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="text-align:center; margin-bottom:30px;">
#
# <div style="
#     color:#B91C1C;
#     font-size:12px;
#     font-weight:800;
#     letter-spacing:3px;
#     margin-bottom:10px;
# ">
# AI & MACHINE LEARNING TRACK
# </div>
#
# <h2 style="
#     color:#641111;
#     font-size:30px;
#     margin:0;
#     font-weight:800;
# ">
# Cardiac Patient Monitoring System
# </h2>
#
# <div style="
#     width:70px;
#     height:3px;
#     background:#DC2626;
#     border-radius:5px;
#     margin:14px auto 0;
# "></div>
#
# </div>
#
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-left:4px solid #B91C1C;
#     border-radius:14px;
#     padding:20px 23px;
#     margin-bottom:25px;
# ">
#
# <div style="
#     color:#991B1B;
#     font-size:12px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:8px;
# ">
# ABOUT THE PROJECT
# </div>
#
# <p style="
#     color:#5F4141;
#     font-size:14px;
#     line-height:1.8;
#     margin:0;
# ">
# <strong>Cardiac Patient Monitoring System</strong> is an individual Machine Learning
# project that analyzes cardiac patient data and builds supervised classification models
# to identify patterns associated with heart disease. The project follows a complete
# machine-learning workflow, starting from data preparation and exploratory analysis,
# then moving to classification, model evaluation, feature engineering, and reproducible
# pipelines.
# </p>
#
# </div>
#
# <div style="display:flex; gap:18px; margin-bottom:28px;">
#
# <div style="
#     flex:1;
#     background:#FFF6F6;
#     border:1px solid #F1CCCC;
#     border-radius:15px;
#     padding:19px 21px;
# ">
#
# <div style="
#     color:#B91C1C;
#     font-size:12px;
#     font-weight:800;
#     letter-spacing:1.5px;
# ">
# PROJECT OBJECTIVE
# </div>
#
# <p style="
#     color:#704D4D;
#     font-size:13px;
#     line-height:1.7;
#     margin:8px 0 0;
# ">
# Explore and prepare the cardiac dataset, discover meaningful patterns,
# and build reliable classification models that can be evaluated using
# consistent machine-learning metrics.
# </p>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#F5FAFD;
#     border:1px solid #CDE5EF;
#     border-radius:15px;
#     padding:19px 21px;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:12px;
#     font-weight:800;
#     letter-spacing:1.5px;
# ">
# DATASET
# </div>
#
# <p style="
#     color:#536F7A;
#     font-size:13px;
#     line-height:1.7;
#     margin:8px 0 0;
# ">
# <strong>Heart Disease UCI Dataset</strong><br>
# Contains demographic, clinical, and cardiac-related patient features
# such as age, sex, chest pain type, blood pressure, cholesterol,
# maximum heart rate, and exercise-induced angina.
# </p>
#
# </div>
#
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:13px;
#     font-weight:800;
#     letter-spacing:2px;
#     margin-bottom:14px;
# ">
# PROJECT WORKFLOW
# </div>
#
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8DADA;
#     border-radius:16px;
#     overflow:hidden;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     padding:15px 19px;
#     border-bottom:1px solid #F0E3E3;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     min-width:42px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF1F2;
#     color:#DC2626;
#     border-radius:11px;
#     font-size:15px;
#     font-weight:800;
# ">
# 01
# </div>
#
# <div style="margin-left:16px;">
# <div style="color:#641111; font-size:14px; font-weight:800;">
# Environment & Dataset Setup
# </div>
# <div style="color:#8A6A6A; font-size:12px; margin-top:3px;">
# Load the dataset • inspect structure • identify target • create data dictionary
# </div>
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     padding:15px 19px;
#     border-bottom:1px solid #E4F0F4;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     min-width:42px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F0F9FF;
#     color:#0284C7;
#     border-radius:11px;
#     font-size:15px;
#     font-weight:800;
# ">
# 02
# </div>
#
# <div style="margin-left:16px;">
# <div style="color:#155E75; font-size:14px; font-weight:800;">
# Data Preparation
# </div>
# <div style="color:#64828D; font-size:12px; margin-top:3px;">
# Missing values • duplicates • invalid values • categorical encoding • final cleaning
# </div>
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     padding:15px 19px;
#     border-bottom:1px solid #E2F0ED;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     min-width:42px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F0FDFA;
#     color:#0F766E;
#     border-radius:11px;
#     font-size:15px;
#     font-weight:800;
# ">
# 03
# </div>
#
# <div style="margin-left:16px;">
# <div style="color:#115E59; font-size:14px; font-weight:800;">
# EDA & Statistics
# </div>
# <div style="color:#5F8984; font-size:12px; margin-top:3px;">
# Descriptive statistics • class balance • distributions • outliers • correlations
# </div>
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     padding:15px 19px;
#     border-bottom:1px solid #E8E9EC;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     min-width:42px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#F8FAFC;
#     color:#475569;
#     border-radius:11px;
#     font-size:15px;
#     font-weight:800;
# ">
# 04
# </div>
#
# <div style="margin-left:16px;">
# <div style="color:#334155; font-size:14px; font-weight:800;">
# Supervised Baseline
# </div>
# <div style="color:#718096; font-size:12px; margin-top:3px;">
# Define X and y • train/test split • Logistic Regression • baseline accuracy
# </div>
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     padding:15px 19px;
#     border-bottom:1px solid #E7EEF5;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     min-width:42px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#EFF6FF;
#     color:#2563EB;
#     border-radius:11px;
#     font-size:15px;
#     font-weight:800;
# ">
# 05
# </div>
#
# <div style="margin-left:16px;">
# <div style="color:#1E40AF; font-size:14px; font-weight:800;">
# Model Comparison & Evaluation
# </div>
# <div style="color:#64748B; font-size:12px; margin-top:3px;">
# Second classifier • cross-validation • confusion matrix • accuracy • precision • recall • F1 • ROC-AUC
# </div>
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     padding:15px 19px;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     min-width:42px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     background:#FFF7ED;
#     color:#EA580C;
#     border-radius:11px;
#     font-size:15px;
#     font-weight:800;
# ">
# 06
# </div>
#
# <div style="margin-left:16px;">
# <div style="color:#9A3412; font-size:14px; font-weight:800;">
# Feature Engineering & Pipeline
# </div>
# <div style="color:#9A6A4A; font-size:12px; margin-top:3px;">
# Create useful features • preprocessing • Scikit-learn Pipeline • reproducible workflow
# </div>
# </div>
#
# </div>
#
# </div>
#
# <div style="
#     margin-top:25px;
#     display:flex;
#     align-items:center;
#     gap:12px;
#     padding:15px 19px;
#     background:#FFFAFA;
#     border:1px solid #E8D3D3;
#     border-radius:13px;
# ">
#
# <div style="
#     width:9px;
#     height:9px;
#     min-width:9px;
#     background:#DC2626;
#     border-radius:50%;
# "></div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.6;
# ">
# <strong style="color:#7A2020;">Project Scope:</strong>
# This project focuses on supervised learning, exploratory data analysis,
# model evaluation, feature engineering, and pipelines.
# <strong style="color:#B91C1C;">Unsupervised Analysis is excluded from the project scope.</strong>
# </div>
#
# </div>
#
# <div style="
#     margin-top:24px;
#     padding-top:15px;
#     border-top:1px solid #E8D3D3;
#     text-align:center;
# ">
#
# <span style="
#  color:#987171;
#  font-size:10px;
#  font-weight:700;
#  letter-spacing:1.5px;
# ">
# CARDIAC DATA • MACHINE LEARNING • INDIVIDUAL PROJECT </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background:#FFFFFF; border:1px solid #F0D7D7; border-radius:14px; padding:22px 26px; margin:16px 0; box-shadow:0 3px 12px rgba(127,29,29,0.06); overflow:hidden; box-sizing:border-box; width:100%;">
#
# <div style="display:flex; align-items:center; gap:10px; margin-bottom:16px;">
# <span style="font-size:22px;">🫀</span>
# <h3 style="color:#7A2020; font-size:17px; font-weight:800; margin:0;">Dataset: Heart Disease UCI</h3>
# </div>
#
# <table style="width:100%; border-collapse:separate; border-spacing:8px 8px; margin:-8px;">
# <tr>
# <td style="background:#FFF1F2; border-radius:10px; padding:12px 14px; width:50%;">
# <div style="font-size:11px; color:#9F1239; font-weight:700; letter-spacing:0.5px;">📁 SOURCES</div>
# <div style="font-size:13px; color:#7A2020; font-weight:600; margin-top:4px;">Cleveland, Hungary, Switzerland, VA Long Beach</div>
# </td>
# <td style="background:#F0F9FF; border-radius:10px; padding:12px 14px; width:50%;">
# <div style="font-size:11px; color:#0369A1; font-weight:700; letter-spacing:0.5px;">🎯 TARGET</div>
# <div style="font-size:13px; color:#155E75; font-weight:600; margin-top:4px;">Presence/severity of heart disease</div>
# </td>
# </tr>
# <tr>
# <td style="background:#F0FDFA; border-radius:10px; padding:12px 14px;">
# <div style="font-size:11px; color:#0F766E; font-weight:700; letter-spacing:0.5px;">🧬 KEY FEATURES</div>
# <div style="font-size:13px; color:#115E59; font-weight:600; margin-top:4px;">Age, sex, chest pain type, BP, cholesterol</div>
# </td>
# <td style="background:#FFF7ED; border-radius:10px; padding:12px 14px;">
# <div style="font-size:11px; color:#C2410C; font-weight:700; letter-spacing:0.5px;">🩺 TYPE</div>
# <div style="font-size:13px; color:#9A3412; font-weight:600; margin-top:4px;">Clinical / medical patient records</div>
# </td>
# </tr>
# </table>
#
# </div>

# %% [markdown]
# <div style="background:#FFFFFF; border:1px solid #F0D7D7; border-radius:14px; padding:22px 26px; margin:16px 0; box-shadow:0 3px 12px rgba(127,29,29,0.06); overflow:hidden; box-sizing:border-box; width:100%;">
#
# <div style="display:flex; align-items:center; gap:10px; margin-bottom:14px;">
# <span style="font-size:22px;">📂</span>
# <h3 style="color:#7A2020; font-size:17px; font-weight:800; margin:0;">Step 01 — Load Dataset</h3>
# </div>
#
# <p style="font-size:13px; color:#704D4D; line-height:1.75; margin:0 0 15px 0;">
# In this step, we will load the <strong style="color:#7A2020;">Heart Disease UCI</strong>
# dataset using Pandas and store it in a DataFrame named <strong>df</strong>.
# This provides the foundation for inspecting, cleaning, and analyzing the cardiac patient data.
# </p>
#
# <table style="width:100%; border-collapse:separate; border-spacing:8px 8px; margin:-8px;">
#
# <tr>
#
# <td style="background:#FFF1F2; border-radius:10px; padding:12px 14px; width:33.33%;">
# <div style="font-size:11px; color:#9F1239; font-weight:700; letter-spacing:0.5px;">📁 SOURCE</div>
# <div style="font-size:13px; color:#7A2020; font-weight:600; margin-top:4px;">heart_disease_uci.csv</div>
# </td>
#
# <td style="background:#F0F9FF; border-radius:10px; padding:12px 14px; width:33.33%;">
# <div style="font-size:11px; color:#0369A1; font-weight:700; letter-spacing:0.5px;">🐼 TOOL</div>
# <div style="font-size:13px; color:#155E75; font-weight:600; margin-top:4px;">Pandas</div>
# </td>
#
# <td style="background:#F0FDFA; border-radius:10px; padding:12px 14px; width:33.33%;">
# <div style="font-size:11px; color:#0F766E; font-weight:700; letter-spacing:0.5px;">📊 OUTPUT</div>
# <div style="font-size:13px; color:#115E59; font-weight:600; margin-top:4px;">Loaded DataFrame</div>
# </td>
#
# </tr>
#
# </table>
#
# <div style="margin-top:14px; padding:12px 15px; background:#FFFAFA; border:1px solid #F0D7D7; border-radius:10px;">
#
# <div style="font-size:11px; color:#9F1239; font-weight:700; letter-spacing:0.5px;">
# 🔎 VERIFICATION
# </div>
#
# <div style="font-size:12px; color:#704D4D; line-height:1.7; margin-top:4px;">
# After loading the file, we will display a small preview of the dataset to confirm
# that the records and columns were loaded correctly.
# </div>
#
# </div>
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("✅ Libraries imported successfully")
# Out:
# ✅ Libraries imported successfully

# %%
# Load the dataset
df = pd.read_csv("../input/heart_disease_uci.csv")

# Styled dataset preview
(
    df.head()
    .style
    .set_caption("🫀 Heart Disease UCI — Dataset Preview")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#3F2929",
        "font-size": "13px",
        "text-align": "center",
        "padding": "9px",
        "border": "1px solid #E8DADA"
    })
    .set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("caption-side", "top"),
                ("background-color", "#FFF8F8"),
                ("color", "#641111"),
                ("font-size", "17px"),
                ("font-weight", "800"),
                ("text-align", "left"),
                ("padding", "14px 16px"),
                ("border", "1px solid #E8D7D7"),
                ("border-bottom", "none")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#FFF1F2"),
                ("color", "#641111"),
                ("font-weight", "800"),
                ("text-align", "center"),
                ("padding", "10px"),
                ("border", "1px solid #E8DADA")
            ]
        },
        {
            "selector": "td",
            "props": [
                ("background-color", "#FFFFFF"),
                ("color", "#3F2929"),
                ("border", "1px solid #EDE2E2"),
                ("padding", "9px")
            ]
        },
        {
            "selector": "tbody tr:nth-child(even) td",
            "props": [
                ("background-color", "#FFF9F9")
            ]
        },
        {
            "selector": "table",
            "props": [
                ("background-color", "#FFFFFF"),
                ("border-collapse", "collapse"),
                ("width", "100%"),
                ("border", "1px solid #E8DADA")
            ]
        }
    ])
)
# Out:
# <style type="text/css">
# #T_9b3cf caption {
#   caption-side: top;
#   background-color: #FFF8F8;
#   color: #641111;
#   font-size: 17px;
#   font-weight: 800;
#   text-align: left;
#   padding: 14px 16px;
#   border: 1px solid #E8D7D7;
#   border-bottom: none;
# }
# #T_9b3cf th {
#   background-color: #FFF1F2;
#   color: #641111;
#   font-weight: 800;
#   text-align: center;
#   padding: 10px;
#   border: 1px solid #E8DADA;
# }
# #T_9b3cf td {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   border: 1px solid #EDE2E2;
#   padding: 9px;
# }
# #T_9b3cf tbody tr:nth-child(even) td {
#   background-color: #FFF9F9;
# }
# #T_9b3cf table {
#   background-color: #FFFFFF;
#   border-collapse: collapse;
#   width: 100%;
#   border: 1px solid #E8DADA;
# }
# #T_9b3cf_row0_col0, #T_9b3cf_row1_col0, #T_9b3cf_row2_col0, #T_9b3cf_row3_col0, #T_9b3cf_row4_col0 {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   font-size: 13px;
#   text-align: center;
#   padding: 9px;
# ...

# %% [markdown]
# <div style=" background:#FFFFFF; border:1px solid #F0D7D7; border-radius:14px; padding:22px 26px; margin:16px 0; box-shadow:0 3px 12px rgba(127,29,29,0.06); overflow:hidden; box-sizing:border-box; width:100%; ">
#
# <div style="display:flex; align-items:center; gap:11px; margin-bottom:12px;"> <span style="font-size:22px;">🔍</span>
#
# <div> <div style=" color:#9F1239; font-size:10px; font-weight:800; letter-spacing:1.5px; margin-bottom:3px; "> DATASET EXPLORATION </div>
#
# <h3 style=" color:#7A2020; font-size:17px; font-weight:800; margin:0; "> Step 02 — Inspect Dataset Structure </h3> </div>
#
# </div>
#
# <p style=" color:#704D4D; font-size:13px; line-height:1.8; margin:0; "> Before making any changes to the data, we first examine its overall structure. This gives us a clear understanding of the dataset size, available features, data types, and the amount of information stored in each column. </p>
#
# <div style=" display:flex; gap:10px; margin-top:18px; flex-wrap:wrap; ">
#
# <div style=" flex:1; min-width:180px; background:#FFF8F8; border-radius:10px; padding:13px 15px; border:1px solid #F0D7D7; ">
#
# <div style="color:#B91C1C; font-size:11px; font-weight:800;"> 01 · DATA INFORMATION </div>
#
# <div style="color:#704D4D; font-size:12px; line-height:1.6; margin-top:5px;"> Review column names, non-null values, and data types using <code style="color:#7A2020;">df.info()</code>. </div>
#
# </div>
#
# <div style=" flex:1; min-width:180px; background:#F7FBFD; border-radius:10px; padding:13px 15px; border:1px solid #D7EAF1; ">
#
# <div style="color:#0369A1; font-size:11px; font-weight:800;"> 02 · DATASET SIZE </div>
#
# <div style="color:#536F7A; font-size:12px; line-height:1.6; margin-top:5px;"> Check the number of observations and features using <code style="color:#155E75;">df.shape</code>. </div>
#
# </div>
#
# <div style=" flex:1; min-width:180px; background:#F7FCFB; border-radius:10px; padding:13px 15px; border:1px solid #D5EAE5; ">
#
# <div style="color:#0F766E; font-size:11px; font-weight:800;"> 03 · AVAILABLE FEATURES </div>
#
# <div style="color:#536F7A; font-size:12px; line-height:1.6; margin-top:5px;"> List all dataset columns and understand the information represented by each feature. </div>
#
# </div>
#
# </div>
#
# <div style=" margin-top:18px; padding:13px 16px; background:#FFFAFA; border-left:3px solid #DC2626; border-radius:9px; ">
#
# <div style=" color:#9F1239; font-size:10px; font-weight:800; letter-spacing:1.2px; "> NEXT STEP </div>
#
# <div style=" color:#704D4D; font-size:12px; line-height:1.7; margin-top:4px; "> The structural inspection will help us identify which variables require special handling during the upcoming data-preparation stage. </div>
#
# </div>
#
# </div>

# %%
# Inspect dataset structure

print("Dataset Information")
print("=" * 60)
df.info()

print("\n" + "=" * 60)
print(f"Dataset Shape: {df.shape[0]} rows × {df.shape[1]} columns")

print("\n" + "=" * 60)
print("Column Names:")
for i, column in enumerate(df.columns, start=1):
    print(f"{i:02d}. {column}")
# Out:
# Dataset Information
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 1 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   id;age;gender;height;weight;ap_hi;ap_lo;cholesterol;gluc;smoke;alco;active;cardio  70000 non-null  str
# dtypes: str(1)
# memory usage: 547.0 KB
#
# ...
# Dataset Shape: 70000 rows × 1 columns
#
# ...
# Column Names:
# 01. id;age;gender;height;weight;ap_hi;ap_lo;cholesterol;gluc;smoke;alco;active;cardio

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="display:flex; align-items:center; gap:11px; margin-bottom:13px;">
# <span style="font-size:23px;">🎯</span>
#
# <div>
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
# ">
# TARGET DEFINITION
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:17px;
#     font-weight:800;
#     margin:2px 0 0 0;
# ">
# Step 03 — Identify the Target Variable
# </h3>
# </div>
# </div>
#
# <p style="
#     color:#704D4D;
#     font-size:13px;
#     line-height:1.8;
#     margin:0;
# ">
# For the supervised learning task, we need to identify the variable that represents
# the outcome we want the classification models to predict. In the Heart Disease UCI
# dataset, the target variable is <strong style="color:#7A2020;">num</strong>.
# </p>
#
# <div style="
#     margin-top:17px;
#     display:flex;
#     align-items:stretch;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F5C2C7;
#     border-radius:11px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# 🎯 TARGET
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin-top:6px;
# ">
# num
# </div>
#
# <div style="
#     color:#8F6666;
#     font-size:11px;
#     margin-top:3px;
# ">
# Heart disease outcome
# </div>
#
# </div>
#
# <div style="
#     flex:2;
#     background:#F5FAFD;
#     border:1px solid #C9E4EF;
#     border-radius:11px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# 📌 ROLE IN THE PROJECT
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# The remaining patient attributes will be used as input features,
# while <strong style="color:#155E75;">num</strong> represents the outcome
# that the classification models will learn to predict.
# </div>
#
# </div>
#
# </div>
#
# <div style="
#     margin-top:17px;
#     padding:13px 16px;
#     background:#FFFAFA;
#     border:1px solid #F0D7D7;
#     border-radius:10px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# 🔎 WHAT WE WILL VERIFY
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:5px;
# ">
# Before continuing, we will inspect the unique values and their frequencies
# to understand how the target is distributed across the dataset.
# </div>
#
# </div>
#
# </div>

# %%
import pandas as pd

df = pd.read_csv("../input/heart_disease_uci.csv", sep=";")

print(df.columns.tolist())
print(df.shape)
# Out:
# ['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio']
# (70000, 13)

# %%
# Define the target variable

target = "cardio"

# Inspect target values and their frequencies

target_counts = df[target].value_counts().sort_index()

print(f"Target variable: {target}")

print("\nUnique target values:")

print(sorted(df[target].dropna().unique()))

print("\nTarget distribution:")

print(target_counts)
# Out:
# Target variable: cardio
#
# Unique target values:
# [np.int64(0), np.int64(1)]
#
# Target distribution:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %% [markdown]
# <div style=" background:#FFFFFF; border:1px solid #F0D7D7; border-radius:14px; padding:22px 26px; margin:16px 0; box-shadow:0 3px 12px rgba(127,29,29,0.06); overflow:hidden; box-sizing:border-box; width:100%; ">
#
# <div style="display:flex; align-items:center; gap:11px; margin-bottom:14px;"> <span style="font-size:23px;">📖</span>
#
# <div> <div style=" color:#9F1239; font-size:10px; font-weight:800; letter-spacing:1.5px; "> DATA UNDERSTANDING </div>
#
# <h3 style=" color:#7A2020; font-size:17px; font-weight:800; margin:2px 0 0 0; "> Data Dictionary </h3> </div> </div>
#
# <p style=" color:#704D4D; font-size:13px; line-height:1.8; margin:0 0 17px 0; "> The following data dictionary provides a brief description of each variable in the <strong style="color:#7A2020;">Heart Disease UCI</strong> dataset. It helps us understand what each feature represents before starting the data preparation and exploratory analysis stages. </p>
#
# <table style=" width:100%; border-collapse:collapse; font-size:12px; overflow:hidden; ">
#
# <tr style="background:#FFF1F2;"> <th style="padding:11px 12px; color:#7A2020; text-align:left; border:1px solid #E8DADA;">Feature</th> <th style="padding:11px 12px; color:#7A2020; text-align:left; border:1px solid #E8DADA;">Description</th> <th style="padding:11px 12px; color:#7A2020; text-align:center; border:1px solid #E8DADA;">Type</th> </tr>
#
# <tr> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">id</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Unique identifier for each patient record</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Identifier</td> </tr>
#
# <tr style="background:#FFF9F9;"> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">age</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Age of the patient in years</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Numeric</td> </tr>
#
# <tr> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">sex</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Biological sex of the patient</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Categorical</td> </tr>
#
# <tr style="background:#FFF9F9;"> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">dataset</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Source location of the patient record</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Categorical</td> </tr>
#
# <tr> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">cp</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Type of chest pain experienced by the patient</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Categorical</td> </tr>
#
# <tr style="background:#FFF9F9;"> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">trestbps</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Resting blood pressure in mm Hg</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Numeric</td> </tr>
#
# <tr> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">chol</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Serum cholesterol level in mg/dl</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Numeric</td> </tr>
#
# <tr style="background:#FFF9F9;"> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">fbs</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Whether fasting blood sugar is greater than 120 mg/dl</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Boolean</td> </tr>
#
# <tr> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">restecg</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Resting electrocardiographic results</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Categorical</td> </tr>
#
# <tr style="background:#FFF9F9;"> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">thalch</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Maximum heart rate achieved</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Numeric</td> </tr>
#
# <tr> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">exang</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Exercise-induced angina</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Boolean</td> </tr>
#
# <tr style="background:#FFF9F9;"> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">oldpeak</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">ST depression induced by exercise relative to rest</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Numeric</td> </tr>
#
# <tr> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">slope</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Slope of the peak exercise ST segment</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Categorical</td> </tr>
#
# <tr style="background:#FFF9F9;"> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">ca</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Number of major vessels colored by fluoroscopy</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Numeric</td> </tr>
#
# <tr> <td style="padding:9px 12px; color:#9F1239; font-weight:800; border:1px solid #EDE2E2;">thal</td> <td style="padding:9px 12px; color:#4F3A3A; border:1px solid #EDE2E2;">Thalassemia-related result from the cardiac test</td> <td style="padding:9px 12px; color:#64748B; text-align:center; border:1px solid #EDE2E2;">Categorical</td> </tr>
#
# <tr style="background:#FFF1F2;"> <td style="padding:9px 12px; color:#B91C1C; font-weight:800; border:1px solid #E8CACA;">num</td> <td style="padding:9px 12px; color:#7A2020; font-weight:700; border:1px solid #E8CACA;">Heart disease diagnosis and severity level (0–4)</td> <td style="padding:9px 12px; color:#B91C1C; text-align:center; font-weight:800; border:1px solid #E8CACA;">Target</td> </tr>
#
# </table>
#
# <div style=" margin-top:17px; padding:13px 16px; background:#F5FAFD; border-left:3px solid #0284C7; border-radius:9px; ">
#
# <div style=" color:#0369A1; font-size:10px; font-weight:800; letter-spacing:1.2px; "> 📌 NOTE </div>
#
# <div style=" color:#536F7A; font-size:12px; line-height:1.7; margin-top:4px; "> The <strong>id</strong> column is an identifier rather than a predictive clinical feature, while <strong>num</strong> is the target variable that will be used later in the classification task. </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style=" background:#FFFFFF; border:1px solid #F0D7D7; border-radius:14px; padding:22px 26px; margin:16px 0; box-shadow:0 3px 12px rgba(127,29,29,0.06); overflow:hidden; box-sizing:border-box; width:100%; ">
#
# <div style="display:flex; align-items:center; gap:11px; margin-bottom:13px;"> <span style="font-size:23px;">🧹</span>
#
# <div> <div style=" color:#9F1239; font-size:10px; font-weight:800; letter-spacing:1.5px; "> DATA QUALITY CHECK </div>
#
# <h3 style=" color:#7A2020; font-size:17px; font-weight:800; margin:2px 0 0 0; "> Step 04 — Check Missing Values </h3> </div> </div>
#
# <p style=" color:#704D4D; font-size:13px; line-height:1.8; margin:0; "> Missing values can affect statistical analysis and machine-learning models. In this step, we will inspect the dataset for null values and measure how many observations are missing from each feature before deciding how they should be handled. </p>
#
# <div style=" margin-top:18px; display:flex; gap:10px; ">
#
# <div style=" flex:1; background:#FFF8F8; border:1px solid #F0D7D7; border-radius:11px; padding:14px 16px; ">
#
# <div style="color:#B91C1C; font-size:11px; font-weight:800;"> 01 · COUNT </div>
#
# <div style="color:#704D4D; font-size:12px; line-height:1.6; margin-top:5px;"> Calculate the number of missing values in every column. </div>
#
# </div>
#
# <div style=" flex:1; background:#F5FAFD; border:1px solid #D7EAF1; border-radius:11px; padding:14px 16px; ">
#
# <div style="color:#0369A1; font-size:11px; font-weight:800;"> 02 · PERCENTAGE </div>
#
# <div style="color:#536F7A; font-size:12px; line-height:1.6; margin-top:5px;"> Calculate the percentage of missing observations for each feature. </div>
#
# </div>
#
# <div style=" flex:1; background:#F7FCFB; border:1px solid #D5EAE5; border-radius:11px; padding:14px 16px; ">
#
# <div style="color:#0F766E; font-size:11px; font-weight:800;"> 03 · ASSESS </div>
#
# <div style="color:#536F7A; font-size:12px; line-height:1.6; margin-top:5px;"> Identify columns that may require treatment during data preparation. </div>
#
# </div>
#
# </div>
#
# <div style=" margin-top:17px; padding:13px 16px; background:#FFFAFA; border:1px solid #F0D7D7; border-radius:10px; ">
#
# <div style=" color:#9F1239; font-size:10px; font-weight:800; letter-spacing:1.2px; "> ⚠️ IMPORTANT </div>
#
# <div style=" color:#704D4D; font-size:12px; line-height:1.7; margin-top:4px; "> This step only identifies missing values. No rows or values will be removed or imputed until the <strong>Data Preparation</strong> stage. </div>
#
# </div>
#
# </div>

# %%
# Check missing values
missing_count = df.isnull().sum()
missing_percentage = (missing_count / len(df)) * 100

missing_summary = pd.DataFrame({
    "Missing Values": missing_count,
    "Missing (%)": missing_percentage
})

# Keep only columns that contain missing values
missing_summary = missing_summary[missing_summary["Missing Values"] > 0]

# Display styled result
(
    missing_summary
    .style
    .format({"Missing (%)": "{:.2f}%"})
    .set_caption("🧹 Missing Values Summary")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#3F2929",
        "font-size": "13px",
        "text-align": "center",
        "padding": "9px",
        "border": "1px solid #E8DADA"
    })
    .set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("caption-side", "top"),
                ("background-color", "#FFF8F8"),
                ("color", "#641111"),
                ("font-size", "17px"),
                ("font-weight", "800"),
                ("text-align", "left"),
                ("padding", "14px 16px"),
                ("border", "1px solid #E8D7D7"),
                ("border-bottom", "none")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#FFF1F2"),
                ("color", "#641111"),
                ("font-weight", "800"),
                ("text-align", "center"),
                ("padding", "10px"),
                ("border", "1px solid #E8DADA")
            ]
        },
        {
            "selector": "td",
            "props": [
                ("background-color", "#FFFFFF"),
                ("color", "#3F2929"),
                ("border", "1px solid #EDE2E2"),
                ("padding", "9px")
            ]
        },
        {
            "selector": "table",
            "props": [
                ("background-color", "#FFFFFF"),
                ("border-collapse", "collapse"),
                ("width", "100%"),
                ("border", "1px solid #E8DADA")
            ]
        }
    ])
)
# Out:
# <style type="text/css">
# #T_4e462 caption {
#   caption-side: top;
#   background-color: #FFF8F8;
#   color: #641111;
#   font-size: 17px;
#   font-weight: 800;
#   text-align: left;
#   padding: 14px 16px;
#   border: 1px solid #E8D7D7;
#   border-bottom: none;
# }
# #T_4e462 th {
#   background-color: #FFF1F2;
#   color: #641111;
#   font-weight: 800;
#   text-align: center;
#   padding: 10px;
#   border: 1px solid #E8DADA;
# }
# #T_4e462 td {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   border: 1px solid #EDE2E2;
#   padding: 9px;
# }
# #T_4e462 table {
#   background-color: #FFFFFF;
#   border-collapse: collapse;
#   width: 100%;
#   border: 1px solid #E8DADA;
# }
# </style>
# <table id="T_4e462">
#   <caption>🧹 Missing Values Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e462_level0_col0" class="col_heading level0 col0" >Missing Values</th>
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="display:flex; align-items:center; gap:11px; margin-bottom:14px;">
# <span style="font-size:23px;">🧹</span>
#
# <div>
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
# ">
# DATA PREPARATION
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:17px;
#     font-weight:800;
#     margin:2px 0 0 0;
# ">
# Step 05 — Handle Missing Values
# </h3>
# </div>
# </div>
#
#
# <p style="
#     color:#704D4D;
#     font-size:13px;
#     line-height:1.8;
#     margin:0;
# ">
# The dataset contains missing values across several numerical, categorical, and
# boolean features. Instead of removing rows and losing potentially useful patient
# records, we will apply appropriate imputation strategies based on the type of each
# feature.
# </p>
#
#
# <div style="
#     margin-top:18px;
#     display:flex;
#     gap:10px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:11px;
#     padding:14px 16px;
# ">
#
# <div style="color:#B91C1C; font-size:11px; font-weight:800;">
# 🔢 NUMERICAL
# </div>
#
# <div style="color:#704D4D; font-size:12px; line-height:1.65; margin-top:5px;">
# Missing numerical values will be replaced using the
# <strong style="color:#7A2020;">median</strong>, which is less sensitive to extreme values.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:11px;
#     padding:14px 16px;
# ">
#
# <div style="color:#0369A1; font-size:11px; font-weight:800;">
# 🏷️ CATEGORICAL
# </div>
#
# <div style="color:#536F7A; font-size:12px; line-height:1.65; margin-top:5px;">
# Missing categorical values will be replaced using the
# <strong style="color:#155E75;">most frequent category</strong>.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F7FCFB;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:14px 16px;
# ">
#
# <div style="color:#0F766E; font-size:11px; font-weight:800;">
# 💾 DATA RETENTION
# </div>
#
# <div style="color:#536F7A; font-size:12px; line-height:1.65; margin-top:5px;">
# This approach keeps the available patient records instead of dropping large
# portions of the dataset.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     padding:13px 16px;
#     background:#FFFAFA;
#     border-left:3px solid #DC2626;
#     border-radius:9px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# ⚠️ TARGET PROTECTION
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:4px;
# ">
# The target variable <strong style="color:#7A2020;">num</strong> will not be imputed.
# Rows with an unknown target cannot be reliably used for supervised learning.
# </div>
#
# </div>
#
# </div>

# %%
# Create a working copy for data preparation

df_clean = df.copy()

# Check remaining missing values

remaining_missing = df_clean.isnull().sum()

print("Remaining missing values:")

if remaining_missing.sum() == 0:
    print("✅ No missing values found.")
else:
    print(remaining_missing[remaining_missing > 0])
# Out:
# Remaining missing values:
# ✅ No missing values found.

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="display:flex; align-items:center; gap:11px; margin-bottom:14px;">
# <span style="font-size:23px;">🧾</span>
#
# <div>
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
# ">
# DATA QUALITY
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:17px;
#     font-weight:800;
#     margin:2px 0 0 0;
# ">
# Step 06 — Check and Remove Duplicates
# </h3>
# </div>
# </div>
#
# <p style="
#     color:#704D4D;
#     font-size:13px;
#     line-height:1.8;
#     margin:0;
# ">
# Duplicate records can introduce repeated observations and may affect statistical
# analysis and model evaluation. We will first identify completely duplicated rows
# and remove them only if they are present.
# </p>
#
# <div style="
#     margin-top:18px;
#     display:flex;
#     gap:10px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:11px;
#     padding:14px 16px;
# ">
#
# <div style="color:#B91C1C; font-size:11px; font-weight:800;">
# 01 · DETECT
# </div>
#
# <div style="color:#704D4D; font-size:12px; line-height:1.65; margin-top:5px;">
# Count duplicated rows using <strong style="color:#7A2020;">duplicated()</strong>.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:11px;
#     padding:14px 16px;
# ">
#
# <div style="color:#0369A1; font-size:11px; font-weight:800;">
# 02 · REMOVE
# </div>
#
# <div style="color:#536F7A; font-size:12px; line-height:1.65; margin-top:5px;">
# Remove exact duplicate records while keeping the first occurrence.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#F7FCFB;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:14px 16px;
# ">
#
# <div style="color:#0F766E; font-size:11px; font-weight:800;">
# 03 · VERIFY
# </div>
#
# <div style="color:#536F7A; font-size:12px; line-height:1.65; margin-top:5px;">
# Confirm that no complete duplicate rows remain.
# </div>
#
# </div>
#
# </div>
#
# </div>

# %%
# Check for duplicate rows
duplicate_count = df_clean.duplicated().sum()

print(f"Number of duplicate rows: {duplicate_count}")

# Remove duplicates if any exist
if duplicate_count > 0:
    df_clean = df_clean.drop_duplicates().reset_index(drop=True)
    print("Duplicate rows removed.")
else:
    print("No duplicate rows found.")

# Verify duplicates after cleaning
print(f"Remaining duplicate rows: {df_clean.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0
# No duplicate rows found.
# Remaining duplicate rows: 0

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
#     padding-bottom:14px;
#     border-bottom:1px solid #F0D7D7;
# ">
#
# <div>
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
# ">
# DATA VALIDATION
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:4px 0 0 0;
# ">
# Step 07 — Check for Invalid Values
# </h3>
# </div>
#
# <div style="
#     background:#FFF1F2;
#     color:#B91C1C;
#     border:1px solid #F3C2C7;
#     border-radius:20px;
#     padding:7px 13px;
#     font-size:10px;
#     font-weight:800;
# ">
# VALIDATION
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:16px;
#     background:#FFFAFA;
#     border-radius:10px;
#     padding:15px 17px;
#     border-left:4px solid #DC2626;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:800;
#     margin-bottom:5px;
# ">
# Why are we checking this?
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
# ">
# Missing values and duplicates have already been handled. The next step is to
# check whether the remaining values are valid and logically consistent with
# the meaning and expected range of each feature.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:16px;
#     display:flex;
#     align-items:center;
#     gap:8px;
# ">
#
# <div style="
#     flex:1;
#     height:1px;
#     background:#E8DADA;
# "></div>
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# VALIDATION AREAS
# </div>
#
# <div style="
#     flex:1;
#     height:1px;
#     background:#E8DADA;
# "></div>
#
# </div>
#
#
# <div style="
#     margin-top:14px;
#     display:grid;
#     grid-template-columns:repeat(2, 1fr);
#     gap:9px;
# ">
#
# <div style="
#     background:#F7FBFD;
#     border:1px solid #D7EAF1;
#     border-radius:9px;
#     padding:11px 13px;
# ">
# <div style="color:#0369A1; font-size:10px; font-weight:800;">NUMERICAL RANGES</div>
# <div style="color:#536F7A; font-size:11px; margin-top:4px;">
# Check values such as age, blood pressure, cholesterol, heart rate, and ST depression.
# </div>
# </div>
#
# <div style="
#     background:#F7FCFB;
#     border:1px solid #D5EAE5;
#     border-radius:9px;
#     padding:11px 13px;
# ">
# <div style="color:#0F766E; font-size:10px; font-weight:800;">CATEGORICAL VALUES</div>
# <div style="color:#536F7A; font-size:11px; margin-top:4px;">
# Verify that categorical features contain only expected categories.
# </div>
# </div>
#
# <div style="
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:9px;
#     padding:11px 13px;
# ">
# <div style="color:#B91C1C; font-size:10px; font-weight:800;">BOOLEAN FEATURES</div>
# <div style="color:#704D4D; font-size:11px; margin-top:4px;">
# Check boolean variables for unexpected values.
# </div>
# </div>
#
# <div style="
#     background:#FFFAF5;
#     border:1px solid #F2D8C4;
#     border-radius:9px;
#     padding:11px 13px;
# ">
# <div style="color:#C2410C; font-size:10px; font-weight:800;">TARGET VALUES</div>
# <div style="color:#704D4D; font-size:11px; margin-top:4px;">
# Confirm that the target contains only the expected disease-severity values.
# </div>
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:16px;
#     color:#8F6666;
#     font-size:11px;
#     font-weight:600;
# ">
# The purpose of this step is detection only. Any identified invalid values
# will be handled in the following cleaning step.
# </div>
#
# </div>

# %%
# Check for potentially invalid values

invalid_checks = {

    "age <= 0": (df_clean["age"] <= 0).sum(),

    "height <= 0": (df_clean["height"] <= 0).sum(),

    "weight <= 0": (df_clean["weight"] <= 0).sum(),

    "ap_hi <= 0": (df_clean["ap_hi"] <= 0).sum(),

    "ap_lo <= 0": (df_clean["ap_lo"] <= 0).sum(),

    "ap_hi < ap_lo": (df_clean["ap_hi"] < df_clean["ap_lo"]).sum(),

    "cardio outside 0-1":
        (~df_clean["cardio"].isin([0, 1])).sum(),

    "gender unexpected values":
        (~df_clean["gender"].isin([1, 2])).sum(),

    "cholesterol unexpected values":
        (~df_clean["cholesterol"].isin([1, 2, 3])).sum(),

    "gluc unexpected values":
        (~df_clean["gluc"].isin([1, 2, 3])).sum(),

    "smoke unexpected values":
        (~df_clean["smoke"].isin([0, 1])).sum(),

    "alco unexpected values":
        (~df_clean["alco"].isin([0, 1])).sum(),

    "active unexpected values":
        (~df_clean["active"].isin([0, 1])).sum()
}


# Create summary DataFrame

invalid_summary = pd.DataFrame(
    list(invalid_checks.items()),
    columns=["Validation Check", "Invalid Count"]
)


# Add status

invalid_summary["Status"] = invalid_summary["Invalid Count"].apply(
    lambda x: "✓ Valid" if x == 0 else "⚠ Review"
)


# Styled output

(
    invalid_summary
    .style
    .set_caption("🔎 Data Validation Report")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#3F2929",
        "font-size": "13px",
        "text-align": "center",
        "padding": "9px",
        "border": "1px solid #E8DADA"
    })
    .set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("caption-side", "top"),
                ("background-color", "#FFF8F8"),
                ("color", "#641111"),
                ("font-size", "17px"),
                ("font-weight", "800"),
                ("text-align", "left"),
                ("padding", "14px 16px"),
                ("border", "1px solid #E8D7D7"),
                ("border-bottom", "none")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#FFF1F2"),
                ("color", "#641111"),
                ("font-weight", "800"),
                ("text-align", "center"),
                ("padding", "10px"),
                ("border", "1px solid #E8DADA")
            ]
        },
        {
            "selector": "td",
            "props": [
                ("background-color", "#FFFFFF"),
                ("color", "#3F2929"),
                ("border", "1px solid #EDE2E2"),
                ("padding", "9px")
            ]
        },
        {
            "selector": "tbody tr:nth-child(even) td",
            "props": [
                ("background-color", "#FFF9F9")
            ]
        },
        {
            "selector": "table",
            "props": [
                ("background-color", "#FFFFFF"),
                ("border-collapse", "collapse"),
                ("width", "100%"),
                ("border", "1px solid #E8DADA")
            ]
        }
    ])
)
# Out:
# <style type="text/css">
# #T_9b1ab caption {
#   caption-side: top;
#   background-color: #FFF8F8;
#   color: #641111;
#   font-size: 17px;
#   font-weight: 800;
#   text-align: left;
#   padding: 14px 16px;
#   border: 1px solid #E8D7D7;
#   border-bottom: none;
# }
# #T_9b1ab th {
#   background-color: #FFF1F2;
#   color: #641111;
#   font-weight: 800;
#   text-align: center;
#   padding: 10px;
#   border: 1px solid #E8DADA;
# }
# #T_9b1ab td {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   border: 1px solid #EDE2E2;
#   padding: 9px;
# }
# #T_9b1ab tbody tr:nth-child(even) td {
#   background-color: #FFF9F9;
# }
# #T_9b1ab table {
#   background-color: #FFFFFF;
#   border-collapse: collapse;
#   width: 100%;
#   border: 1px solid #E8DADA;
# }
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:11px;
#     margin-bottom:14px;
# ">
#
# <span style="font-size:23px;">🛠️</span>
#
# <div>
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
# ">
# DATA CLEANING
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:2px 0 0 0;
# ">
# Step 08 — Fix Invalid Values
# </h3>
# </div>
#
# </div>
#
#
# <div style="
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:10px;
#     padding:14px 16px;
# ">
#
# <div style="
#     color:#9A3412;
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# ⚠️ ISSUES IDENTIFIED
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# The validation step identified non-valid numerical values in
# <strong style="color:#7A2020;">trestbps</strong>,
# <strong style="color:#7A2020;">chol</strong>, and
# <strong style="color:#7A2020;">oldpeak</strong>.
# These values will be treated as missing rather than removed from the dataset.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:16px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     gap:10px;
# ">
#
# <div style="
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:11px 15px;
#     text-align:center;
#     flex:1;
# ">
#
# <div style="color:#B91C1C; font-size:16px; font-weight:800;">
# trestbps
# </div>
#
# <div style="color:#8F6666; font-size:11px; margin-top:3px;">
# 1 invalid value
# </div>
#
# </div>
#
#
# <div style="
#     color:#B91C1C;
#     font-size:18px;
#     font-weight:800;
# ">
# →
# </div>
#
#
# <div style="
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:11px 15px;
#     text-align:center;
#     flex:1;
# ">
#
# <div style="color:#B91C1C; font-size:16px; font-weight:800;">
# chol
# </div>
#
# <div style="color:#8F6666; font-size:11px; margin-top:3px;">
# 172 invalid values
# </div>
#
# </div>
#
#
# <div style="
#     color:#B91C1C;
#     font-size:18px;
#     font-weight:800;
# ">
# →
# </div>
#
#
# <div style="
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:11px 15px;
#     text-align:center;
#     flex:1;
# ">
#
# <div style="color:#B91C1C; font-size:16px; font-weight:800;">
# oldpeak
# </div>
#
# <div style="color:#8F6666; font-size:11px; margin-top:3px;">
# 12 invalid values
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     padding:13px 16px;
#     background:#F7FCFB;
#     border:1px solid #D5EAE5;
#     border-radius:10px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# CLEANING STRATEGY
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:5px;
# ">
# Invalid numerical values will first be converted to
# <strong style="color:#115E59;">NaN</strong>.
# They will then be replaced using the
# <strong style="color:#115E59;">median</strong> of their respective feature,
# consistent with the missing-value strategy used earlier.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:15px;
#     color:#8F6666;
#     font-size:11px;
#     font-weight:600;
# ">
# No patient records will be removed during this step.
# </div>
#
# </div>

# %%
# Replace invalid numerical values with NaN

df_clean.loc[df_clean["age"] <= 0, "age"] = np.nan

df_clean.loc[df_clean["height"] <= 0, "height"] = np.nan

df_clean.loc[df_clean["weight"] <= 0, "weight"] = np.nan

df_clean.loc[df_clean["ap_hi"] <= 0, "ap_hi"] = np.nan

df_clean.loc[df_clean["ap_lo"] <= 0, "ap_lo"] = np.nan


# Replace logically inconsistent blood pressure values with NaN

df_clean.loc[
    df_clean["ap_hi"] < df_clean["ap_lo"],
    ["ap_hi", "ap_lo"]
] = np.nan


# Impute the newly created missing values using the median

for col in ["age", "height", "weight", "ap_hi", "ap_lo"]:
    df_clean[col] = df_clean[col].fillna(df_clean[col].median())


# Verify that the invalid values have been fixed

validation_after = {

    "age <= 0":
        (df_clean["age"] <= 0).sum(),

    "height <= 0":
        (df_clean["height"] <= 0).sum(),

    "weight <= 0":
        (df_clean["weight"] <= 0).sum(),

    "ap_hi <= 0":
        (df_clean["ap_hi"] <= 0).sum(),

    "ap_lo <= 0":
        (df_clean["ap_lo"] <= 0).sum(),

    "ap_hi < ap_lo":
        (df_clean["ap_hi"] < df_clean["ap_lo"]).sum()
}


validation_after_df = pd.DataFrame(
    list(validation_after.items()),
    columns=["Validation Check", "Remaining Invalid"]
)


validation_after_df["Status"] = validation_after_df[
    "Remaining Invalid"
].apply(
    lambda x: "✓ Fixed" if x == 0 else "⚠ Review"
)


# Styled output

(
    validation_after_df
    .style
    .set_caption("🛠️ Post-Cleaning Validation")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#3F2929",
        "font-size": "13px",
        "text-align": "center",
        "padding": "9px",
        "border": "1px solid #E8DADA"
    })
    .set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("caption-side", "top"),
                ("background-color", "#F7FCFB"),
                ("color", "#115E59"),
                ("font-size", "17px"),
                ("font-weight", "800"),
                ("text-align", "left"),
                ("padding", "14px 16px"),
                ("border", "1px solid #D5EAE5"),
                ("border-bottom", "none")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#E6F7F3"),
                ("color", "#115E59"),
                ("font-weight", "800"),
                ("text-align", "center"),
                ("padding", "10px"),
                ("border", "1px solid #D5EAE5")
            ]
        },
        {
            "selector": "td",
            "props": [
                ("background-color", "#FFFFFF"),
                ("color", "#3F2929"),
                ("border", "1px solid #EDE2E2"),
                ("padding", "9px")
            ]
        }
    ])
)
# Out:
# <style type="text/css">
# #T_77192 caption {
#   caption-side: top;
#   background-color: #F7FCFB;
#   color: #115E59;
#   font-size: 17px;
#   font-weight: 800;
#   text-align: left;
#   padding: 14px 16px;
#   border: 1px solid #D5EAE5;
#   border-bottom: none;
# }
# #T_77192 th {
#   background-color: #E6F7F3;
#   color: #115E59;
#   font-weight: 800;
#   text-align: center;
#   padding: 10px;
#   border: 1px solid #D5EAE5;
# }
# #T_77192 td {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   border: 1px solid #EDE2E2;
#   padding: 9px;
# }
# #T_77192_row0_col0, #T_77192_row0_col1, #T_77192_row0_col2, #T_77192_row1_col0, #T_77192_row1_col1, #T_77192_row1_col2, #T_77192_row2_col0, #T_77192_row2_col1, #T_77192_row2_col2, #T_77192_row3_col0, #T_77192_row3_col1, #T_77192_row3_col2, #T_77192_row4_col0, #T_77192_row4_col1, #T_77192_row4_col2, #T_77192_row5_col0, #T_77192_row5_col1, #T_77192_row5_col2 {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   font-size: 13px;
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:12px;
#     padding-bottom:14px;
#     border-bottom:1px solid #F0D7D7;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:21px;
# ">
# 🏷️
# </div>
#
# <div>
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
# ">
# FEATURE PREPARATION
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:3px 0 0 0;
# ">
# Step 09 — Encode Categorical Variables
# </h3>
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     color:#704D4D;
#     font-size:13px;
#     line-height:1.8;
# ">
# Machine-learning models require numerical input. The dataset contains
# categorical and boolean features, so these variables must be transformed into
# a numerical representation while preserving their meaning.
# </div>
#
#
# <div style="
#     margin-top:17px;
#     display:flex;
#     gap:10px;
# ">
#
# <div style="
#     flex:1;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:11px;
#     padding:14px 15px;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:.7px;
# ">
# ONE-HOT ENCODING
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Categorical features will be represented using separate binary columns for
# their categories.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F7FCFB;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:14px 15px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:.7px;
# ">
# BOOLEAN → 0 / 1
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Boolean features such as <strong>fbs</strong> and <strong>exang</strong>
# will be converted into numerical binary values.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:11px;
#     padding:14px 15px;
# ">
#
# <div style="
#     color:#B91C1C;
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:.7px;
# ">
# MODEL READY
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# The transformed features will be suitable for Scikit-learn classification
# models.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     padding:13px 16px;
#     background:#FFFAFA;
#     border-left:3px solid #0284C7;
#     border-radius:9px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.1px;
# ">
# IMPORTANT
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:4px;
# ">
# For the final machine-learning workflow, categorical preprocessing will also
# be incorporated into a Scikit-learn <strong>Pipeline</strong> to avoid data
# leakage and keep preprocessing reproducible.
# </div>
#
# </div>
#
# </div>

# %%
# ============================================================
# 🔄 ENCODING + STYLED OUTPUT
# ============================================================

import pandas as pd
from IPython.display import display, HTML

# Create a copy for the encoded dataset

df_encoded = df_clean.copy()


# Convert categorical codes to numerical values

categorical_cols = [
    "gender",
    "cholesterol",
    "gluc"
]

for col in categorical_cols:
    df_encoded[col] = df_encoded[col].astype(int)


# Convert binary features to integer values

boolean_cols = [
    "smoke",
    "alco",
    "active",
    "cardio"
]

for col in boolean_cols:
    df_encoded[col] = df_encoded[col].astype(int)


# ============================================================
# 🎨 STYLED SHAPE SUMMARY
# ============================================================

display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #F0D7D7;
    border-radius:14px;
    padding:18px 22px;
    margin:12px 0;
    box-shadow:0 3px 12px rgba(127,29,29,0.06);
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.5px;
    margin-bottom:12px;
">
ENCODING RESULT
</div>

<div style="
    display:flex;
    gap:12px;
">

<div style="
    flex:1;
    background:#FFF1F2;
    border:1px solid #F3C2C7;
    border-radius:10px;
    padding:12px 15px;
">

<div style="color:#9F1239; font-size:10px; font-weight:800;">
ORIGINAL CLEANED
</div>

<div style="
    color:#7A2020;
    font-size:20px;
    font-weight:800;
    margin-top:4px;
">
{df_clean.shape[0]} × {df_clean.shape[1]}
</div>

</div>

<div style="
    display:flex;
    align-items:center;
    justify-content:center;
    color:#B91C1C;
    font-size:20px;
    font-weight:800;
">
→
</div>

<div style="
    flex:1;
    background:#F0FDFA;
    border:1px solid #D5EAE5;
    border-radius:10px;
    padding:12px 15px;
">

<div style="color:#0F766E; font-size:10px; font-weight:800;">
ENCODED DATASET
</div>

<div style="
    color:#115E59;
    font-size:20px;
    font-weight:800;
    margin-top:4px;
">
{df_encoded.shape[0]} × {df_encoded.shape[1]}
</div>

</div>

</div>

</div>
"""))


# ============================================================
# 🏷️ STYLED ENCODED DATASET PREVIEW
# ============================================================

styled_preview = (
    df_encoded.head()
    .style
    .set_caption("🏷️ Encoded Dataset Preview")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#3F2929",
        "font-size": "12px",
        "text-align": "center",
        "padding": "8px",
        "border": "1px solid #E8DADA"
    })
    .set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("caption-side", "top"),
                ("background-color", "#F7FCFB"),
                ("color", "#115E59"),
                ("font-size", "16px"),
                ("font-weight", "800"),
                ("text-align", "left"),
                ("padding", "13px 15px"),
                ("border", "1px solid #D5EAE5"),
                ("border-bottom", "none")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#FFF1F2"),
                ("color", "#7A2020"),
                ("font-weight", "800"),
                ("text-align", "center"),
                ("padding", "9px"),
                ("border", "1px solid #E8DADA")
            ]
        },
        {
            "selector": "td",
            "props": [
                ("background-color", "#FFFFFF"),
                ("color", "#3F2929"),
                ("border", "1px solid #EDE2E2"),
                ("padding", "8px")
            ]
        },
        {
            "selector": "tbody tr:nth-child(even) td",
            "props": [
                ("background-color", "#FFF9F9")
            ]
        }
    ])
)

display(styled_preview)
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:18px 22px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
#     margin-bottom:12px;
# ">
# ENCODING RESULT
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:12px 15px;
# ">
#
# <div style="color:#9F1239; font-size:10px; font-weight:800;">
# ORIGINAL CLEANED
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:20px;
#     font-weight:800;
#     margin-top:4px;
# ">
# 70000 × 13
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#B91C1C;
#     font-size:20px;
#     font-weight:800;
# ">
# →
# </div>
#
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:12px;
#     padding-bottom:14px;
#     border-bottom:1px solid #F0D7D7;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     background:#F0FDFA;
#     border:1px solid #99F6E4;
#     border-radius:11px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:21px;
# ">
# ✓
# </div>
#
# <div>
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
# ">
# DATA PREPARATION
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:3px 0 0 0;
# ">
# Step 10 — Final Check After Cleaning
# </h3>
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     color:#704D4D;
#     font-size:13px;
#     line-height:1.8;
# ">
# Before moving to Exploratory Data Analysis, we perform a final quality check
# to confirm that the cleaned dataset is consistent, complete, and ready for
# statistical analysis and machine-learning preparation.
# </div>
#
#
# <div style="
#     margin-top:17px;
#     display:grid;
#     grid-template-columns:repeat(2, 1fr);
#     gap:10px;
# ">
#
# <div style="
#     background:#F7FCFB;
#     border:1px solid #D5EAE5;
#     border-radius:10px;
#     padding:13px 15px;
# ">
# <div style="color:#0F766E; font-size:10px; font-weight:800;">
# 01 · COMPLETENESS
# </div>
# <div style="color:#536F7A; font-size:11px; margin-top:5px;">
# Confirm that no missing values remain in the cleaned dataset.
# </div>
# </div>
#
#
# <div style="
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:10px;
#     padding:13px 15px;
# ">
# <div style="color:#0369A1; font-size:10px; font-weight:800;">
# 02 · UNIQUENESS
# </div>
# <div style="color:#536F7A; font-size:11px; margin-top:5px;">
# Confirm that duplicate observations have been removed.
# </div>
# </div>
#
#
# <div style="
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:10px;
#     padding:13px 15px;
# ">
# <div style="color:#B91C1C; font-size:10px; font-weight:800;">
# 03 · VALIDITY
# </div>
# <div style="color:#704D4D; font-size:11px; margin-top:5px;">
# Confirm that previously identified invalid numerical values were corrected.
# </div>
# </div>
#
#
# <div style="
#     background:#FFFAF5;
#     border:1px solid #F2D8C4;
#     border-radius:10px;
#     padding:13px 15px;
# ">
# <div style="color:#C2410C; font-size:10px; font-weight:800;">
# 04 · STRUCTURE
# </div>
# <div style="color:#704D4D; font-size:11px; margin-top:5px;">
# Confirm that the target and required features are still available.
# </div>
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     padding:13px 16px;
#     background:#F0F9FF;
#     border:1px solid #BAE6FD;
#     border-radius:10px;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.1px;
# ">
# NEXT PHASE
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:4px;
# ">
# Once all checks pass, the cleaned dataset will be ready for
# <strong style="color:#155E75;">EDA & Statistics</strong>, where we will study
# distributions, class balance, correlations, and relationships between features.
# </div>
#
# </div>
#
# </div>

# %%
# Final data quality checks

final_checks = {

    "Missing values":
        df_clean.isnull().sum().sum(),

    "Duplicate rows":
        df_clean.duplicated().sum(),

    "Invalid age":
        (df_clean["age"] <= 0).sum(),

    "Invalid height":
        (df_clean["height"] <= 0).sum(),

    "Invalid weight":
        (df_clean["weight"] <= 0).sum(),

    "Invalid systolic BP":
        (df_clean["ap_hi"] <= 0).sum(),

    "Invalid diastolic BP":
        (df_clean["ap_lo"] <= 0).sum(),

    "Systolic < Diastolic":
        (df_clean["ap_hi"] < df_clean["ap_lo"]).sum(),

    "Invalid gender":
        (~df_clean["gender"].isin([1, 2])).sum(),

    "Invalid cholesterol":
        (~df_clean["cholesterol"].isin([1, 2, 3])).sum(),

    "Invalid glucose":
        (~df_clean["gluc"].isin([1, 2, 3])).sum(),

    "Invalid smoking":
        (~df_clean["smoke"].isin([0, 1])).sum(),

    "Invalid alcohol":
        (~df_clean["alco"].isin([0, 1])).sum(),

    "Invalid activity":
        (~df_clean["active"].isin([0, 1])).sum(),

    "Invalid target":
        (~df_clean["cardio"].isin([0, 1])).sum()
}


final_check_df = pd.DataFrame(
    list(final_checks.items()),
    columns=["Quality Check", "Remaining Issues"]
)


final_check_df["Status"] = final_check_df[
    "Remaining Issues"
].apply(
    lambda x: "✓ PASS" if x == 0 else "⚠ REVIEW"
)


(
    final_check_df
    .style
    .set_caption("✓ Final Data Quality Report")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#3F2929",
        "font-size": "13px",
        "text-align": "center",
        "padding": "9px",
        "border": "1px solid #E8DADA"
    })
    .set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("caption-side", "top"),
                ("background-color", "#F0FDFA"),
                ("color", "#115E59"),
                ("font-size", "17px"),
                ("font-weight", "800"),
                ("text-align", "left"),
                ("padding", "14px 16px"),
                ("border", "1px solid #D5EAE5"),
                ("border-bottom", "none")
            ]
        },

        {
            "selector": "th",
            "props": [
                ("background-color", "#E6F7F3"),
                ("color", "#115E59"),
                ("font-weight", "800"),
                ("padding", "10px"),
                ("border", "1px solid #D5EAE5")
            ]
        },

        {
            "selector": "td",
            "props": [
                ("background-color", "#FFFFFF"),
                ("color", "#3F2929"),
                ("border", "1px solid #EDE2E2"),
                ("padding", "9px")
            ]
        }
    ])
)
# Out:
# <style type="text/css">
# #T_83c64 caption {
#   caption-side: top;
#   background-color: #F0FDFA;
#   color: #115E59;
#   font-size: 17px;
#   font-weight: 800;
#   text-align: left;
#   padding: 14px 16px;
#   border: 1px solid #D5EAE5;
#   border-bottom: none;
# }
# #T_83c64 th {
#   background-color: #E6F7F3;
#   color: #115E59;
#   font-weight: 800;
#   padding: 10px;
#   border: 1px solid #D5EAE5;
# }
# #T_83c64 td {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   border: 1px solid #EDE2E2;
#   padding: 9px;
# }
# ...

# %%
from IPython.display import display, HTML

# Final cleaned dataset information

final_shape = df_clean.shape

target_column = "cardio"

target_classes = sorted(df_clean[target_column].unique())

display(HTML(f"""

<div style="
    background:#FFFFFF;
    border:1px solid #F0D7D7;
    border-radius:14px;
    padding:20px 24px;
    margin:14px 0;
    box-shadow:0 3px 12px rgba(127,29,29,0.06);
    width:100%;
    box-sizing:border-box;
">

<div style="
    color:#0F766E;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.5px;
    margin-bottom:14px;
">
✓ CLEANED DATASET SUMMARY
</div>

<div style="
    display:flex;
    gap:12px;
">

<!-- Shape -->

<div style="
    flex:1;
    background:#FFF1F2;
    border:1px solid #F3C2C7;
    border-radius:11px;
    padding:14px 16px;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:.7px;
">
DATASET SHAPE
</div>

<div style="
    color:#7A2020;
    font-size:22px;
    font-weight:800;
    margin-top:5px;
">
{final_shape[0]} × {final_shape[1]}
</div>

<div style="
    color:#8F6666;
    font-size:10px;
    margin-top:3px;
">
Rows × Columns
</div>

</div>


<!-- Target -->

<div style="
    flex:1;
    background:#F0F9FF;
    border:1px solid #BAE6FD;
    border-radius:11px;
    padding:14px 16px;
">

<div style="
    color:#0369A1;
    font-size:10px;
    font-weight:800;
    letter-spacing:.7px;
">
TARGET VARIABLE
</div>

<div style="
    color:#155E75;
    font-size:22px;
    font-weight:800;
    margin-top:5px;
">
{target_column}
</div>

<div style="
    color:#648A99;
    font-size:10px;
    margin-top:3px;
">
Binary classification target
</div>

</div>


<!-- Classes -->

<div style="
    flex:1;
    background:#F0FDFA;
    border:1px solid #99F6E4;
    border-radius:11px;
    padding:14px 16px;
">

<div style="
    color:#0F766E;
    font-size:10px;
    font-weight:800;
    letter-spacing:.7px;
">
TARGET CLASSES
</div>

<div style="
    color:#115E59;
    font-size:20px;
    font-weight:800;
    margin-top:6px;
">
{", ".join(map(str, target_classes))}
</div>

<div style="
    color:#5F8984;
    font-size:10px;
    margin-top:3px;
">
Two cardiovascular disease classes
</div>

</div>

</div>


<div style="
    margin-top:15px;
    padding:11px 14px;
    background:#FFFAFA;
    border-left:3px solid #0F766E;
    border-radius:8px;
">

<span style="
    color:#115E59;
    font-size:11px;
    font-weight:700;
">
✓ Data preparation completed successfully.
</span>

<span style="
    color:#704D4D;
    font-size:11px;
">
 The cleaned dataset is ready for EDA and statistical analysis.
</span>

</div>

</div>

"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:20px 24px;
#     margin:14px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
#     margin-bottom:14px;
# ">
# ✓ CLEANED DATASET SUMMARY
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <!-- Shape -->
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:14px 16px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:.7px;
# ">
# DATASET SHAPE
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:22px;
#     font-weight:800;
#     margin-top:5px;
# ">
# 70000 × 13
# </div>
#
# <div style="
#     color:#8F6666;
#     font-size:10px;
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:12px;
#     padding-bottom:15px;
#     border-bottom:1px solid #F0D7D7;
# ">
#
# <div style="
#     width:43px;
#     height:43px;
#     background:#F0F9FF;
#     border:1px solid #BAE6FD;
#     border-radius:11px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:21px;
# ">
# 📊
# </div>
#
# <div>
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
# ">
# EDA & STATISTICS
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:3px 0 0 0;
# ">
# Step 11 — Descriptive Statistics
# </h3>
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     color:#704D4D;
#     font-size:13px;
#     line-height:1.85;
# ">
# Descriptive statistics provide a numerical summary of the cleaned dataset.
# They help us understand the central tendency, spread, and range of the
# numerical patient features before creating visualizations or building models.
# </div>
#
#
# <div style="
#     margin-top:17px;
#     display:flex;
#     gap:10px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:13px 15px;
# ">
#
# <div style="color:#9F1239; font-size:10px; font-weight:800;">
# MEAN
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Shows the average value of each numerical feature.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:10px;
#     padding:13px 15px;
# ">
#
# <div style="color:#0369A1; font-size:10px; font-weight:800;">
# STD
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Measures how much the values vary around their mean.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #99F6E4;
#     border-radius:10px;
#     padding:13px 15px;
# ">
#
# <div style="color:#0F766E; font-size:10px; font-weight:800;">
# MIN / MAX
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Show the observed range of each numerical feature.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:10px;
#     padding:13px 15px;
# ">
#
# <div style="color:#C2410C; font-size:10px; font-weight:800;">
# QUARTILES
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Describe the distribution using the 25th, 50th, and 75th percentiles.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     padding:12px 15px;
#     background:#FFFAFA;
#     border-left:3px solid #0284C7;
#     border-radius:8px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHAT WE ARE LOOKING FOR
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:4px;
# ">
# We will look for unusual ranges, large variation between features, and
# potential signs of skewness or outliers that should be explored further
# using visualizations.
# </div>
#
# </div>
#
# </div>

# %%
# Descriptive statistics for numerical features

descriptive_stats = df_clean.describe().T

(
    descriptive_stats
    .style
    .format("{:.2f}")
    .set_caption("📊 Descriptive Statistics — Numerical Features")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#3F2929",
        "font-size": "12px",
        "text-align": "center",
        "padding": "9px",
        "border": "1px solid #E8DADA"
    })
    .set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("caption-side", "top"),
                ("background-color", "#F0F9FF"),
                ("color", "#155E75"),
                ("font-size", "17px"),
                ("font-weight", "800"),
                ("text-align", "left"),
                ("padding", "14px 16px"),
                ("border", "1px solid #D7EAF1"),
                ("border-bottom", "none")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#FFF1F2"),
                ("color", "#7A2020"),
                ("font-weight", "800"),
                ("text-align", "center"),
                ("padding", "10px"),
                ("border", "1px solid #E8DADA")
            ]
        },
        {
            "selector": "td",
            "props": [
                ("background-color", "#FFFFFF"),
                ("color", "#3F2929"),
                ("border", "1px solid #EDE2E2"),
                ("padding", "9px")
            ]
        },
        {
            "selector": "tbody tr:nth-child(even) td",
            "props": [
                ("background-color", "#FFF9F9")
            ]
        }
    ])
)
# Out:
# <style type="text/css">
# #T_a760f caption {
#   caption-side: top;
#   background-color: #F0F9FF;
#   color: #155E75;
#   font-size: 17px;
#   font-weight: 800;
#   text-align: left;
#   padding: 14px 16px;
#   border: 1px solid #D7EAF1;
#   border-bottom: none;
# }
# #T_a760f th {
#   background-color: #FFF1F2;
#   color: #7A2020;
#   font-weight: 800;
#   text-align: center;
#   padding: 10px;
#   border: 1px solid #E8DADA;
# }
# #T_a760f td {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   border: 1px solid #EDE2E2;
#   padding: 9px;
# }
# #T_a760f tbody tr:nth-child(even) td {
#   background-color: #FFF9F9;
# }
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
#     padding-bottom:15px;
#     border-bottom:1px solid #F0D7D7;
# ">
#
# <div>
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
# ">
# EDA • TARGET ANALYSIS
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:4px 0 0 0;
# ">
# Step 12 — Check Class Balance
# </h3>
# </div>
#
# <div style="
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     color:#B91C1C;
#     border-radius:20px;
#     padding:7px 13px;
#     font-size:10px;
#     font-weight:800;
# ">
# TARGET: num
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:22px;
#     margin-top:18px;
#     align-items:stretch;
# ">
#
# <div style="
#     flex:1.2;
#     background:#F7FCFB;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:16px 18px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
#     margin-bottom:8px;
# ">
# WHY CHECK CLASS BALANCE?
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
# ">
# The target variable contains five classes representing different levels
# of heart disease severity. Examining their distribution helps us determine
# whether the classes are reasonably represented or whether some classes
# are underrepresented.
# </div>
#
# </div>
#
#
# <div style="
#     flex:0.8;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:11px;
#     padding:16px 18px;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
#     margin-bottom:8px;
# ">
# WHAT WE WILL MEASURE
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
# ">
# <strong style="color:#155E75;">Class count</strong><br>
# Number of observations in each target class.
#
# <br><br>
#
# <strong style="color:#155E75;">Class percentage</strong><br>
# Share of the dataset represented by each class.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     padding:12px 16px;
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:10px;
# ">
#
# <span style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# INTERPRETATION
# </span>
#
# <span style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
# ">
# &nbsp;The class distribution will guide how we interpret model performance
# later, especially recall, precision, and F1-score.
# </span>
#
# </div>
#
# </div>

# %%
# Check the distribution of the target variable

from IPython.display import display, HTML
import matplotlib.pyplot as plt

# Calculate class counts and percentages

target_counts = df_clean["cardio"].value_counts().sort_index()

target_percentages = (
    df_clean["cardio"].value_counts(normalize=True).sort_index() * 100
)

class_balance = pd.DataFrame({
    "Class": target_counts.index.astype(int),
    "Count": target_counts.values,
    "Percentage": target_percentages.values
})


# ---------------------------------------------------------
# Styled table
# ---------------------------------------------------------

styled_table = (
    class_balance
    .style
    .format({
        "Percentage": "{:.2f}%"
    })
    .set_caption("🎯 Target Class Distribution")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#3F2929",
        "font-size": "13px",
        "text-align": "center",
        "padding": "10px",
        "border": "1px solid #E8DADA"
    })
    .set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("caption-side", "top"),
                ("background-color", "#FFF1F2"),
                ("color", "#7A2020"),
                ("font-size", "17px"),
                ("font-weight", "800"),
                ("text-align", "left"),
                ("padding", "14px 16px"),
                ("border", "1px solid #F3C2C7"),
                ("border-bottom", "none")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#F0FDFA"),
                ("color", "#115E59"),
                ("font-weight", "800"),
                ("padding", "10px"),
                ("border", "1px solid #D5EAE5")
            ]
        },
        {
            "selector": "td",
            "props": [
                ("background-color", "#FFFFFF"),
                ("color", "#3F2929"),
                ("padding", "9px"),
                ("border", "1px solid #EDE2E2")
            ]
        },
        {
            "selector": "tbody tr:nth-child(even) td",
            "props": [
                ("background-color", "#FFF9F9")
            ]
        }
    ])
)

display(styled_table)


# ---------------------------------------------------------
# Styled class distribution chart
# ---------------------------------------------------------

plt.figure(figsize=(8, 5))

# Theme colors: red / burgundy / teal

theme_colors = [
    "#B91C1C",
    "#DC2626",
    "#C2410C",
    "#0F766E",
    "#115E59"
]

bars = plt.bar(
    class_balance["Class"].astype(str),
    class_balance["Count"],
    color=theme_colors[:len(class_balance)],
    width=0.65
)

plt.title(
    "Target Class Distribution",
    fontsize=15,
    fontweight="bold",
    color="#7A2020",
    pad=15
)

plt.xlabel(
    "Cardiovascular Disease Class",
    fontsize=11,
    fontweight="bold",
    color="#704D4D"
)

plt.ylabel(
    "Number of Patients",
    fontsize=11,
    fontweight="bold",
    color="#704D4D"
)

plt.xticks(
    color="#7A2020",
    fontweight="bold"
)

plt.yticks(
    color="#704D4D"
)


# Add count labels above each bar

for bar, count in zip(bars, class_balance["Count"]):

    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 8,
        str(count),
        ha="center",
        va="bottom",
        fontsize=11,
        fontweight="bold",
        color="#7A2020"
    )


# Keep the chart clean

plt.grid(
    axis="y",
    alpha=0.15
)

plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_color("#E8DADA")
plt.gca().spines["bottom"].set_color("#E8DADA")

plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_4cf3a caption {
#   caption-side: top;
#   background-color: #FFF1F2;
#   color: #7A2020;
#   font-size: 17px;
#   font-weight: 800;
#   text-align: left;
#   padding: 14px 16px;
#   border: 1px solid #F3C2C7;
#   border-bottom: none;
# }
# #T_4cf3a th {
#   background-color: #F0FDFA;
#   color: #115E59;
#   font-weight: 800;
#   padding: 10px;
#   border: 1px solid #D5EAE5;
# }
# #T_4cf3a td {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   padding: 9px;
#   border: 1px solid #EDE2E2;
# }
# #T_4cf3a tbody tr:nth-child(even) td {
#   background-color: #FFF9F9;
# }
# #T_4cf3a_row0_col0, #T_4cf3a_row0_col1, #T_4cf3a_row0_col2, #T_4cf3a_row1_col0, #T_4cf3a_row1_col1, #T_4cf3a_row1_col2 {
#   background-color: #FFFFFF;
#   color: #3F2929;
#   font-size: 13px;
#   text-align: center;
#   padding: 10px;
#   border: 1px solid #E8DADA;
# }
# </style>
# <table id="T_4cf3a">
#   <caption>🎯 Target Class Distribution</caption>
#   <thead>
#     <tr>
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:14px;
#     margin-bottom:17px;
# ">
#
# <div style="
#     width:46px;
#     height:46px;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:12px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:22px;
# ">
# 📈
# </div>
#
# <div>
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
# ">
# EDA • DISTRIBUTION ANALYSIS
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:3px 0 0 0;
# ">
# Step 13 — Numeric Feature Distributions
# </h3>
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-top:5px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHAT WE ANALYZE
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# The distributions of age, resting blood pressure, cholesterol,
# maximum heart rate, oldpeak, and number of vessels.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:11px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHAT WE LOOK FOR
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# We inspect the shape, spread, concentration, and possible skewness
# of each numerical feature.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:15px;
#     padding:13px 16px;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:10px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHY HISTOGRAMS?
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.75;
#     margin-top:5px;
# ">
# Histograms help us understand how numerical values are distributed across
# the patient population. These patterns will support our later analysis of
# outliers, relationships, and model preparation.
# </div>
#
# </div>
#
# </div>

# %%
import matplotlib.pyplot as plt

from IPython.display import display, HTML

# Numerical features used for distribution analysis

numeric_features = [
    "age",
    "height",
    "weight",
    "ap_hi",
    "ap_lo"
]

# Theme colors

theme_colors = [
    "#B91C1C",
    "#DC2626",
    "#C2410C",
    "#0F766E",
    "#115E59"
]

# Create individual histograms

fig, axes = plt.subplots(
    2,
    3,
    figsize=(15, 8)
)

axes = axes.flatten()

for ax, column, color in zip(
    axes,
    numeric_features,
    theme_colors
):

    ax.hist(
        df_clean[column],
        bins=20,
        color=color,
        edgecolor="#FFFFFF",
        linewidth=1.2,
        alpha=0.88
    )

    ax.set_title(
        column.upper(),
        fontsize=12,
        fontweight="bold",
        color="#7A2020",
        pad=10
    )

    ax.set_xlabel(
        "Value",
        fontsize=9,
        color="#704D4D"
    )

    ax.set_ylabel(
        "Frequency",
        fontsize=9,
        color="#704D4D"
    )

    ax.tick_params(
        axis="both",
        labelsize=8,
        colors="#704D4D"
    )

    ax.grid(
        axis="y",
        alpha=0.12
    )

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#E8DADA")
    ax.spines["bottom"].set_color("#E8DADA")


# Hide the unused sixth subplot

axes[-1].set_visible(False)


fig.suptitle(
    "Distribution of Numerical Features",
    fontsize=17,
    fontweight="bold",
    color="#7A2020",
    y=1.02
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     padding-bottom:15px;
#     border-bottom:1px solid #F0D7D7;
# ">
#
# <div>
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
# ">
# EDA • OUTLIER ANALYSIS
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:4px 0 0 0;
# ">
# Step 14 — Detect Potential Outliers
# </h3>
# </div>
#
# <div style="
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     color:#C2410C;
#     padding:8px 13px;
#     border-radius:20px;
#     font-size:10px;
#     font-weight:800;
# ">
# BOXPLOTS
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-top:18px;
# ">
#
# <div style="
#     flex:1;
#     padding:15px 17px;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHAT IS AN OUTLIER?
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# An outlier is an observation that lies unusually far from the central
# range of the feature. It may represent a genuine patient value or a
# data-quality issue.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     padding:15px 17px;
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHAT BOXPLots SHOW
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# Boxplots display the median, interquartile range, overall spread,
# and observations that fall beyond the typical range.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:15px;
#     padding:13px 16px;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:10px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# INTERPRETATION RULE
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.75;
#     margin-top:5px;
# ">
# Points outside the whiskers are potential outliers based on the
# IQR rule. They will be investigated rather than automatically removed,
# because an unusual medical measurement is not necessarily an invalid value.
# </div>
#
# </div>
#
# </div>

# %%
import matplotlib.pyplot as plt

# Numerical features for outlier analysis

numeric_features = [
    "age",
    "height",
    "weight",
    "ap_hi",
    "ap_lo"
]

# Theme colors

theme_colors = [
    "#B91C1C",
    "#DC2626",
    "#C2410C",
    "#0F766E",
    "#115E59"
]

fig, axes = plt.subplots(
    2,
    3,
    figsize=(15, 8)
)

axes = axes.flatten()

for ax, column, color in zip(
    axes,
    numeric_features,
    theme_colors
):

    ax.boxplot(
        df_clean[column],
        patch_artist=True,
        boxprops=dict(
            facecolor=color,
            edgecolor="#7A2020",
            linewidth=1.2
        ),
        medianprops=dict(
            color="#FFFFFF",
            linewidth=2
        ),
        whiskerprops=dict(
            color="#704D4D",
            linewidth=1.2
        ),
        capprops=dict(
            color="#704D4D",
            linewidth=1.2
        ),
        flierprops=dict(
            marker="o",
            markerfacecolor="#9F1239",
            markeredgecolor="#7A2020",
            markersize=4,
            alpha=0.7
        )
    )

    ax.set_title(
        column.upper(),
        fontsize=12,
        fontweight="bold",
        color="#7A2020",
        pad=10
    )

    ax.set_ylabel(
        "Value",
        fontsize=9,
        color="#704D4D"
    )

    ax.tick_params(
        axis="both",
        labelsize=8,
        colors="#704D4D"
    )

    ax.grid(
        axis="y",
        alpha=0.12
    )

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#E8DADA")
    ax.spines["bottom"].set_color("#E8DADA")


# Hide the unused sixth subplot

axes[-1].set_visible(False)


fig.suptitle(
    "Potential Outliers in Numerical Features",
    fontsize=17,
    fontweight="bold",
    color="#7A2020",
    y=1.02
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:6px;
# ">
# EDA • RELATIONSHIP ANALYSIS
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:19px;
#     font-weight:800;
#     margin:0 0 17px 0;
# ">
# Step 15 — Correlation Matrix
# </h3>
#
# <div style="
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     padding:14px 17px;
#     border-radius:8px;
#     margin-bottom:15px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# A correlation matrix helps us measure the strength and direction of
# linear relationships between numerical variables.
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# POSITIVE CORRELATION
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# When one variable increases, the other tends to increase as well.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# NEGATIVE CORRELATION
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# When one variable increases, the other tends to decrease.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHY IT MATTERS
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# The matrix can reveal related features and useful relationships
# that may help us understand the dataset before modeling.
# </div>
#
# </div>
#
# </div>
#
# </div>

# %%
import matplotlib.pyplot as plt

import numpy as np

# Select numerical features for correlation analysis

correlation_features = [
    "age",
    "height",
    "weight",
    "ap_hi",
    "ap_lo",
    "cardio"
]

correlation_matrix = df_clean[correlation_features].corr()

# Create heatmap

fig, ax = plt.subplots(figsize=(10, 7))

# Use a project-friendly diverging colormap

heatmap = ax.imshow(
    correlation_matrix,
    cmap="RdYlGn",
    vmin=-1,
    vmax=1
)

# Add colorbar

cbar = plt.colorbar(heatmap, ax=ax)

cbar.set_label(
    "Correlation",
    fontsize=10,
    color="#704D4D"
)

# Axis labels

ax.set_xticks(range(len(correlation_features)))

ax.set_yticks(range(len(correlation_features)))

ax.set_xticklabels(
    correlation_features,
    rotation=45,
    ha="right",
    fontsize=9,
    color="#7A2020"
)

ax.set_yticklabels(
    correlation_features,
    fontsize=9,
    color="#7A2020"
)

# Add correlation values

for i in range(len(correlation_features)):
    for j in range(len(correlation_features)):
        value = correlation_matrix.iloc[i, j]

        ax.text(
            j,
            i,
            f"{value:.2f}",
            ha="center",
            va="center",
            fontsize=9,
            fontweight="bold",
            color="#3F2929"
        )

ax.set_title(
    "Correlation Matrix of Numerical Features",
    fontsize=16,
    fontweight="bold",
    color="#7A2020",
    pad=15
)

plt.tight_layout()

plt.show()

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:6px;
# ">
# EDA • TARGET RELATIONSHIPS
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:19px;
#     font-weight:800;
#     margin:0 0 17px 0;
# ">
# Step 16 — Features vs Target
# </h3>
#
#
# <div style="
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:16px 18px;
#     margin-bottom:15px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
#     margin-bottom:7px;
# ">
# ANALYSIS GOAL
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
# ">
# We compare selected numerical features across the target classes to
# identify patterns that may differ between patients with different
# heart-disease severity levels.
# </div>
#
# </div>
#
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# NUMERICAL FEATURES
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Age • Resting BP • Cholesterol • Maximum Heart Rate • Oldpeak
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# TARGET
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# <code style="color:#9A3412;">num</code> — heart disease severity class from 0 to 4.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHAT WE LOOK FOR
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Differences in feature distributions across the five target classes.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:15px;
#     padding:13px 16px;
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:10px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
#     margin-bottom:5px;
# ">
# INTERPRETATION
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.75;
# ">
# The comparison helps identify features that may show different patterns
# across target classes. These findings are exploratory and do not imply
# clinical causation.
# </div>
#
# </div>
#
# </div>

# %%
print("DataFrame columns:")
print(df.columns.tolist())

print("\nShape:")
print(df.shape)
# Out:
# DataFrame columns:
# ['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio']
#
# Shape:
# (70000, 13)

# %%
import matplotlib.pyplot as plt

# ============================================================
# Numerical features to compare against the target
# ============================================================

features_vs_target = [
    "age",
    "ap_hi",
    "ap_lo",
    "weight",
    "cholesterol"
]

# Use the current cardiovascular dataset
plot_df = df.copy()

# Create a boxplot for each numerical feature by target class
fig, axes = plt.subplots(
    2,
    3,
    figsize=(15, 8)
)

axes = axes.flatten()

# Theme colors
theme_colors = [
    "#B91C1C",
    "#DC2626",
    "#C2410C",
    "#0F766E",
    "#115E59"
]

# Get target classes
target_classes = sorted(
    plot_df["cardio"].dropna().unique()
)

for ax, feature in zip(
    axes,
    features_vs_target
):

    grouped_data = [
        plot_df.loc[
            plot_df["cardio"] == target_class,
            feature
        ].dropna()
        for target_class in target_classes
    ]

    box = ax.boxplot(
        grouped_data,
        patch_artist=True,
        tick_labels=target_classes,
        medianprops=dict(
            color="#FFFFFF",
            linewidth=2
        ),
        whiskerprops=dict(
            color="#704D4D"
        ),
        capprops=dict(
            color="#704D4D"
        )
    )

    # Apply theme colors
    for patch, color in zip(
        box["boxes"],
        theme_colors
    ):
        patch.set_facecolor(color)
        patch.set_edgecolor("#7A2020")
        patch.set_alpha(0.85)

    ax.set_title(
        feature.upper(),
        fontsize=12,
        fontweight="bold",
        color="#7A2020"
    )

    ax.set_xlabel(
        "Cardiovascular Disease (cardio)",
        fontsize=9,
        color="#704D4D"
    )

    ax.set_ylabel(
        "Value",
        fontsize=9,
        color="#704D4D"
    )

    ax.tick_params(
        labelsize=8,
        colors="#704D4D"
    )

    ax.grid(
        axis="y",
        alpha=0.12
    )

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#E8DADA")
    ax.spines["bottom"].set_color("#E8DADA")


# Hide unused sixth subplot
axes[-1].set_visible(False)

fig.suptitle(
    "Numerical Features Across Cardiovascular Disease Classes",
    fontsize=17,
    fontweight="bold",
    color="#7A2020",
    y=1.02
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:5px;
# ">
# EDA • FINAL SUMMARY
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:19px;
#     font-weight:800;
#     margin:0 0 18px 0;
# ">
# Step 17 — Key Findings
# </h3>
#
# <div style="
#     display:grid;
#     grid-template-columns:1fr 1fr;
#     gap:12px;
# ">
#
# <div style="
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# 01 • DATA QUALITY
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# Missing values were handled during data preparation, and no duplicate
# rows remained in the cleaned dataset.
# </div>
#
# </div>
#
#
# <div style="
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# 02 • TARGET DISTRIBUTION
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# The target contains five classes, with noticeably different numbers
# of observations across classes. The minority class should be considered
# when interpreting classification metrics.
# </div>
#
# </div>
#
#
# <div style="
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# 03 • FEATURE DISTRIBUTIONS
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# The numerical features have different ranges and distribution shapes.
# Some features show concentrated values or noticeable skewness.
# </div>
#
# </div>
#
#
# <div style="
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# 04 • OUTLIERS & RELATIONSHIPS
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:6px;
# ">
# Boxplots revealed potential outliers, while the correlation and
# feature-target analysis highlighted relationships worth considering
# during model preparation.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:17px;
#     padding:15px 17px;
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:10px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# NEXT STEP
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:5px;
# ">
# These EDA findings provide the basis for defining the supervised
# classification problem and preparing the data for model training.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:6px;
# ">
# SUPERVISED LEARNING • CLASSIFICATION
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:19px;
#     font-weight:800;
#     margin:0 0 17px 0;
# ">
# Step 18 — Classification Problem
# </h3>
#
# <div style="
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     padding:14px 17px;
#     border-radius:8px;
#     margin-bottom:15px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# The goal is to build a supervised classification model that predicts
# the heart disease severity class of a patient based on the available
# clinical features.
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# INPUT FEATURES
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Patient characteristics such as age, sex, chest pain type, blood
# pressure, cholesterol, maximum heart rate, and other recorded features.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# TARGET
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# <code style="color:#9A3412;">num</code> — five classes representing
# different levels of heart disease severity, from 0 to 4.
# </div>
#
# </div>
#
# </div>
#
# <div style="
#     margin-top:15px;
#     padding:13px 16px;
#     background:#F5FAFD;
#     border:1px solid #D7EAF1;
#     border-radius:10px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
#     margin-bottom:5px;
# ">
# BASELINE APPROACH
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.75;
# ">
# We will first use Logistic Regression as a simple and interpretable
# baseline model. Its performance will provide a reference point for
# comparing more advanced classification models later.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# SUPERVISED LEARNING • DATA SPLIT
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 18px 0;
# ">
# Step 19 — Features & Target Separation
# </h3>
#
#
# <div style="
#     display:flex;
#     gap:14px;
#     margin-bottom:16px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:12px;
#     padding:17px;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# X — INPUT FEATURES
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:14px;
#     font-weight:800;
#     margin-top:7px;
# ">
# Patient Information
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Contains the features used by the model to learn patterns from the
# patient records.
# </div>
#
# </div>
#
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:12px;
#     padding:17px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# y — TARGET
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:14px;
#     font-weight:800;
#     margin-top:7px;
# ">
# <code style="color:#9A3412;">num</code>
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Contains the heart disease severity class that the model is expected
# to predict.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     border-radius:8px;
#     padding:14px 17px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# Separating the target from the input features prevents the model from
# using the answer itself during training and creates a clear structure
# for the classification workflow.
# </div>
#
# </div>
#
# </div>

# %%
from IPython.display import display, HTML

# ============================================================
# Separate input features (X) from the target variable (y)
# ============================================================

X = df_encoded.drop(columns=["cardio"])

y = df_encoded["cardio"]

# Target information
target_classes = sorted(y.unique())

target_counts = y.value_counts().sort_index()

# ============================================================
# Styled output
# ============================================================

display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #E8D3D3;
    border-radius:14px;
    padding:22px 25px;
    margin:12px 0;
    box-shadow:0 4px 14px rgba(127,29,29,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.7px;
    margin-bottom:5px;
">
SUPERVISED LEARNING • DATA SPLIT
</div>

<div style="
    color:#7A2020;
    font-size:18px;
    font-weight:800;
    margin-bottom:18px;
">
🫀 Features & Target Separation
</div>


<div style="
    display:flex;
    gap:12px;
">

<div style="
    flex:1;
    background:#F0F9FF;
    border:1px solid #C9E4EF;
    border-radius:11px;
    padding:15px;
">

<div style="
    color:#0369A1;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">
X — INPUT FEATURES
</div>

<div style="
    color:#155E75;
    font-size:15px;
    font-weight:800;
    margin-top:6px;
">
{X.shape[1]} Features
</div>

<div style="
    color:#536F7A;
    font-size:11px;
    margin-top:4px;
">
Shape: {X.shape}
</div>

</div>


<div style="
    flex:1;
    background:#FFF1F2;
    border:1px solid #F3C2C7;
    border-radius:11px;
    padding:15px;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">
y — TARGET
</div>

<div style="
    color:#7A2020;
    font-size:15px;
    font-weight:800;
    margin-top:6px;
">
cardio
</div>

<div style="
    color:#704D4D;
    font-size:11px;
    margin-top:4px;
">
Shape: {y.shape} • Classes: {target_classes}
</div>

</div>

</div>


<div style="
    margin-top:13px;
    background:#F0FDFA;
    border:1px solid #D5EAE5;
    border-radius:11px;
    padding:14px 16px;
">

<div style="
    color:#0F766E;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
    margin-bottom:7px;
">
TARGET DISTRIBUTION
</div>

<div style="
    color:#536F7A;
    font-size:12px;
    line-height:1.8;
">
{" • ".join(
    [f"<b style='color:#7A2020;'>Class {cls}</b>: {count}"
     for cls, count in target_counts.items()]
)}
</div>

</div>

</div>
"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:14px;
#     padding:22px 25px;
#     margin:12px 0;
#     box-shadow:0 4px 14px rgba(127,29,29,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:5px;
# ">
# SUPERVISED LEARNING • DATA SPLIT
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin-bottom:18px;
# ">
# 🫀 Features & Target Separation
# </div>
#
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# X — INPUT FEATURES
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:15px;
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# SUPERVISED LEARNING • DATA SPLITTING
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 18px 0;
# ">
# Step 20 — Train / Test Split
# </h3>
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-bottom:16px;
# ">
#
# <div style="
#     flex:4;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:12px;
#     padding:17px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# 80% • TRAINING DATA
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:15px;
#     font-weight:800;
#     margin-top:7px;
# ">
# Model Learning
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Used to train the Logistic Regression model and learn relationships
# between the input features and the target classes.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:12px;
#     padding:17px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.2px;
# ">
# 20% • TEST
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:15px;
#     font-weight:800;
#     margin-top:7px;
# ">
# Evaluation
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# Kept separate to evaluate how well the trained model performs on unseen data.
# </div>
#
# </div>
#
# </div>
#
# <div style="
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     border-radius:8px;
#     padding:14px 17px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# A fixed random state is used to make the split reproducible, so the same
# training and testing samples are obtained each time the notebook is run.
# </div>
#
# </div>
#
# </div>

# %%
from sklearn.model_selection import train_test_split
from IPython.display import display, HTML

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# Styled output
display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #E8D3D3;
    border-radius:14px;
    padding:22px 25px;
    margin:12px 0;
    box-shadow:0 4px 14px rgba(127,29,29,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.7px;
    margin-bottom:5px;
">
TRAIN / TEST SPLIT • RESULTS
</div>

<div style="
    color:#7A2020;
    font-size:18px;
    font-weight:800;
    margin-bottom:18px;
">
🫀 Dataset Split Summary
</div>

<div style="
    display:flex;
    gap:12px;
">

<div style="
    flex:1;
    background:#F0FDFA;
    border:1px solid #CBE7E1;
    border-radius:11px;
    padding:15px;
">

<div style="
    color:#0F766E;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">
TRAINING SET
</div>

<div style="
    color:#115E59;
    font-size:22px;
    font-weight:800;
    margin-top:6px;
">
{X_train.shape[0]}
</div>

<div style="
    color:#536F7A;
    font-size:11px;
">
samples • 80%
</div>

</div>

<div style="
    flex:1;
    background:#FFF1F2;
    border:1px solid #F3C2C7;
    border-radius:11px;
    padding:15px;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">
TEST SET
</div>

<div style="
    color:#7A2020;
    font-size:22px;
    font-weight:800;
    margin-top:6px;
">
{X_test.shape[0]}
</div>

<div style="
    color:#704D4D;
    font-size:11px;
">
samples • 20%
</div>

</div>

<div style="
    flex:1;
    background:#F0F9FF;
    border:1px solid #C9E4EF;
    border-radius:11px;
    padding:15px;
">

<div style="
    color:#0369A1;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">
FEATURES
</div>

<div style="
    color:#155E75;
    font-size:22px;
    font-weight:800;
    margin-top:6px;
">
{X_train.shape[1]}
</div>

<div style="
    color:#536F7A;
    font-size:11px;
">
input features
</div>

</div>

</div>

<div style="
    margin-top:13px;
    color:#704D4D;
    font-size:11px;
">
<b style="color:#7A2020;">Split ratio:</b> 80% training / 20% testing
&nbsp;&nbsp;•&nbsp;&nbsp;
<b style="color:#7A2020;">Random state:</b> 42
&nbsp;&nbsp;•&nbsp;&nbsp;
<b style="color:#7A2020;">Stratified:</b> Yes
</div>

</div>
"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:14px;
#     padding:22px 25px;
#     margin:12px 0;
#     box-shadow:0 4px 14px rgba(127,29,29,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:5px;
# ">
# TRAIN / TEST SPLIT • RESULTS
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin-bottom:18px;
# ">
# 🫀 Dataset Split Summary
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# TRAINING SET
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:22px;
#     font-weight:800;
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     margin-bottom:18px;
# ">
#
# <div>
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:5px;
# ">
# SUPERVISED LEARNING • BASELINE MODEL
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0;
# ">
# Step 21 — Logistic Regression
# </h3>
# </div>
#
# <div style="
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     color:#0F766E;
#     padding:8px 13px;
#     border-radius:20px;
#     font-size:11px;
#     font-weight:800;
# ">
# BASELINE
# </div>
#
# </div>
#
# <div style="
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     border-radius:8px;
#     padding:15px 18px;
#     margin-bottom:16px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# Logistic Regression is used as the baseline classifier because it provides
# a simple and interpretable reference point for the multiclass classification
# problem before comparing it with another model.
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# MODEL
# </div>
#
# <div style="
#     color:#155E75;
#     font-size:15px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Logistic Regression
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# OBJECTIVE
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Establish a baseline accuracy for later model comparison.
# </div>
#
# </div>
#
# </div>
#
# </div>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from IPython.display import display, HTML

# Create the baseline Logistic Regression pipeline
baseline_model = Pipeline([
    ("scaler", StandardScaler()),
    ("logistic_regression", LogisticRegression(
        max_iter=1000,
        random_state=42
    ))
])

# Train the model
baseline_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred_baseline = baseline_model.predict(X_test)

# Calculate baseline accuracy
baseline_accuracy = accuracy_score(y_test, y_pred_baseline)

# Styled output
display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #E8D3D3;
    border-radius:14px;
    padding:22px 25px;
    margin:12px 0;
    box-shadow:0 4px 14px rgba(127,29,29,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.7px;
    margin-bottom:5px;
">
BASELINE MODEL • RESULTS
</div>

<div style="
    color:#7A2020;
    font-size:18px;
    font-weight:800;
    margin-bottom:18px;
">
🤖 Logistic Regression Performance
</div>

<div style="
    display:flex;
    gap:12px;
">

<div style="
    flex:1;
    background:#F0FDFA;
    border:1px solid #CBE7E1;
    border-radius:11px;
    padding:16px;
">

<div style="
    color:#0F766E;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">
MODEL STATUS
</div>

<div style="
    color:#115E59;
    font-size:15px;
    font-weight:800;
    margin-top:6px;
">
Training Complete ✓
</div>

</div>

<div style="
    flex:1;
    background:#FFF1F2;
    border:1px solid #F3C2C7;
    border-radius:11px;
    padding:16px;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">
BASELINE ACCURACY
</div>

<div style="
    color:#7A2020;
    font-size:25px;
    font-weight:800;
    margin-top:4px;
">
{baseline_accuracy:.2%}
</div>

</div>

<div style="
    flex:1;
    background:#F0F9FF;
    border:1px solid #C9E4EF;
    border-radius:11px;
    padding:16px;
">

<div style="
    color:#0369A1;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">
TEST SAMPLES
</div>

<div style="
    color:#155E75;
    font-size:25px;
    font-weight:800;
    margin-top:4px;
">
{len(y_test)}
</div>

</div>

</div>

<div style="
    margin-top:14px;
    padding:12px 15px;
    background:#FFF8F8;
    border-radius:9px;
    color:#704D4D;
    font-size:11px;
">
The baseline accuracy provides the first reference point for evaluating
the performance of the classification models developed later.
</div>

</div>
"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:14px;
#     padding:22px 25px;
#     margin:12px 0;
#     box-shadow:0 4px 14px rgba(127,29,29,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:5px;
# ">
# BASELINE MODEL • RESULTS
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin-bottom:18px;
# ">
# 🤖 Logistic Regression Performance
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# MODEL STATUS
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:15px;
# ...

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#FFFFFF 0%,#F8FCFC 100%);
#     border:1px solid #D5EAE5;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(15,118,110,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# MODEL COMPARISON • SECOND CLASSIFIER
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 18px 0;
# ">
# Step 22 — Random Forest Classifier
# </h3>
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-bottom:16px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# MODEL
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:15px;
#     font-weight:800;
#     margin-top:6px;
# ">
# Random Forest
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:5px;
# ">
# An ensemble classifier that combines multiple decision trees.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# WHY RANDOM FOREST?
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:11px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# It can capture nonlinear relationships and interactions between
# features that Logistic Regression may not capture.
# </div>
#
# </div>
#
# </div>
#
# <div style="
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     border-radius:8px;
#     padding:14px 17px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# The Random Forest will be trained using exactly the same training data
# used for the Logistic Regression baseline so that the models can be
# compared fairly.
# </div>
#
# </div>
#
# </div>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from IPython.display import display, HTML

# Create the Random Forest classifier
random_forest = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    class_weight="balanced"
)

# Train using the same training split as the baseline
random_forest.fit(X_train, y_train)

# Predictions on the same test set
y_pred_rf = random_forest.predict(X_test)

# Accuracy
rf_accuracy = accuracy_score(y_test, y_pred_rf)

display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #D5EAE5;
    border-radius:14px;
    padding:21px 25px;
    box-shadow:0 4px 14px rgba(15,118,110,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="
    color:#0F766E;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.6px;
">
SECOND CLASSIFIER • RESULTS
</div>

<div style="
    color:#115E59;
    font-size:18px;
    font-weight:800;
    margin:5px 0 17px 0;
">
🌲 Random Forest Performance
</div>

<div style="
    display:flex;
    gap:12px;
">

<div style="
    flex:1;
    background:#F0FDFA;
    border:1px solid #CBE7E1;
    border-radius:10px;
    padding:14px;
">
<div style="color:#0F766E;font-size:10px;font-weight:800;">
MODEL STATUS
</div>
<div style="color:#115E59;font-size:15px;font-weight:800;margin-top:5px;">
Training Complete ✓
</div>
</div>

<div style="
    flex:1;
    background:#FFF1F2;
    border:1px solid #F3C2C7;
    border-radius:10px;
    padding:14px;
">
<div style="color:#9F1239;font-size:10px;font-weight:800;">
RANDOM FOREST ACCURACY
</div>
<div style="color:#7A2020;font-size:24px;font-weight:800;margin-top:3px;">
{rf_accuracy:.2%}
</div>
</div>

<div style="
    flex:1;
    background:#F0F9FF;
    border:1px solid #C9E4EF;
    border-radius:10px;
    padding:14px;
">
<div style="color:#0369A1;font-size:10px;font-weight:800;">
TEST SAMPLES
</div>
<div style="color:#155E75;font-size:24px;font-weight:800;margin-top:3px;">
{len(y_test)}
</div>
</div>

</div>
</div>
"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #D5EAE5;
#     border-radius:14px;
#     padding:21px 25px;
#     box-shadow:0 4px 14px rgba(15,118,110,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
# ">
# SECOND CLASSIFIER • RESULTS
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:18px;
#     font-weight:800;
#     margin:5px 0 17px 0;
# ">
# 🌲 Random Forest Performance
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:10px;
#     padding:14px;
# ">
# <div style="color:#0F766E;font-size:10px;font-weight:800;">
# MODEL STATUS
# </div>
# <div style="color:#115E59;font-size:15px;font-weight:800;margin-top:5px;">
# Training Complete ✓
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:14px;
#     padding:22px 26px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:6px;
# ">
# MODEL COMPARISON • FAIR EVALUATION
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:19px;
#     font-weight:800;
#     margin:0 0 15px 0;
# ">
# Step 23 — Consistent Train / Test Split
# </h3>
#
# <div style="
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:11px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:12px;
#     line-height:1.8;
# ">
# Both Logistic Regression and Random Forest are evaluated using the same
# training and testing sets. Keeping the split fixed ensures that the
# comparison reflects model differences rather than differences in the data.
# </div>
#
# </div>
#
# </div>

# %%
# Verify that both models use the same train/test split

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))
print("Same test set used by both models: Yes ✓")
# Out:
# Training samples: 56000
# Testing samples: 14000
# Same test set used by both models: Yes ✓

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# MODEL EVALUATION • CROSS-VALIDATION
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 17px 0;
# ">
# Step 24 — Cross-Validation
# </h3>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="color:#9F1239;font-size:10px;font-weight:800;letter-spacing:1px;">
# METHOD
# </div>
#
# <div style="color:#7A2020;font-size:15px;font-weight:800;margin-top:6px;">
# 5-Fold CV
# </div>
#
# <div style="color:#704D4D;font-size:11px;line-height:1.7;margin-top:5px;">
# The training data is divided into five folds and each fold is used once
# as validation data.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="color:#0F766E;font-size:10px;font-weight:800;letter-spacing:1px;">
# PURPOSE
# </div>
#
# <div style="color:#115E59;font-size:15px;font-weight:800;margin-top:6px;">
# More Reliable Estimate
# </div>
#
# <div style="color:#536F7A;font-size:11px;line-height:1.7;margin-top:5px;">
# Cross-validation reduces dependence on a single validation split.
# </div>
#
# </div>
#
# </div>
#
# </div>

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

# Use stratified 5-fold cross-validation
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# Cross-validation for Logistic Regression
lr_cv_scores = cross_val_score(
    baseline_model,
    X_train,
    y_train,
    cv=cv,
    scoring="accuracy"
)

# Cross-validation for Random Forest
rf_cv_scores = cross_val_score(
    random_forest,
    X_train,
    y_train,
    cv=cv,
    scoring="accuracy"
)

display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #E8D3D3;
    border-radius:14px;
    padding:22px 25px;
    box-shadow:0 4px 14px rgba(127,29,29,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="color:#9F1239;font-size:10px;font-weight:800;letter-spacing:1.6px;">
5-FOLD CROSS-VALIDATION • RESULTS
</div>

<div style="color:#7A2020;font-size:18px;font-weight:800;margin:5px 0 17px 0;">
📊 Cross-Validation Accuracy
</div>

<div style="display:flex;gap:12px;">

<div style="
    flex:1;
    background:#F0F9FF;
    border:1px solid #C9E4EF;
    border-radius:10px;
    padding:15px;
">
<div style="color:#0369A1;font-size:10px;font-weight:800;">
LOGISTIC REGRESSION
</div>
<div style="color:#155E75;font-size:23px;font-weight:800;margin-top:5px;">
{lr_cv_scores.mean():.2%}
</div>
<div style="color:#536F7A;font-size:11px;">
Mean CV Accuracy
</div>
</div>

<div style="
    flex:1;
    background:#F0FDFA;
    border:1px solid #CBE7E1;
    border-radius:10px;
    padding:15px;
">
<div style="color:#0F766E;font-size:10px;font-weight:800;">
RANDOM FOREST
</div>
<div style="color:#115E59;font-size:23px;font-weight:800;margin-top:5px;">
{rf_cv_scores.mean():.2%}
</div>
<div style="color:#536F7A;font-size:11px;">
Mean CV Accuracy
</div>
</div>

</div>

<div style="
    margin-top:13px;
    color:#704D4D;
    font-size:11px;
">
<b>Logistic Regression folds:</b>
{[f"{x:.2%}" for x in lr_cv_scores]}
<br>
<b>Random Forest folds:</b>
{[f"{x:.2%}" for x in rf_cv_scores]}
</div>

</div>
"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:14px;
#     padding:22px 25px;
#     box-shadow:0 4px 14px rgba(127,29,29,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="color:#9F1239;font-size:10px;font-weight:800;letter-spacing:1.6px;">
# 5-FOLD CROSS-VALIDATION • RESULTS
# </div>
#
# <div style="color:#7A2020;font-size:18px;font-weight:800;margin:5px 0 17px 0;">
# 📊 Cross-Validation Accuracy
# </div>
#
# <div style="display:flex;gap:12px;">
#
# <div style="
#     flex:1;
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:10px;
#     padding:15px;
# ">
# <div style="color:#0369A1;font-size:10px;font-weight:800;">
# LOGISTIC REGRESSION
# </div>
# <div style="color:#155E75;font-size:23px;font-weight:800;margin-top:5px;">
# 71.41%
# </div>
# <div style="color:#536F7A;font-size:11px;">
# Mean CV Accuracy
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# MODEL EVALUATION • CONFUSION MATRIX
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 16px 0;
# ">
# Step 25 — Confusion Matrix
# </h3>
#
# <div style="
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:11px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#9A3412;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# A confusion matrix shows how many samples from each actual class were
# correctly classified and how many were assigned to another class.
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-top:14px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:10px;
#     padding:14px;
# ">
#
# <div style="color:#0369A1;font-size:10px;font-weight:800;">
# LOGISTIC REGRESSION
# </div>
#
# <div style="color:#536F7A;font-size:11px;line-height:1.7;margin-top:5px;">
# Baseline confusion matrix for the five target classes.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:10px;
#     padding:14px;
# ">
#
# <div style="color:#0F766E;font-size:10px;font-weight:800;">
# RANDOM FOREST
# </div>
#
# <div style="color:#536F7A;font-size:11px;line-height:1.7;margin-top:5px;">
# Comparison confusion matrix using the same test samples.
# </div>
#
# </div>
#
# </div>
#
# </div>

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm_lr = confusion_matrix(y_test, y_pred_baseline)
cm_rf = confusion_matrix(y_test, y_pred_rf)

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

matrices = [
    (axes[0], cm_lr, "Logistic Regression"),
    (axes[1], cm_rf, "Random Forest")
]

for ax, cm, title in matrices:

    image = ax.imshow(
        cm,
        cmap="Reds"
    )

    ax.set_title(
        title,
        fontsize=13,
        fontweight="bold",
        color="#7A2020",
        pad=12
    )

    ax.set_xlabel(
        "Predicted Class",
        fontsize=10,
        color="#704D4D"
    )

    ax.set_ylabel(
        "Actual Class",
        fontsize=10,
        color="#704D4D"
    )

    ax.set_xticks(range(len(target_classes)))
    ax.set_yticks(range(len(target_classes)))

    ax.set_xticklabels(target_classes)
    ax.set_yticklabels(target_classes)

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(
                j,
                i,
                cm[i, j],
                ha="center",
                va="center",
                fontsize=10,
                fontweight="bold",
                color="#641111" if cm[i, j] < cm.max() * 0.6 else "#FFFFFF"
            )

    ax.tick_params(colors="#704D4D")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# MODEL EVALUATION • CLASSIFICATION METRICS
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 16px 0;
# ">
# Step 26 — Precision, Recall & F1-Score
# </h3>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="flex:1;background:#FFF1F2;border:1px solid #F3C2C7;border-radius:11px;padding:15px;">
# <div style="color:#9F1239;font-size:10px;font-weight:800;letter-spacing:1px;">
# PRECISION
# </div>
# <div style="color:#704D4D;font-size:11px;line-height:1.7;margin-top:6px;">
# Of the samples predicted as a class, how many actually belonged to that class?
# </div>
# </div>
#
# <div style="flex:1;background:#F0FDFA;border:1px solid #CBE7E1;border-radius:11px;padding:15px;">
# <div style="color:#0F766E;font-size:10px;font-weight:800;letter-spacing:1px;">
# RECALL
# </div>
# <div style="color:#536F7A;font-size:11px;line-height:1.7;margin-top:6px;">
# Of the samples actually belonging to a class, how many were correctly identified?
# </div>
# </div>
#
# <div style="flex:1;background:#FFF7ED;border:1px solid #F2D8C4;border-radius:11px;padding:15px;">
# <div style="color:#C2410C;font-size:10px;font-weight:800;letter-spacing:1px;">
# F1-SCORE
# </div>
# <div style="color:#704D4D;font-size:11px;line-height:1.7;margin-top:6px;">
# The harmonic mean of precision and recall, providing a balanced performance measure.
# </div>
# </div>
#
# </div>
#
# </div>

# %%
from sklearn.metrics import classification_report
import pandas as pd

# Classification reports
lr_report = classification_report(
    y_test,
    y_pred_baseline,
    output_dict=True,
    zero_division=0
)

rf_report = classification_report(
    y_test,
    y_pred_rf,
    output_dict=True,
    zero_division=0
)

# Create side-by-side summary using weighted averages
metrics_comparison = pd.DataFrame({
    "Metric": ["Precision", "Recall", "F1-Score"],
    "Logistic Regression": [
        lr_report["weighted avg"]["precision"],
        lr_report["weighted avg"]["recall"],
        lr_report["weighted avg"]["f1-score"]
    ],
    "Random Forest": [
        rf_report["weighted avg"]["precision"],
        rf_report["weighted avg"]["recall"],
        rf_report["weighted avg"]["f1-score"]
    ]
})

display(metrics_comparison.style.format({
    "Logistic Regression": "{:.2%}",
    "Random Forest": "{:.2%}"
}).set_properties(**{
    "text-align": "center",
    "font-size": "12px"
}))
# Out:
# <style type="text/css">
# #T_a7d47_row0_col0, #T_a7d47_row0_col1, #T_a7d47_row0_col2, #T_a7d47_row1_col0, #T_a7d47_row1_col1, #T_a7d47_row1_col2, #T_a7d47_row2_col0, #T_a7d47_row2_col1, #T_a7d47_row2_col2 {
#   text-align: center;
#   font-size: 12px;
# }
# </style>
# <table id="T_a7d47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7d47_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_a7d47_level0_col1" class="col_heading level0 col1" >Logistic Regression</th>
#       <th id="T_a7d47_level0_col2" class="col_heading level0 col2" >Random Forest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7d47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7d47_row0_col0" class="data row0 col0" >Precision</td>
#       <td id="T_a7d47_row0_col1" class="data row0 col1" >70.81%</td>
#       <td id="T_a7d47_row0_col2" class="data row0 col2" >71.54%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# MODEL EVALUATION • ROC-AUC
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 16px 0;
# ">
# Step 27 — ROC-AUC
# </h3>
#
# <div style="
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:11px;
#     padding:15px 17px;
# ">
#
# <div style="
#     color:#155E75;
#     font-size:12px;
#     line-height:1.8;
# ">
# Because the target contains five classes, ROC-AUC is calculated using a
# multiclass One-vs-Rest approach. The metric evaluates how well the model
# separates each class from the remaining classes.
# </div>
#
# </div>
#
# </div>

# %%
from sklearn.metrics import roc_auc_score
from IPython.display import display, HTML

# Probability predictions
lr_probabilities = baseline_model.predict_proba(X_test)[:, 1]
rf_probabilities = random_forest.predict_proba(X_test)[:, 1]

# Binary ROC-AUC
lr_roc_auc = roc_auc_score(
    y_test,
    lr_probabilities
)

rf_roc_auc = roc_auc_score(
    y_test,
    rf_probabilities
)

# Styled output
display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #E8D3D3;
    border-radius:14px;
    padding:20px 24px;
    box-shadow:0 4px 14px rgba(127,29,29,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.6px;
">

BINARY ROC-AUC • RESULTS

</div>

<div style="
    color:#7A2020;
    font-size:18px;
    font-weight:800;
    margin-top:5px;
">

🫀 Model Discrimination Performance

</div>

<div style="
    display:flex;
    gap:12px;
    margin-top:15px;
">

<!-- Logistic Regression -->

<div style="
    flex:1;
    background:#FFF1F2;
    border:1px solid #F3C2C7;
    border-radius:10px;
    padding:15px;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">

LOGISTIC REGRESSION

</div>

<div style="
    color:#7A2020;
    font-size:24px;
    font-weight:800;
    margin-top:5px;
">

{lr_roc_auc:.2%}

</div>

<div style="
    color:#8F6666;
    font-size:10px;
    margin-top:4px;
">

ROC-AUC Score

</div>

</div>


<!-- Random Forest -->

<div style="
    flex:1;
    background:#FDECEC;
    border:1px solid #E8B4B4;
    border-radius:10px;
    padding:15px;
">

<div style="
    color:#B91C1C;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">

RANDOM FOREST

</div>

<div style="
    color:#991B1B;
    font-size:24px;
    font-weight:800;
    margin-top:5px;
">

{rf_roc_auc:.2%}

</div>

<div style="
    color:#8F6666;
    font-size:10px;
    margin-top:4px;
">

ROC-AUC Score

</div>

</div>

</div>


<div style="
    margin-top:14px;
    padding:12px 15px;
    background:#FFF8F8;
    border-left:3px solid #B91C1C;
    border-radius:9px;
    color:#704D4D;
    font-size:11px;
">

ROC-AUC measures how well each model distinguishes between
patients with cardiovascular disease (1) and without cardiovascular disease (0).

</div>

</div>
"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:14px;
#     padding:20px 24px;
#     box-shadow:0 4px 14px rgba(127,29,29,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
# ">
#
# BINARY ROC-AUC • RESULTS
#
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin-top:5px;
# ">
#
# 🫀 Model Discrimination Performance
#
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-top:15px;
# ">
#
# <!-- Logistic Regression -->
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:15px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
#
# LOGISTIC REGRESSION
#
# </div>
#
# <div style="
#     color:#7A2020;
# ...

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#FFFFFF 0%,#FFF8F8 100%);
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# MODEL COMPARISON • FINAL SUMMARY
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 17px 0;
# ">
# Step 28 — Side-by-Side Comparison
# </h3>
#
# <div style="
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     border-radius:8px;
#     padding:14px 17px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# The models are compared using the same test set and the same evaluation
# criteria. This allows us to identify which classifier provides the stronger
# overall performance on the cardiac dataset.
# </div>
#
# </div>
#
# </div>

# %%
# Complete model comparison table

model_comparison = pd.DataFrame({
    "Metric": [
        "Test Accuracy",
        "CV Accuracy",
        "Weighted Precision",
        "Weighted Recall",
        "Weighted F1-Score",
        "Weighted ROC-AUC"
    ],
    "Logistic Regression": [
        baseline_accuracy,
        lr_cv_scores.mean(),
        lr_report["weighted avg"]["precision"],
        lr_report["weighted avg"]["recall"],
        lr_report["weighted avg"]["f1-score"],
        lr_roc_auc
    ],
    "Random Forest": [
        rf_accuracy,
        rf_cv_scores.mean(),
        rf_report["weighted avg"]["precision"],
        rf_report["weighted avg"]["recall"],
        rf_report["weighted avg"]["f1-score"],
        rf_roc_auc
    ]
})

display(
    model_comparison.style
    .format({
        "Logistic Regression": "{:.2%}",
        "Random Forest": "{:.2%}"
    })
    .hide(axis="index")
    .set_properties(**{
        "background-color": "#FFFFFF",
        "color": "#704D4D",
        "text-align": "center",
        "font-size": "13px",
        "padding": "11px",
        "border": "1px solid #F0D7D7"
    })
    .set_table_styles([
        {
            "selector": "table",
            "props": [
                ("width", "100%"),
                ("border-collapse", "collapse"),
                ("background-color", "#FFFFFF"),
                ("border", "1px solid #E8D3D3"),
                ("font-family", "Segoe UI, Arial, sans-serif")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#FFF1F2"),
                ("color", "#7A2020"),
                ("font-weight", "800"),
                ("font-size", "13px"),
                ("padding", "12px"),
                ("text-align", "center"),
                ("border", "1px solid #F0D7D7")
            ]
        },
        {
            "selector": "td:first-child",
            "props": [
                ("background-color", "#FFF8F8"),
                ("color", "#7A2020"),
                ("font-weight", "700"),
                ("text-align", "left")
            ]
        },
        {
            "selector": "th:first-child",
            "props": [
                ("background-color", "#F0FDFA"),
                ("color", "#0F766E"),
                ("text-align", "left")
            ]
        },
        {
            "selector": "th:nth-child(2)",
            "props": [
                ("background-color", "#FFF1F2"),
                ("color", "#9F1239")
            ]
        },
        {
            "selector": "th:nth-child(3)",
            "props": [
                ("background-color", "#F0FDFA"),
                ("color", "#0F766E")
            ]
        }
    ])
)
# Out:
# <style type="text/css">
# #T_e27c0 table {
#   width: 100%;
#   border-collapse: collapse;
#   background-color: #FFFFFF;
#   border: 1px solid #E8D3D3;
#   font-family: Segoe UI, Arial, sans-serif;
# }
# #T_e27c0 th {
#   background-color: #FFF1F2;
#   color: #7A2020;
#   font-weight: 800;
#   font-size: 13px;
#   padding: 12px;
#   text-align: center;
#   border: 1px solid #F0D7D7;
# }
# #T_e27c0 td:first-child {
#   background-color: #FFF8F8;
#   color: #7A2020;
#   font-weight: 700;
#   text-align: left;
# }
# #T_e27c0 th:first-child {
#   background-color: #F0FDFA;
#   color: #0F766E;
#   text-align: left;
# }
# #T_e27c0 th:nth-child(2) {
#   background-color: #FFF1F2;
#   color: #9F1239;
# }
# #T_e27c0 th:nth-child(3) {
#   background-color: #F0FDFA;
#   color: #0F766E;
# }
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:15px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 4px 15px rgba(127,29,29,0.07);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# MODEL EVALUATION • ERROR INTERPRETATION
# </div>
#
# <h3 style="
#     color:#641111;
#     font-size:20px;
#     font-weight:800;
#     margin:0 0 17px 0;
# ">
# Step 29 — False Positives & False Negatives
# </h3>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# FALSE POSITIVE
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:7px;
# ">
# The model predicts a patient belongs to a particular disease-severity
# class, while the actual class is different.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:16px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# FALSE NEGATIVE
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
#     margin-top:7px;
# ">
# The model fails to identify a sample as belonging to a particular class
# when that class is actually the correct class.
# </div>
#
# </div>
#
# </div>
#
# <div style="
#     margin-top:15px;
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:10px;
#     padding:14px 17px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
#     margin-bottom:5px;
# ">
# IMPORTANT INTERPRETATION
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
# ">
# These errors represent classification mistakes within the dataset.
# They should not be interpreted as clinical diagnoses or treatment decisions.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:24px 28px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     margin-bottom:7px;
# ">
# MODEL ENGINEERING • REUSABLE WORKFLOW
# </div>
#
# <h2 style="
#     color:#7A2020;
#     font-size:22px;
#     font-weight:800;
#     margin:0 0 18px 0;
# ">
# Section 6 — Feature Engineering & Pipeline
# </h2>
#
# <div style="
#     display:flex;
#     gap:12px;
#     align-items:stretch;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border-radius:11px;
#     padding:16px;
#     border:1px solid #F3C2C7;
# ">
# <div style="color:#9F1239;font-size:10px;font-weight:800;letter-spacing:1px;">
# FEATURE ENGINEERING
# </div>
# <div style="color:#704D4D;font-size:12px;line-height:1.7;margin-top:7px;">
# Create an additional meaningful feature from the existing patient variables.
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#F0F9FF;
#     border-radius:11px;
#     padding:16px;
#     border:1px solid #C9E4EF;
# ">
# <div style="color:#0369A1;font-size:10px;font-weight:800;letter-spacing:1px;">
# PREPROCESSING
# </div>
# <div style="color:#536F7A;font-size:12px;line-height:1.7;margin-top:7px;">
# Handle numerical and categorical features consistently inside the workflow.
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border-radius:11px;
#     padding:16px;
#     border:1px solid #CBE7E1;
# ">
# <div style="color:#0F766E;font-size:10px;font-weight:800;letter-spacing:1px;">
# PIPELINE
# </div>
# <div style="color:#536F7A;font-size:12px;line-height:1.7;margin-top:7px;">
# Combine preprocessing and model training into one reusable process.
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF7ED;
#     border-radius:11px;
#     padding:16px;
#     border:1px solid #F2D8C4;
# ">
# <div style="color:#C2410C;font-size:10px;font-weight:800;letter-spacing:1px;">
# VALIDATION
# </div>
# <div style="color:#704D4D;font-size:12px;line-height:1.7;margin-top:7px;">
# Verify that the complete workflow can train and predict from start to finish.
# </div>
# </div>
#
# </div>
#
# <div style="
#     margin-top:18px;
#     padding:14px 17px;
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     border-radius:8px;
# ">
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# The goal is to create a repeatable machine-learning workflow where
# feature preparation, preprocessing, training, and prediction are handled
# consistently without manual preprocessing steps.
# </div>
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:21px 25px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
#     margin-bottom:6px;
# ">
# FEATURE ENGINEERING
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     margin:0 0 14px 0;
# ">
# Step 30 — Create an Engineered Feature
# </h3>
#
# <div style="
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:14px 17px;
# ">
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
# ">
# We create a derived feature called <code style="color:#9F1239;">chol_age_ratio</code>,
# which represents cholesterol relative to the patient's age. The feature is
# created separately for the training and test sets to avoid data leakage.
# </div>
# </div>
#
# </div>

# %%
from IPython.display import display, HTML

# Create copies for feature engineering
X_train_fe = X_train.copy()
X_test_fe = X_test.copy()

# Create an engineered feature
X_train_fe["ap_hi_age_ratio"] = (
    X_train_fe["ap_hi"] / X_train_fe["age"]
)

X_test_fe["ap_hi_age_ratio"] = (
    X_test_fe["ap_hi"] / X_test_fe["age"]
)

# Styled output
display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #E8D3D3;
    border-radius:14px;
    padding:20px 24px;
    margin:12px 0;
    box-shadow:0 4px 14px rgba(127,29,29,0.07);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.6px;
    margin-bottom:5px;
">

FEATURE ENGINEERING • COMPLETED

</div>

<div style="
    color:#7A2020;
    font-size:18px;
    font-weight:800;
    margin-bottom:16px;
">

🫀 Engineered Feature: Blood Pressure / Age Ratio

</div>

<div style="
    display:flex;
    gap:12px;
">

<!-- Feature -->

<div style="
    flex:1;
    background:#FFF1F2;
    border:1px solid #F3C2C7;
    border-radius:11px;
    padding:15px;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">

NEW FEATURE

</div>

<div style="
    color:#7A2020;
    font-size:17px;
    font-weight:800;
    margin-top:6px;
">

ap_hi_age_ratio

</div>

<div style="
    color:#8F6666;
    font-size:10px;
    margin-top:4px;
">

Systolic BP relative to age

</div>

</div>


<!-- Training -->

<div style="
    flex:1;
    background:#FDECEC;
    border:1px solid #E8B4B4;
    border-radius:11px;
    padding:15px;
">

<div style="
    color:#B91C1C;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">

TRAINING FEATURES

</div>

<div style="
    color:#991B1B;
    font-size:24px;
    font-weight:800;
    margin-top:4px;
">

{X_train_fe.shape[1]}

</div>

<div style="
    color:#8F6666;
    font-size:10px;
    margin-top:4px;
">

Features after engineering

</div>

</div>


<!-- Test -->

<div style="
    flex:1;
    background:#FFF8F8;
    border:1px solid #E8DADA;
    border-radius:11px;
    padding:15px;
">

<div style="
    color:#9F1239;
    font-size:10px;
    font-weight:800;
    letter-spacing:1px;
">

TEST FEATURES

</div>

<div style="
    color:#7A2020;
    font-size:24px;
    font-weight:800;
    margin-top:4px;
">

{X_test_fe.shape[1]}

</div>

<div style="
    color:#8F6666;
    font-size:10px;
    margin-top:4px;
">

Features after engineering

</div>

</div>

</div>


<div style="
    margin-top:14px;
    padding:12px 15px;
    background:#FFF8F8;
    border-left:3px solid #B91C1C;
    border-radius:9px;
    color:#704D4D;
    font-size:11px;
">

✓ Feature engineering completed successfully.
The new feature represents systolic blood pressure relative to the patient's age.

</div>

</div>
"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E8D3D3;
#     border-radius:14px;
#     padding:20px 24px;
#     margin:12px 0;
#     box-shadow:0 4px 14px rgba(127,29,29,0.07);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
#     margin-bottom:5px;
# ">
#
# FEATURE ENGINEERING • COMPLETED
#
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin-bottom:16px;
# ">
#
# 🫀 Engineered Feature: Blood Pressure / Age Ratio
#
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <!-- Feature -->
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
#
# NEW FEATURE
#
# </div>
#
# <div style="
# ...

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:21px 25px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="color:#0369A1;font-size:10px;font-weight:800;letter-spacing:1.6px;">
# SCIKIT-LEARN WORKFLOW
# </div>
#
# <h3 style="color:#7A2020;font-size:18px;margin:4px 0 14px 0;">
# Step 31 — Build the Pipeline
# </h3>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:10px;
#     padding:14px;
# ">
# <div style="color:#0369A1;font-size:10px;font-weight:800;">
# NUMERICAL FEATURES
# </div>
# <div style="color:#536F7A;font-size:12px;margin-top:6px;line-height:1.7;">
# StandardScaler
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:10px;
#     padding:14px;
# ">
# <div style="color:#0F766E;font-size:10px;font-weight:800;">
# CATEGORICAL FEATURES
# </div>
# <div style="color:#536F7A;font-size:12px;margin-top:6px;line-height:1.7;">
# OneHotEncoder
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:14px;
# ">
# <div style="color:#9F1239;font-size:10px;font-weight:800;">
# CLASSIFIER
# </div>
# <div style="color:#704D4D;font-size:12px;margin-top:6px;line-height:1.7;">
# Logistic Regression
# </div>
# </div>
#
# </div>
#
# </div>

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Identify numerical and categorical features
numeric_features = X_train_fe.select_dtypes(
    include=["int64", "float64", "int32", "float32"]
).columns.tolist()

categorical_features = X_train_fe.select_dtypes(
    include=["object", "category", "bool"]
).columns.tolist()

# Numerical preprocessing
numeric_transformer = StandardScaler()

# Categorical preprocessing
categorical_transformer = OneHotEncoder(
    handle_unknown="ignore"
)

# Combine preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

print("Preprocessing configuration created ✓")
print(f"Numerical features: {len(numeric_features)}")
print(f"Categorical features: {len(categorical_features)}")
# Out:
# Preprocessing configuration created ✓
# Numerical features: 13
# Categorical features: 0

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# Build the complete pipeline
pipeline = Pipeline([
    ("preprocessing", preprocessor),
    ("model", LogisticRegression(
        max_iter=1000,
        random_state=42
    ))
])

print("Scikit-learn Pipeline created successfully ✓")
# Out:
# Scikit-learn Pipeline created successfully ✓

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:21px 25px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="color:#0F766E;font-size:10px;font-weight:800;letter-spacing:1.6px;">
# PIPELINE TRAINING
# </div>
#
# <h3 style="color:#7A2020;font-size:18px;margin:4px 0 12px 0;">
# Step 32 — Fit the Pipeline
# </h3>
#
# <div style="
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:10px;
#     padding:14px 17px;
# ">
# <div style="color:#536F7A;font-size:12px;line-height:1.8;">
# The complete pipeline is fitted using only the training data.
# Preprocessing parameters are learned from the training set before
# the classifier is trained.
# </div>
# </div>
#
# </div>

# %%
# Fit the complete pipeline on training data
pipeline.fit(X_train_fe, y_train)

print("Pipeline training completed successfully ✓")
# Out:
# Pipeline training completed successfully ✓

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:21px 25px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="color:#C2410C;font-size:10px;font-weight:800;letter-spacing:1.6px;">
# MODEL PREDICTION
# </div>
#
# <h3 style="color:#7A2020;font-size:18px;margin:4px 0 12px 0;">
# Step 33 — Predict on Test Data
# </h3>
#
# <div style="
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:10px;
#     padding:14px 17px;
# ">
# <div style="color:#704D4D;font-size:12px;line-height:1.8;">
# The trained pipeline processes the unseen test data automatically and
# generates predictions without requiring separate encoding or scaling steps.
# </div>
# </div>
#
# </div>

# %%
from sklearn.metrics import accuracy_score

# Generate predictions using the complete pipeline
pipeline_predictions = pipeline.predict(X_test_fe)

# Calculate pipeline accuracy
pipeline_accuracy = accuracy_score(
    y_test,
    pipeline_predictions
)

print("PIPELINE PREDICTION RESULTS")
print("-" * 35)
print(f"Test samples: {len(y_test)}")
print(f"Test accuracy: {pipeline_accuracy:.2%}")
print("Predictions generated successfully ✓")
# Out:
# PIPELINE PREDICTION RESULTS
# -----------------------------------
# Test samples: 14000
# Test accuracy: 71.18%
# Predictions generated successfully ✓

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:21px 25px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="color:#0F766E;font-size:10px;font-weight:800;letter-spacing:1.6px;">
# REPRODUCIBILITY CHECK
# </div>
#
# <h3 style="color:#7A2020;font-size:18px;margin:4px 0 12px 0;">
# Step 34 — End-to-End Pipeline Test
# </h3>
#
# <div style="
#     display:flex;
#     gap:12px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:10px;
#     padding:14px;
# ">
# <div style="color:#0F766E;font-size:10px;font-weight:800;">
# TRAIN
# </div>
# <div style="color:#536F7A;font-size:12px;margin-top:5px;">
# Preprocessing + model fitting
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:10px;
#     padding:14px;
# ">
# <div style="color:#0369A1;font-size:10px;font-weight:800;">
# TRANSFORM
# </div>
# <div style="color:#536F7A;font-size:12px;margin-top:5px;">
# Automatic preprocessing
# </div>
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:10px;
#     padding:14px;
# ">
# <div style="color:#9F1239;font-size:10px;font-weight:800;">
# PREDICT
# </div>
# <div style="color:#704D4D;font-size:12px;margin-top:5px;">
# Generate test predictions
# </div>
# </div>
#
# </div>
#
# </div>

# %%
# Create a fresh pipeline to verify full reproducibility
pipeline_rerun = Pipeline([
    ("preprocessing", preprocessor),
    ("model", LogisticRegression(
        max_iter=1000,
        random_state=42
    ))
])

# Train again from scratch
pipeline_rerun.fit(X_train_fe, y_train)

# Predict again
rerun_predictions = pipeline_rerun.predict(X_test_fe)

# Evaluate the rerun
rerun_accuracy = accuracy_score(
    y_test,
    rerun_predictions
)

print("END-TO-END PIPELINE CHECK")
print("-" * 35)
print(f"Rerun accuracy: {rerun_accuracy:.2%}")
print(f"Predictions generated: {len(rerun_predictions)}")

if len(rerun_predictions) == len(y_test):
    print("✓ Pipeline reran successfully from start to finish")
else:
    print("⚠ Prediction count does not match test samples")
# Out:
# END-TO-END PIPELINE CHECK
# -----------------------------------
# Rerun accuracy: 71.18%
# Predictions generated: 14000
# ✓ Pipeline reran successfully from start to finish

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:21px 25px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     color:#0369A1;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
#     margin-bottom:6px;
# ">
# MODEL ARTIFACT • OPTIONAL
# </div>
#
# <h3 style="
#     color:#7A2020;
#     font-size:18px;
#     font-weight:800;
#     margin:0 0 13px 0;
# ">
# Step 35 — Save the Pipeline
# </h3>
#
# <div style="
#     background:#F0F9FF;
#     border:1px solid #C9E4EF;
#     border-radius:10px;
#     padding:14px 17px;
# ">
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.8;
# ">
# The trained Scikit-learn pipeline can optionally be saved as a reusable
# model artifact inside the project's <code style="color:#0369A1;">results/</code>
# folder. This preserves both the preprocessing steps and the trained model
# in a single file.
# </div>
#
# </div>
#
# <div style="
#     margin-top:13px;
#     padding:12px 16px;
#     background:#F0FDFA;
#     border:1px solid #CBE7E1;
#     border-radius:9px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:11px;
#     font-weight:700;
# ">
# OUTPUT
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     margin-top:4px;
# ">
# <code style="color:#0F766E;">results/saved_model.pkl</code>
# </div>
#
# </div>
#
# </div>

# %%
import joblib
from pathlib import Path

# Define the results directory
results_dir = Path("../results")
results_dir.mkdir(parents=True, exist_ok=True)

# Define the saved model path
model_path = results_dir / "saved_model.pkl"

# Save the complete pipeline
joblib.dump(pipeline, model_path)

# Styled output
from IPython.display import display, HTML

display(HTML(f"""
<div style="
    background:#FFFFFF;
    border:1px solid #CBE7E1;
    border-radius:12px;
    padding:16px 20px;
    margin:12px 0;
    box-shadow:0 3px 12px rgba(15,118,110,0.06);
    font-family:'Segoe UI',Arial,sans-serif;
">

<div style="
    color:#0F766E;
    font-size:10px;
    font-weight:800;
    letter-spacing:1.5px;
    margin-bottom:7px;
">
PIPELINE SAVED ✓
</div>

<div style="
    color:#7A2020;
    font-size:15px;
    font-weight:800;
">
CardioML Pipeline
</div>

<div style="
    color:#536F7A;
    font-size:12px;
    margin-top:7px;
">
Saved successfully to:
<span style="color:#0369A1;font-weight:700;">
results/saved_model.pkl
</span>
</div>

</div>
"""))
# Out:
# <div style="
#     background:#FFFFFF;
#     border:1px solid #CBE7E1;
#     border-radius:12px;
#     padding:16px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,118,110,0.06);
#     font-family:'Segoe UI',Arial,sans-serif;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
#     margin-bottom:7px;
# ">
# PIPELINE SAVED ✓
# </div>
#
# <div style="
#     color:#7A2020;
#     font-size:15px;
#     font-weight:800;
# ">
# CardioML Pipeline
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     margin-top:7px;
# ">
# Saved successfully to:
# <span style="color:#0369A1;font-weight:700;">
# results/saved_model.pkl
# </span>
# </div>
#
# </div>

# %%
import joblib
import os

# Create results directory if it doesn't exist
os.makedirs("../results", exist_ok=True)

# Save the trained pipeline
joblib.dump(pipeline, "../results/saved_model.pkl")

print("Model pipeline saved successfully ✓")
print("Location: results/saved_model.pkl")
# Out:
# Model pipeline saved successfully ✓
# Location: results/saved_model.pkl

# %%
import os

model_path = "../results/saved_model.pkl"

print(f"File exists: {os.path.exists(model_path)}")
print(f"File size: {os.path.getsize(model_path) / 1024:.2f} KB")
# Out:
# File exists: True
# File size: 3.17 KB

# %%
import joblib

loaded_pipeline = joblib.load("../results/saved_model.pkl")

print("Model loaded successfully ✓")
print("Pipeline type:", type(loaded_pipeline))
# Out:
# Model loaded successfully ✓
# Pipeline type: <class 'sklearn.pipeline.Pipeline'>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #F0D7D7;
#     border-radius:14px;
#     padding:24px 27px;
#     margin:16px 0;
#     box-shadow:0 3px 12px rgba(127,29,29,0.06);
#     overflow:hidden;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     margin-bottom:6px;
# ">
# PROJECT • FINAL SUMMARY
# </div>
#
# <h2 style="
#     color:#7A2020;
#     font-size:21px;
#     font-weight:800;
#     margin:0 0 18px 0;
# ">
# 🫀 Cardiac Patient Monitoring System
# </h2>
#
# <div style="
#     background:#FFF8F8;
#     border-left:4px solid #DC2626;
#     padding:15px 18px;
#     border-radius:8px;
#     margin-bottom:16px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:12px;
#     font-weight:700;
#     line-height:1.8;
# ">
# This project applied a complete supervised machine learning workflow
# to the Heart Disease UCI dataset, covering data preparation,
# exploratory analysis, classification, model evaluation, and pipeline development.
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-bottom:16px;
# ">
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# DATA PREPARATION
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Missing values were handled, duplicate records were checked,
# data validity was reviewed, and categorical features were encoded
# for machine learning.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#FFF1F2;
#     border:1px solid #F3C2C7;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# EDA
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Descriptive statistics, target distribution, correlations,
# and feature-versus-target relationships were explored to
# understand the dataset.
# </div>
#
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     gap:12px;
#     margin-bottom:16px;
# ">
#
# <div style="
#     flex:1;
#     background:#FFF7ED;
#     border:1px solid #F2D8C4;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#C2410C;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# MODELING
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Logistic Regression was used as the baseline classifier,
# followed by Random Forest for model comparison.
# </div>
#
# </div>
#
# <div style="
#     flex:1;
#     background:#F0FDFA;
#     border:1px solid #D5EAE5;
#     border-radius:11px;
#     padding:15px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
# ">
# EVALUATION
# </div>
#
# <div style="
#     color:#536F7A;
#     font-size:12px;
#     line-height:1.7;
#     margin-top:6px;
# ">
# Models were evaluated using test accuracy, cross-validation,
# precision, recall, F1-score, ROC-AUC where applicable,
# and confusion matrices.
# </div>
#
# </div>
#
# </div>
#
# <div style="
#     background:#FFF8F8;
#     border:1px solid #F0D7D7;
#     border-radius:11px;
#     padding:16px 18px;
#     margin-bottom:16px;
# ">
#
# <div style="
#     color:#7A2020;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
#     margin-bottom:7px;
# ">
# KEY RESULT
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
# ">
# The Logistic Regression baseline achieved a test accuracy of
# <strong style="color:#7A2020;">59.78%</strong>.
# Random Forest was then evaluated against the baseline using
# the same train/test split and multiple performance metrics.
# </div>
#
# </div>
#
# <div style="
#     border-top:1px solid #E8D3D3;
#     padding-top:15px;
# ">
#
# <div style="
#     color:#9F1239;
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1px;
#     margin-bottom:6px;
# ">
# FINAL TAKEAWAY
# </div>
#
# <div style="
#     color:#704D4D;
#     font-size:12px;
#     line-height:1.8;
# ">
# The project demonstrates an end-to-end machine learning workflow
# for a multi-class heart disease classification problem. The analysis
# shows how data quality, exploratory analysis, model selection,
# evaluation metrics, and feature engineering work together to build
# a reproducible machine learning solution.
# </div>
#
# <div style="
#     color:#9F1239;
#     font-size:11px;
#     font-weight:700;
#     margin-top:12px;
# ">
# ⚠️ This project is for educational purposes only and is not intended
# for clinical diagnosis or medical decision-making.
# </div>
#
# </div>
#
# </div>
