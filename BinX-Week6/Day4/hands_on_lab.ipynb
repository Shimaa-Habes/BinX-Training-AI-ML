# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 10% 12%,rgba(194,139,88,0.10),transparent 24%),
#         radial-gradient(circle at 90% 85%,rgba(111,125,91,0.09),transparent 26%),
#         linear-gradient(135deg,#FAF7F1 0%,#FFFDF9 52%,#F3F0E8 100%);
#     padding:34px 38px 30px 38px;
#     border-radius:28px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 14px 34px rgba(91,76,53,0.10);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#8A6245;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:2.8px;
#     margin-bottom:10px;
# ">
# WEEK 6 • DAY 4
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:38px;
#     font-weight:900;
#     line-height:1.12;
#     letter-spacing:-0.8px;
# ">
# 🧪 Hands-On Lab
# </div>
#
# <div style="
#     color:#9A6947;
#     font-size:27px;
#     font-weight:900;
#     line-height:1.2;
#     margin-top:5px;
# ">
# Training a Neural Network
# </div>
#
# <div style="
#     width:105px;
#     height:5px;
#     background:#B97852;
#     border-radius:20px;
#     margin:18px 0 16px 0;
# ">
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:15px;
#     line-height:1.85;
#     font-weight:600;
#     max-width:1000px;
# ">
# In this hands-on lab, we will build, train, diagnose, and improve a neural network
# for the
# <span style="
#     color:#9A6947;
#     font-weight:900;
# ">
# CardioML binary classification task
# </span>.
# We will start with a clean Sequential baseline, monitor its learning behavior,
# apply regularization techniques, and finally compare the trained network with
# the Day 1 machine-learning baseline.
# </div>
#
#
# <div style="
#     margin-top:23px;
#     padding:18px 20px;
#     background:#F5EFE6;
#     border:1px solid #E0D0BE;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.5px;
#     margin-bottom:8px;
# ">
# LAB GOAL
# </div>
#
# <div style="
#     color:#4A4338;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:700;
# ">
# Build a complete Keras training workflow:
# <strong>Build → Compile → Train → Diagnose → Improve → Evaluate</strong>.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:15px;
#     padding:16px 20px;
#     background:#EFF1E8;
#     border:1px solid #D0D4C2;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#687455;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.5px;
#     margin-bottom:8px;
# ">
# WHAT WE WILL MEASURE
# </div>
#
# <div style="
#     color:#4A4F3E;
#     font-size:14px;
#     line-height:1.8;
#     font-weight:700;
# ">
# Training loss • Validation loss • Training accuracy • Validation accuracy • Test accuracy
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:15px;
#     padding:16px 20px;
#     background:#F9F0E9;
#     border:1px solid #E4C6B1;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#A35F3D;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.5px;
#     margin-bottom:8px;
# ">
# FINAL COMPARISON
# </div>
#
# <div style="
#     color:#684535;
#     font-size:14px;
#     line-height:1.8;
#     font-weight:700;
# ">
# At the end of the lab, the neural network will be compared against the
# <strong>Day 1 baseline accuracy of 71.3%</strong> to determine whether the
# deep-learning approach provides an improvement.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:18px;
#     padding-top:14px;
#     border-top:1px solid #DDD4C4;
#     text-align:center;
# ">
#
# <span style="
#     color:#9A9186;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:1.6px;
# ">
# CARDIOML • KERAS • BINARY CLASSIFICATION • MODEL IMPROVEMENT
# </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 90% 8%,rgba(111,125,91,0.08),transparent 24%),
#         linear-gradient(135deg,#FAF7F1 0%,#FFFDF9 55%,#F3F0E8 100%);
#     padding:28px 32px;
#     border-radius:24px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 9px 24px rgba(91,76,53,0.07);
#     overflow:hidden;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:18px;
# ">
#
# <div style="
#     flex-shrink:0;
#     color:#FFFDF9;
#     background:linear-gradient(145deg,#9A6947,#81543A);
#     width:92px;
#     height:92px;
#     border-radius:22px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:34px;
#     font-weight:900;
#     letter-spacing:-1px;
#     box-shadow:0 8px 18px rgba(154,105,71,0.18);
# ">
# 01
# </div>
#
# <div style="min-width:0;">
#
# <div style="
#     color:#687455;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:6px;
# ">
# STEP 1 • MODEL BUILDING
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:30px;
#     font-weight:900;
#     line-height:1.15;
# ">
# Build a Keras Sequential Network
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:15px;
#     font-weight:600;
#     line-height:1.85;
#     margin-top:8px;
# ">
# We start with a simple neural network for the CardioML binary classification task.
# The output layer and loss function must match the fact that the target contains
# two classes.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:17px 20px;
#     background:#F5EFE6;
#     border:1px solid #E0D0BE;
#     border-left:5px solid #B97852;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# MODEL DESIGN
# </div>
#
# <div style="
#     color:#4A4338;
#     font-size:15px;
#     line-height:1.85;
#     font-weight:700;
#     margin-top:6px;
# ">
# Hidden layers use
# <span style="color:#9A6947;font-weight:900;">ReLU</span>
# to learn non-linear patterns,
# while the final layer uses
# <span style="color:#A35F3D;font-weight:900;">Sigmoid</span>
# to output a probability between 0 and 1.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:12px;
#     padding:17px 20px;
#     background:#EFF1E8;
#     border:1px solid #D0D4C2;
#     border-left:5px solid #687455;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#687455;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# EXPECTED ARCHITECTURE
# </div>
#
# <div style="
#     color:#4A4F3E;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:800;
#     margin-top:6px;
# ">
# Input → Dense(64, ReLU) → Dense(32, ReLU) → Dense(1, Sigmoid)
# </div>
#
# </div>
#
# </div>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers
from IPython.display import display, HTML

df = pd.read_csv("../Day1/heart_disease_uci.csv", sep=";")

X = df.drop(columns=["cardio"])
y = df["cardio"]

X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train_raw)
X_test = scaler.transform(X_test_raw)

input_dim = X_train.shape[1]

baseline_model = keras.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(64, activation="relu"),
    layers.Dense(32, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

rows = []

for layer in baseline_model.layers:
    output_shape = tuple(layer.output.shape)
    params = layer.count_params()

    rows.append(f"""
    <tr>
        <td style="
            padding:13px 16px;
            text-align:left;
            border-bottom:1px solid #E5D8CB;
            color:#4A4338;
            font-weight:800;
        ">
            {layer.name}
        </td>

        <td style="
            padding:13px 16px;
            text-align:left;
            border-bottom:1px solid #E5D8CB;
            color:#684535;
            font-weight:700;
        ">
            {layer.__class__.__name__}
        </td>

        <td style="
            padding:13px 16px;
            text-align:left;
            border-bottom:1px solid #E5D8CB;
            color:#687455;
            font-weight:700;
        ">
            {output_shape}
        </td>

        <td style="
            padding:13px 16px;
            text-align:left;
            border-bottom:1px solid #E5D8CB;
            color:#9A6947;
            font-weight:900;
        ">
            {params:,}
        </td>
    </tr>
    """)

total_params = baseline_model.count_params()

display(HTML(f"""
<div style="
    width:100%;
    box-sizing:border-box;
    background:#FFFDF9;
    padding:24px 26px;
    border-radius:20px;
    font-family:'Segoe UI',Arial,sans-serif;
    border:1px solid #DDD4C4;
    box-shadow:0 8px 22px rgba(91,76,53,0.07);
    overflow:hidden;
">

<div style="
    color:#9A6947;
    font-size:12px;
    font-weight:900;
    letter-spacing:1.8px;
    margin-bottom:6px;
    text-align:left;
">
MODEL SUMMARY
</div>

<div style="
    color:#2F2A24;
    font-size:25px;
    font-weight:900;
    margin-bottom:18px;
    text-align:left;
">
CardioML Baseline Network
</div>

<table style="
    width:100%;
    border-collapse:collapse;
    border:1px solid #D8C6B7;
    font-size:13px;
    text-align:left;
">

<thead>
<tr style="
    background:#8B5E3C;
    color:#FFFDF9;
">

<th style="padding:14px 16px;text-align:left;font-weight:900;">
Layer
</th>

<th style="padding:14px 16px;text-align:left;font-weight:900;">
Type
</th>

<th style="padding:14px 16px;text-align:left;font-weight:900;">
Output Shape
</th>

<th style="padding:14px 16px;text-align:left;font-weight:900;">
Parameters
</th>

</tr>
</thead>

<tbody>
{''.join(rows)}
</tbody>

</table>


<div style="
    margin-top:15px;
    padding:14px 17px;
    background:#F5EFE6;
    border:1px solid #E0D0BE;
    border-radius:13px;
    display:flex;
    justify-content:space-between;
    align-items:center;
">

<div style="
    color:#9A6947;
    font-size:11px;
    font-weight:900;
    letter-spacing:1.2px;
">
TOTAL PARAMETERS
</div>

<div style="
    color:#684535;
    font-size:19px;
    font-weight:900;
">
{total_params:,}
</div>

</div>


<div style="
    margin-top:14px;
    color:#6B665D;
    font-size:12px;
    font-weight:700;
    text-align:left;
">
Dataset: {len(df):,} records • Input features: {input_dim} • Binary target: cardio
</div>

</div>
"""))
# Out:
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#FFFDF9;
#     padding:24px 26px;
#     border-radius:20px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 8px 22px rgba(91,76,53,0.07);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
#     text-align:left;
# ">
# MODEL SUMMARY
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:25px;
#     font-weight:900;
#     margin-bottom:18px;
#     text-align:left;
# ">
# CardioML Baseline Network
# </div>
#
# <table style="
#     width:100%;
#     border-collapse:collapse;
#     border:1px solid #D8C6B7;
#     font-size:13px;
#     text-align:left;
# ">
#
# <thead>
# <tr style="
#     background:#8B5E3C;
#     color:#FFFDF9;
# ">
#
# <th style="padding:14px 16px;text-align:left;font-weight:900;">
# Layer
# </th>
#
# <th style="padding:14px 16px;text-align:left;font-weight:900;">
# Type
# </th>
#
# <th style="padding:14px 16px;text-align:left;font-weight:900;">
# Output Shape
# </th>
#
# <th style="padding:14px 16px;text-align:left;font-weight:900;">
# Parameters
# </th>
#
# </tr>
# </thead>
#
# <tbody>
#
#     <tr>
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#4A4338;
#             font-weight:800;
#         ">
#             dense_26
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#684535;
#             font-weight:700;
#         ">
#             Dense
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#687455;
#             font-weight:700;
#         ">
#             (None, 64)
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#9A6947;
#             font-weight:900;
#         ">
#             832
#         </td>
#     </tr>
#
#     <tr>
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#4A4338;
#             font-weight:800;
#         ">
#             dense_27
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#684535;
#             font-weight:700;
#         ">
#             Dense
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#687455;
#             font-weight:700;
#         ">
#             (None, 32)
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#9A6947;
#             font-weight:900;
#         ">
#             2,080
#         </td>
#     </tr>
#
#     <tr>
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#4A4338;
#             font-weight:800;
#         ">
#             dense_28
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#684535;
#             font-weight:700;
#         ">
#             Dense
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#687455;
#             font-weight:700;
#         ">
#             (None, 1)
#         </td>
#
#         <td style="
#             padding:13px 16px;
#             text-align:left;
#             border-bottom:1px solid #E5D8CB;
#             color:#9A6947;
#             font-weight:900;
#         ">
#             33
#         </td>
#     </tr>
#
# </tbody>
#
# </table>
#
#
# <div style="
#     margin-top:15px;
#     padding:14px 17px;
#     background:#F5EFE6;
#     border:1px solid #E0D0BE;
#     border-radius:13px;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# TOTAL PARAMETERS
# </div>
#
# <div style="
#     color:#684535;
#     font-size:19px;
#     font-weight:900;
# ">
# 2,945
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:14px;
#     color:#6B665D;
#     font-size:12px;
#     font-weight:700;
#     text-align:left;
# ">
# Dataset: 70,000 records • Input features: 12 • Binary target: cardio
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 10%,rgba(111,125,91,0.08),transparent 24%),
#         linear-gradient(135deg,#FAF7F1 0%,#FFFDF9 55%,#F3F0E8 100%);
#     padding:28px 32px;
#     border-radius:24px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 9px 24px rgba(91,76,53,0.07);
#     overflow:hidden;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:18px;
# ">
#
# <div style="
#     flex-shrink:0;
#     color:#FFFDF9;
#     background:linear-gradient(145deg,#9A6947,#81543A);
#     width:92px;
#     height:92px;
#     border-radius:22px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:34px;
#     font-weight:900;
#     letter-spacing:-1px;
#     box-shadow:0 8px 18px rgba(154,105,71,0.18);
# ">
# 02
# </div>
#
# <div style="min-width:0;">
#
# <div style="
#     color:#687455;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:6px;
# ">
# STEP 2 • COMPILE & TRAIN
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:30px;
#     font-weight:900;
#     line-height:1.15;
# ">
# Compile and Train the Network
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:15px;
#     font-weight:600;
#     line-height:1.85;
#     margin-top:8px;
# ">
# Before learning begins, we configure the optimizer, loss function, and metrics.
# Then we train the model over multiple epochs while monitoring validation performance.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:17px 20px;
#     background:#F5EFE6;
#     border:1px solid #E0D0BE;
#     border-left:5px solid #B97852;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# TRAINING CONFIGURATION
# </div>
#
# <div style="
#     color:#4A4338;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:700;
#     margin-top:6px;
# ">
# Optimizer:
# <span style="color:#9A6947;font-weight:900;">Adam</span>
# &nbsp;•&nbsp;
# Loss:
# <span style="color:#9A6947;font-weight:900;">Binary Crossentropy</span>
# &nbsp;•&nbsp;
# Epochs:
# <span style="color:#9A6947;font-weight:900;">30+</span>
# &nbsp;•&nbsp;
# Validation Split:
# <span style="color:#9A6947;font-weight:900;">20%</span>
# </div>
#
# </div>
#
# </div>

# %%
baseline_model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

print("Model compiled successfully.")
# Out:
# Model compiled successfully.

# %%
history = baseline_model.fit(
    X_train,
    y_train,
    validation_split=0.20,
    epochs=30,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6916 - loss: 0.5960 - val_accuracy: 0.7272 - val_loss: 0.5696
# Epoch 2/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7238 - loss: 0.5655 - val_accuracy: 0.7315 - val_loss: 0.5578
# Epoch 3/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7287 - loss: 0.5564 - val_accuracy: 0.7354 - val_loss: 0.5471
# Epoch 4/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7293 - loss: 0.5509 - val_accuracy: 0.7345 - val_loss: 0.5471
# Epoch 5/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7309 - loss: 0.5467 - val_accuracy: 0.7345 - val_loss: 0.5517
# Epoch 6/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7322 - loss: 0.5464 - val_accuracy: 0.7380 - val_loss: 0.5428
# Epoch 7/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7334 - loss: 0.5442 - val_accuracy: 0.7365 - val_loss: 0.5398
# Epoch 8/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7337 - loss: 0.5432 - val_accuracy: 0.7385 - val_loss: 0.5410
# Epoch 9/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.7347 - loss: 0.5426 - val_accuracy: 0.7392 - val_loss: 0.5399
# Epoch 10/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7355 - loss: 0.5414 - val_accuracy: 0.7391 - val_loss: 0.5387
# Epoch 11/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7351 - loss: 0.5410 - val_accuracy: 0.7394 - val_loss: 0.5402
# Epoch 12/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7348 - loss: 0.5407 - val_accuracy: 0.7398 - val_loss: 0.5383
# Epoch 13/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7357 - loss: 0.5403 - val_accuracy: 0.7367 - val_loss: 0.5401
# Epoch 14/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7360 - loss: 0.5394 - val_accuracy: 0.7374 - val_loss: 0.5431
# Epoch 15/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7365 - loss: 0.5386 - val_accuracy: 0.7366 - val_loss: 0.5384
# Epoch 16/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7364 - loss: 0.5392 - val_accuracy: 0.7389 - val_loss: 0.5441
# Epoch 17/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7367 - loss: 0.5372 - val_accuracy: 0.7354 - val_loss: 0.5450
# Epoch 18/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7363 - loss: 0.5377 - val_accuracy: 0.7379 - val_loss: 0.5440
# Epoch 19/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7369 - loss: 0.5375 - val_accuracy: 0.7399 - val_loss: 0.5406
# Epoch 20/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7369 - loss: 0.5369 - val_accuracy: 0.7371 - val_loss: 0.5400
# Epoch 21/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7367 - loss: 0.5359 - val_accuracy: 0.7361 - val_loss: 0.5446
# Epoch 22/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7375 - loss: 0.5361 - val_accuracy: 0.7363 - val_loss: 0.5395
# Epoch 23/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7377 - loss: 0.5353 - val_accuracy: 0.7359 - val_loss: 0.5429
# Epoch 24/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7385 - loss: 0.5350 - val_accuracy: 0.7373 - val_loss: 0.5418
# Epoch 25/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7379 - loss: 0.5354 - val_accuracy: 0.7370 - val_loss: 0.5426
# Epoch 26/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7386 - loss: 0.5339 - val_accuracy: 0.7365 - val_loss: 0.5418
# Epoch 27/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7386 - loss: 0.5342 - val_accuracy: 0.7373 - val_loss: 0.5410
# Epoch 28/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7379 - loss: 0.5340 - val_accuracy: 0.7386 - val_loss: 0.5414
# Epoch 29/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7388 - loss: 0.5333 - val_accuracy: 0.7373 - val_loss: 0.5438
# Epoch 30/30
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7390 - loss: 0.5329 - val_accuracy: 0.7377 - val_loss: 0.5426

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 10%,rgba(111,125,91,0.08),transparent 24%),
#         linear-gradient(135deg,#FAF7F1 0%,#FFFDF9 55%,#F3F0E8 100%);
#     padding:28px 32px;
#     border-radius:24px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 9px 24px rgba(91,76,53,0.07);
#     overflow:hidden;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:18px;
# ">
#
# <div style="
#     flex-shrink:0;
#     color:#FFFDF9;
#     background:linear-gradient(145deg,#9A6947,#81543A);
#     width:92px;
#     height:92px;
#     border-radius:22px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:34px;
#     font-weight:900;
#     letter-spacing:-1px;
#     box-shadow:0 8px 18px rgba(154,105,71,0.18);
# ">
# 03
# </div>
#
# <div style="min-width:0;">
#
# <div style="
#     color:#687455;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:6px;
# ">
# STEP 3 • TRAINING ANALYSIS
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:30px;
#     font-weight:900;
#     line-height:1.15;
# ">
# Plot Training vs Validation Performance
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:15px;
#     font-weight:600;
#     line-height:1.85;
#     margin-top:8px;
# ">
# Use the training history to visualize how loss and accuracy change across epochs.
# Comparing training and validation curves helps us determine whether the model is
# learning well, underfitting, or beginning to overfit.
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:17px 20px;
#     background:#F5EFE6;
#     border:1px solid #E0D0BE;
#     border-left:5px solid #B97852;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# WHAT WE WILL PLOT
# </div>
#
# <div style="
#     color:#4A4338;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:700;
#     margin-top:6px;
# ">
# Training Loss
# <span style="color:#9A6947;font-weight:900;">•</span>
# Validation Loss
# &nbsp;&nbsp;|&nbsp;&nbsp;
# Training Accuracy
# <span style="color:#9A6947;font-weight:900;">•</span>
# Validation Accuracy
# </div>
#
# </div>
#
# </div>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 5))

plt.plot(
    history.history["loss"],
    label="Training Loss",
    linewidth=2
)

plt.plot(
    history.history["val_loss"],
    label="Validation Loss",
    linewidth=2
)

plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.title("Training vs Validation Loss", fontsize=15, fontweight="bold")
plt.legend()
plt.grid(alpha=0.25)

plt.show()

# %%
plt.figure(figsize=(9, 5))

plt.plot(
    history.history["accuracy"],
    label="Training Accuracy",
    linewidth=2
)

plt.plot(
    history.history["val_accuracy"],
    label="Validation Accuracy",
    linewidth=2
)

plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.title("Training vs Validation Accuracy", fontsize=15, fontweight="bold")
plt.legend()
plt.grid(alpha=0.25)

plt.show()

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 90% 10%,rgba(111,125,91,0.08),transparent 24%),
#         linear-gradient(135deg,#FAF7F1 0%,#FFFDF9 55%,#F3F0E8 100%);
#     padding:28px 32px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 8px 22px rgba(91,76,53,0.06);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-bottom:8px;
# ">
# STEP 3 • FIT DIAGNOSIS
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:28px;
#     font-weight:900;
#     line-height:1.2;
# ">
# How Well Is the Model Learning?
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:16px;
#     line-height:1.9;
#     font-weight:600;
#     margin-top:12px;
# ">
# The training and validation curves help us understand whether the model is learning
# useful patterns or starting to overfit the training data.
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:17px 20px;
#     background:#F5EFE6;
#     border:1px solid #E0D0BE;
#     border-left:5px solid #B97852;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# WHAT TO LOOK FOR
# </div>
#
# <div style="
#     color:#4A4338;
#     font-size:15px;
#     line-height:1.85;
#     font-weight:700;
#     margin-top:7px;
# ">
# A good fit is indicated when training and validation loss decrease together
# and remain relatively close. A large gap between them can indicate overfitting,
# while high loss on both curves can indicate underfitting.
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:12px;
#     padding:17px 20px;
#     background:#EFF1E8;
#     border:1px solid #D0D4C2;
#     border-left:5px solid #687455;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#687455;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# CURRENT DIAGNOSIS
# </div>
#
# <div style="
#     color:#4A4F3E;
#     font-size:15px;
#     line-height:1.85;
#     font-weight:700;
#     margin-top:7px;
# ">
# The diagnosis will be based on the actual training and validation curves above.
# Pay particular attention to whether validation loss stops improving while
# training loss continues to decrease.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 10%,rgba(111,125,91,0.08),transparent 24%),
#         linear-gradient(135deg,#FAF7F1 0%,#FFFDF9 55%,#F3F0E8 100%);
#     padding:28px 32px;
#     border-radius:24px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 9px 24px rgba(91,76,53,0.07);
#     overflow:hidden;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:18px;
# ">
#
# <div style="
#     flex-shrink:0;
#     color:#FFFDF9;
#     background:linear-gradient(145deg,#9A6947,#81543A);
#     width:92px;
#     height:92px;
#     border-radius:22px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:34px;
#     font-weight:900;
#     letter-spacing:-1px;
#     box-shadow:0 8px 18px rgba(154,105,71,0.18);
# ">
# 04
# </div>
#
# <div style="
#     flex:1;
#     min-width:0;
# ">
#
# <div style="
#     color:#687455;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:6px;
# ">
# STEP 4 • REGULARIZATION
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:30px;
#     font-weight:900;
#     line-height:1.15;
# ">
# Add Dropout & Batch Normalization
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:15px;
#     font-weight:600;
#     line-height:1.85;
#     margin-top:8px;
# ">
# We now improve the baseline network by adding regularization and normalization,
# then retrain it and compare its validation loss with the original model.
# </div>
#
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#FFFDF9;
#     padding:26px 30px;
#     border-radius:21px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 8px 20px rgba(91,76,53,0.06);
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:1.7px;
#     margin-bottom:7px;
# ">
# WHY IMPROVE THE BASELINE?
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:27px;
#     font-weight:900;
# ">
# Normalize the Network. Reduce Overfitting.
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:16px;
#     line-height:1.9;
#     font-weight:600;
#     margin-top:11px;
# ">
# Batch Normalization helps keep activations on a more stable scale during training,
# while Dropout randomly disables a fraction of neurons during each training step.
# Together, these techniques can make training more stable and encourage the model
# to learn representations that generalize better to unseen data.
# </div>
#
# <div style="
#     margin-top:18px;
#     padding:15px 18px;
#     background:#F5EFE6;
#     border:1px solid #E0D0BE;
#     border-left:5px solid #B97852;
#     border-radius:14px;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# EXPERIMENT
# </div>
#
# <div style="
#     color:#4A4338;
#     font-size:15px;
#     font-weight:800;
#     line-height:1.8;
#     margin-top:6px;
# ">
# Baseline model → Add Batch Normalization + Dropout → Retrain → Compare validation curves
# </div>
#
# </div>
#
# </div>

# %%
from tensorflow import keras
from tensorflow.keras import layers

improved_model = keras.Sequential([
    layers.Input(shape=(input_dim,)),

    layers.Dense(128),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.Dropout(0.20),

    layers.Dense(64),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.Dropout(0.20),

    layers.Dense(32),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.Dropout(0.10),

    layers.Dense(1, activation="sigmoid")
])

improved_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=8,
        restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=4,
        min_lr=1e-6
    )
]

improved_history = improved_model.fit(
    X_train,
    y_train,
    validation_split=0.20,
    epochs=100,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6427 - loss: 0.6394 - val_accuracy: 0.7041 - val_loss: 0.5974 - learning_rate: 0.0010
# Epoch 2/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7044 - loss: 0.5821 - val_accuracy: 0.7270 - val_loss: 0.5779 - learning_rate: 0.0010
# Epoch 3/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7186 - loss: 0.5657 - val_accuracy: 0.7343 - val_loss: 0.5593 - learning_rate: 0.0010
# Epoch 4/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7242 - loss: 0.5595 - val_accuracy: 0.7321 - val_loss: 0.5627 - learning_rate: 0.0010
# Epoch 5/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7242 - loss: 0.5585 - val_accuracy: 0.7373 - val_loss: 0.5519 - learning_rate: 0.0010
# Epoch 6/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7266 - loss: 0.5564 - val_accuracy: 0.7325 - val_loss: 0.5755 - learning_rate: 0.0010
# Epoch 7/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7272 - loss: 0.5548 - val_accuracy: 0.7342 - val_loss: 0.5701 - learning_rate: 0.0010
# Epoch 8/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7259 - loss: 0.5540 - val_accuracy: 0.7329 - val_loss: 0.5740 - learning_rate: 0.0010
# Epoch 9/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7272 - loss: 0.5538 - val_accuracy: 0.7398 - val_loss: 0.5469 - learning_rate: 0.0010
# Epoch 10/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7281 - loss: 0.5529 - val_accuracy: 0.7406 - val_loss: 0.5504 - learning_rate: 0.0010
# Epoch 11/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7280 - loss: 0.5520 - val_accuracy: 0.7378 - val_loss: 0.5622 - learning_rate: 0.0010
# Epoch 12/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7288 - loss: 0.5512 - val_accuracy: 0.7401 - val_loss: 0.5613 - learning_rate: 0.0010
# Epoch 13/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7306 - loss: 0.5508 - val_accuracy: 0.7396 - val_loss: 0.5532 - learning_rate: 0.0010
# Epoch 14/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7296 - loss: 0.5487 - val_accuracy: 0.7286 - val_loss: 0.5909 - learning_rate: 5.0000e-04
# Epoch 15/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7308 - loss: 0.5484 - val_accuracy: 0.7325 - val_loss: 0.5758 - learning_rate: 5.0000e-04
# Epoch 16/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7306 - loss: 0.5480 - val_accuracy: 0.7216 - val_loss: 0.6044 - learning_rate: 5.0000e-04
# Epoch 17/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7287 - loss: 0.5486 - val_accuracy: 0.7422 - val_loss: 0.5480 - learning_rate: 5.0000e-04

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 5))

plt.plot(
    history.history["val_loss"],
    label="Baseline Validation Loss",
    linewidth=2
)

plt.plot(
    improved_history.history["val_loss"],
    label="Improved Validation Loss",
    linewidth=2
)

plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Baseline vs Improved Model — Validation Loss")
plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %%
plt.figure(figsize=(9, 5))

plt.plot(
    history.history["val_accuracy"],
    label="Baseline Validation Accuracy",
    linewidth=2
)

plt.plot(
    improved_history.history["val_accuracy"],
    label="Improved Validation Accuracy",
    linewidth=2
)

plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Baseline vs Improved Model — Validation Accuracy")
plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         linear-gradient(135deg,#FFFDF9 0%,#F3F0E8 100%);
#     padding:26px 30px;
#     border-radius:21px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 8px 20px rgba(91,76,53,0.06);
# ">
#
# <div style="
#     color:#687455;
#     font-size:13px;
#     font-weight:900;
#     letter-spacing:1.7px;
# ">
# COMPARISON
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:27px;
#     font-weight:900;
#     margin-top:4px;
# ">
# Baseline vs Improved Network
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:16px;
#     line-height:1.9;
#     font-weight:600;
#     margin-top:11px;
# ">
# The validation curves show how adding Batch Normalization and Dropout changed
# the training behavior of the network. The improved model should be judged by
# the stability of its validation performance and whether it generalizes better
# than the original baseline.
# </div>
#
# <div style="
#     margin-top:18px;
#     padding:15px 18px;
#     background:#EFF1E8;
#     border:1px solid #D0D4C2;
#     border-radius:14px;
#     color:#4A4F3E;
#     font-size:15px;
#     line-height:1.8;
#     font-weight:800;
# ">
# Look for a smoother validation curve, a smaller gap between training and validation
# performance, and more stable behavior across later epochs.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 10%,rgba(111,125,91,0.08),transparent 24%),
#         linear-gradient(135deg,#FAF7F1 0%,#FFFDF9 55%,#F3F0E8 100%);
#     padding:28px 32px;
#     border-radius:24px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 9px 24px rgba(91,76,53,0.07);
#     overflow:hidden;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:18px;
# ">
#
# <div style="
#     flex-shrink:0;
#     color:#FFFDF9;
#     background:linear-gradient(145deg,#9A6947,#81543A);
#     width:92px;
#     height:92px;
#     border-radius:22px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     font-size:34px;
#     font-weight:900;
#     letter-spacing:-1px;
#     box-shadow:0 8px 18px rgba(154,105,71,0.18);
# ">
# 05
# </div>
#
# <div style="min-width:0;">
#
# <div style="
#     color:#687455;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:6px;
# ">
# STEP 5 • FINAL EVALUATION
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:30px;
#     font-weight:900;
#     line-height:1.15;
# ">
# Evaluate & Compare the Final Model
# </div>
#
# <div style="
#     color:#6B665D;
#     font-size:15px;
#     font-weight:600;
#     line-height:1.85;
#     margin-top:8px;
# ">
# The improved neural network will be evaluated on the unseen test set.
# Its accuracy will then be compared with the
# <span style="color:#9A6947;font-weight:900;">
# Day 1 baseline of 71.3%
# </span>
# to determine whether the deep-learning approach provides an improvement.
# </div>
#
# </div>
#
# </div>
#
# </div>

# %%
test_loss, test_accuracy = improved_model.evaluate(
    X_test,
    y_test,
    verbose=0
)

print(f"Test Accuracy: {test_accuracy:.2%}")
# Out:
# Test Accuracy: 72.68%

# %%
from IPython.display import display, HTML

baseline_accuracy = 0.713
improvement = test_accuracy - baseline_accuracy

display(HTML(f"""
<div style="
    width:100%;
    box-sizing:border-box;
    background:
        linear-gradient(135deg,#FFFDF9 0%,#F3F0E8 100%);
    padding:26px 30px;
    border-radius:22px;
    font-family:'Segoe UI',Arial,sans-serif;
    border:1px solid #DDD4C4;
    box-shadow:0 8px 22px rgba(91,76,53,0.06);
    overflow:hidden;
">

<div style="
    color:#9A6947;
    font-size:12px;
    font-weight:900;
    letter-spacing:1.8px;
    margin-bottom:6px;
">
FINAL RESULT
</div>

<div style="
    color:#2F2A24;
    font-size:27px;
    font-weight:900;
    line-height:1.2;
">
Neural Network vs Day 1 Baseline
</div>

<div style="
    margin-top:20px;
    width:100%;
    box-sizing:border-box;
">

<div style="
    width:100%;
    box-sizing:border-box;
    padding:17px 20px;
    background:#F5EFE6;
    border:1px solid #E0D0BE;
    border-left:5px solid #9A6947;
    border-radius:15px;
    margin-bottom:12px;
">

<div style="
    color:#9A6947;
    font-size:12px;
    font-weight:900;
    letter-spacing:1.2px;
">
DAY 1 BASELINE
</div>

<div style="
    color:#4A4338;
    font-size:25px;
    font-weight:900;
    margin-top:5px;
">
{baseline_accuracy:.2%}
</div>

</div>


<div style="
    width:100%;
    box-sizing:border-box;
    padding:17px 20px;
    background:#EFF1E8;
    border:1px solid #D0D4C2;
    border-left:5px solid #687455;
    border-radius:15px;
    margin-bottom:12px;
">

<div style="
    color:#687455;
    font-size:12px;
    font-weight:900;
    letter-spacing:1.2px;
">
IMPROVED NEURAL NETWORK
</div>

<div style="
    color:#4A4F3E;
    font-size:25px;
    font-weight:900;
    margin-top:5px;
">
{test_accuracy:.2%}
</div>

</div>


<div style="
    width:100%;
    box-sizing:border-box;
    padding:17px 20px;
    background:#F9F0E9;
    border:1px solid #E4C6B1;
    border-left:5px solid #A35F3D;
    border-radius:15px;
">

<div style="
    color:#A35F3D;
    font-size:12px;
    font-weight:900;
    letter-spacing:1.2px;
">
IMPROVEMENT
</div>

<div style="
    color:#684535;
    font-size:25px;
    font-weight:900;
    margin-top:5px;
">
{improvement:+.2%}
</div>

</div>

</div>


<div style="
    margin-top:18px;
    padding:15px 18px;
    background:#F7F4EE;
    border:1px dashed #CFC5B4;
    border-radius:14px;
    text-align:center;
    color:#6B665D;
    font-size:14px;
    font-weight:700;
    line-height:1.8;
">
The final comparison shows whether the improved neural network
outperforms the Day 1 baseline on unseen test data.
</div>

</div>
"""))
# Out:
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         linear-gradient(135deg,#FFFDF9 0%,#F3F0E8 100%);
#     padding:26px 30px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 8px 22px rgba(91,76,53,0.06);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# FINAL RESULT
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:27px;
#     font-weight:900;
#     line-height:1.2;
# ">
# Neural Network vs Day 1 Baseline
# </div>
#
# <div style="
#     margin-top:20px;
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:17px 20px;
#     background:#F5EFE6;
#     border:1px solid #E0D0BE;
#     border-left:5px solid #9A6947;
#     border-radius:15px;
#     margin-bottom:12px;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# DAY 1 BASELINE
# </div>
#
# <div style="
#     color:#4A4338;
#     font-size:25px;
#     font-weight:900;
#     margin-top:5px;
# ">
# 71.30%
# </div>
#
# </div>
#
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:17px 20px;
#     background:#EFF1E8;
#     border:1px solid #D0D4C2;
#     border-left:5px solid #687455;
#     border-radius:15px;
#     margin-bottom:12px;
# ">
#
# <div style="
#     color:#687455;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# IMPROVED NEURAL NETWORK
# </div>
#
# <div style="
#     color:#4A4F3E;
#     font-size:25px;
#     font-weight:900;
#     margin-top:5px;
# ">
# 72.68%
# </div>
#
# </div>
#
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:17px 20px;
#     background:#F9F0E9;
#     border:1px solid #E4C6B1;
#     border-left:5px solid #A35F3D;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#A35F3D;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# IMPROVEMENT
# </div>
#
# <div style="
#     color:#684535;
#     font-size:25px;
#     font-weight:900;
#     margin-top:5px;
# ">
# +1.38%
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:18px;
#     padding:15px 18px;
#     background:#F7F4EE;
#     border:1px dashed #CFC5B4;
#     border-radius:14px;
#     text-align:center;
#     color:#6B665D;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.8;
# ">
# The final comparison shows whether the improved neural network
# outperforms the Day 1 baseline on unseen test data.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         linear-gradient(135deg,#FFFDF9 0%,#F5EFE6 100%);
#     padding:22px 26px;
#     border-radius:20px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #DDD4C4;
#     box-shadow:0 8px 22px rgba(91,76,53,0.07);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#9A6947;
#     font-size:12px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-bottom:7px;
# ">
# FINAL RESULT
# </div>
#
# <div style="
#     color:#2F2A24;
#     font-size:25px;
#     font-weight:900;
#     line-height:1.2;
# ">
# Neural Network vs Day 1 Baseline
# </div>
#
# <div style="
#     margin-top:14px;
#     color:#6B665D;
#     font-size:16px;
#     line-height:1.9;
#     font-weight:600;
# ">
# The neural network achieved
# <span style="color:#9A6947;font-size:17px;font-weight:900;">
# 71.46% test accuracy
# </span>,
# slightly outperforming the Day 1 baseline of
# <span style="color:#5E684F;font-size:17px;font-weight:900;">
# 71.30%
# </span>
# by
# <span style="color:#A35F3D;font-size:17px;font-weight:900;">
# 0.16 percentage points
# </span>.
# </div>
#
# <div style="
#     margin-top:16px;
#     padding:14px 17px;
#     background:#F9F0E9;
#     border:1px solid #E4C6B1;
#     border-left:5px solid #B97852;
#     border-radius:14px;
# ">
#
# <div style="
#     color:#684535;
#     font-size:13px;
#     font-weight:800;
#     line-height:1.7;
# ">
# The neural network performed slightly better than the classical baseline,
# showing a small but measurable improvement on the test set.
# </div>
#
# </div>
#
# </div>
