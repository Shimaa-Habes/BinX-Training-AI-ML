# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 88% 8%,rgba(16,185,129,0.10),transparent 25%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.07),transparent 28%),
#         linear-gradient(135deg,#F4FBF8 0%,#FFFFFF 48%,#EFFAF6 100%);
#     padding:38px 42px 28px 42px;
#     border-radius:30px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #A8D2C3;
#     box-shadow:0 16px 40px rgba(6,78,59,0.12);
#     overflow:hidden;
# ">
#
# <!-- TOP LABEL -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     margin-bottom:24px;
# ">
#
# <div style="
#     color:#065F46;
#     font-size:11px;
#     font-weight:900;
#     letter-spacing:3px;
# ">
# WEEK 6 • DAY 3
# </div>
#
# <div style="
#     color:#115E59;
#     background:#E0F2EC;
#     border:1px solid #A8D2C3;
#     padding:7px 13px;
#     border-radius:20px;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# DEEP LEARNING • SPRINT 1
# </div>
#
# </div>
#
#
# <!-- MAIN HERO -->
#
# <div style="
#     display:grid;
#     grid-template-columns:0.92fr 1.08fr;
#     gap:34px;
#     align-items:center;
# ">
#
# <!-- LEFT -->
#
# <div>
#
# <div style="
#     color:#115E59;
#     font-size:10px;
#     font-weight:900;
#     letter-spacing:2.5px;
#     margin-bottom:12px;
# ">
# HOW NEURAL NETWORKS LEARN
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:38px;
#     font-weight:900;
#     line-height:1.08;
#     letter-spacing:-1px;
# ">
# Backpropagation,
# <span style="color:#047857;">Gradient Descent</span>
# <span style="color:#334155;"> & Optimizers</span>
# </div>
#
# <div style="
#     width:145px;
#     height:5px;
#     margin:20px 0 18px 0;
#     background:linear-gradient(90deg,#047857,#0F766E,#34D399);
#     border-radius:20px;
# "></div>
#
# <p style="
#     color:#3F514B;
#     font-size:14px;
#     line-height:1.85;
#     font-weight:600;
#     margin:0;
#     max-width:500px;
# ">
# From
# <span style="color:#065F46;font-weight:900;">prediction</span>
# to
# <span style="color:#115E59;font-weight:900;">loss</span>,
# then backward through the network to calculate
# <span style="color:#334155;font-weight:900;">gradients</span>
# and update the weights.
# </p>
#
# </div>
#
#
# <!-- RIGHT IMAGE -->
#
# <div style="
#     position:relative;
#     min-height:310px;
#     display:flex;
#     align-items:center;
#     justify-content:center;
# ">
#
# <div style="
#     position:absolute;
#     width:340px;
#     height:340px;
#     border-radius:50%;
#     background:
#         radial-gradient(circle,
#         rgba(16,185,129,0.16) 0%,
#         rgba(20,184,166,0.07) 42%,
#         transparent 72%);
#     filter:blur(12px);
# "></div>
#
# <div style="
#     position:relative;
#     width:100%;
#     height:310px;
#     border-radius:24px;
#     border:2px solid rgba(16,185,129,0.16) 0%,;
#     box-shadow:
#         0 18px 40px rgba(6,78,59,0.18),
#         0 0 35px rgba(16,185,129,0.08);
#     overflow:hidden;
#     display:flex;
#     align-items:center;
#     justify-content:center;
# ">
#
# <div style="
#     position:absolute;
#     top:15px;
#     left:18px;
#     z-index:2;
#     color:#6EE7B7;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
# ">
# BACKPROPAGATION
# </div>
#
# <img src="../media/backpropagation_neural_network.png"
#      style="
#         width:100%;
#         height:100%;
#         object-fit:contain;
#         display:block;
#         padding:18px;
#         box-sizing:border-box;
#      ">
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- TRAINING LOOP -->
#
# <div style="
#     margin-top:30px;
#     padding:18px 20px;
#     background:#F7FBF9;
#     border:1px solid #C1DED2;
#     border-radius:20px;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:13px;
# ">
# THE TRAINING LOOP
# </div>
#
# <div style="
#     display:grid;
#     grid-template-columns:1fr 25px 1fr 25px 1fr 25px 1fr;
#     align-items:center;
#     gap:7px;
# ">
#
# <!-- FORWARD -->
#
# <div style="
#     background:#E8F8F1;
#     border:1px solid #98D0B9;
#     border-radius:13px;
#     padding:13px 10px;
#     text-align:center;
# ">
# <div style="color:#047857;font-size:15px;font-weight:900;">01</div>
# <div style="color:#14532D;font-size:11px;font-weight:900;margin-top:4px;">FORWARD</div>
# <div style="color:#475569;font-size:9px;margin-top:3px;">Make prediction</div>
# </div>
#
# <div style="
#     color:#059669;
#     font-size:18px;
#     font-weight:900;
#     text-align:center;
# ">
# →
# </div>
#
# <!-- LOSS -->
#
# <div style="
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:13px;
#     padding:13px 10px;
#     text-align:center;
# ">
# <div style="color:#0F766E;font-size:15px;font-weight:900;">02</div>
# <div style="color:#134E4A;font-size:11px;font-weight:900;margin-top:4px;">LOSS</div>
# <div style="color:#475569;font-size:9px;margin-top:3px;">Measure error</div>
# </div>
#
# <div style="
#     color:#0F9F8F;
#     font-size:18px;
#     font-weight:900;
#     text-align:center;
# ">
# →
# </div>
#
# <!-- BACKPROP -->
#
# <div style="
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:13px;
#     padding:13px 10px;
#     text-align:center;
# ">
# <div style="color:#62559B;font-size:15px;font-weight:900;">03</div>
# <div style="color:#3F3566;font-size:11px;font-weight:900;margin-top:4px;">BACKPROP</div>
# <div style="color:#475569;font-size:9px;margin-top:3px;">Find gradients</div>
# </div>
#
# <div style="
#     color:#6B5FA5;
#     font-size:18px;
#     font-weight:900;
#     text-align:center;
# ">
# →
# </div>
#
# <!-- UPDATE -->
#
# <div style="
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:13px;
#     padding:13px 10px;
#     text-align:center;
# ">
# <div style="color:#166534;font-size:15px;font-weight:900;">04</div>
# <div style="color:#14532D;font-size:11px;font-weight:900;margin-top:4px;">UPDATE</div>
# <div style="color:#475569;font-size:9px;margin-top:3px;">Adjust weights</div>
# </div>
#
# </div>
#
# </div>
#
#
# <!-- BOTTOM -->
#
# <div style="
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
#     margin-top:20px;
# ">
#
# <div style="
#     color:#52665F;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# LEARNING RATE • GRADIENTS • OPTIMIZATION
# </div>
#
# <div style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:24px 30px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 8px 24px rgba(6,78,59,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:14px;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     border-radius:13px;
#     background:#E1F4EC;
#     border:1px solid #A8D2C3;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#047857;
#     font-size:14px;
#     font-weight:900;
# ">
# 3.1
# </div>
#
# <div>
#
# <div style="
#     color:#0B2923;
#     font-size:23px;
#     font-weight:900;
#     line-height:1.2;
# ">
# The Training Loop in One Picture
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-top:6px;
# ">
# HOW A NEURAL NETWORK LEARNS
# </div>
#
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.08),transparent 24%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.06),transparent 28%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:34px 38px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 12px 32px rgba(6,78,59,0.09);
#     overflow:hidden;
# ">
#
# <!-- INTRO -->
# <div style="
#     padding:16px 19px;
#     background:#F1F9F6;
#     border:1px solid #C1DED2;
#     border-left:4px solid #10B981;
#     border-radius:14px;
#     margin-bottom:24px;
# ">
# <p style="margin:0;color:#3F514B;font-size:12px;line-height:1.8;font-weight:600;">
# Training a neural network is a repeated loop that gradually improves the model.
# For every batch of data, the network makes a prediction, measures its error,
# calculates how the weights contributed to that error, and then updates the
# weights to reduce the loss.
# </p>
# </div>
#
# <!-- FOUR STEP LOOP -->
# <div style="
#     display:grid;
#     grid-template-columns:1fr 30px 1fr 30px 1fr 30px 1fr;
#     align-items:center;
#     gap:7px;
# ">
#
# <!-- FORWARD -->
# <div style="
#     background:#E8F8F1;
#     border:1px solid #98D0B9;
#     border-radius:17px;
#     padding:19px 12px;
#     text-align:center;
#     min-height:125px;
#     box-sizing:border-box;
# ">
# <div style="color:#047857;font-size:9px;font-weight:900;letter-spacing:1.5px;">STEP 01</div>
# <div style="color:#14532D;font-size:16px;font-weight:900;margin-top:8px;">FORWARD</div>
# <div style="color:#475569;font-size:10px;line-height:1.6;margin-top:7px;">
# Pass the input through the network and produce a prediction.
# </div>
# </div>
#
# <div style="color:#059669;font-size:20px;font-weight:900;text-align:center;">→</div>
#
# <!-- LOSS -->
# <div style="
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:17px;
#     padding:19px 12px;
#     text-align:center;
#     min-height:125px;
#     box-sizing:border-box;
# ">
# <div style="color:#0F766E;font-size:9px;font-weight:900;letter-spacing:1.5px;">STEP 02</div>
# <div style="color:#134E4A;font-size:16px;font-weight:900;margin-top:8px;">LOSS</div>
# <div style="color:#475569;font-size:10px;line-height:1.6;margin-top:7px;">
# Compare the prediction with the true target and measure the error.
# </div>
# </div>
#
# <div style="color:#0F9F8F;font-size:20px;font-weight:900;text-align:center;">→</div>
#
# <!-- BACKPROP -->
# <div style="
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:17px;
#     padding:19px 12px;
#     text-align:center;
#     min-height:125px;
#     box-sizing:border-box;
# ">
# <div style="color:#62559B;font-size:9px;font-weight:900;letter-spacing:1.5px;">STEP 03</div>
# <div style="color:#3F3566;font-size:16px;font-weight:900;margin-top:8px;">BACKPROP</div>
# <div style="color:#475569;font-size:10px;line-height:1.6;margin-top:7px;">
# Calculate gradients to determine each weight's contribution to the loss.
# </div>
# </div>
#
# <div style="color:#6B5FA5;font-size:20px;font-weight:900;text-align:center;">→</div>
#
# <!-- UPDATE -->
# <div style="
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:17px;
#     padding:19px 12px;
#     text-align:center;
#     min-height:125px;
#     box-sizing:border-box;
# ">
# <div style="color:#166534;font-size:9px;font-weight:900;letter-spacing:1.5px;">STEP 04</div>
# <div style="color:#14532D;font-size:16px;font-weight:900;margin-top:8px;">UPDATE</div>
# <div style="color:#475569;font-size:10px;line-height:1.6;margin-top:7px;">
# Adjust the weights using the gradients to reduce the loss.
# </div>
# </div>
#
# </div>
#
# <!-- KEY IDEA -->
# <div style="
#     margin-top:23px;
#     padding:15px 18px;
#     background:#F7FBF9;
#     border:1px dashed #A8D2C3;
#     border-radius:15px;
#     text-align:center;
# ">
# <span style="color:#065F46;font-size:9px;font-weight:900;letter-spacing:1.5px;">
# KEY IDEA
# </span>
# <span style="color:#475569;font-size:11px;font-weight:600;margin-left:8px;">
# Each of the four steps has one job —
# </span>
# <span style="color:#047857;font-size:11px;font-weight:900;">
# predict, measure, assign blame, and correct.
# </span>
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.07),transparent 24%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 52%,#F1FAF7 100%);
#     padding:24px 28px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 8px 24px rgba(6,78,59,0.07);
#     text-align:center;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# FORWARD PROPAGATION
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:19px;
#     font-weight:900;
#     margin-bottom:17px;
# ">
# How the Network Produces a Prediction
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#FFFFFF;
#     border:1px solid #C8DED6;
#     border-radius:17px;
#     padding:14px;
#     overflow:hidden;
# ">
#
# <img src="../../BinX-Week6/media/forward_propagation.png"
#      style="
#         display:block;
#         width:100%;
#         max-width:900px;
#         height:auto;
#         margin:0 auto;
#         border-radius:10px;
#      ">
#
# </div>
#
# <div style="
#     margin-top:13px;
#     color:#64748B;
#     font-size:10px;
#     line-height:1.6;
#     font-weight:600;
# ">
# The input moves forward through the network, producing an output prediction.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.08),transparent 24%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.06),transparent 28%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:30px 36px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 12px 32px rgba(6,78,59,0.09);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:7px;
# ">
# REPEATED TRAINING
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:22px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# One Loop, Thousands of Updates
# </div>
#
# <div style="
#     color:#52665F;
#     font-size:11px;
#     line-height:1.7;
#     font-weight:600;
#     margin-bottom:24px;
# ">
# The same four-step training loop is repeated for many iterations.
# Each iteration updates the weights and moves the model toward lower loss.
# </div>
#
#
# <!-- ITERATION TIMELINE -->
#
# <div style="
#     position:relative;
#     padding:18px 0 8px 0;
# ">
#
# <div style="
#     position:absolute;
#     left:7%;
#     right:7%;
#     top:43px;
#     height:3px;
#     background:#B8DACE;
#     border-radius:10px;
# "></div>
#
#
# <div style="
#     display:grid;
#     grid-template-columns:1fr 1fr 1fr 1fr 1fr;
#     gap:12px;
#     position:relative;
# ">
#
#
# <!-- ITERATION 1 -->
#
# <div style="
#     text-align:center;
# ">
#
# <div style="
#     width:50px;
#     height:50px;
#     margin:0 auto;
#     border-radius:50%;
#     background:#E8F8F1;
#     border:2px solid #98D0B9;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#047857;
#     font-size:14px;
#     font-weight:900;
#     box-sizing:border-box;
# ">
# 01
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:11px;
#     font-weight:900;
#     margin-top:12px;
# ">
# FIRST LOOP
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:9px;
#     margin-top:4px;
# ">
# Initial weights
# </div>
#
# </div>
#
#
# <!-- ITERATION 2 -->
#
# <div style="
#     text-align:center;
# ">
#
# <div style="
#     width:50px;
#     height:50px;
#     margin:0 auto;
#     border-radius:50%;
#     background:#EAF9F7;
#     border:2px solid #99D4CB;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#0F766E;
#     font-size:14px;
#     font-weight:900;
#     box-sizing:border-box;
# ">
# 02
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:11px;
#     font-weight:900;
#     margin-top:12px;
# ">
# NEXT LOOP
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:9px;
#     margin-top:4px;
# ">
# Weights updated
# </div>
#
# </div>
#
#
# <!-- ITERATION 3 -->
#
# <div style="
#     text-align:center;
# ">
#
# <div style="
#     width:50px;
#     height:50px;
#     margin:0 auto;
#     border-radius:50%;
#     background:#F4F1FC;
#     border:2px solid #CCC4E5;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#62559B;
#     font-size:14px;
#     font-weight:900;
#     box-sizing:border-box;
# ">
# 03
# </div>
#
# <div style="
#     color:#3F3566;
#     font-size:11px;
#     font-weight:900;
#     margin-top:12px;
# ">
# MORE LOOPS
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:9px;
#     margin-top:4px;
# ">
# Better parameters
# </div>
#
# </div>
#
#
# <!-- ELLIPSIS -->
#
# <div style="
#     text-align:center;
# ">
#
# <div style="
#     width:50px;
#     height:50px;
#     margin:0 auto;
#     border-radius:50%;
#     background:#F8FAFC;
#     border:2px dashed #B8C5D1;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#64748B;
#     font-size:20px;
#     font-weight:900;
#     box-sizing:border-box;
# ">
# …
# </div>
#
# <div style="
#     color:#334155;
#     font-size:11px;
#     font-weight:900;
#     margin-top:12px;
# ">
# HUNDREDS
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:9px;
#     margin-top:4px;
# ">
# More updates
# </div>
#
# </div>
#
#
# <!-- THOUSANDS -->
#
# <div style="
#     text-align:center;
# ">
#
# <div style="
#     width:50px;
#     height:50px;
#     margin:0 auto;
#     border-radius:50%;
#     background:#EDF9F1;
#     border:2px solid #A9D2B7;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#166534;
#     font-size:13px;
#     font-weight:900;
#     box-sizing:border-box;
# ">
# 1K+
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:11px;
#     font-weight:900;
#     margin-top:12px;
# ">
# THOUSANDS
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:9px;
#     margin-top:4px;
# ">
# Repeated updates
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- PROGRESSION -->
#
# <div style="
#     margin-top:22px;
#     display:grid;
#     grid-template-columns:1fr 1fr 1fr;
#     gap:12px;
# ">
#
# <div style="
#     padding:14px 15px;
#     background:#E8F8F1;
#     border:1px solid #98D0B9;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <div style="
#     color:#047857;
#     font-size:16px;
#     font-weight:900;
# ">
# Weights
# </div>
#
# <div style="
#     color:#52665F;
#     font-size:9px;
#     font-weight:700;
#     margin-top:5px;
# ">
# updated repeatedly
# </div>
#
# </div>
#
#
# <div style="
#     padding:14px 15px;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:16px;
#     font-weight:900;
# ">
# Loss ↓
# </div>
#
# <div style="
#     color:#52665F;
#     font-size:9px;
#     font-weight:700;
#     margin-top:5px;
# ">
# generally decreases
# </div>
#
# </div>
#
#
# <div style="
#     padding:14px 15px;
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <div style="
#     color:#62559B;
#     font-size:16px;
#     font-weight:900;
# ">
# Predictions ↑
# </div>
#
# <div style="
#     color:#52665F;
#     font-size:9px;
#     font-weight:700;
#     margin-top:5px;
# ">
# become more accurate
# </div>
#
# </div>
#
# </div>
#
#
# <div style="
#     margin-top:20px;
#     padding:14px 18px;
#     background:#F7FBF9;
#     border:1px dashed #A8D2C3;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <span style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# KEY IDEA
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
#     margin-left:8px;
# ">
# Thousands of iterations mean thousands of small weight updates —
# </span>
#
# <span style="
#     color:#047857;
#     font-size:10px;
#     font-weight:900;
# ">
# not thousands of different training processes.
# </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:24px 30px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 8px 24px rgba(6,78,59,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:14px;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     border-radius:13px;
#     background:#E1F4EC;
#     border:1px solid #A8D2C3;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#047857;
#     font-size:14px;
#     font-weight:900;
# ">
# 3.2
# </div>
#
# <div>
#
# <div style="
#     color:#0B2923;
#     font-size:23px;
#     font-weight:900;
#     line-height:1.2;
# ">
# Gradient Descent
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-top:6px;
# ">
# HOW THE MODEL MOVES TOWARD LOWER LOSS
# </div>
#
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.08),transparent 24%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.06),transparent 28%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:30px 36px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 12px 30px rgba(6,78,59,0.08);
#     overflow:hidden;
# ">
#
# <!-- HEADER -->
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:7px;
# ">
# UNDERSTANDING THE GRADIENT
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:20px;
# ">
# The Gradient Points Uphill
# </div>
#
#
# <!-- MAIN CONCEPTS -->
#
# <div style="
#     display:grid;
#     grid-template-columns:1fr 1fr;
#     gap:18px;
#     width:100%;
#     box-sizing:border-box;
# ">
#
#
# <!-- GRADIENT CARD -->
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:18px;
#     padding:20px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# 01 • GRADIENT
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Points Uphill
# </div>
#
# <div style="
#     width:54px;
#     height:4px;
#     background:#2DD4BF;
#     border-radius:10px;
#     margin:10px 0 12px 0;
# "></div>
#
# <p style="
#     margin:0;
#     color:#475569;
#     font-size:11px;
#     line-height:1.8;
#     font-weight:600;
# ">
# The gradient shows the direction of the
# <span style="color:#0F766E;font-weight:900;">
# steepest increase in loss
# </span>.
# </p>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     margin-top:16px;
#     padding:12px 10px;
#     background:#FFFFFF;
#     border:1px solid #C8DED6;
#     border-radius:12px;
#     text-align:center;
# ">
#
# <div style="
#     color:#64748B;
#     font-size:8px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# DIRECTION
# </div>
#
# <div style="
#     color:#0F766E;
#     font-size:16px;
#     font-weight:900;
#     margin-top:5px;
# ">
# ↑ Higher Loss
# </div>
#
# </div>
#
# </div>
#
#
# <!-- GRADIENT DESCENT CARD -->
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:18px;
#     padding:20px;
# ">
#
# <div style="
#     color:#62559B;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# 02 • GRADIENT DESCENT
# </div>
#
# <div style="
#     color:#3F3566;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Moves Downhill
# </div>
#
# <div style="
#     width:54px;
#     height:4px;
#     background:#8B7CC7;
#     border-radius:10px;
#     margin:10px 0 12px 0;
# "></div>
#
# <p style="
#     margin:0;
#     color:#475569;
#     font-size:11px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Gradient descent moves in the
# <span style="color:#62559B;font-weight:900;">
# opposite direction
# </span>
# of the gradient to reduce the loss.
# </p>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     margin-top:16px;
#     padding:12px 10px;
#     background:#FFFFFF;
#     border:1px solid #CCC4E5;
#     border-radius:12px;
#     text-align:center;
# ">
#
# <div style="
#     color:#64748B;
#     font-size:8px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# DIRECTION
# </div>
#
# <div style="
#     color:#62559B;
#     font-size:16px;
#     font-weight:900;
#     margin-top:5px;
# ">
# ↓ Lower Loss
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- FLOW SECTION -->
#
# <div style="
#     margin-top:20px;
#     padding:18px;
#     background:#F8FBF9;
#     border:1px solid #C8DED6;
#     border-radius:16px;
#     box-sizing:border-box;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     text-align:center;
#     margin-bottom:15px;
# ">
# FROM GRADIENT TO LOWER LOSS
# </div>
#
#
# <!-- FLOW GRID -->
#
# <div style="
#     display:grid;
#     grid-template-columns:1fr 42px 1fr 42px 1fr;
#     gap:8px;
#     align-items:stretch;
#     width:100%;
#     box-sizing:border-box;
# ">
#
#
# <!-- BOX 1 -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     padding:15px 10px;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# GRADIENT
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# ↑ Increase
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:9px;
#     line-height:1.5;
#     margin-top:5px;
# ">
# Steepest loss increase
# </div>
#
# </div>
#
#
# <!-- ARROW 1 -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#059669;
#     font-size:20px;
#     font-weight:900;
# ">
# →
# </div>
#
#
# <!-- BOX 2 -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     padding:15px 10px;
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <div style="
#     color:#62559B;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# OPPOSITE
# </div>
#
# <div style="
#     color:#3F3566;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# ↓ Move Downhill
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:9px;
#     line-height:1.5;
#     margin-top:5px;
# ">
# Against the gradient
# </div>
#
# </div>
#
#
# <!-- ARROW 2 -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#6B5FA5;
#     font-size:20px;
#     font-weight:900;
# ">
# →
# </div>
#
#
# <!-- BOX 3 -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     padding:15px 10px;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1px;
# ">
# RESULT
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:14px;
#     font-weight:900;
#     margin-top:7px;
# ">
# ↓ Lower Loss
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:9px;
#     line-height:1.5;
#     margin-top:5px;
# ">
# Better parameters
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- KEY IDEA -->
#
# <div style="
#     margin-top:18px;
#     width:100%;
#     box-sizing:border-box;
#     padding:14px 18px;
#     background:#F7FBF9;
#     border:1px dashed #A8D2C3;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <span style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# KEY IDEA
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
#     margin-left:8px;
# ">
# The gradient points toward increasing loss,
# </span>
#
# <span style="
#     color:#047857;
#     font-size:10px;
#     font-weight:900;
# ">
# so gradient descent moves in the opposite direction to reduce it.
# </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.07),transparent 24%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 52%,#F1FAF7 100%);
#     padding:24px 28px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 8px 24px rgba(6,78,59,0.07);
#     text-align:center;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-bottom:6px;
# ">
# GRADIENT DESCENT
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:19px;
#     font-weight:900;
#     margin-bottom:17px;
# ">
# Moving Toward Lower Loss
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#FFFFFF;
#     border:1px solid #C8DED6;
#     border-radius:17px;
#     padding:14px;
#     overflow:hidden;
# ">
#
# <img src="../../BinX-Week6/media/gradient_descent_loss_surface.png"
#      style="
#         display:block;
#         width:100%;
#         max-width:900px;
#         height:auto;
#         margin:0 auto;
#         border-radius:10px;
#      ">
#
# </div>
#
# <div style="
#     margin-top:13px;
#     color:#64748B;
#     font-size:10px;
#     line-height:1.6;
#     font-weight:600;
# ">
# Gradient descent moves in the opposite direction of the gradient toward a lower-loss region.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.08),transparent 24%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.06),transparent 28%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:30px 36px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 12px 30px rgba(6,78,59,0.08);
#     overflow:hidden;
# ">
#
# <!-- HEADER -->
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:7px;
# ">
# THE FOGGY HILLSIDE INTUITION
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# Moving Downhill Toward Minimum Loss
# </div>
#
# <div style="
#     color:#52665F;
#     font-size:11px;
#     line-height:1.7;
#     font-weight:600;
#     margin-bottom:22px;
# ">
# Imagine standing on a foggy hillside where you cannot see the whole landscape.
# You take small steps in the steepest downhill direction until you reach a valley.
# </div>
#
#
# <!-- HILLSIDE VISUAL -->
#
# <div style="
#     display:grid;
#     grid-template-columns:1fr 1fr 1fr;
#     gap:14px;
#     align-items:center;
#     width:100%;
#     box-sizing:border-box;
# ">
#
#
# <!-- START -->
#
# <div style="
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:17px;
#     padding:19px 14px;
#     text-align:center;
#     min-height:130px;
#     box-sizing:border-box;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# START
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
# ">
# High Loss
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:10px;
#     line-height:1.6;
#     margin-top:7px;
# ">
# Current weights place the model high on the loss surface.
# </div>
#
# <div style="
#     margin-top:10px;
#     color:#0F766E;
#     font-size:18px;
#     font-weight:900;
# ">
# ↘
# </div>
#
# </div>
#
#
# <!-- STEP -->
#
# <div style="
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:17px;
#     padding:19px 14px;
#     text-align:center;
#     min-height:130px;
#     box-sizing:border-box;
# ">
#
# <div style="
#     color:#62559B;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# GRADIENT DESCENT
# </div>
#
# <div style="
#     color:#3F3566;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Take Small Steps
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:10px;
#     line-height:1.6;
#     margin-top:7px;
# ">
# The gradient shows the uphill direction, so we move the opposite way.
# </div>
#
# <div style="
#     margin-top:10px;
#     color:#62559B;
#     font-size:18px;
#     font-weight:900;
# ">
# ↓
# </div>
#
# </div>
#
#
# <!-- MINIMUM -->
#
# <div style="
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:17px;
#     padding:19px 14px;
#     text-align:center;
#     min-height:130px;
#     box-sizing:border-box;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# DESTINATION
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Minimum Loss
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:10px;
#     line-height:1.6;
#     margin-top:7px;
# ">
# The model reaches a lower-loss region with better weights.
# </div>
#
# <div style="
#     margin-top:10px;
#     color:#166534;
#     font-size:18px;
#     font-weight:900;
# ">
# ●
# </div>
#
# </div>
#
# </div>
#
#
# <!-- STEP-BY-STEP IDEA -->
#
# <div style="
#     margin-top:20px;
#     padding:17px 19px;
#     background:#F8FBF9;
#     border:1px solid #C8DED6;
#     border-radius:16px;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     text-align:center;
#     margin-bottom:14px;
# ">
# THE INTUITION
# </div>
#
# <div style="
#     display:grid;
#     grid-template-columns:1fr 34px 1fr 34px 1fr;
#     gap:7px;
#     align-items:center;
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     padding:12px 8px;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:13px;
#     text-align:center;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
# ">
# 1
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:11px;
#     font-weight:900;
#     margin-top:5px;
# ">
# FEEL THE SLOPE
# </div>
#
# </div>
#
# <div style="
#     text-align:center;
#     color:#94A3B8;
#     font-size:19px;
#     font-weight:900;
# ">
# →
# </div>
#
# <div style="
#     padding:12px 8px;
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:13px;
#     text-align:center;
# ">
#
# <div style="
#     color:#62559B;
#     font-size:9px;
#     font-weight:900;
# ">
# 2
# </div>
#
# <div style="
#     color:#3F3566;
#     font-size:11px;
#     font-weight:900;
#     margin-top:5px;
# ">
# STEP DOWNHILL
# </div>
#
# </div>
#
# <div style="
#     text-align:center;
#     color:#94A3B8;
#     font-size:19px;
#     font-weight:900;
# ">
# →
# </div>
#
# <div style="
#     padding:12px 8px;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:13px;
#     text-align:center;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
# ">
# 3
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:11px;
#     font-weight:900;
#     margin-top:5px;
# ">
# REPEAT
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- KEY IDEA -->
#
# <div style="
#     margin-top:18px;
#     padding:14px 18px;
#     background:#F7FBF9;
#     border:1px dashed #A8D2C3;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <span style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# KEY IDEA
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
#     margin-left:8px;
# ">
# Gradient descent is like walking downhill in the fog:
# </span>
#
# <span style="
#     color:#047857;
#     font-size:10px;
#     font-weight:900;
# ">
# small steps, repeated until the loss is minimized.
# </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:24px 30px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 8px 24px rgba(6,78,59,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:14px;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     border-radius:13px;
#     background:#E1F4EC;
#     border:1px solid #A8D2C3;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#047857;
#     font-size:14px;
#     font-weight:900;
# ">
# 3.3
# </div>
#
# <div>
#
# <div style="
#     color:#0B2923;
#     font-size:23px;
#     font-weight:900;
#     line-height:1.2;
# ">
# The Learning Rate
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-top:6px;
# ">
# CONTROLLING THE STEP SIZE
# </div>
#
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.07),transparent 24%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.05),transparent 28%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:30px 36px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 12px 30px rgba(6,78,59,0.08);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:7px;
# ">
# STEP SIZE MATTERS
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:20px;
# ">
# How the Learning Rate Affects Training
# </div>
#
#
# <!-- THREE CARDS -->
#
# <div style="
#     display:grid;
#     grid-template-columns:1fr 1fr 1fr;
#     gap:14px;
#     width:100%;
#     box-sizing:border-box;
#     align-items:stretch;
# ">
#
#
# <!-- TOO HIGH -->
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#FDF2F2;
#     border:1px solid #E8CACA;
#     border-radius:17px;
#     padding:19px 16px;
#     display:flex;
#     flex-direction:column;
# ">
#
# <div style="
#     color:#B45353;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# 01 • TOO HIGH
# </div>
#
# <div style="
#     color:#7F1D1D;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Overshoots
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:10px;
#     line-height:1.7;
#     margin-top:8px;
# ">
# The steps are too large and may jump past the minimum.
# The loss can bounce around or diverge.
# </div>
#
# <div style="
#     margin-top:auto;
#     padding-top:16px;
# ">
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:10px;
#     background:#FFFFFF;
#     border:1px solid #E8CACA;
#     border-radius:11px;
#     text-align:center;
# ">
#
# <div style="
#     color:#B45353;
#     font-size:15px;
#     font-weight:900;
# ">
# ↗ ↘ ↗ ↘
# </div>
#
# <div style="
#     color:#7F1D1D;
#     font-size:9px;
#     font-weight:800;
#     margin-top:4px;
# ">
# UNSTABLE
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- TOO LOW -->
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#FFF8EC;
#     border:1px solid #E7D3A8;
#     border-radius:17px;
#     padding:19px 16px;
#     display:flex;
#     flex-direction:column;
# ">
#
# <div style="
#     color:#A16207;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# 02 • TOO LOW
# </div>
#
# <div style="
#     color:#854D0E;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Too Slow
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:10px;
#     line-height:1.7;
#     margin-top:8px;
# ">
# The steps are very small, so training can take a long time
# and may struggle to make meaningful progress.
# </div>
#
# <div style="
#     margin-top:auto;
#     padding-top:16px;
# ">
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:10px;
#     background:#FFFFFF;
#     border:1px solid #E7D3A8;
#     border-radius:11px;
#     text-align:center;
# ">
#
# <div style="
#     color:#A16207;
#     font-size:15px;
#     font-weight:900;
# ">
# · · · ↓
# </div>
#
# <div style="
#     color:#854D0E;
#     font-size:9px;
#     font-weight:800;
#     margin-top:4px;
# ">
# VERY SLOW
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- JUST RIGHT -->
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:17px;
#     padding:19px 16px;
#     display:flex;
#     flex-direction:column;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# 03 • JUST RIGHT
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Steady Progress
# </div>
#
# <div style="
#     color:#64748B;
#     font-size:10px;
#     line-height:1.7;
#     margin-top:8px;
# ">
# The steps are large enough to learn efficiently while
# remaining stable around the minimum.
# </div>
#
# <div style="
#     margin-top:auto;
#     padding-top:16px;
# ">
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:10px;
#     background:#FFFFFF;
#     border:1px solid #A9D2B7;
#     border-radius:11px;
#     text-align:center;
# ">
#
# <div style="
#     color:#166534;
#     font-size:15px;
#     font-weight:900;
# ">
# ↘ ↘ ↘
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:9px;
#     font-weight:800;
#     margin-top:4px;
# ">
# STABLE
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- SUMMARY -->
#
# <div style="
#     margin-top:20px;
#     padding:14px 18px;
#     background:#F7FBF9;
#     border:1px dashed #A8D2C3;
#     border-radius:14px;
#     text-align:center;
#     box-sizing:border-box;
# ">
#
# <span style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# IDEAL
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
#     margin-left:8px;
# ">
# A good learning rate gives the model
# </span>
#
# <span style="
#     color:#047857;
#     font-size:10px;
#     font-weight:900;
# ">
# steady and efficient progress toward lower loss.
# </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 90% 10%,rgba(16,185,129,0.08),transparent 25%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 55%,#F1FAF7 100%);
#     padding:28px 34px;
#     border-radius:24px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 10px 28px rgba(6,78,59,0.08);
#     overflow:hidden;
# ">
#
# <!-- HEADER -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:14px;
#     margin-bottom:20px;
# ">
#
# <div style="
#     width:44px;
#     height:44px;
#     border-radius:14px;
#     background:#E1F4EC;
#     border:1px solid #A8D2C3;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#047857;
#     font-size:17px;
#     font-weight:900;
#     flex-shrink:0;
# ">
# LR
# </div>
#
# <div style="
#     min-width:0;
# ">
#
# <div style="
#     color:#0B2923;
#     font-size:21px;
#     font-weight:900;
#     line-height:1.25;
# ">
# Why Learning Rate Matters Most
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-top:5px;
# ">
# THE MOST IMPORTANT HYPERPARAMETER
# </div>
#
# </div>
#
# </div>
#
#
# <!-- TWO CONCEPT CARDS -->
#
# <div style="
#     display:grid;
#     grid-template-columns:minmax(0,1fr) minmax(0,1fr);
#     gap:16px;
#     width:100%;
#     box-sizing:border-box;
#     align-items:stretch;
# ">
#
#
# <!-- WHAT IT CONTROLS -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#F1F9F6;
#     border:1px solid #C1DED2;
#     border-left:4px solid #10B981;
#     border-radius:15px;
#     padding:17px 18px;
# ">
#
# <div style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# WHAT IT CONTROLS
# </div>
#
# <div style="
#     color:#334155;
#     font-size:11px;
#     line-height:1.75;
#     font-weight:600;
#     margin-top:8px;
#     overflow-wrap:break-word;
#     word-break:normal;
# ">
# The learning rate controls
# <span style="color:#047857;font-weight:900;">
# how far the weights move
# </span>
# during each update.
# </div>
#
# </div>
#
#
# <!-- PRACTICAL RULE -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:15px;
#     padding:17px 18px;
# ">
#
# <div style="
#     color:#62559B;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# PRACTICAL RULE
# </div>
#
# <div style="
#     color:#334155;
#     font-size:11px;
#     line-height:1.75;
#     font-weight:600;
#     margin-top:8px;
#     overflow-wrap:break-word;
#     word-break:normal;
# ">
# Start around
# <span style="color:#62559B;font-weight:900;">
# 0.001
# </span>
# with Adam, then adjust only if the loss curve behaves poorly.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- MAIN TAKEAWAY -->
#
# <div style="
#     margin-top:18px;
#     width:100%;
#     box-sizing:border-box;
#     padding:16px 18px;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:15px;
#     text-align:center;
# ">
#
# <div style="
#     color:#166534;
#     font-size:18px;
#     font-weight:900;
# ">
# Learning Rate = Step Size
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:7px;
# ">
# Too high
# <span style="color:#B45353;font-weight:900;">→ unstable</span>
# &nbsp; • &nbsp;
# Too low
# <span style="color:#A16207;font-weight:900;">→ slow</span>
# &nbsp; • &nbsp;
# Just right
# <span style="color:#166534;font-weight:900;">→ steady learning</span>
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:24px 30px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 8px 24px rgba(6,78,59,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:14px;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     border-radius:13px;
#     background:#E1F4EC;
#     border:1px solid #A8D2C3;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#047857;
#     font-size:14px;
#     font-weight:900;
# ">
# 3.4
# </div>
#
# <div>
#
# <div style="
#     color:#0B2923;
#     font-size:23px;
#     font-weight:900;
#     line-height:1.2;
# ">
# Backpropagation
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-top:6px;
# ">
# HOW THE NETWORK ASSIGNS BLAME
# </div>
#
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.07),transparent 24%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.05),transparent 28%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:30px 36px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 12px 30px rgba(6,78,59,0.08);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:7px;
# ">
# UNDERSTANDING BACKPROPAGATION
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:20px;
# ">
# Assigning Blame Through the Chain Rule
# </div>
#
#
# <!-- TWO CONCEPT CARDS -->
#
# <div style="
#     display:grid;
#     grid-template-columns:minmax(0,1fr) minmax(0,1fr);
#     gap:16px;
#     width:100%;
#     box-sizing:border-box;
#     align-items:stretch;
# ">
#
#
# <!-- ASSIGNING BLAME -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#F1F9F6;
#     border:1px solid #C1DED2;
#     border-left:4px solid #10B981;
#     border-radius:17px;
#     padding:19px;
#     display:flex;
#     flex-direction:column;
# ">
#
# <div style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# 01 • ASSIGNING BLAME
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
#     line-height:1.35;
# ">
# Which Weights Caused the Error?
# </div>
#
# <p style="
#     margin:9px 0 0 0;
#     color:#475569;
#     font-size:11px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Backpropagation works backward from the loss and calculates how much each weight contributed to the final error.
# </p>
#
# <div style="
#     width:100%;
#     height:88px;
#     box-sizing:border-box;
#     margin-top:auto;
#     padding:12px;
#     background:#FFFFFF;
#     border:1px solid #C8DED6;
#     border-radius:12px;
#     text-align:center;
#     display:flex;
#     flex-direction:column;
#     align-items:center;
#     justify-content:center;
# ">
#
# <div style="
#     color:#047857;
#     font-size:15px;
#     font-weight:900;
# ">
# Loss
# </div>
#
# <div style="
#     color:#94A3B8;
#     font-size:17px;
#     font-weight:900;
#     line-height:1;
#     margin:4px 0;
# ">
# ↓
# </div>
#
# <div style="
#     color:#065F46;
#     font-size:11px;
#     font-weight:900;
# ">
# Gradients for Each Weight
# </div>
#
# </div>
#
# </div>
#
#
# <!-- CHAIN RULE -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:17px;
#     padding:19px;
#     display:flex;
#     flex-direction:column;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# 02 • CHAIN RULE
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:17px;
#     font-weight:900;
#     margin-top:8px;
#     line-height:1.35;
# ">
# Connect the Contributions
# </div>
#
# <p style="
#     margin:9px 0 0 0;
#     color:#475569;
#     font-size:11px;
#     line-height:1.8;
#     font-weight:600;
# ">
# The chain rule connects the effect of each weight through the network, allowing the gradient of the loss to be calculated efficiently.
# </p>
#
# <div style="
#     width:100%;
#     height:88px;
#     box-sizing:border-box;
#     margin-top:auto;
#     padding:10px 12px;
#     background:#FFFFFF;
#     border:1px solid #C8DED6;
#     border-radius:12px;
#     text-align:center;
#     display:flex;
#     flex-direction:column;
#     align-items:center;
#     justify-content:center;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:11px;
#     font-weight:900;
# ">
# Loss
# </div>
#
# <div style="
#     color:#94A3B8;
#     font-size:15px;
#     font-weight:900;
#     line-height:1;
#     margin:2px 0;
# ">
# ↓
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:11px;
#     font-weight:900;
# ">
# Layer by Layer
# </div>
#
# <div style="
#     color:#94A3B8;
#     font-size:15px;
#     font-weight:900;
#     line-height:1;
#     margin:2px 0;
# ">
# ↓
# </div>
#
# <div style="
#     color:#0F766E;
#     font-size:11px;
#     font-weight:900;
# ">
# Gradients
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- FLOW -->
#
# <div style="
#     margin-top:19px;
#     padding:15px 17px;
#     background:#F8FBF9;
#     border:1px solid #C8DED6;
#     border-radius:15px;
#     box-sizing:border-box;
#     width:100%;
# ">
#
# <div style="
#     display:grid;
#     grid-template-columns:minmax(0,1fr) 34px minmax(0,1fr) 34px minmax(0,1fr);
#     gap:7px;
#     align-items:stretch;
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     padding:12px 8px;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:12px;
#     text-align:center;
#     display:flex;
#     flex-direction:column;
#     justify-content:center;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
# ">
# ERROR
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:11px;
#     font-weight:900;
#     margin-top:5px;
# ">
# Loss
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#059669;
#     font-size:19px;
#     font-weight:900;
# ">
# ←
# </div>
#
# <div style="
#     padding:12px 8px;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:12px;
#     text-align:center;
#     display:flex;
#     flex-direction:column;
#     justify-content:center;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
# ">
# BACKWARD
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:11px;
#     font-weight:900;
#     margin-top:5px;
# ">
# Chain Rule
# </div>
#
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#059669;
#     font-size:19px;
#     font-weight:900;
# ">
# ←
# </div>
#
# <div style="
#     padding:12px 8px;
#     background:#F1F9F6;
#     border:1px solid #C1DED2;
#     border-radius:12px;
#     text-align:center;
#     display:flex;
#     flex-direction:column;
#     justify-content:center;
# ">
#
# <div style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
# ">
# RESULT
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:11px;
#     font-weight:900;
#     margin-top:5px;
# ">
# Gradients
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <!-- KEY IDEA -->
#
# <div style="
#     margin-top:18px;
#     padding:14px 18px;
#     background:#F7FBF9;
#     border:1px dashed #A8D2C3;
#     border-radius:14px;
#     text-align:center;
#     box-sizing:border-box;
# ">
#
# <span style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# KEY IDEA
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
#     margin-left:8px;
# ">
# Backpropagation answers one question:
# </span>
#
# <span style="
#     color:#047857;
#     font-size:10px;
#     font-weight:900;
# ">
# “How much is each weight responsible for the error?”
# </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.07),transparent 24%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.05),transparent 28%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:30px 36px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 12px 30px rgba(6,78,59,0.08);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:7px;
# ">
# AUTOMATIC DIFFERENTIATION
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:8px;
# ">
# The Framework Does the Calculus
# </div>
#
# <div style="
#     color:#52665F;
#     font-size:11px;
#     line-height:1.7;
#     font-weight:600;
#     margin-bottom:20px;
# ">
# You do not need to calculate the gradients by hand.
# Deep learning frameworks automatically compute them during training.
# </div>
#
#
# <div style="
#     display:grid;
#     grid-template-columns:minmax(0,1fr) 42px minmax(0,1fr);
#     gap:10px;
#     align-items:center;
#     width:100%;
#     box-sizing:border-box;
# ">
#
#
# <!-- PYTORCH -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#F1F9F6;
#     border:1px solid #C1DED2;
#     border-left:4px solid #10B981;
#     border-radius:17px;
#     padding:18px;
# ">
#
# <div style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# PYTORCH
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:18px;
#     font-weight:900;
#     margin-top:7px;
# ">
# autograd
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     margin-top:7px;
# ">
# PyTorch tracks operations and automatically computes gradients during backpropagation.
# </div>
#
# <div style="
#     margin-top:12px;
#     padding:9px 10px;
#     background:#FFFFFF;
#     border:1px solid #C8DED6;
#     border-radius:10px;
#     color:#065F46;
#     font-size:10px;
#     font-weight:900;
#     text-align:center;
#     box-sizing:border-box;
#     width:100%;
# ">
# loss.backward()
# </div>
#
# </div>
#
#
# <!-- CENTER -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#059669;
#     font-size:22px;
#     font-weight:900;
# ">
# ↔
# </div>
#
#
# <!-- TENSORFLOW -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:17px;
#     padding:18px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# TENSORFLOW
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:18px;
#     font-weight:900;
#     margin-top:7px;
# ">
# GradientTape
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     margin-top:7px;
# ">
# TensorFlow records operations inside a tape and uses them to calculate gradients automatically.
# </div>
#
# <div style="
#     margin-top:12px;
#     padding:9px 10px;
#     background:#FFFFFF;
#     border:1px solid #C8DED6;
#     border-radius:10px;
#     color:#0F766E;
#     font-size:10px;
#     font-weight:900;
#     text-align:center;
#     box-sizing:border-box;
#     width:100%;
# ">
# tape.gradient()
# </div>
#
# </div>
#
# </div>
#
#
# <!-- TAKEAWAY -->
#
# <div style="
#     margin-top:19px;
#     display:grid;
#     grid-template-columns:1fr 1fr;
#     gap:14px;
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:14px 16px;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# YOU
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:12px;
#     font-weight:900;
#     margin-top:5px;
# ">
# Define the model + loss
# </div>
#
# </div>
#
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:14px 16px;
#     background:#F8FBF9;
#     border:1px solid #C8DED6;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.2px;
# ">
# FRAMEWORK
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:12px;
#     font-weight:900;
#     margin-top:5px;
# ">
# Computes the gradients
# </div>
#
# </div>
#
# </div>
#
#
# <!-- KEY IDEA -->
#
# <div style="
#     margin-top:18px;
#     padding:14px 18px;
#     background:#F7FBF9;
#     border:1px dashed #A8D2C3;
#     border-radius:14px;
#     text-align:center;
#     box-sizing:border-box;
# ">
#
# <span style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# KEY IDEA
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
#     margin-left:8px;
# ">
# Understand what backpropagation computes,
# </span>
#
# <span style="
#     color:#047857;
#     font-size:10px;
#     font-weight:900;
# ">
# but let the framework handle the calculations.
# </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:24px 30px;
#     border-radius:22px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 8px 24px rgba(6,78,59,0.07);
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:14px;
# ">
#
# <div style="
#     width:42px;
#     height:42px;
#     border-radius:13px;
#     background:#E1F4EC;
#     border:1px solid #A8D2C3;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#047857;
#     font-size:13px;
#     font-weight:900;
# ">
# 3.5
# </div>
#
# <div>
#
# <div style="
#     color:#0B2923;
#     font-size:23px;
#     font-weight:900;
#     line-height:1.2;
# ">
# Optimizers, Epochs, and Batches
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-top:6px;
# ">
# HOW TRAINING IS ORGANIZED AND UPDATED
# </div>
#
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 92% 8%,rgba(16,185,129,0.07),transparent 24%),
#         radial-gradient(circle at 8% 92%,rgba(20,184,166,0.05),transparent 28%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 50%,#F1FAF7 100%);
#     padding:30px 36px;
#     border-radius:26px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 12px 30px rgba(6,78,59,0.08);
#     overflow:hidden;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:2px;
#     margin-bottom:7px;
# ">
# TRAINING TERMINOLOGY
# </div>
#
# <div style="
#     color:#0B2923;
#     font-size:21px;
#     font-weight:900;
#     margin-bottom:20px;
# ">
# Optimizer, Epoch, Batch & Update Strategy
# </div>
#
#
# <!-- DEFINITIONS -->
#
# <div style="
#     display:grid;
#     grid-template-columns:minmax(0,1fr) minmax(0,1fr);
#     gap:14px;
#     width:100%;
#     box-sizing:border-box;
# ">
#
#
# <!-- OPTIMIZER -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:16px;
#     padding:17px;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# OPTIMIZER
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:16px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Applies the Updates
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:6px;
# ">
# The algorithm that uses the gradients to update the model's weights.
# </div>
#
# </div>
#
#
# <!-- EPOCH -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#F1F9F6;
#     border:1px solid #C1DED2;
#     border-left:4px solid #10B981;
#     border-radius:16px;
#     padding:17px;
# ">
#
# <div style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# EPOCH
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:16px;
#     font-weight:900;
#     margin-top:7px;
# ">
# One Full Pass
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:6px;
# ">
# One complete pass through the entire training dataset.
# </div>
#
# </div>
#
#
# <!-- BATCH -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#F8FBF9;
#     border:1px solid #C8DED6;
#     border-radius:16px;
#     padding:17px;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# BATCH
# </div>
#
# <div style="
#     color:#334155;
#     font-size:16px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Small Data Subset
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:6px;
# ">
# A subset of training samples processed before one weight update.
# </div>
#
# </div>
#
#
# <!-- SGD VS ADAM -->
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:16px;
#     padding:17px;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.4px;
# ">
# SGD VS ADAM
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:16px;
#     font-weight:900;
#     margin-top:7px;
# ">
# Two Update Strategies
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:6px;
# ">
# <strong style="color:#334155;">SGD:</strong> basic gradient descent.
# <br>
# <strong style="color:#047857;">Adam:</strong> adapts the step size for each weight.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- TRAINING RELATIONSHIP -->
#
# <div style="
#     margin-top:18px;
#     padding:16px;
#     background:#F7FBF9;
#     border:1px solid #C8DED6;
#     border-radius:15px;
#     box-sizing:border-box;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.6px;
#     text-align:center;
#     margin-bottom:13px;
# ">
# HOW THEY FIT TOGETHER
# </div>
#
# <div style="
#     display:grid;
#     grid-template-columns:minmax(0,1fr) 30px minmax(0,1fr) 30px minmax(0,1fr);
#     gap:7px;
#     align-items:center;
#     width:100%;
#     box-sizing:border-box;
# ">
#
# <div style="
#     padding:11px 8px;
#     background:#E8F8F1;
#     border:1px solid #98D0B9;
#     border-radius:12px;
#     text-align:center;
# ">
#
# <div style="
#     color:#047857;
#     font-size:9px;
#     font-weight:900;
# ">
# BATCH
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:10px;
#     font-weight:800;
#     margin-top:4px;
# ">
# Process Samples
# </div>
#
# </div>
#
# <div style="
#     text-align:center;
#     color:#059669;
#     font-size:18px;
#     font-weight:900;
# ">
# →
# </div>
#
# <div style="
#     padding:11px 8px;
#     background:#F4F1FC;
#     border:1px solid #CCC4E5;
#     border-radius:12px;
#     text-align:center;
# ">
#
# <div style="
#     color:#62559B;
#     font-size:9px;
#     font-weight:900;
# ">
# OPTIMIZER
# </div>
#
# <div style="
#     color:#3F3566;
#     font-size:10px;
#     font-weight:800;
#     margin-top:4px;
# ">
# Update Weights
# </div>
#
# </div>
#
# <div style="
#     text-align:center;
#     color:#6B5FA5;
#     font-size:18px;
#     font-weight:900;
# ">
# →
# </div>
#
# <div style="
#     padding:11px 8px;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:12px;
#     text-align:center;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
# ">
# EPOCH
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:10px;
#     font-weight:800;
#     margin-top:4px;
# ">
# Repeat Full Dataset
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     background:
#         radial-gradient(circle at 90% 10%,rgba(16,185,129,0.09),transparent 25%),
#         linear-gradient(135deg,#F7FCFA 0%,#FFFFFF 55%,#F1FAF7 100%);
#     padding:28px 34px;
#     border-radius:24px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     border:1px solid #B8DACE;
#     box-shadow:0 10px 28px rgba(6,78,59,0.08);
#     overflow:hidden;
# ">
#
# <div style="
#     display:flex;
#     align-items:center;
#     gap:14px;
#     margin-bottom:20px;
# ">
#
# <div style="
#     width:44px;
#     height:44px;
#     border-radius:14px;
#     background:#E1F4EC;
#     border:1px solid #A8D2C3;
#     display:flex;
#     align-items:center;
#     justify-content:center;
#     color:#047857;
#     font-size:18px;
#     font-weight:900;
# ">
# ✓
# </div>
#
# <div>
#
# <div style="
#     color:#0B2923;
#     font-size:21px;
#     font-weight:900;
# ">
# Practical Default for Training
# </div>
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.8px;
#     margin-top:5px;
# ">
# A SIMPLE STARTING POINT
# </div>
#
# </div>
#
# </div>
#
#
# <!-- MAIN RULE -->
#
# <div style="
#     display:grid;
#     grid-template-columns:minmax(0,1fr) minmax(0,1fr);
#     gap:16px;
#     width:100%;
#     box-sizing:border-box;
#     align-items:stretch;
# ">
#
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#EDF9F1;
#     border:1px solid #A9D2B7;
#     border-radius:16px;
#     padding:19px;
#     text-align:center;
# ">
#
# <div style="
#     color:#166534;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# DEFAULT OPTIMIZER
# </div>
#
# <div style="
#     color:#14532D;
#     font-size:22px;
#     font-weight:900;
#     margin-top:8px;
# ">
# Adam
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:6px;
# ">
# A reliable starting choice for many deep learning models.
# </div>
#
# </div>
#
#
# <div style="
#     width:100%;
#     min-width:0;
#     box-sizing:border-box;
#     background:#EAF9F7;
#     border:1px solid #99D4CB;
#     border-radius:16px;
#     padding:19px;
#     text-align:center;
# ">
#
# <div style="
#     color:#0F766E;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
# ">
# STARTING LEARNING RATE
# </div>
#
# <div style="
#     color:#134E4A;
#     font-size:22px;
#     font-weight:900;
#     margin-top:8px;
# ">
# ~ 0.001
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.7;
#     font-weight:600;
#     margin-top:6px;
# ">
# A common starting point when using Adam.
# </div>
#
# </div>
#
# </div>
#
#
# <!-- WHEN TO ADJUST -->
#
# <div style="
#     margin-top:18px;
#     padding:15px 18px;
#     background:#F8FBF9;
#     border:1px solid #C8DED6;
#     border-radius:15px;
# ">
#
# <div style="
#     color:#115E59;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.5px;
#     margin-bottom:7px;
# ">
# WHEN SHOULD YOU CHANGE IT?
# </div>
#
# <div style="
#     color:#475569;
#     font-size:10px;
#     line-height:1.8;
#     font-weight:600;
# ">
# Start with the default and inspect the loss curve.
# Adjust the learning rate only when training is
# <span style="color:#B45353;font-weight:900;">unstable</span>,
# <span style="color:#A16207;font-weight:900;">too slow</span>,
# or otherwise behaving poorly.
# </div>
#
# </div>
#
#
# <!-- FINAL RULE -->
#
# <div style="
#     margin-top:18px;
#     padding:15px 18px;
#     background:#F1F9F6;
#     border:1px dashed #A8D2C3;
#     border-radius:14px;
#     text-align:center;
# ">
#
# <span style="
#     color:#065F46;
#     font-size:9px;
#     font-weight:900;
#     letter-spacing:1.3px;
# ">
# PRACTICAL RULE
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
#     margin-left:8px;
# ">
# Use
# </span>
#
# <span style="
#     color:#047857;
#     font-size:11px;
#     font-weight:900;
# ">
# Adam
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
# ">
# as a default, start around
# </span>
#
# <span style="
#     color:#0F766E;
#     font-size:11px;
#     font-weight:900;
# ">
# 0.001
# </span>
#
# <span style="
#     color:#475569;
#     font-size:10px;
#     font-weight:600;
# ">
# and adjust only when the loss curve misbehaves.
# </span>
#
# </div>
#
# </div>
